# %%
import numpy as np
import pandas as pd
import helper

# %%
path_root = '/home/aldo/Documents/data-cic/preprocess_data/predictions/'
path = '/home/aldo/Documents/data-cic/preprocess_data/'
test_images_300 = np.load(path + 'images_test_300x300.npy')

label_test = np.load(path + '/label_test.npy')
label_all = np.load(path + '/label_all.npy')

pred_voc_07_12_300x300_test = np.load(path_root + 'pred_voc_07_12_300x300_test.npy')
pred_voc_07_12_300x300_all = np.load(path_root + 'pred_voc_07_12_300x300_all.npy')
pred_voc_07_12_512x512_test = np.load(path_root + 'pred_voc_07_12_512x512_test.npy')
pred_voc_07_12_512x512_all = np.load(path_root + 'pred_voc_07_12_512x512_all.npy')

pred_voc_07_plus_12_300x300_test = np.load(path_root + 'pred_voc_07_plus_12_300x300_test.npy')
pred_voc_07_plus_12_300x300_all = np.load(path_root + 'pred_voc_07_plus_12_300x300_all.npy')
pred_voc_07_plus_12_512x512_test = np.load(path_root + 'pred_voc_07_plus_12_512x512_test.npy')
pred_voc_07_plus_12_512x512_all = np.load(path_root + 'pred_voc_07_plus_12_512x512_all.npy')

pred_voc_07_12_coco_300x300_test = np.load(path_root + 'pred_voc_07_12_coco_300x300_test.npy')
pred_voc_07_12_coco_300x300_all = np.load(path_root + 'pred_voc_07_12_coco_300x300_all.npy')
pred_voc_07_12_coco_512x512_test = np.load(path_root + 'pred_voc_07_12_coco_512x512_test.npy')
pred_voc_07_12_coco_512x512_all = np.load(path_root + 'pred_voc_07_12_coco_512x512_all.npy')

pred_voc_07_plus_12_coco_300x300_test = np.load(path_root + 'pred_voc_07_plus_12_coco_300x300_test.npy')
pred_voc_07_plus_12_coco_300x300_all = np.load(path_root + 'pred_voc_07_plus_12_coco_300x300_all.npy')
pred_voc_07_plus_12_coco_512x512_test = np.load(path_root + 'pred_voc_07_plus_12_coco_512x512_test.npy')
pred_voc_07_plus_12_coco_512x512_all = np.load(path_root + 'pred_voc_07_plus_12_coco_512x512_all.npy')

# %%
# Remove class and confidence from predictions
pred_voc_07_12_300x300_test = helper.get_coordinates(pred_voc_07_12_300x300_test)
pred_voc_07_12_300x300_all = helper.get_coordinates(pred_voc_07_12_300x300_all)
pred_voc_07_12_512x512_test = helper.get_coordinates(pred_voc_07_12_512x512_test)
pred_voc_07_12_512x512_all = helper.get_coordinates(pred_voc_07_12_512x512_all)

pred_voc_07_plus_12_300x300_test = helper.get_coordinates(pred_voc_07_plus_12_300x300_test)
pred_voc_07_plus_12_300x300_all = helper.get_coordinates(pred_voc_07_plus_12_300x300_all)
pred_voc_07_plus_12_512x512_test = helper.get_coordinates(pred_voc_07_plus_12_512x512_test)
pred_voc_07_plus_12_512x512_all = helper.get_coordinates(pred_voc_07_plus_12_512x512_all)

pred_voc_07_12_coco_300x300_test = helper.get_coordinates(pred_voc_07_12_coco_300x300_test)
pred_voc_07_12_coco_300x300_all = helper.get_coordinates(pred_voc_07_12_coco_300x300_all)
pred_voc_07_12_coco_512x512_test = helper.get_coordinates(pred_voc_07_12_coco_512x512_test)
pred_voc_07_12_coco_512x512_all = helper.get_coordinates(pred_voc_07_12_coco_512x512_all)

pred_voc_07_plus_12_coco_300x300_test = helper.get_coordinates(pred_voc_07_plus_12_coco_300x300_test)
pred_voc_07_plus_12_coco_300x300_all = helper.get_coordinates(pred_voc_07_plus_12_coco_300x300_all)
pred_voc_07_plus_12_coco_512x512_test = helper.get_coordinates(pred_voc_07_plus_12_coco_512x512_test)
pred_voc_07_plus_12_coco_512x512_all = helper.get_coordinates(pred_voc_07_plus_12_coco_512x512_all)

# %%
# Variable to show in a table
datasets = ['07+12', '07++12', '07+12+COCO', '07++12+COCO']
metrics = ['P', 'R', 'F1']
test_values = np.zeros((2, 12))
all_data_values = np.zeros((2, 12))

# Table columns
list_columns = []
list_all = []

# for test in test_set:
for dataset in datasets:
    for metric in metrics:
        list_columns.append(('Test set', dataset, metric))
        list_all.append(('Complete data set', dataset, metric))
            
columns_test = pd.MultiIndex.from_tuples(list_columns)
columns_all = pd.MultiIndex.from_tuples(list_all)

model_names = ['ssd300_07+12', 'ssd300_07++12', 'ssd30007+12+COCO', 'ssd30007++12+COCO',
                    'ssd512_07+12', 'ssd512_07++12', 'ssd51207+12+COCO', 'ssd51207++12+COCO']

presicion_test = []
presicion_complete = []
recall_test = []
recall_complete = []
f1_test = []
f1_complete = []

# Test performance
# SSD300
print('Performance ssd300 TEST set with 07+12')
presicion, recall, f1_score = helper.cal_performance(label_test, pred_voc_07_12_300x300_test)
presicion_test.append(presicion)
recall_test.append(recall)
f1_test.append(f1_score)
test_values[0, :3] = [presicion, recall, f1_score]
print()
print('Performance ssd300 TEST set with 07++12')
presicion, recall, f1_score = helper.cal_performance(label_test, pred_voc_07_plus_12_300x300_test)
presicion_test.append(presicion)
recall_test.append(recall)
f1_test.append(f1_score)
test_values[0, 3:6] = [presicion, recall, f1_score]
print()
print('Performance ssd300 TEST set with 07+12+COCO')
presicion, recall, f1_score = helper.cal_performance(label_test, pred_voc_07_12_coco_300x300_test)
presicion_test.append(presicion)
recall_test.append(recall)
f1_test.append(f1_score)
test_values[0, 6:9] = [presicion, recall, f1_score]
print()
print('Performance ssd300 TEST set with 07++12+COCO')
presicion, recall, f1_score = helper.cal_performance(label_test, pred_voc_07_plus_12_coco_300x300_test)
presicion_test.append(presicion)
recall_test.append(recall)
f1_test.append(f1_score)
test_values[0, 9:12] = [presicion, recall, f1_score]
print()

#SSD512
print('Performance ssd512 TEST set with 07+12')
presicion, recall, f1_score = helper.cal_performance(label_test, pred_voc_07_12_512x512_test)
presicion_test.append(presicion)
recall_test.append(recall)
f1_test.append(f1_score)
test_values[1, :3] = [presicion, recall, f1_score]
print()
print('Performance ssd512 TEST set with 07++12')
presicion, recall, f1_score = helper.cal_performance(label_test, pred_voc_07_plus_12_512x512_test)
presicion_test.append(presicion)
recall_test.append(recall)
f1_test.append(f1_score)
test_values[1, 3:6] = [presicion, recall, f1_score]
print()
print('Performance ssd512 TEST set with 07+12+COCO')
presicion, recall, f1_score = helper.cal_performance(label_test, pred_voc_07_12_coco_512x512_test)
presicion_test.append(presicion)
recall_test.append(recall)
f1_test.append(f1_score)
test_values[1, 6:9] = [presicion, recall, f1_score]
print()
print('Performance ssd512 TEST set with 07++12+COCO')
presicion, recall, f1_score = helper.cal_performance(label_test, pred_voc_07_plus_12_coco_512x512_test)
presicion_test.append(presicion)
recall_test.append(recall)
f1_test.append(f1_score)
test_values[1, 9:12] = [presicion, recall, f1_score]
print()

# All data set
#SSD300
print('Performance ssd300 COMPLETE data set with 07+12')
presicion, recall, f1_score = helper.cal_performance(label_all, pred_voc_07_12_300x300_all)
presicion_complete.append(presicion)
recall_complete.append(recall)
f1_complete.append(f1_score)
all_data_values[0, :3] = [presicion, recall, f1_score]
print()
print('Performance ssd300 COMPLETE data set with 07++12')
presicion, recall, f1_score = helper.cal_performance(label_all, pred_voc_07_plus_12_300x300_all)
presicion_complete.append(presicion)
recall_complete.append(recall)
f1_complete.append(f1_score)
all_data_values[0, 3:6] = [presicion, recall, f1_score]
print()
print('Performance ssd300 COMPLETE data set with 07+12+COCO')
presicion, recall, f1_score = helper.cal_performance(label_all, pred_voc_07_12_coco_300x300_all)
presicion_complete.append(presicion)
recall_complete.append(recall)
f1_complete.append(f1_score)
all_data_values[0, 6:9] = [presicion, recall, f1_score]
print()
print('Performance ssd300 COMPLETE data set with 07++12+COCO')
presicion, recall, f1_score = helper.cal_performance(label_all, pred_voc_07_plus_12_coco_300x300_all)
presicion_complete.append(presicion)
recall_complete.append(recall)
f1_complete.append(f1_score)
all_data_values[0, 9:12] = [presicion, recall, f1_score]
print()

# SSD512
print('Performance ssd512 COMPLETE data set with 07+12')
presicion, recall, f1_score = helper.cal_performance(label_all, pred_voc_07_12_512x512_all)
presicion_complete.append(presicion)
recall_complete.append(recall)
f1_complete.append(f1_score)
all_data_values[1, :3] = [presicion, recall, f1_score]
print()
print('Performance ssd512 COMPLETE data set with 07++12')
presicion, recall, f1_score = helper.cal_performance(label_all, pred_voc_07_plus_12_512x512_all)
presicion_complete.append(presicion)
recall_complete.append(recall)
f1_complete.append(f1_score)
all_data_values[1, 3:6] = [presicion, recall, f1_score]
print()
print('Performance ssd512 COMPLETE data set with 07+12+COCO')
presicion, recall, f1_score = helper.cal_performance(label_all, pred_voc_07_12_coco_512x512_all)
presicion_complete.append(presicion)
recall_complete.append(recall)
f1_complete.append(f1_score)
all_data_values[1, 6:9] = [presicion, recall, f1_score]
print()
print('Performance ssd512 COMPLETE data set with 07++12+COCO')
presicion, recall, f1_score = helper.cal_performance(label_all, pred_voc_07_plus_12_coco_512x512_all)
presicion_complete.append(presicion)
recall_complete.append(recall)
f1_complete.append(f1_score)
all_data_values[1, 9:12] = [presicion, recall, f1_score]

# Create table
table_test = pd.DataFrame(test_values,index=['SSD300', 'SSD512'],columns=columns_test)
table_all_dataset = pd.DataFrame(all_data_values,index=['SSD300', 'SSD512'],columns=columns_all)
# Out:
# Performance ssd300 TEST set with 07+12
# Number of images: 45
# Presicion: 0.6039
# Recall: 0.6129
# F1 score: 0.6084
#
# Performance ssd300 TEST set with 07++12
# Number of images: 45
# Presicion: 0.6052
# Recall: 0.6365
# F1 score: 0.6205
#
# Performance ssd300 TEST set with 07+12+COCO
# Number of images: 45
# Presicion: 0.6263
# Recall: 0.6826
# F1 score: 0.6533
#
# Performance ssd300 TEST set with 07++12+COCO
# Number of images: 45
# Presicion: 0.6215
# Recall: 0.6771
# F1 score: 0.6481
#
# Performance ssd512 TEST set with 07+12
# Number of images: 45
# Presicion: 0.5806
# Recall: 0.6341
# F1 score: 0.6062
#
# Performance ssd512 TEST set with 07++12
# Number of images: 45
# Presicion: 0.5713
# Recall: 0.6665
# F1 score: 0.6152
#
# Performance ssd512 TEST set with 07+12+COCO
# Number of images: 45
# Presicion: 0.6662
# Recall: 0.7525
# F1 score: 0.7068
#
# Performance ssd512 TEST set with 07++12+COCO
# Number of images: 45
# Presicion: 0.6507
# Recall: 0.7498
# F1 score: 0.6967
#
# ...

# %%
idx_p_t = presicion_test.index(max(presicion_test))
idx_p_c = presicion_complete.index(max(presicion_complete))
idx_r_t = recall_test.index(max(recall_test))
idx_r_c = recall_complete.index(max(recall_complete))
idx_f_t = f1_test.index(max(f1_test))
idx_f_c = f1_complete.index(max(f1_complete))

# %% [markdown]
# ## Performance on test set

# %%
table_test.round(4)
# Out:
#        Test set                                                             \
#           07+12                  07++12                 07+12+COCO
#               P       R      F1       P       R      F1          P       R
# SSD300   0.6039  0.6129  0.6084  0.6052  0.6365  0.6205     0.6263  0.6826
# SSD512   0.5806  0.6341  0.6062  0.5713  0.6665  0.6152     0.6662  0.7525
#
#
#                07++12+COCO
#             F1           P       R      F1
# SSD300  0.6533      0.6215  0.6771  0.6481
# SSD512  0.7068      0.6507  0.7498  0.6967

# %%
print('Best presicion on test set:')
print(model_names[idx_p_t], presicion_test[idx_p_t])

print('Best recall on test set:')
print(model_names[idx_r_t], recall_test[idx_r_t])

print('Best f1 score on test set:')
print(model_names[idx_f_t], f1_test[idx_f_t])
# Out:
# Best presicion on test set:
# ssd51207+12+COCO 0.6662425971290682
# Best recall on test set:
# ssd51207+12+COCO 0.7525135399393951
# Best f1 score on test set:
# ssd51207+12+COCO 0.7067551105152582

# %% [markdown]
# ## Performance on all dataset

# %%
table_all_dataset
# Out:
#        Complete data set                                                    \
#                    07+12                        07++12
#                        P         R        F1         P         R        F1
# SSD300          0.599261  0.561776  0.579913  0.613113  0.579306  0.595730
# SSD512          0.607505  0.615982  0.611714  0.608544  0.633119  0.620588
#
#
#        07+12+COCO                     07++12+COCO
#                 P         R        F1           P         R        F1
# SSD300   0.626810  0.638467  0.632585    0.629103  0.635469  0.632270
# SSD512   0.650551  0.689607  0.669510    0.654126  0.691348  0.672222

# %%
print('Best presicion on all data set:')
print(model_names[idx_p_c], presicion_complete[idx_p_c])

print('Best recall on all data set:')
print(model_names[idx_r_c], recall_complete[idx_r_c])

print('Best f1 score on all data set:')
print(model_names[idx_f_c], f1_complete[idx_f_c])
# Out:
# Best presicion on all data set:
# ssd51207++12+COCO 0.6541260946757036
# Best recall on all data set:
# ssd51207++12+COCO 0.6913484759903494
# Best f1 score on all data set:
# ssd51207++12+COCO 0.6722224091321158
