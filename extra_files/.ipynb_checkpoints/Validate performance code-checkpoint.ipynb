# %%
import numpy as np
import helper

# %%
path_root = '/home/aldopedraza/Documentos/data-cic/preprocess_data/predictions/'
path = '/home/aldopedraza/Documentos/data-cic/preprocess_data/'
test_images_300 = np.load(path + '/images_test_300x300.npy')

label_test = np.load(path + '/label_test.npy')

pred = np.load(path_root + 'pred_voc_07_12_300x300_test.npy')
pred = helper.get_coordinates(pred)
ground = helper.normilize_to_pixel(label_test, 300, 300)

# %%
ground[9]
# Out:
# [[96.0, 101.0, 32.0, 82.0], [18.0, 90.0, 70.0, 92.0]]

# %%
pred[9]
# Out:
# [[15.514755249023438, 89.35948181152344, 67.07980346679688, 94.78311157226562],
#  [93.57877349853516,
#   100.65802764892578,
#   41.809120178222656,
#   79.17015838623047]]

# %%
iou_d1_g1_1 = helper.bb_intersection_over_union(pred[0][0], ground[0][0])
iou_d1_g2_1 = helper.bb_intersection_over_union(pred[0][0], ground[0][1])

iou_d2_g1_1 = helper.bb_intersection_over_union(pred[0][1], ground[0][0])
iou_d2_g2_1 = helper.bb_intersection_over_union(pred[0][1], ground[0][1])

iou_d3_g1_1 = helper.bb_intersection_over_union(pred[0][2], ground[0][0])
iou_d3_g2_1 = helper.bb_intersection_over_union(pred[0][2], ground[0][1])

## second image
iou_d1_g1_2 = helper.bb_intersection_over_union(pred[1][0], ground[1][0])
iou_d1_g2_2 = helper.bb_intersection_over_union(pred[1][0], ground[1][1])
iou_d1_g3_2 = helper.bb_intersection_over_union(pred[1][0], ground[1][2])
iou_d1_g4_2 = helper.bb_intersection_over_union(pred[1][0], ground[1][3])

iou_d2_g1_2 = helper.bb_intersection_over_union(pred[1][1], ground[1][0])
iou_d2_g2_2 = helper.bb_intersection_over_union(pred[1][1], ground[1][1])
iou_d2_g3_2 = helper.bb_intersection_over_union(pred[1][1], ground[1][2])
iou_d2_g4_2 = helper.bb_intersection_over_union(pred[1][1], ground[1][3])

iou_d3_g1_2 = helper.bb_intersection_over_union(pred[1][2], ground[1][0])
iou_d3_g2_2 = helper.bb_intersection_over_union(pred[1][2], ground[1][1])
iou_d3_g3_2 = helper.bb_intersection_over_union(pred[1][2], ground[1][2])
iou_d3_g4_2 = helper.bb_intersection_over_union(pred[1][2], ground[1][3])

## fifth image
iou_d1_g1_5 = helper.bb_intersection_over_union(pred[4][0], ground[4][0])

## sexth image
iou_d1_g1_6 = helper.bb_intersection_over_union(pred[5][0], ground[5][0])
iou_d1_g2_6 = helper.bb_intersection_over_union(pred[5][0], ground[5][1])
iou_d1_g3_6 = helper.bb_intersection_over_union(pred[5][0], ground[5][2])

iou_d2_g1_6 = helper.bb_intersection_over_union(pred[5][1], ground[5][0])
iou_d2_g2_6 = helper.bb_intersection_over_union(pred[5][1], ground[5][1])
iou_d2_g3_6 = helper.bb_intersection_over_union(pred[5][1], ground[5][2])

## seventh image
iou_d1_g1_7 = helper.bb_intersection_over_union(pred[6][0], ground[6][0])
iou_d1_g2_7 = helper.bb_intersection_over_union(pred[6][0], ground[6][1])
iou_d1_g3_7 = helper.bb_intersection_over_union(pred[6][0], ground[6][2])

## eighth image
iou_d1_g1_8 = helper.bb_intersection_over_union(pred[7][0], ground[7][0])

## ninth image
iou_d1_g1_9 = helper.bb_intersection_over_union(pred[8][0], ground[8][0])
iou_d1_g2_9 = helper.bb_intersection_over_union(pred[8][0], ground[8][1])
iou_d1_g3_9 = helper.bb_intersection_over_union(pred[8][0], ground[8][2])
iou_d1_g4_9 = helper.bb_intersection_over_union(pred[8][0], ground[8][3])
iou_d1_g5_9 = helper.bb_intersection_over_union(pred[8][0], ground[8][4])
iou_d1_g6_9 = helper.bb_intersection_over_union(pred[8][0], ground[8][5])

iou_d2_g1_9 = helper.bb_intersection_over_union(pred[8][1], ground[8][0])
iou_d2_g2_9 = helper.bb_intersection_over_union(pred[8][1], ground[8][1])
iou_d2_g3_9 = helper.bb_intersection_over_union(pred[8][1], ground[8][2])
iou_d2_g4_9 = helper.bb_intersection_over_union(pred[8][1], ground[8][3])
iou_d2_g5_9 = helper.bb_intersection_over_union(pred[8][1], ground[8][4])
iou_d2_g6_9 = helper.bb_intersection_over_union(pred[8][1], ground[8][5])

iou_d3_g1_9 = helper.bb_intersection_over_union(pred[8][2], ground[8][0])
iou_d3_g2_9 = helper.bb_intersection_over_union(pred[8][2], ground[8][1])
iou_d3_g3_9 = helper.bb_intersection_over_union(pred[8][2], ground[8][2])
iou_d3_g4_9 = helper.bb_intersection_over_union(pred[8][2], ground[8][3])
iou_d3_g5_9 = helper.bb_intersection_over_union(pred[8][2], ground[8][4])
iou_d3_g6_9 = helper.bb_intersection_over_union(pred[8][2], ground[8][5])

## Tenth image
iou_d1_g1_10 = helper.bb_intersection_over_union(pred[9][0], ground[9][0])
iou_d1_g2_10 = helper.bb_intersection_over_union(pred[9][0], ground[9][1])

iou_d2_g1_10 = helper.bb_intersection_over_union(pred[9][1], ground[9][0])
iou_d2_g2_10 = helper.bb_intersection_over_union(pred[9][1], ground[9][1])


print(iou_d1_g1_1)
print(iou_d1_g2_1)
print()
print(iou_d2_g1_1)
print(iou_d2_g2_1)
print()
print(iou_d3_g1_1)
print(iou_d3_g2_1)
print()
print('Second image')
print(iou_d1_g1_2)
print(iou_d1_g2_2)
print(iou_d1_g3_2)
print(iou_d1_g4_2)
print()
print(iou_d2_g1_2)
print(iou_d2_g2_2)
print(iou_d2_g3_2)
print(iou_d2_g4_2)
print()
print(iou_d3_g1_2)
print(iou_d3_g2_2)
print(iou_d3_g3_2)
print(iou_d3_g4_2)
print()
print('Fifth image')
print(iou_d1_g1_5)
print()
print('Sexth image')
print(iou_d1_g1_6)
print(iou_d1_g2_6)
print(iou_d1_g3_6)
print()
print(iou_d2_g1_6)
print(iou_d2_g2_6)
print(iou_d2_g3_6)
print()
print('Seventh image')
print(iou_d1_g1_7)
print(iou_d1_g2_7)
print(iou_d1_g3_7)
print()
print('Eighth image')
print(iou_d1_g1_8)
print()
print('Ninth image')
print(iou_d1_g1_9)
print(iou_d1_g2_9)
print(iou_d1_g3_9)
print(iou_d1_g4_9)
print(iou_d1_g5_9)
print(iou_d1_g6_9)
print()
print(iou_d2_g1_9)
print(iou_d2_g2_9)
print(iou_d2_g3_9)
print(iou_d2_g4_9)
print(iou_d2_g5_9)
print(iou_d2_g6_9)
print()
print(iou_d3_g1_9)
print(iou_d3_g2_9)
print(iou_d3_g3_9)
print(iou_d3_g4_9)
print(iou_d3_g5_9)
print(iou_d3_g6_9)
print()
print('Tenth image')
print(iou_d1_g1_10)
print(iou_d1_g2_10)

print(iou_d2_g1_10)
print(iou_d2_g2_10)
# Out:
# 0.7814865209701172
# 0.12829769880257896
#
# 0.07951319187533464
# 0.30647237771189806
#
# 0.2502014338830686
# 0.7152340741868969
#
# Second image
# 0.750916715625104
# 0.0
# 0.0
# 0.0
#
# 0.0
# 0.005224153673957545
# 0.09333971352985139
# 0.3796882170972695
#
# 0.0
# 0.6630677382649633
# 0.2545239621490246
# 0.20024522739311737
#
# Fifth image
# 0.7887821658710511
#
# Sexth image
# 0.683254944918041
# 0.0
# 0.0
#
# 0.0
# 0.0
# 0.2603750719362591
#
# Seventh image
# 0.6559272959819951
# 0.07615473097240996
# 0.8255601995081261
#
# Eighth image
# 0.9702620064887351
#
# Ninth image
# 0.0
# 0.0
# 0.48881829116621217
# 0.941145296535565
# 0.03554871313821987
# 0.0
#
# 0.0
# 0.7389444149171774
# 0.0
# 0.0
# 0.03680055003506182
# 0.6151062695942336
#
# 0.0
# 0.0
# 0.714208856699211
# 0.4156701670495843
# 0.33336066757201105
# 0.0
#
# Tenth image
# 0.0
# 0.910799059725177
# 0.798353342650602
# 0.0

# %%
sum_ioud = iou_d1_g1_1 + iou_d2_g2_1 + iou_d3_g2_1 + iou_d1_g1_2 + iou_d2_g4_2 + iou_d3_g2_2 + iou_d1_g1_5 + \
           iou_d1_g1_6 + iou_d2_g3_6 + iou_d1_g3_7 + iou_d1_g1_8 + iou_d1_g4_9 + iou_d2_g2_9 + iou_d3_g3_9 + \
           iou_d1_g2_10 + iou_d2_g1_10
presicion1 = sum_ioud / 16
print(presicion1)
print(helper.cal_performance(ground[0:10], pred[0:10]))
# Out:
# 0.7017844376941371
# Number of images: 10
# Presicion: 0.7018
# Recall: 0.5357
# F1 score: 0.6076
# (0.7017844376941371, 0.5357146479859988, 0.6076064335752446)

# %%
ground[9]
# Out:
# [[96.0, 101.0, 32.0, 82.0], [18.0, 90.0, 70.0, 92.0]]

# %%
pred[9]
# Out:
# [[15.514755249023438, 89.35948181152344, 67.07980346679688, 94.78311157226562],
#  [93.57877349853516,
#   100.65802764892578,
#   41.809120178222656,
#   79.17015838623047]]

# %%
# First image
iou_g1_d1_1 = helper.bb_intersection_over_union(ground[0][0], pred[0][0])
iou_g1_d2_1 = helper.bb_intersection_over_union(ground[0][0], pred[0][1])
iou_g1_d3_1 = helper.bb_intersection_over_union(ground[0][0], pred[0][2])

iou_g2_d1_1 = helper.bb_intersection_over_union(ground[0][1], pred[0][0])
iou_g2_d2_1 = helper.bb_intersection_over_union(ground[0][1], pred[0][1])
iou_g2_d3_1 = helper.bb_intersection_over_union(ground[0][1], pred[0][2])

# Second image
iou_g1_d1_2 = helper.bb_intersection_over_union(ground[1][0], pred[1][0])
iou_g1_d2_2 = helper.bb_intersection_over_union(ground[1][0], pred[1][1])
iou_g1_d3_2 = helper.bb_intersection_over_union(ground[1][0], pred[1][2])

iou_g2_d1_2 = helper.bb_intersection_over_union(ground[1][1], pred[1][0])
iou_g2_d2_2 = helper.bb_intersection_over_union(ground[1][1], pred[1][1])
iou_g2_d3_2 = helper.bb_intersection_over_union(ground[1][1], pred[1][2])

iou_g3_d1_2 = helper.bb_intersection_over_union(ground[1][2], pred[1][0])
iou_g3_d2_2 = helper.bb_intersection_over_union(ground[1][2], pred[1][1])
iou_g3_d3_2 = helper.bb_intersection_over_union(ground[1][2], pred[1][2])

iou_g4_d1_2 = helper.bb_intersection_over_union(ground[1][3], pred[1][0])
iou_g4_d2_2 = helper.bb_intersection_over_union(ground[1][3], pred[1][1])
iou_g4_d3_2 = helper.bb_intersection_over_union(ground[1][3], pred[1][2])

# Third image
# No detections

# Fourth image
# No detections

# Fifth image
iou_g1_d1_5 = helper.bb_intersection_over_union(ground[4][0], pred[4][0])

# Sexth image
iou_g1_d1_6 = helper.bb_intersection_over_union(ground[5][0], pred[5][0])
iou_g1_d2_6 = helper.bb_intersection_over_union(ground[5][0], pred[5][1])

iou_g2_d1_6 = helper.bb_intersection_over_union(ground[5][1], pred[5][0])
iou_g2_d2_6 = helper.bb_intersection_over_union(ground[5][1], pred[5][1])

iou_g3_d1_6 = helper.bb_intersection_over_union(ground[5][2], pred[5][0])
iou_g3_d2_6 = helper.bb_intersection_over_union(ground[5][2], pred[5][1])

# Seventh image
iou_g1_d1_7 = helper.bb_intersection_over_union(ground[6][0], pred[6][0])
iou_g2_d1_7 = helper.bb_intersection_over_union(ground[6][1], pred[6][0])
iou_g3_d1_7 = helper.bb_intersection_over_union(ground[6][2], pred[6][0])

# Eighth image
iou_g1_d1_8 = helper.bb_intersection_over_union(ground[7][0], pred[7][0])

# Ninth image
iou_g1_d1_9 = helper.bb_intersection_over_union(ground[8][0], pred[8][0])
iou_g1_d2_9 = helper.bb_intersection_over_union(ground[8][0], pred[8][1])
iou_g1_d3_9 = helper.bb_intersection_over_union(ground[8][0], pred[8][2])

iou_g2_d1_9 = helper.bb_intersection_over_union(ground[8][1], pred[8][0])
iou_g2_d2_9 = helper.bb_intersection_over_union(ground[8][1], pred[8][1])
iou_g2_d3_9 = helper.bb_intersection_over_union(ground[8][1], pred[8][2])

iou_g3_d1_9 = helper.bb_intersection_over_union(ground[8][2], pred[8][0])
iou_g3_d2_9 = helper.bb_intersection_over_union(ground[8][2], pred[8][1])
iou_g3_d3_9 = helper.bb_intersection_over_union(ground[8][2], pred[8][2])

iou_g4_d1_9 = helper.bb_intersection_over_union(ground[8][3], pred[8][0])
iou_g4_d2_9 = helper.bb_intersection_over_union(ground[8][3], pred[8][1])
iou_g4_d3_9 = helper.bb_intersection_over_union(ground[8][3], pred[8][2])

iou_g5_d1_9 = helper.bb_intersection_over_union(ground[8][4], pred[8][0])
iou_g5_d2_9 = helper.bb_intersection_over_union(ground[8][4], pred[8][1])
iou_g5_d3_9 = helper.bb_intersection_over_union(ground[8][4], pred[8][2])

iou_g6_d1_9 = helper.bb_intersection_over_union(ground[8][5], pred[8][0])
iou_g6_d2_9 = helper.bb_intersection_over_union(ground[8][5], pred[8][1])
iou_g6_d3_9 = helper.bb_intersection_over_union(ground[8][5], pred[8][2])

# Tenth image
iou_g1_d1_10 = helper.bb_intersection_over_union(ground[9][0], pred[9][0])
iou_g1_d2_10 = helper.bb_intersection_over_union(ground[9][0], pred[9][1])

iou_g2_d1_10 = helper.bb_intersection_over_union(ground[9][1], pred[9][0])
iou_g2_d2_10 = helper.bb_intersection_over_union(ground[9][1], pred[9][1])

print('First image')
print(iou_g1_d1_1)
print(iou_g1_d2_1)
print(iou_g1_d3_1)
print()
print(iou_g2_d1_1)
print(iou_g2_d2_1)
print(iou_g2_d3_1)
print()
print('Second image')
print(iou_g1_d1_2)
print(iou_g1_d2_2)
print(iou_g1_d3_2)
print()
print(iou_g2_d1_2)
print(iou_g2_d2_2)
print(iou_g2_d3_2)
print()
print(iou_g3_d1_2)
print(iou_g3_d2_2)
print(iou_g3_d3_2)
print()
print(iou_g4_d1_2)
print(iou_g4_d2_2)
print(iou_g4_d3_2)
print()
print('Third image')
print()
print('Fourth image')
print()
print('Fifth image')
print(iou_g1_d1_5)
print()
print('Sexth image')
print(iou_g1_d1_6)
print(iou_g1_d2_6)
print()
print(iou_g2_d1_6)
print(iou_g2_d2_6)
print()
print(iou_g3_d1_6)
print(iou_g3_d2_6)
print()
print('Seventh image')
print(iou_g1_d1_7)
print(iou_g2_d1_7)
print(iou_g3_d1_7)
print()
print('Eighth image')
print(iou_g1_d1_8)
print()
print('Ninth image')
print(iou_g1_d1_9)
print(iou_g1_d2_9)
print(iou_g1_d3_9)
print()
print(iou_g2_d1_9)
print(iou_g2_d2_9)
print(iou_g2_d3_9)
print()
print(iou_g3_d1_9)
print(iou_g3_d2_9)
print(iou_g3_d3_9)
print()
print(iou_g4_d1_9)
print(iou_g4_d2_9)
print(iou_g4_d3_9)
print()
print(iou_g5_d1_9)
print(iou_g5_d2_9)
print(iou_g5_d3_9)
print()
print(iou_g6_d1_9)
print(iou_g6_d2_9)
print(iou_g6_d3_9)
print()
print('Tenth image')
print(iou_g1_d1_10)
print(iou_g1_d2_10)
print()
print(iou_g2_d1_10)
print(iou_g2_d2_10)
# Out:
# First image
# 0.7814865209701172
# 0.07951319187533464
# 0.2502014338830686
#
# 0.12829769880257896
# 0.30647237771189806
# 0.7152340741868969
#
# Second image
# 0.750916715625104
# 0.0
# 0.0
#
# 0.0
# 0.005224153673957545
# 0.6630677382649633
#
# 0.0
# 0.09333971352985139
# 0.2545239621490246
#
# 0.0
# 0.3796882170972695
# 0.20024522739311737
#
# Third image
#
# Fourth image
#
# Fifth image
# 0.7887821658710511
#
# Sexth image
# 0.683254944918041
# 0.0
#
# 0.0
# 0.0
#
# 0.0
# 0.2603750719362591
#
# Seventh image
# 0.6559272959819951
# 0.07615473097240996
# 0.8255601995081261
#
# Eighth image
# 0.9702620064887351
#
# Ninth image
# 0.0
# 0.0
# 0.0
#
# 0.0
# 0.7389444149171774
# 0.0
#
# 0.48881829116621217
# 0.0
# 0.714208856699211
#
# 0.941145296535565
# 0.0
# 0.4156701670495843
#
# 0.03554871313821987
# 0.03680055003506182
# 0.33336066757201105
#
# 0.0
# 0.6151062695942336
# 0.0
#
# Tenth image
# 0.0
# 0.798353342650602
#
# 0.910799059725177
# 0.0

# %%
sum_ioug = iou_g1_d1_1 + iou_g2_d3_1 + iou_g1_d1_2 + iou_g2_d3_2 + iou_g3_d3_2 + iou_g4_d2_2 + iou_g1_d1_5 + \
           iou_g1_d1_6 + iou_g3_d2_6 + iou_g1_d1_7 + iou_g2_d1_7 + iou_g3_d1_7 + iou_g1_d1_8 + iou_g2_d2_9 + \
           iou_g3_d3_9 + iou_g4_d1_9 + iou_g5_d3_9 + iou_g6_d2_9 + iou_g1_d2_10 + iou_g2_d1_10
recall1 = sum_ioug / 24
print(recall1)
print(helper.cal_performance(ground[0:10], pred[0:10]))
# Out:
# 0.5357146479859988
# Number of images: 10
# Presicion: 0.7018
# Recall: 0.5357
# F1 score: 0.6076
# (0.7017844376941371, 0.5357146479859988, 0.6076064335752446)

# %%
f = (2*presicion1*recall1)/ (presicion1 + recall1)
f
# Out:
# 0.6076064335752446
