# %%
# libraries
import os
import json
import numpy as np
import pandas as pd
from extra_files import helper as hp
from imageio import imwrite, imread
from skimage.transform import resize

# %%
# File paths
data_path = '/home/aldo/Documents/data-cic/'
preprocess_path = data_path + 'preprocess_data'

# %% [markdown]
# ## Training SSDLite300

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, EarlyStopping, ReduceLROnPlateau, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssdlite320_mobilenetv2 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

from extra_files.f1_callback import F1_callback as f1_call
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /home/aldo/Documents/ssd/data_generator/object_detection_2d_data_generator.py:43: UserWarning: 'BeautifulSoup' module is missing. The XML-parser will be unavailable.
#   warnings.warn("'BeautifulSoup' module is missing. The XML-parser will be unavailable.")

# %% [markdown]
# ### Parameters (original SSD300 architecture)

# %%
## Parameteres needed for ssd_300() and SSDInputEncoder()

img_height = 320 # Height of the model input images
img_width = 320 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [-1., -1., -1.] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
divide_by_stddev = [127.5, 127.5, 127.5]
swap_channels = False # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 1 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
new_scales = [0.15, 0.33, 0.47, 0.61, 0.76, 0.90, 1.05]
scales = new_scales
aspect_ratios = [[1.0, 0.5, 2.0/3.0],
                 [1.0, 0.5, 2.0/3.0, 1.0/3.0, 3.0/4.0],
                 [1.0, 2.0, 0.5, 2.0/3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 2.0/3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [16, 32, 64, 107, 160, 320] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True
list_alpha = [1.0]
list_expansion = [6]

# %% [markdown]
# ## Data generator for the training

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset_pascal = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset_pascal = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
images_dir = data_path + 'pascal_dataset'

# Ground truth
train_labels_filename = preprocess_path + '/pascal_train.csv'
val_labels_filename   = preprocess_path + '/pascal_val.csv'

train_dataset_pascal.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset_pascal.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Get the number of samples in the training and validations datasets.
train_dataset_size_pascal = train_dataset_pascal.get_dataset_size()
val_dataset_size_pascal   = val_dataset_pascal.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size_pascal))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size_pascal))

# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [(20, 20),
                   (10, 10),
                   (5, 5),
                   (3, 3),
                   (2, 2),
                   (1, 1)]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator_pascal = train_dataset_pascal.generate(batch_size=batch_size,
                                              shuffle=True,
                                              transformations=[ssd_data_augmentation],
                                              label_encoder=ssd_input_encoder,
                                              returns={'processed_images',
                                                       'encoded_labels'},
                                              keep_images_without_gt=False)

val_generator_pascal = val_dataset_pascal.generate(batch_size=batch_size,
                                          shuffle=False,
                                          transformations=[convert_to_3_channels,
                                                           resize],
                                          label_encoder=ssd_input_encoder,
                                          returns={'processed_images',
                                                   'encoded_labels'},
                                          keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size_pascal = train_dataset_pascal.get_dataset_size()
val_dataset_size_pascal   = val_dataset_pascal.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size_pascal))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size_pascal))
# Out:
# Loading images into memory: 100%|██████████| 6469/6469 [00:27<00:00, 232.93it/s]
# Loading images into memory: 100%|██████████| 2097/2097 [00:08<00:00, 254.57it/s]
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  2097
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  2097

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset_cic = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset_cic = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
images_dir = data_path + 'images'

# Ground truth
train_labels_filename = preprocess_path + '/cic_train.csv'
val_labels_filename   = preprocess_path + '/cic_val.csv'

train_dataset_cic.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset_cic.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Get the number of samples in the training and validations datasets.
train_dataset_size_cic = train_dataset_cic.get_dataset_size()
val_dataset_size_cic   = val_dataset_cic.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size_cic))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size_cic))

# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [(20, 20),
                   (10, 10),
                   (5, 5),
                   (3, 3),
                   (2, 2),
                   (1, 1)]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator_cic = train_dataset_cic.generate(batch_size=batch_size,
                                            shuffle=True,
                                            transformations=[ssd_data_augmentation],
                                            label_encoder=ssd_input_encoder,
                                            returns={'processed_images',
                                                     'encoded_labels'},
                                            keep_images_without_gt=False)

val_generator_cic = val_dataset_cic.generate(batch_size=batch_size,
                                        shuffle=False,
                                        transformations=[convert_to_3_channels,
                                                         resize],
                                        label_encoder=ssd_input_encoder,
                                        returns={'processed_images',
                                                 'encoded_labels'},
                                        keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size_cic = train_dataset_cic.get_dataset_size()
val_dataset_size_cic   = val_dataset_cic.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size_cic))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size_cic))
# Out:
# Loading images into memory: 100%|██████████| 210/210 [00:07<00:00, 28.03it/s]
# Loading images into memory: 100%|██████████| 45/45 [00:01<00:00, 27.70it/s]
# Number of images in the training dataset:	   210
# Number of images in the validation dataset:	    45
# Number of images in the training dataset:	   210
# Number of images in the validation dataset:	    45

# %%
label_val = np.load('../data-cic/preprocess_data/label_val_320.npy')
val_images_320 = np.load('../data-cic/preprocess_data/images_val_320x320.npy')

# %%
def return_callbacks(path_weights, name_weights, path_logger, path_tensorboard, path_f1, save_f1):
    
    # Define model callbacks.
    # TODO: Set the filepath under which you want to save the model.
    model_checkpoint = ModelCheckpoint(filepath=path_weights + name_weights,
                                       monitor='val_loss',
                                       verbose=1,
                                       save_best_only=True,
                                       save_weights_only=False,
                                       mode='auto',
                                       period=1)

    csv_logger = CSVLogger(filename= path_logger,
                           separator=',',
                           append=True)

    reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                             factor=0.5,
                                             patience=10,
                                             verbose=1,
                                             min_delta=0.001,
                                             cooldown=0,
                                             min_lr=0.000001)
    
    tbCallBack = TensorBoard(log_dir=path_tensorboard, 
                                       histogram_freq=0, 
                                       write_graph=False, 
                                       write_images=False,
                                       update_freq='epoch')


    f1_callback = f1_call(0.20, 
                          0.45, 
                          200, 
                          normalize_coords, 
                          img_height, 
                          img_width, 
                          val_images_320, 
                          label_val, (1, 2424, 14),
                          path_f1,
                          save_f1)

    callbacks = [model_checkpoint,
                 csv_logger,
                 reduce_learning_rate,
                 f1_callback,
                 tbCallBack]
    return callbacks

# %% [markdown]
# ## Loop to train different models

# %%
for alpha in list_alpha:
    for expansion in list_expansion:
        # 1: Build the Keras model.

        K.clear_session() # Clear previous models from memory.

        model = ssd_300(image_size=(img_height, img_width, img_channels),
                        n_classes=n_classes,
                        alpha=alpha,
                        expansion=expansion,
                        mode='training',
                        scales=scales,
                        aspect_ratios_per_layer=aspect_ratios,
                        two_boxes_for_ar1=two_boxes_for_ar1,
                        steps=steps,
                        offsets=offsets,
                        clip_boxes=clip_boxes,
                        variances=variances,
                        normalize_coords=normalize_coords,
                        subtract_mean=mean_color,
                        divide_by_stddev=divide_by_stddev,
                        swap_channels=swap_channels)

        print('\n---->Training model with alpha', alpha, 'and expansion', expansion, 'with pascal')
        print('Number of parameters:', model.count_params())
        
        ## Train over pascal
        adam = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
        ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
        model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
        
        # set callbacks
        str_alpha = str(alpha)
        str_exp = str(expansion)
        callbacks_pascal =  return_callbacks('/home/aldo/Documents/weights/models/tradeoff/', 
                              'ssdlite320_mobilenetv2_pascal_' + str_alpha + '_exp_' + str_exp + '.h5',
                              data_path + 'history/tradeoff/ssdlite320_mobilenetv2_pascal_alpha_' + str_alpha + '_exp_' + str_exp + '.csv',
                              data_path + 'history/tradeoff/tensorboard/pascal/' + str_alpha + '_exp_' + str_exp +'/pascal_' + str_alpha + '_exp_' + str_exp,
                              data_path + 'history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_' + str_alpha + '_exp_' + str_exp + '.csv',
                              '/home/aldo/Documents/weights/models/tradeoff/' + 'ssdlite320_mobilenetv2_pascal_f1_' + str_alpha + '_exp_' + str_exp + '.h5' )
        # If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
        initial_epoch   = 0
        final_epoch     = 120
        steps_per_epoch = 400

        history = model.fit_generator(generator=train_generator_pascal,
                                      steps_per_epoch=steps_per_epoch,
                                      epochs=final_epoch,
                                      callbacks=callbacks_pascal,
                                      validation_data=val_generator_pascal,
                                      validation_steps=ceil(val_dataset_size_pascal/batch_size),
                                      initial_epoch=initial_epoch)
        
        print('\n---->Training model with alpha', alpha, 'and expansion', expansion, 'with cic')
        # Train over cic
        # Reset learning rate to 0.001
        adam = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
        ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
        model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
        
        callbacks_cic =  return_callbacks('/home/aldo/Documents/weights/models/tradeoff/', 
                              'ssdlite320_mobilenetv2_pascal_cic_' + str_alpha + '_exp_' + str_exp + '.h5',
                              data_path + 'history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_alpha_' + str_alpha + '_exp_' + str_exp + '.csv',
                              data_path + 'history/tradeoff/tensorboard/cic/' + str_alpha + '_exp_' + str_exp +'/cic' + str_alpha + '_exp_' + str_exp,  
                              data_path + 'history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_' + str_alpha + '_exp_' + str_exp + '.csv',
                              '/home/aldo/Documents/weights/models/tradeoff/' + 'ssdlite320_mobilenetv2_pascal_cic_f1_' + str_alpha + '_exp_' + str_exp + '.h5')
        
        initial_epoch   = 0
        final_epoch     = 100
        steps_per_epoch = 15

        history = model.fit_generator(generator=train_generator_cic,
                                      steps_per_epoch=steps_per_epoch,
                                      epochs=final_epoch,
                                      callbacks=callbacks_cic,
                                      validation_data=val_generator_cic,
                                      validation_steps=ceil(val_dataset_size_cic/batch_size),
                                      initial_epoch=initial_epoch)
# Out:
# ---->Training model with alpha 1.0 and expansion 6 with pascal
# Number of parameters: 3790132
# Epoch 1/120
# 400/400 [==============================] - 240s 600ms/step - loss: 5.4069 - val_loss: 4.5421
#
# Epoch 00001: val_loss improved from inf to 4.54213, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.1467665204423544
# Improve F1 score from -inf to 0.1467665204423544
# Epoch 2/120
# 400/400 [==============================] - 234s 586ms/step - loss: 4.3696 - val_loss: 5.2821
#
# Epoch 00002: val_loss did not improve from 4.54213
# F1 score: 0.16336292187967857
# Improve F1 score from 0.1467665204423544 to 0.16336292187967857
# Epoch 3/120
# 400/400 [==============================] - 241s 602ms/step - loss: 3.7374 - val_loss: 4.1742
#
# Epoch 00003: val_loss improved from 4.54213 to 4.17421, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.35776119478759827
# Improve F1 score from 0.16336292187967857 to 0.35776119478759827
# Epoch 4/120
# 400/400 [==============================] - 237s 593ms/step - loss: 3.5620 - val_loss: 4.0248
#
# Epoch 00004: val_loss improved from 4.17421 to 4.02480, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.2616467506504639
# Epoch 5/120
# 400/400 [==============================] - 240s 599ms/step - loss: 3.4859 - val_loss: 4.0005
#
# Epoch 00005: val_loss improved from 4.02480 to 4.00054, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.4013309436881949
# Improve F1 score from 0.35776119478759827 to 0.4013309436881949
# Epoch 6/120
# 400/400 [==============================] - 244s 611ms/step - loss: 3.4261 - val_loss: 3.7362
#
# Epoch 00006: val_loss improved from 4.00054 to 3.73623, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.35714770609818164
# Epoch 7/120
# 400/400 [==============================] - 237s 593ms/step - loss: 3.3793 - val_loss: 3.9041
#
# Epoch 00007: val_loss did not improve from 3.73623
# F1 score: 0.35634782728541353
# Epoch 8/120
# 400/400 [==============================] - 230s 575ms/step - loss: 3.3593 - val_loss: 3.4582
#
# Epoch 00008: val_loss improved from 3.73623 to 3.45823, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.38395475115511396
# Epoch 9/120
# 400/400 [==============================] - 249s 622ms/step - loss: 3.3114 - val_loss: 3.5830
#
# Epoch 00009: val_loss did not improve from 3.45823
# F1 score: 0.39621392265207167
# Epoch 10/120
# 400/400 [==============================] - 247s 616ms/step - loss: 3.2571 - val_loss: 3.6264
#
# Epoch 00010: val_loss did not improve from 3.45823
# F1 score: 0.3817728929954058
# Epoch 11/120
# 400/400 [==============================] - 238s 594ms/step - loss: 3.2419 - val_loss: 3.3648
#
# Epoch 00011: val_loss improved from 3.45823 to 3.36480, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.34882162839918157
# Epoch 12/120
# 400/400 [==============================] - 232s 579ms/step - loss: 3.2329 - val_loss: 3.2981
#
# Epoch 00012: val_loss improved from 3.36480 to 3.29806, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.4235366561621154
# Improve F1 score from 0.4013309436881949 to 0.4235366561621154
# Epoch 13/120
# 400/400 [==============================] - 227s 568ms/step - loss: 3.2171 - val_loss: 3.4930
#
# Epoch 00013: val_loss did not improve from 3.29806
# F1 score: 0.4162921021316022
# Epoch 14/120
# 400/400 [==============================] - 224s 561ms/step - loss: 3.1978 - val_loss: 3.4401
#
# Epoch 00014: val_loss did not improve from 3.29806
# F1 score: 0.3444287939153892
# Epoch 15/120
# 400/400 [==============================] - 227s 567ms/step - loss: 3.3039 - val_loss: 5.2446
#
# Epoch 00015: val_loss did not improve from 3.29806
# F1 score: 0.12407729924340012
# Epoch 16/120
# 400/400 [==============================] - 225s 561ms/step - loss: 3.1724 - val_loss: 3.8171
#
# Epoch 00016: val_loss did not improve from 3.29806
# F1 score: 0.14693524175525907
# Epoch 17/120
# 400/400 [==============================] - 227s 567ms/step - loss: 3.1526 - val_loss: 3.4983
#
# Epoch 00017: val_loss did not improve from 3.29806
# F1 score: 0.32469061358166024
# Epoch 18/120
# 400/400 [==============================] - 227s 567ms/step - loss: 3.0980 - val_loss: 3.2505
#
# Epoch 00018: val_loss improved from 3.29806 to 3.25051, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.366659153752173
# Epoch 19/120
# 400/400 [==============================] - 226s 565ms/step - loss: 3.0525 - val_loss: 3.2711
#
# Epoch 00019: val_loss did not improve from 3.25051
# F1 score: 0.39869258471699287
# Epoch 20/120
# 400/400 [==============================] - 226s 564ms/step - loss: 3.0768 - val_loss: 3.0752
#
# Epoch 00020: val_loss improved from 3.25051 to 3.07521, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.4346743667576573
# Improve F1 score from 0.4235366561621154 to 0.4346743667576573
# Epoch 21/120
# 400/400 [==============================] - 226s 564ms/step - loss: 3.0538 - val_loss: 3.4417
#
# Epoch 00021: val_loss did not improve from 3.07521
# F1 score: 0.40451181952463205
# Epoch 22/120
# 400/400 [==============================] - 227s 567ms/step - loss: 3.0207 - val_loss: 3.2535
#
# Epoch 00022: val_loss did not improve from 3.07521
# F1 score: 0.39266864792002715
# Epoch 23/120
# 400/400 [==============================] - 227s 569ms/step - loss: 3.0291 - val_loss: 3.1039
#
# Epoch 00023: val_loss did not improve from 3.07521
# F1 score: 0.3956790019631933
# Epoch 24/120
# 400/400 [==============================] - 227s 567ms/step - loss: 3.0187 - val_loss: 3.0706
#
# Epoch 00024: val_loss improved from 3.07521 to 3.07061, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.44952214062052676
# Improve F1 score from 0.4346743667576573 to 0.44952214062052676
# Epoch 25/120
# 400/400 [==============================] - 226s 564ms/step - loss: 3.0147 - val_loss: 3.0533
#
# Epoch 00025: val_loss improved from 3.07061 to 3.05328, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.45237909326724807
# Improve F1 score from 0.44952214062052676 to 0.45237909326724807
# Epoch 26/120
# 400/400 [==============================] - 226s 564ms/step - loss: 2.9960 - val_loss: 3.1317
#
# Epoch 00026: val_loss did not improve from 3.05328
# F1 score: 0.4277008362288598
# Epoch 27/120
# 400/400 [==============================] - 225s 563ms/step - loss: 2.9426 - val_loss: 3.3202
#
# Epoch 00027: val_loss did not improve from 3.05328
# F1 score: 0.4307925763958527
# Epoch 28/120
# 400/400 [==============================] - 228s 570ms/step - loss: 2.9989 - val_loss: 3.0961
#
# Epoch 00028: val_loss did not improve from 3.05328
# F1 score: 0.42265278204306
# Epoch 29/120
# 400/400 [==============================] - 232s 580ms/step - loss: 2.9471 - val_loss: 3.2121
#
# Epoch 00029: val_loss did not improve from 3.05328
# F1 score: 0.42675554451266384
# Epoch 30/120
# 400/400 [==============================] - 242s 606ms/step - loss: 2.9468 - val_loss: 3.1418
#
# Epoch 00030: val_loss did not improve from 3.05328
# F1 score: 0.4190194374740867
# Epoch 31/120
# 400/400 [==============================] - 254s 635ms/step - loss: 2.9564 - val_loss: 3.1285
#
# Epoch 00031: val_loss did not improve from 3.05328
# F1 score: 0.4052718752161673
# Epoch 32/120
# 400/400 [==============================] - 231s 578ms/step - loss: 2.9247 - val_loss: 3.0397
#
# Epoch 00032: val_loss improved from 3.05328 to 3.03965, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.451485805000208
# Epoch 33/120
# 400/400 [==============================] - 231s 577ms/step - loss: 2.8848 - val_loss: 3.1469
#
# Epoch 00033: val_loss did not improve from 3.03965
# F1 score: 0.43476006428263103
# Epoch 34/120
# 400/400 [==============================] - 233s 584ms/step - loss: 2.8834 - val_loss: 3.3818
#
# Epoch 00034: val_loss did not improve from 3.03965
# F1 score: 0.40220924380794376
# Epoch 35/120
# 400/400 [==============================] - 240s 601ms/step - loss: 2.8783 - val_loss: 3.0471
#
# Epoch 00035: val_loss did not improve from 3.03965
# F1 score: 0.4503724234090202
# Epoch 36/120
# 400/400 [==============================] - 237s 592ms/step - loss: 2.8688 - val_loss: 3.0037
#
# Epoch 00036: val_loss improved from 3.03965 to 3.00372, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.4562058432471824
# Improve F1 score from 0.45237909326724807 to 0.4562058432471824
# Epoch 37/120
# 400/400 [==============================] - 235s 588ms/step - loss: 2.8543 - val_loss: 3.0796
#
# Epoch 00037: val_loss did not improve from 3.00372
# F1 score: 0.42368808435648464
# Epoch 38/120
# 400/400 [==============================] - 240s 601ms/step - loss: 2.8658 - val_loss: 3.0129
#
# Epoch 00038: val_loss did not improve from 3.00372
# F1 score: 0.4429542876551162
# Epoch 39/120
# 400/400 [==============================] - 233s 582ms/step - loss: 2.8183 - val_loss: 3.0273
#
# Epoch 00039: val_loss did not improve from 3.00372
# F1 score: 0.46123394813109564
# Improve F1 score from 0.4562058432471824 to 0.46123394813109564
# Epoch 40/120
# 400/400 [==============================] - 238s 596ms/step - loss: 2.8328 - val_loss: 3.1679
#
# Epoch 00040: val_loss did not improve from 3.00372
# F1 score: 0.4565377141074557
# Epoch 41/120
# 400/400 [==============================] - 233s 582ms/step - loss: 2.8017 - val_loss: 3.2192
#
# Epoch 00041: val_loss did not improve from 3.00372
# F1 score: 0.4210326159636517
# Epoch 42/120
# 400/400 [==============================] - 231s 578ms/step - loss: 2.8207 - val_loss: 3.0590
#
# Epoch 00042: val_loss did not improve from 3.00372
# F1 score: 0.4363523918196808
# Epoch 43/120
# 400/400 [==============================] - 233s 583ms/step - loss: 2.8344 - val_loss: 3.1432
#
# Epoch 00043: val_loss did not improve from 3.00372
# F1 score: 0.4314459380062228
# Epoch 44/120
# 400/400 [==============================] - 227s 567ms/step - loss: 2.7920 - val_loss: 3.0197
#
# Epoch 00044: val_loss did not improve from 3.00372
# F1 score: 0.4919984665069161
# Improve F1 score from 0.46123394813109564 to 0.4919984665069161
# Epoch 45/120
# 400/400 [==============================] - 228s 569ms/step - loss: 2.8135 - val_loss: 3.0019
#
# Epoch 00045: val_loss improved from 3.00372 to 3.00192, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.49480028716275376
# Improve F1 score from 0.4919984665069161 to 0.49480028716275376
# Epoch 46/120
# 400/400 [==============================] - 233s 584ms/step - loss: 2.7951 - val_loss: 3.0443
#
# Epoch 00046: val_loss did not improve from 3.00192
# F1 score: 0.48413389367686216
# Epoch 47/120
# 400/400 [==============================] - 231s 579ms/step - loss: 2.7675 - val_loss: 2.9968
#
# Epoch 00047: val_loss improved from 3.00192 to 2.99683, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.464645527865515
# Epoch 48/120
# 400/400 [==============================] - 231s 577ms/step - loss: 2.7707 - val_loss: 3.1140
#
# Epoch 00048: val_loss did not improve from 2.99683
# F1 score: 0.4627915369791713
# Epoch 49/120
# 400/400 [==============================] - 231s 577ms/step - loss: 2.7667 - val_loss: 3.1984
#
# Epoch 00049: val_loss did not improve from 2.99683
# F1 score: 0.45152631447197794
# Epoch 50/120
# 400/400 [==============================] - 230s 574ms/step - loss: 2.7694 - val_loss: 3.0346
#
# Epoch 00050: val_loss did not improve from 2.99683
# F1 score: 0.47452892800769186
# Epoch 51/120
# 400/400 [==============================] - 231s 578ms/step - loss: 2.7351 - val_loss: 3.2555
#
# Epoch 00051: val_loss did not improve from 2.99683
# F1 score: 0.42212299018022
# Epoch 52/120
# 400/400 [==============================] - 230s 576ms/step - loss: 2.7291 - val_loss: 2.8889
#
# Epoch 00052: val_loss improved from 2.99683 to 2.88888, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.4879630360092723
# Epoch 53/120
# 400/400 [==============================] - 230s 576ms/step - loss: 2.7358 - val_loss: 3.0725
#
# Epoch 00053: val_loss did not improve from 2.88888
# F1 score: 0.4290589861161383
# Epoch 54/120
# 400/400 [==============================] - 230s 575ms/step - loss: 2.7182 - val_loss: 2.9365
#
# Epoch 00054: val_loss did not improve from 2.88888
# F1 score: 0.4429490231050467
# Epoch 55/120
# 400/400 [==============================] - 232s 579ms/step - loss: 2.7162 - val_loss: 2.9349
#
# Epoch 00055: val_loss did not improve from 2.88888
# F1 score: 0.457428064075607
# Epoch 56/120
# 400/400 [==============================] - 231s 577ms/step - loss: 2.7537 - val_loss: 2.9776
#
# Epoch 00056: val_loss did not improve from 2.88888
# F1 score: 0.4639654867465832
# Epoch 57/120
# 400/400 [==============================] - 230s 576ms/step - loss: 2.6974 - val_loss: 3.0889
#
# Epoch 00057: val_loss did not improve from 2.88888
# F1 score: 0.4449988882157371
# Epoch 58/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.7151 - val_loss: 3.1617
#
# Epoch 00058: val_loss did not improve from 2.88888
# F1 score: 0.47808005872512144
# Epoch 59/120
# 400/400 [==============================] - 231s 576ms/step - loss: 2.7267 - val_loss: 2.9564
#
# Epoch 00059: val_loss did not improve from 2.88888
# F1 score: 0.4485560160876795
# Epoch 60/120
# 400/400 [==============================] - 230s 576ms/step - loss: 2.6869 - val_loss: 2.8861
#
# Epoch 00060: val_loss improved from 2.88888 to 2.88609, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.48032737807537723
# Epoch 61/120
# 400/400 [==============================] - 230s 576ms/step - loss: 2.7491 - val_loss: 3.0924
#
# Epoch 00061: val_loss did not improve from 2.88609
# F1 score: 0.4103322268637494
# Epoch 62/120
# 400/400 [==============================] - 230s 574ms/step - loss: 2.7001 - val_loss: 3.0809
#
# Epoch 00062: val_loss did not improve from 2.88609
# F1 score: 0.3840183989008617
# Epoch 63/120
# 400/400 [==============================] - 230s 575ms/step - loss: 2.6851 - val_loss: 3.1101
#
# Epoch 00063: val_loss did not improve from 2.88609
# F1 score: 0.4355891856520473
# Epoch 64/120
# 400/400 [==============================] - 232s 581ms/step - loss: 2.6973 - val_loss: 2.9577
#
# Epoch 00064: val_loss did not improve from 2.88609
# F1 score: 0.4454566417534342
# Epoch 65/120
# 400/400 [==============================] - 231s 578ms/step - loss: 2.6884 - val_loss: 2.9947
#
# Epoch 00065: val_loss did not improve from 2.88609
# F1 score: 0.42174347840525117
# Epoch 66/120
# 400/400 [==============================] - 231s 579ms/step - loss: 2.6656 - val_loss: 2.9524
#
# Epoch 00066: val_loss did not improve from 2.88609
# F1 score: 0.49529603557490476
# Improve F1 score from 0.49480028716275376 to 0.49529603557490476
# Epoch 67/120
# 400/400 [==============================] - 230s 575ms/step - loss: 2.6664 - val_loss: 3.2109
#
# Epoch 00067: val_loss did not improve from 2.88609
# F1 score: 0.4313263189316189
# Epoch 68/120
# 400/400 [==============================] - 231s 577ms/step - loss: 2.6579 - val_loss: 2.8815
#
# Epoch 00068: val_loss improved from 2.88609 to 2.88153, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.48177496363717226
# Epoch 69/120
# 400/400 [==============================] - 231s 577ms/step - loss: 2.6417 - val_loss: 2.8968
#
# Epoch 00069: val_loss did not improve from 2.88153
# F1 score: 0.4523609091156747
# Epoch 70/120
# 400/400 [==============================] - 232s 580ms/step - loss: 2.6426 - val_loss: 2.8180
#
# Epoch 00070: val_loss improved from 2.88153 to 2.81805, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.4924658188101216
# Epoch 71/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.6470 - val_loss: 2.9211
#
# Epoch 00071: val_loss did not improve from 2.81805
# F1 score: 0.4540632321004219
# Epoch 72/120
# 400/400 [==============================] - 231s 576ms/step - loss: 2.6424 - val_loss: 3.1233
#
# Epoch 00072: val_loss did not improve from 2.81805
# F1 score: 0.4768695898596181
# Epoch 73/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.6398 - val_loss: 2.8597
#
# Epoch 00073: val_loss did not improve from 2.81805
# F1 score: 0.4956862540902815
# Improve F1 score from 0.49529603557490476 to 0.4956862540902815
# Epoch 74/120
# 400/400 [==============================] - 229s 572ms/step - loss: 2.6152 - val_loss: 3.0288
#
# Epoch 00074: val_loss did not improve from 2.81805
# F1 score: 0.47703778532145097
# Epoch 75/120
# 400/400 [==============================] - 231s 578ms/step - loss: 2.6122 - val_loss: 2.8939
#
# Epoch 00075: val_loss did not improve from 2.81805
# F1 score: 0.46537105249917304
# Epoch 76/120
# 400/400 [==============================] - 229s 572ms/step - loss: 2.6264 - val_loss: 3.0593
#
# Epoch 00076: val_loss did not improve from 2.81805
# F1 score: 0.4742859612188279
# Epoch 77/120
# 400/400 [==============================] - 230s 575ms/step - loss: 2.6209 - val_loss: 2.9061
#
# Epoch 00077: val_loss did not improve from 2.81805
# F1 score: 0.49544192204990706
# Epoch 78/120
# 400/400 [==============================] - 230s 574ms/step - loss: 2.5970 - val_loss: 2.8624
#
# Epoch 00078: val_loss did not improve from 2.81805
# F1 score: 0.48759715293622735
# Epoch 79/120
# 400/400 [==============================] - 230s 575ms/step - loss: 2.6102 - val_loss: 2.9003
#
# Epoch 00079: val_loss did not improve from 2.81805
# F1 score: 0.4841341150421314
# Epoch 80/120
# 400/400 [==============================] - 229s 572ms/step - loss: 2.6034 - val_loss: 2.8820
#
# Epoch 00080: val_loss did not improve from 2.81805
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# F1 score: 0.46020517430587243
# Epoch 81/120
# 400/400 [==============================] - 230s 575ms/step - loss: 2.4988 - val_loss: 2.6839
#
# Epoch 00081: val_loss improved from 2.81805 to 2.68390, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.4354179180778071
# Epoch 82/120
# 400/400 [==============================] - 228s 571ms/step - loss: 2.4592 - val_loss: 2.7248
#
# Epoch 00082: val_loss did not improve from 2.68390
# F1 score: 0.46014640073537255
# Epoch 83/120
# 400/400 [==============================] - 231s 577ms/step - loss: 2.4894 - val_loss: 2.7642
#
# Epoch 00083: val_loss did not improve from 2.68390
# F1 score: 0.43745512695053096
# Epoch 84/120
# 400/400 [==============================] - 229s 574ms/step - loss: 2.4414 - val_loss: 2.6680
#
# Epoch 00084: val_loss improved from 2.68390 to 2.66804, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.47838653479131515
# Epoch 85/120
# 400/400 [==============================] - 231s 576ms/step - loss: 2.4396 - val_loss: 2.6387
#
# Epoch 00085: val_loss improved from 2.66804 to 2.63874, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.49645195406473364
# Improve F1 score from 0.4956862540902815 to 0.49645195406473364
# Epoch 86/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.4305 - val_loss: 2.6872
#
# Epoch 00086: val_loss did not improve from 2.63874
# F1 score: 0.5106136832343295
# Improve F1 score from 0.49645195406473364 to 0.5106136832343295
# Epoch 87/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.4219 - val_loss: 2.6840
#
# Epoch 00087: val_loss did not improve from 2.63874
# F1 score: 0.5084502043562642
# Epoch 88/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.4320 - val_loss: 2.6787
#
# Epoch 00088: val_loss did not improve from 2.63874
# F1 score: 0.48276154437865443
# Epoch 89/120
# 400/400 [==============================] - 229s 572ms/step - loss: 2.4262 - val_loss: 2.6767
#
# Epoch 00089: val_loss did not improve from 2.63874
# F1 score: 0.518328627480907
# Improve F1 score from 0.5106136832343295 to 0.518328627480907
# Epoch 90/120
# 400/400 [==============================] - 231s 576ms/step - loss: 2.4159 - val_loss: 2.6821
#
# Epoch 00090: val_loss did not improve from 2.63874
# F1 score: 0.528578590291421
# Improve F1 score from 0.518328627480907 to 0.528578590291421
# Epoch 91/120
# 400/400 [==============================] - 230s 574ms/step - loss: 2.4196 - val_loss: 2.6728
#
# Epoch 00091: val_loss did not improve from 2.63874
# F1 score: 0.5187433378424852
# Epoch 92/120
# 400/400 [==============================] - 230s 575ms/step - loss: 2.3912 - val_loss: 2.6686
#
# Epoch 00092: val_loss did not improve from 2.63874
# F1 score: 0.4884317476675568
# Epoch 93/120
# 400/400 [==============================] - 228s 571ms/step - loss: 2.3754 - val_loss: 2.6404
#
# Epoch 00093: val_loss did not improve from 2.63874
# F1 score: 0.49595372129672055
# Epoch 94/120
# 400/400 [==============================] - 228s 570ms/step - loss: 2.3933 - val_loss: 2.6395
#
# Epoch 00094: val_loss did not improve from 2.63874
# F1 score: 0.4750928046319285
# Epoch 95/120
# 400/400 [==============================] - 229s 572ms/step - loss: 2.4086 - val_loss: 2.6598
#
# Epoch 00095: val_loss did not improve from 2.63874
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# F1 score: 0.49207208310971695
# Epoch 96/120
# 400/400 [==============================] - 232s 580ms/step - loss: 2.3503 - val_loss: 2.5959
#
# Epoch 00096: val_loss improved from 2.63874 to 2.59585, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.5019686534545462
# Epoch 97/120
# 400/400 [==============================] - 231s 578ms/step - loss: 2.3157 - val_loss: 2.5964
#
# Epoch 00097: val_loss did not improve from 2.59585
# F1 score: 0.51243828357346
# Epoch 98/120
# 400/400 [==============================] - 230s 575ms/step - loss: 2.3143 - val_loss: 2.6144
#
# Epoch 00098: val_loss did not improve from 2.59585
# F1 score: 0.48464460231790835
# Epoch 99/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.3181 - val_loss: 2.5892
#
# Epoch 00099: val_loss improved from 2.59585 to 2.58919, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.48540706807988127
# Epoch 100/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.3077 - val_loss: 2.5694
#
# Epoch 00100: val_loss improved from 2.58919 to 2.56938, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.4954705857248235
# Epoch 101/120
# 400/400 [==============================] - 229s 572ms/step - loss: 2.3046 - val_loss: 2.5811
#
# Epoch 00101: val_loss did not improve from 2.56938
# F1 score: 0.4920396212450938
# Epoch 102/120
# 400/400 [==============================] - 231s 579ms/step - loss: 2.3214 - val_loss: 2.5810
#
# Epoch 00102: val_loss did not improve from 2.56938
# F1 score: 0.4921547512864318
# Epoch 103/120
# 400/400 [==============================] - 230s 575ms/step - loss: 2.2939 - val_loss: 2.5612
#
# Epoch 00103: val_loss improved from 2.56938 to 2.56120, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.5095253900067145
# Epoch 104/120
# 400/400 [==============================] - 230s 574ms/step - loss: 2.3064 - val_loss: 2.5777
#
# Epoch 00104: val_loss did not improve from 2.56120
# F1 score: 0.5136944963426014
# Epoch 105/120
# 400/400 [==============================] - 230s 576ms/step - loss: 2.3021 - val_loss: 2.5937
#
# Epoch 00105: val_loss did not improve from 2.56120
# F1 score: 0.4995084607139664
# Epoch 106/120
# 400/400 [==============================] - 228s 571ms/step - loss: 2.2833 - val_loss: 2.5860
#
# Epoch 00106: val_loss did not improve from 2.56120
# F1 score: 0.5205170274326588
# Epoch 107/120
# 400/400 [==============================] - 232s 581ms/step - loss: 2.2809 - val_loss: 2.5793
#
# Epoch 00107: val_loss did not improve from 2.56120
# F1 score: 0.5103751698114514
# Epoch 108/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.2635 - val_loss: 2.5707
#
# Epoch 00108: val_loss did not improve from 2.56120
# F1 score: 0.5010314479608923
# Epoch 109/120
# 400/400 [==============================] - 230s 575ms/step - loss: 2.2731 - val_loss: 2.5675
#
# Epoch 00109: val_loss did not improve from 2.56120
# F1 score: 0.503647439710347
# Epoch 110/120
# 400/400 [==============================] - 229s 572ms/step - loss: 2.2640 - val_loss: 2.5720
#
# Epoch 00110: val_loss did not improve from 2.56120
# F1 score: 0.5052499132756085
# Epoch 111/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.2947 - val_loss: 2.6189
#
# Epoch 00111: val_loss did not improve from 2.56120
# F1 score: 0.4979047544034193
# Epoch 112/120
# 400/400 [==============================] - 231s 576ms/step - loss: 2.2538 - val_loss: 2.5830
#
# Epoch 00112: val_loss did not improve from 2.56120
# F1 score: 0.5048552128620041
# Epoch 113/120
# 400/400 [==============================] - 230s 576ms/step - loss: 2.2706 - val_loss: 2.5742
#
# Epoch 00113: val_loss did not improve from 2.56120
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# F1 score: 0.5137726472438879
# Epoch 114/120
# 400/400 [==============================] - 229s 571ms/step - loss: 2.2505 - val_loss: 2.5509
#
# Epoch 00114: val_loss improved from 2.56120 to 2.55094, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.5188126693589872
# Epoch 115/120
# 400/400 [==============================] - 228s 571ms/step - loss: 2.2420 - val_loss: 2.5402
#
# Epoch 00115: val_loss improved from 2.55094 to 2.54019, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_1.0_exp_6.h5
# F1 score: 0.5135267462155882
# Epoch 116/120
# 400/400 [==============================] - 229s 572ms/step - loss: 2.2418 - val_loss: 2.5561
#
# Epoch 00116: val_loss did not improve from 2.54019
# F1 score: 0.5094403919280944
# Epoch 117/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.2579 - val_loss: 2.5498
#
# Epoch 00117: val_loss did not improve from 2.54019
# F1 score: 0.5117173121408637
# Epoch 118/120
# 400/400 [==============================] - 230s 576ms/step - loss: 2.2418 - val_loss: 2.5531
#
# Epoch 00118: val_loss did not improve from 2.54019
# F1 score: 0.5050384542989613
# Epoch 119/120
# 400/400 [==============================] - 231s 577ms/step - loss: 2.2399 - val_loss: 2.5513
#
# Epoch 00119: val_loss did not improve from 2.54019
# F1 score: 0.5100892343876156
# Epoch 120/120
# 400/400 [==============================] - 229s 573ms/step - loss: 2.2126 - val_loss: 2.5575
#
# Epoch 00120: val_loss did not improve from 2.54019
# F1 score: 0.5255988474076062
#
# ---->Training model with alpha 1.0 and expansion 6 with cic
# Epoch 1/100
# 15/15 [==============================] - 70s 5s/step - loss: 3.1777 - val_loss: 2.9244
#
# Epoch 00001: val_loss improved from inf to 2.92438, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5478575968426521
# Improve F1 score from -inf to 0.5478575968426521
# Epoch 2/100
# 15/15 [==============================] - 59s 4s/step - loss: 2.8146 - val_loss: 2.8559
#
# Epoch 00002: val_loss improved from 2.92438 to 2.85589, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5563989373421043
# Improve F1 score from 0.5478575968426521 to 0.5563989373421043
# Epoch 3/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.6082 - val_loss: 2.8876
#
# Epoch 00003: val_loss did not improve from 2.85589
# F1 score: 0.5728350553149552
# Improve F1 score from 0.5563989373421043 to 0.5728350553149552
# Epoch 4/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.6439 - val_loss: 2.7554
#
# Epoch 00004: val_loss improved from 2.85589 to 2.75543, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.561647762016501
# Epoch 5/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.5396 - val_loss: 2.8501
#
# Epoch 00005: val_loss did not improve from 2.75543
# F1 score: 0.530697120559089
# Epoch 6/100
# 15/15 [==============================] - 67s 4s/step - loss: 2.4869 - val_loss: 2.9133
#
# Epoch 00006: val_loss did not improve from 2.75543
# F1 score: 0.5089616714449211
# Epoch 7/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.3970 - val_loss: 2.8306
#
# Epoch 00007: val_loss did not improve from 2.75543
# F1 score: 0.5537440520591304
# Epoch 8/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.3255 - val_loss: 2.8328
#
# Epoch 00008: val_loss did not improve from 2.75543
# F1 score: 0.5455209414338056
# Epoch 9/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.1315 - val_loss: 2.7274
#
# Epoch 00009: val_loss improved from 2.75543 to 2.72740, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5586887689172412
# Epoch 10/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.4114 - val_loss: 2.5756
#
# Epoch 00010: val_loss improved from 2.72740 to 2.57560, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5740653637839099
# Improve F1 score from 0.5728350553149552 to 0.5740653637839099
# Epoch 11/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.1983 - val_loss: 2.6256
#
# Epoch 00011: val_loss did not improve from 2.57560
# F1 score: 0.5507489940860109
# Epoch 12/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.3312 - val_loss: 2.7310
#
# Epoch 00012: val_loss did not improve from 2.57560
# F1 score: 0.5290562865006505
# Epoch 13/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.2627 - val_loss: 2.8190
#
# Epoch 00013: val_loss did not improve from 2.57560
# F1 score: 0.4982981974046557
# Epoch 14/100
# 15/15 [==============================] - 61s 4s/step - loss: 2.1368 - val_loss: 2.9679
#
# Epoch 00014: val_loss did not improve from 2.57560
# F1 score: 0.4928192740629268
# Epoch 15/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.3231 - val_loss: 2.9678
#
# Epoch 00015: val_loss did not improve from 2.57560
# F1 score: 0.512180394941582
# Epoch 16/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.1377 - val_loss: 3.0289
#
# Epoch 00016: val_loss did not improve from 2.57560
# F1 score: 0.5157524515201017
# Epoch 17/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.1680 - val_loss: 3.0202
#
# Epoch 00017: val_loss did not improve from 2.57560
# F1 score: 0.49914893840632213
# Epoch 18/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.1216 - val_loss: 2.7468
#
# Epoch 00018: val_loss did not improve from 2.57560
# F1 score: 0.5483337690646347
# Epoch 19/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.0566 - val_loss: 2.6568
#
# Epoch 00019: val_loss did not improve from 2.57560
# F1 score: 0.5672933686614816
# Epoch 20/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.1421 - val_loss: 2.7734
#
# Epoch 00020: val_loss did not improve from 2.57560
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# F1 score: 0.5347338130626849
# Epoch 21/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.1616 - val_loss: 2.7662
#
# Epoch 00021: val_loss did not improve from 2.57560
# F1 score: 0.5374404049649831
# Epoch 22/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.0232 - val_loss: 2.8640
#
# Epoch 00022: val_loss did not improve from 2.57560
# F1 score: 0.5273937907687434
# Epoch 23/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.0470 - val_loss: 3.0272
#
# Epoch 00023: val_loss did not improve from 2.57560
# F1 score: 0.5045420201931667
# Epoch 24/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.0323 - val_loss: 2.9831
#
# Epoch 00024: val_loss did not improve from 2.57560
# F1 score: 0.5112462958926957
# Epoch 25/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.9208 - val_loss: 2.9969
#
# Epoch 00025: val_loss did not improve from 2.57560
# F1 score: 0.5138248547045288
# Epoch 26/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.8315 - val_loss: 2.9549
#
# Epoch 00026: val_loss did not improve from 2.57560
# F1 score: 0.5068852758142831
# Epoch 27/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.8953 - val_loss: 2.9463
#
# Epoch 00027: val_loss did not improve from 2.57560
# F1 score: 0.5140767869636838
# Epoch 28/100
# 15/15 [==============================] - 60s 4s/step - loss: 1.9029 - val_loss: 2.7977
#
# Epoch 00028: val_loss did not improve from 2.57560
# F1 score: 0.5205008272990759
# Epoch 29/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.9416 - val_loss: 2.9123
#
# Epoch 00029: val_loss did not improve from 2.57560
# F1 score: 0.5042554063960275
# Epoch 30/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.9111 - val_loss: 2.8763
#
# Epoch 00030: val_loss did not improve from 2.57560
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# F1 score: 0.5098331002367593
# Epoch 31/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.9612 - val_loss: 2.8616
#
# Epoch 00031: val_loss did not improve from 2.57560
# F1 score: 0.5349644655072169
# Epoch 32/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.8675 - val_loss: 2.8398
#
# Epoch 00032: val_loss did not improve from 2.57560
# F1 score: 0.5342108409677128
# Epoch 33/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.7991 - val_loss: 2.8112
#
# Epoch 00033: val_loss did not improve from 2.57560
# F1 score: 0.5330941979161062
# Epoch 34/100
# 15/15 [==============================] - 67s 4s/step - loss: 1.9924 - val_loss: 2.8081
#
# Epoch 00034: val_loss did not improve from 2.57560
# F1 score: 0.5239202740733008
# Epoch 35/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.9216 - val_loss: 2.8130
#
# Epoch 00035: val_loss did not improve from 2.57560
# F1 score: 0.5438249886272607
# Epoch 36/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.9360 - val_loss: 2.7662
#
# Epoch 00036: val_loss did not improve from 2.57560
# F1 score: 0.543262674044684
# Epoch 37/100
# 15/15 [==============================] - 60s 4s/step - loss: 1.8453 - val_loss: 2.8183
#
# Epoch 00037: val_loss did not improve from 2.57560
# F1 score: 0.5428156726667585
# Epoch 38/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.8844 - val_loss: 2.8155
#
# Epoch 00038: val_loss did not improve from 2.57560
# F1 score: 0.5490133797747612
# Epoch 39/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.8179 - val_loss: 2.8306
#
# Epoch 00039: val_loss did not improve from 2.57560
# F1 score: 0.550382200276198
# Epoch 40/100
# 15/15 [==============================] - 66s 4s/step - loss: 1.7473 - val_loss: 2.8412
#
# Epoch 00040: val_loss did not improve from 2.57560
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# F1 score: 0.5544584313139667
# Epoch 41/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7430 - val_loss: 2.8180
#
# Epoch 00041: val_loss did not improve from 2.57560
# F1 score: 0.5578147529255411
# Epoch 42/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.7969 - val_loss: 2.7365
#
# Epoch 00042: val_loss did not improve from 2.57560
# F1 score: 0.5637253776318557
# Epoch 43/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.8557 - val_loss: 2.7377
#
# Epoch 00043: val_loss did not improve from 2.57560
# F1 score: 0.5665069953370033
# Epoch 44/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.8187 - val_loss: 2.6888
#
# Epoch 00044: val_loss did not improve from 2.57560
# F1 score: 0.5715305125359464
# Epoch 45/100
# 15/15 [==============================] - 60s 4s/step - loss: 1.8154 - val_loss: 2.6674
#
# Epoch 00045: val_loss did not improve from 2.57560
# F1 score: 0.5718133581045668
# Epoch 46/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7837 - val_loss: 2.6702
#
# Epoch 00046: val_loss did not improve from 2.57560
# F1 score: 0.5789043037582032
# Improve F1 score from 0.5740653637839099 to 0.5789043037582032
# Epoch 47/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.9160 - val_loss: 2.6771
#
# Epoch 00047: val_loss did not improve from 2.57560
# F1 score: 0.572248341847044
# Epoch 48/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.9101 - val_loss: 2.6134
#
# Epoch 00048: val_loss did not improve from 2.57560
# F1 score: 0.5820192395591899
# Improve F1 score from 0.5789043037582032 to 0.5820192395591899
# Epoch 49/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7691 - val_loss: 2.6482
#
# Epoch 00049: val_loss did not improve from 2.57560
# F1 score: 0.5766782415255878
# Epoch 50/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7970 - val_loss: 2.5971
#
# Epoch 00050: val_loss did not improve from 2.57560
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# F1 score: 0.5778340961499397
# Epoch 51/100
# 15/15 [==============================] - 66s 4s/step - loss: 1.7713 - val_loss: 2.6037
#
# Epoch 00051: val_loss did not improve from 2.57560
# F1 score: 0.5790052532170261
# Epoch 52/100
# 15/15 [==============================] - 66s 4s/step - loss: 1.8157 - val_loss: 2.5976
#
# Epoch 00052: val_loss did not improve from 2.57560
# F1 score: 0.5810019690473553
# Epoch 53/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.8310 - val_loss: 2.5963
#
# Epoch 00053: val_loss did not improve from 2.57560
# F1 score: 0.5822125528612845
# Improve F1 score from 0.5820192395591899 to 0.5822125528612845
# Epoch 54/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8110 - val_loss: 2.5755
#
# Epoch 00054: val_loss improved from 2.57560 to 2.57553, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5793236812568868
# Epoch 55/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.8745 - val_loss: 2.5483
#
# Epoch 00055: val_loss improved from 2.57553 to 2.54825, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5804685565343364
# Epoch 56/100
# 15/15 [==============================] - 60s 4s/step - loss: 1.7899 - val_loss: 2.5479
#
# Epoch 00056: val_loss improved from 2.54825 to 2.54792, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5789170060083517
# Epoch 57/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.7015 - val_loss: 2.5560
#
# Epoch 00057: val_loss did not improve from 2.54792
# F1 score: 0.5824564279227439
# Improve F1 score from 0.5822125528612845 to 0.5824564279227439
# Epoch 58/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.7475 - val_loss: 2.5037
#
# Epoch 00058: val_loss improved from 2.54792 to 2.50367, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5833446313311368
# Improve F1 score from 0.5824564279227439 to 0.5833446313311368
# Epoch 59/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7772 - val_loss: 2.4851
#
# Epoch 00059: val_loss improved from 2.50367 to 2.48508, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5836355774542161
# Improve F1 score from 0.5833446313311368 to 0.5836355774542161
# Epoch 60/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.8231 - val_loss: 2.5147
#
# Epoch 00060: val_loss did not improve from 2.48508
# F1 score: 0.5822024501100481
# Epoch 61/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8290 - val_loss: 2.4669
#
# Epoch 00061: val_loss improved from 2.48508 to 2.46685, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5838401145012365
# Improve F1 score from 0.5836355774542161 to 0.5838401145012365
# Epoch 62/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.7148 - val_loss: 2.4320
#
# Epoch 00062: val_loss improved from 2.46685 to 2.43197, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5933600854731004
# Improve F1 score from 0.5838401145012365 to 0.5933600854731004
# Epoch 63/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.7649 - val_loss: 2.4259
#
# Epoch 00063: val_loss improved from 2.43197 to 2.42593, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5948345477368924
# Improve F1 score from 0.5933600854731004 to 0.5948345477368924
# Epoch 64/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.7735 - val_loss: 2.4233
#
# Epoch 00064: val_loss improved from 2.42593 to 2.42329, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5924302111784585
# Epoch 65/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.7404 - val_loss: 2.4137
#
# Epoch 00065: val_loss improved from 2.42329 to 2.41367, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5926057537354851
# Epoch 66/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.7737 - val_loss: 2.3981
#
# Epoch 00066: val_loss improved from 2.41367 to 2.39805, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5925863815599399
# Epoch 67/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.7434 - val_loss: 2.3848
#
# Epoch 00067: val_loss improved from 2.39805 to 2.38479, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.5995360480893487
# Improve F1 score from 0.5948345477368924 to 0.5995360480893487
# Epoch 68/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.8094 - val_loss: 2.3730
#
# Epoch 00068: val_loss improved from 2.38479 to 2.37298, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.6028496880815833
# Improve F1 score from 0.5995360480893487 to 0.6028496880815833
# Epoch 69/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.6789 - val_loss: 2.3519
#
# Epoch 00069: val_loss improved from 2.37298 to 2.35190, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.6083852627765785
# Improve F1 score from 0.6028496880815833 to 0.6083852627765785
# Epoch 70/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.7248 - val_loss: 2.3704
#
# Epoch 00070: val_loss did not improve from 2.35190
# F1 score: 0.6079313209719985
# Epoch 71/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.7088 - val_loss: 2.3861
#
# Epoch 00071: val_loss did not improve from 2.35190
# F1 score: 0.6053718729397904
# Epoch 72/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.9128 - val_loss: 2.3935
#
# Epoch 00072: val_loss did not improve from 2.35190
# F1 score: 0.605688181509001
# Epoch 73/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.6947 - val_loss: 2.3564
#
# Epoch 00073: val_loss did not improve from 2.35190
# F1 score: 0.6066855360617219
# Epoch 74/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.7875 - val_loss: 2.3071
#
# Epoch 00074: val_loss improved from 2.35190 to 2.30710, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.6101323933006808
# Improve F1 score from 0.6083852627765785 to 0.6101323933006808
# Epoch 75/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8172 - val_loss: 2.3203
#
# Epoch 00075: val_loss did not improve from 2.30710
# F1 score: 0.6131463603058868
# Improve F1 score from 0.6101323933006808 to 0.6131463603058868
# Epoch 76/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.8224 - val_loss: 2.2982
#
# Epoch 00076: val_loss improved from 2.30710 to 2.29824, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.61035271910349
# Epoch 77/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.8537 - val_loss: 2.2747
#
# Epoch 00077: val_loss improved from 2.29824 to 2.27475, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.6115985764108851
# Epoch 78/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.8104 - val_loss: 2.2944
#
# Epoch 00078: val_loss did not improve from 2.27475
# F1 score: 0.6108368785664112
# Epoch 79/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7471 - val_loss: 2.2951
#
# Epoch 00079: val_loss did not improve from 2.27475
# F1 score: 0.6121563133268759
# Epoch 80/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7590 - val_loss: 2.2983
#
# Epoch 00080: val_loss did not improve from 2.27475
# F1 score: 0.6110940791555645
# Epoch 81/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8703 - val_loss: 2.3070
#
# Epoch 00081: val_loss did not improve from 2.27475
# F1 score: 0.6119005746300383
# Epoch 82/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.6925 - val_loss: 2.2971
#
# Epoch 00082: val_loss did not improve from 2.27475
# F1 score: 0.6137798195747088
# Improve F1 score from 0.6131463603058868 to 0.6137798195747088
# Epoch 83/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8389 - val_loss: 2.2603
#
# Epoch 00083: val_loss improved from 2.27475 to 2.26035, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.6162375236964026
# Improve F1 score from 0.6137798195747088 to 0.6162375236964026
# Epoch 84/100
# 15/15 [==============================] - 58s 4s/step - loss: 1.7680 - val_loss: 2.3163
#
# Epoch 00084: val_loss did not improve from 2.26035
# F1 score: 0.6103054632532019
# Epoch 85/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7340 - val_loss: 2.3041
#
# Epoch 00085: val_loss did not improve from 2.26035
# F1 score: 0.6110483183877974
# Epoch 86/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.7399 - val_loss: 2.2682
#
# Epoch 00086: val_loss did not improve from 2.26035
# F1 score: 0.6236577642168608
# Improve F1 score from 0.6162375236964026 to 0.6236577642168608
# Epoch 87/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.7662 - val_loss: 2.2545
#
# Epoch 00087: val_loss improved from 2.26035 to 2.25455, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.6304641180052509
# Improve F1 score from 0.6236577642168608 to 0.6304641180052509
# Epoch 88/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7696 - val_loss: 2.2343
#
# Epoch 00088: val_loss improved from 2.25455 to 2.23434, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.6246312533029131
# Epoch 89/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.6902 - val_loss: 2.2621
#
# Epoch 00089: val_loss did not improve from 2.23434
# F1 score: 0.62388897135117
# Epoch 90/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7128 - val_loss: 2.2486
#
# Epoch 00090: val_loss did not improve from 2.23434
# F1 score: 0.6263349523958173
# Epoch 91/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7783 - val_loss: 2.2478
#
# Epoch 00091: val_loss did not improve from 2.23434
# F1 score: 0.6310969692824518
# Improve F1 score from 0.6304641180052509 to 0.6310969692824518
# Epoch 92/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7686 - val_loss: 2.2443
#
# Epoch 00092: val_loss did not improve from 2.23434
# F1 score: 0.6364398428860596
# Improve F1 score from 0.6310969692824518 to 0.6364398428860596
# Epoch 93/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.6970 - val_loss: 2.2373
#
# Epoch 00093: val_loss did not improve from 2.23434
# F1 score: 0.6324042161268687
# Epoch 94/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.7504 - val_loss: 2.2266
#
# Epoch 00094: val_loss improved from 2.23434 to 2.22658, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.6384781801075575
# Improve F1 score from 0.6364398428860596 to 0.6384781801075575
# Epoch 95/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.8451 - val_loss: 2.2463
#
# Epoch 00095: val_loss did not improve from 2.22658
# F1 score: 0.6365558224181445
# Epoch 96/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8045 - val_loss: 2.2321
# Epoch 00096: val_loss did not improve from 2.22658
# F1 score: 0.6324781488782408
# Epoch 97/100
# 15/15 [==============================] - 68s 5s/step - loss: 1.6953 - val_loss: 2.2640
#
# Epoch 00097: val_loss did not improve from 2.22658
# F1 score: 0.62374436331122
# Epoch 98/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.7835 - val_loss: 2.1928
#
# Epoch 00098: val_loss improved from 2.22658 to 2.19279, saving model to /home/aldo/Documents/weights/models/tradeoff/ssdlite320_mobilenetv2_pascal_cic_1.0_exp_6.h5
# F1 score: 0.6479149510645251
# Improve F1 score from 0.6384781801075575 to 0.6479149510645251
# Epoch 99/100
# 15/15 [==============================] - 66s 4s/step - loss: 1.7680 - val_loss: 2.2173
#
# Epoch 00099: val_loss did not improve from 2.19279
# F1 score: 0.6455255395702816
# Epoch 100/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8131 - val_loss: 2.2194
#
# Epoch 00100: val_loss did not improve from 2.19279
# F1 score: 0.64575254282842
