# %% [markdown]
# # Optimization IOU and Confidence over SSD300

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import time
import json
import os.path

from keras import backend as K
from keras.models import load_model
from keras.preprocessing import image
from keras.optimizers import Adam
from imageio import imread
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D

from models.keras_ssd300 import ssd_300
from models.keras_ssd512 import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

from extra_files import helper

# %matplotlib inline

# %% [markdown]
# ## 1. Load a trained SSD

# %% [markdown]
# ### Build the model and load trained weights into it wih parameters confidence and iou threshold

# %%
def load_model(model_path, confidence_thresh, iou_threshold):
    '''
    model_path: path to the weight's model
    conficence_thresh: confidence threshold needed to keep a predition
    iou: iou threshold to remove multiple bounding boxes
    return keras model
    '''
    # 1: Build the Keras model
    K.clear_session() # Clear previous models from memory.

    model = ssd_300(image_size=(300, 300, 3),
                    n_classes=20,
                    mode='inference',
                    l2_regularization=0.0005,
                    scales=[0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05], # The scales for MS COCO are [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05]
                    aspect_ratios_per_layer=[[1.0, 2.0, 0.5],
                                             [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                             [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                             [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                             [1.0, 2.0, 0.5],
                                             [1.0, 2.0, 0.5]],
                    two_boxes_for_ar1=True,
                    steps=[8, 16, 32, 64, 100, 300],
                    offsets=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
                    clip_boxes=False,
                    variances=[0.1, 0.1, 0.2, 0.2],
                    normalize_coords=True,
                    subtract_mean=[123, 117, 104],
                    swap_channels=[2, 1, 0],
                    confidence_thresh=confidence_thresh,
                    iou_threshold=iou_threshold,
                    top_k=9000,
                    nms_max_output_size=9000)

    # 2: Load the trained weights into the model.
    # TODO: Set the path of the trained weights.
    model.load_weights(model_path, by_name=True)

    # 3: Compile the model so that Keras won't complain the next time you load it.

    adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

    ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

    model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
    
    return model

# %% [markdown]
#   ## 2. Load Images
#
# Load some images for which you'd like the model to make predictions.

# %%
path_root = '/home/aldopedraza/Documentos/data-cic/preprocess_data'
path_save = path_root + '/predictions/'
train_img = np.load(path_root + '/images_train_300x300.npy')

# %% [markdown]
# ## 3. Make predictions

# %%
model_pascal_voc_07_plus_12_300x300 = '../weights/pascal_voc/pascal_voc_07_plus_12_300x300.h5'

# %%
def get_predictions(path_model, batch_size, images_list, confidence, iou):
    '''
    Make predictions from a model
    path_model: the path to the weights' model
    batch_size: size of the batch
    images_list: list of images to make predictions
    confidence: confidence threshold
    iou: iou threshold
    return predictions
    '''
    # Create variable to store predictions
    predictions = np.zeros(shape=(1, 9000, 6))
    
    model = load_model(path_model, confidence, iou)

    for batch in helper.get_batch(batch_size, images_list):
        predictions = np.append(predictions, model.predict(batch), axis=0)
    predictions = predictions[1:] # delete empty item

    clean_pre = helper.clean_predictions(predictions)
    adjust_pre = helper.adjust_predictions(clean_pre)
    K.clear_session()
    return adjust_pre

# %%
# Make predictions of the models
# 07++12
predictions_list = []
confidence_list = np.arange(0.0, 1.05, 0.05)
iou_list= np.arange(0.0, 1.05, 0.05)

columns = ['Conficence', 'IOU', 'Predictions']

for conf in confidence_list:
    for iou in iou_list:
        print('Predictions with confidence: ', conf, ' iou: ', iou)
        start = time.time()

        pred = get_predictions(model_pascal_voc_07_plus_12_300x300, 8, train_img, conf.item(), iou.item())
        predictions_list.append([conf, iou, pred])
        
        end = time.time()
        print(round(end - start, 4))

predictions_list = np.array(predictions_list)

# Create DataFrame with all predictions
pred_data = pd.DataFrame(predictions_list, columns=columns)
pred_data.to_csv(path_save + 'optimization_pred.csv')
# Out:
# Predictions with confidence:  0.0  iou:  0.0
# 10.8492
# Predictions with confidence:  0.0  iou:  0.05
# 10.7386
# Predictions with confidence:  0.0  iou:  0.1
# 10.9561
# Predictions with confidence:  0.0  iou:  0.15000000000000002
# 11.0223
# Predictions with confidence:  0.0  iou:  0.2
# 11.2622
# Predictions with confidence:  0.0  iou:  0.25
# 11.5953
# Predictions with confidence:  0.0  iou:  0.30000000000000004
# 12.0215
# Predictions with confidence:  0.0  iou:  0.35000000000000003
# 12.4786
# Predictions with confidence:  0.0  iou:  0.4
# 13.5436
# Predictions with confidence:  0.0  iou:  0.45
# 14.4861
# Predictions with confidence:  0.0  iou:  0.5
# 15.9266
# Predictions with confidence:  0.0  iou:  0.55
# 17.7832
# Predictions with confidence:  0.0  iou:  0.6000000000000001
# 21.0987
# Predictions with confidence:  0.0  iou:  0.65
# 25.1975
# Predictions with confidence:  0.0  iou:  0.7000000000000001
# 30.3437
# Predictions with confidence:  0.0  iou:  0.75
# 36.0038
# Predictions with confidence:  0.0  iou:  0.8
# 39.2485
# Predictions with confidence:  0.0  iou:  0.8500000000000001
# 41.4627
# Predictions with confidence:  0.0  iou:  0.9
# 41.8126
# Predictions with confidence:  0.0  iou:  0.9500000000000001
# 51.8259
# Predictions with confidence:  0.0  iou:  1.0
# 61.1019
# Predictions with confidence:  0.05  iou:  0.0
# 17.1056
# Predictions with confidence:  0.05  iou:  0.05
# 10.472
# Predictions with confidence:  0.05  iou:  0.1
# 10.7627
# Predictions with confidence:  0.05  iou:  0.15000000000000002
# 10.4146
# Predictions with confidence:  0.05  iou:  0.2
# 10.7255
# Predictions with confidence:  0.05  iou:  0.25
# 10.4418
# Predictions with confidence:  0.05  iou:  0.30000000000000004
# 10.5515
# Predictions with confidence:  0.05  iou:  0.35000000000000003
# 10.874
# Predictions with confidence:  0.05  iou:  0.4
# 10.5753
# Predictions with confidence:  0.05  iou:  0.45
# 10.7473
# Predictions with confidence:  0.05  iou:  0.5
# 10.4952
# Predictions with confidence:  0.05  iou:  0.55
# 10.5316
# Predictions with confidence:  0.05  iou:  0.6000000000000001
# 10.672
# Predictions with confidence:  0.05  iou:  0.65
# 10.5463
# Predictions with confidence:  0.05  iou:  0.7000000000000001
# 10.8149
# Predictions with confidence:  0.05  iou:  0.75
# 10.4874
# Predictions with confidence:  0.05  iou:  0.8
# 10.4758
# Predictions with confidence:  0.05  iou:  0.8500000000000001
# 10.7383
# Predictions with confidence:  0.05  iou:  0.9
# 10.6388
# Predictions with confidence:  0.05  iou:  0.9500000000000001
# 10.8425
# Predictions with confidence:  0.05  iou:  1.0
# 10.5777
# Predictions with confidence:  0.1  iou:  0.0
# 10.5879
# Predictions with confidence:  0.1  iou:  0.05
# 10.8408
# Predictions with confidence:  0.1  iou:  0.1
# 10.6578
# Predictions with confidence:  0.1  iou:  0.15000000000000002
# 10.7651
# Predictions with confidence:  0.1  iou:  0.2
# 10.6742
# Predictions with confidence:  0.1  iou:  0.25
# 10.5649
# Predictions with confidence:  0.1  iou:  0.30000000000000004
# 10.807
# Predictions with confidence:  0.1  iou:  0.35000000000000003
# 10.5076
# Predictions with confidence:  0.1  iou:  0.4
# 10.882
# Predictions with confidence:  0.1  iou:  0.45
# 10.7166
# Predictions with confidence:  0.1  iou:  0.5
# 10.8792
# Predictions with confidence:  0.1  iou:  0.55
# 10.6128
# Predictions with confidence:  0.1  iou:  0.6000000000000001
# 10.6356
# Predictions with confidence:  0.1  iou:  0.65
# 10.8856
# Predictions with confidence:  0.1  iou:  0.7000000000000001
# 10.6071
# Predictions with confidence:  0.1  iou:  0.75
# 10.8596
# Predictions with confidence:  0.1  iou:  0.8
# 10.5718
# Predictions with confidence:  0.1  iou:  0.8500000000000001
# 10.5824
# Predictions with confidence:  0.1  iou:  0.9
# 10.8749
# Predictions with confidence:  0.1  iou:  0.9500000000000001
# 10.6635
# Predictions with confidence:  0.1  iou:  1.0
# 10.8998
# Predictions with confidence:  0.15000000000000002  iou:  0.0
# 10.691
# Predictions with confidence:  0.15000000000000002  iou:  0.05
# 10.5692
# Predictions with confidence:  0.15000000000000002  iou:  0.1
# 10.9771
# Predictions with confidence:  0.15000000000000002  iou:  0.15000000000000002
# 10.7024
# Predictions with confidence:  0.15000000000000002  iou:  0.2
# 10.842
# Predictions with confidence:  0.15000000000000002  iou:  0.25
# 10.6917
# Predictions with confidence:  0.15000000000000002  iou:  0.30000000000000004
# 10.6288
# Predictions with confidence:  0.15000000000000002  iou:  0.35000000000000003
# 10.8753
# Predictions with confidence:  0.15000000000000002  iou:  0.4
# 10.7189
# Predictions with confidence:  0.15000000000000002  iou:  0.45
# 10.9415
# Predictions with confidence:  0.15000000000000002  iou:  0.5
# 10.7891
# Predictions with confidence:  0.15000000000000002  iou:  0.55
# 10.716
# Predictions with confidence:  0.15000000000000002  iou:  0.6000000000000001
# 10.8832
# Predictions with confidence:  0.15000000000000002  iou:  0.65
# 10.6849
# Predictions with confidence:  0.15000000000000002  iou:  0.7000000000000001
# 10.974
# Predictions with confidence:  0.15000000000000002  iou:  0.75
# 10.6698
# Predictions with confidence:  0.15000000000000002  iou:  0.8
# 10.7817
# Predictions with confidence:  0.15000000000000002  iou:  0.8500000000000001
# 11.0708
# Predictions with confidence:  0.15000000000000002  iou:  0.9
# 10.7858
# Predictions with confidence:  0.15000000000000002  iou:  0.9500000000000001
# 10.9248
# Predictions with confidence:  0.15000000000000002  iou:  1.0
# 10.7378
# Predictions with confidence:  0.2  iou:  0.0
# 10.6756
# Predictions with confidence:  0.2  iou:  0.05
# 10.9915
# Predictions with confidence:  0.2  iou:  0.1
# 10.7131
# Predictions with confidence:  0.2  iou:  0.15000000000000002
# 10.8829
# Predictions with confidence:  0.2  iou:  0.2
# 10.7814
# Predictions with confidence:  0.2  iou:  0.25
# 10.7357
# Predictions with confidence:  0.2  iou:  0.30000000000000004
# 10.9589
# Predictions with confidence:  0.2  iou:  0.35000000000000003
# 10.8546
# Predictions with confidence:  0.2  iou:  0.4
# 10.8573
# Predictions with confidence:  0.2  iou:  0.45
# 10.6777
# Predictions with confidence:  0.2  iou:  0.5
# 10.7584
# Predictions with confidence:  0.2  iou:  0.55
# 11.0087
# Predictions with confidence:  0.2  iou:  0.6000000000000001
# 10.7222
# Predictions with confidence:  0.2  iou:  0.65
# 10.9282
# Predictions with confidence:  0.2  iou:  0.7000000000000001
# 10.7376
# Predictions with confidence:  0.2  iou:  0.75
# 10.7852
# Predictions with confidence:  0.2  iou:  0.8
# 10.9332
# Predictions with confidence:  0.2  iou:  0.8500000000000001
# 10.7782
# Predictions with confidence:  0.2  iou:  0.9
# 10.9861
# Predictions with confidence:  0.2  iou:  0.9500000000000001
# 10.7553
# Predictions with confidence:  0.2  iou:  1.0
# 11.0232
# Predictions with confidence:  0.25  iou:  0.0
# 10.7583
# Predictions with confidence:  0.25  iou:  0.05
# 10.7249
# Predictions with confidence:  0.25  iou:  0.1
# 10.9537
# Predictions with confidence:  0.25  iou:  0.15000000000000002
# 10.6973
# Predictions with confidence:  0.25  iou:  0.2
# 10.887
# Predictions with confidence:  0.25  iou:  0.25
# 10.7243
# Predictions with confidence:  0.25  iou:  0.30000000000000004
# 10.7111
# Predictions with confidence:  0.25  iou:  0.35000000000000003
# 11.0107
# Predictions with confidence:  0.25  iou:  0.4
# 10.8423
# Predictions with confidence:  0.25  iou:  0.45
# 10.998
# Predictions with confidence:  0.25  iou:  0.5
# 10.7957
# Predictions with confidence:  0.25  iou:  0.55
# 10.7599
# Predictions with confidence:  0.25  iou:  0.6000000000000001
# 10.9388
# Predictions with confidence:  0.25  iou:  0.65
# 10.7652
# Predictions with confidence:  0.25  iou:  0.7000000000000001
# 10.9844
# Predictions with confidence:  0.25  iou:  0.75
# 10.7792
# Predictions with confidence:  0.25  iou:  0.8
# 10.7201
# Predictions with confidence:  0.25  iou:  0.8500000000000001
# 10.9551
# Predictions with confidence:  0.25  iou:  0.9
# 10.8307
# Predictions with confidence:  0.25  iou:  0.9500000000000001
# 11.0277
# Predictions with confidence:  0.25  iou:  1.0
# 10.9031
# Predictions with confidence:  0.30000000000000004  iou:  0.0
# 10.7305
# Predictions with confidence:  0.30000000000000004  iou:  0.05
# 10.9981
# Predictions with confidence:  0.30000000000000004  iou:  0.1
# 10.6944
# Predictions with confidence:  0.30000000000000004  iou:  0.15000000000000002
# 11.0365
# Predictions with confidence:  0.30000000000000004  iou:  0.2
# 10.8193
# Predictions with confidence:  0.30000000000000004  iou:  0.25
# 10.7474
# Predictions with confidence:  0.30000000000000004  iou:  0.30000000000000004
# 11.0073
# Predictions with confidence:  0.30000000000000004  iou:  0.35000000000000003
# 10.7853
# Predictions with confidence:  0.30000000000000004  iou:  0.4
# 11.0121
# Predictions with confidence:  0.30000000000000004  iou:  0.45
# 10.9207
# Predictions with confidence:  0.30000000000000004  iou:  0.5
# 10.7337
# Predictions with confidence:  0.30000000000000004  iou:  0.55
# 10.9837
# Predictions with confidence:  0.30000000000000004  iou:  0.6000000000000001
# 10.7977
# Predictions with confidence:  0.30000000000000004  iou:  0.65
# 11.055
# Predictions with confidence:  0.30000000000000004  iou:  0.7000000000000001
# 10.8119
# Predictions with confidence:  0.30000000000000004  iou:  0.75
# 10.768
# Predictions with confidence:  0.30000000000000004  iou:  0.8
# 11.0575
# Predictions with confidence:  0.30000000000000004  iou:  0.8500000000000001
# 10.8315
# Predictions with confidence:  0.30000000000000004  iou:  0.9
# 11.0939
# Predictions with confidence:  0.30000000000000004  iou:  0.9500000000000001
# 10.8496
# Predictions with confidence:  0.30000000000000004  iou:  1.0
# 10.8835
# Predictions with confidence:  0.35000000000000003  iou:  0.0
# 11.0702
# Predictions with confidence:  0.35000000000000003  iou:  0.05
# 10.7876
# Predictions with confidence:  0.35000000000000003  iou:  0.1
# 11.0473
# Predictions with confidence:  0.35000000000000003  iou:  0.15000000000000002
# 10.9168
# Predictions with confidence:  0.35000000000000003  iou:  0.2
# 10.8513
# Predictions with confidence:  0.35000000000000003  iou:  0.25
# 11.0983
# Predictions with confidence:  0.35000000000000003  iou:  0.30000000000000004
# 10.8922
# Predictions with confidence:  0.35000000000000003  iou:  0.35000000000000003
# 11.0703
# Predictions with confidence:  0.35000000000000003  iou:  0.4
# 10.9739
# Predictions with confidence:  0.35000000000000003  iou:  0.45
# 10.7578
# Predictions with confidence:  0.35000000000000003  iou:  0.5
# 11.0594
# Predictions with confidence:  0.35000000000000003  iou:  0.55
# 11.2166
# Predictions with confidence:  0.35000000000000003  iou:  0.6000000000000001
# 11.1226
# Predictions with confidence:  0.35000000000000003  iou:  0.65
# 10.8623
# Predictions with confidence:  0.35000000000000003  iou:  0.7000000000000001
# 10.8739
# Predictions with confidence:  0.35000000000000003  iou:  0.75
# 11.2588
# Predictions with confidence:  0.35000000000000003  iou:  0.8
# 10.7816
# Predictions with confidence:  0.35000000000000003  iou:  0.8500000000000001
# 10.7976
# Predictions with confidence:  0.35000000000000003  iou:  0.9
# 11.0791
# Predictions with confidence:  0.35000000000000003  iou:  0.9500000000000001
# 10.8587
# Predictions with confidence:  0.35000000000000003  iou:  1.0
# 11.2103
# Predictions with confidence:  0.4  iou:  0.0
# 10.9105
# Predictions with confidence:  0.4  iou:  0.05
# 10.8487
# Predictions with confidence:  0.4  iou:  0.1
# 11.1157
# Predictions with confidence:  0.4  iou:  0.15000000000000002
# 10.896
# Predictions with confidence:  0.4  iou:  0.2
# 11.119
# Predictions with confidence:  0.4  iou:  0.25
# 10.8833
# Predictions with confidence:  0.4  iou:  0.30000000000000004
# 10.8043
# Predictions with confidence:  0.4  iou:  0.35000000000000003
# 11.1434
# Predictions with confidence:  0.4  iou:  0.4
# 10.823
# Predictions with confidence:  0.4  iou:  0.45
# 10.8574
# Predictions with confidence:  0.4  iou:  0.5
# 11.0527
# Predictions with confidence:  0.4  iou:  0.55
# 10.8567
# Predictions with confidence:  0.4  iou:  0.6000000000000001
# 11.2099
# Predictions with confidence:  0.4  iou:  0.65
# 10.8842
# Predictions with confidence:  0.4  iou:  0.7000000000000001
# 10.7911
# Predictions with confidence:  0.4  iou:  0.75
# 11.0795
# Predictions with confidence:  0.4  iou:  0.8
# 10.9024
# Predictions with confidence:  0.4  iou:  0.8500000000000001
# 10.9139
# Predictions with confidence:  0.4  iou:  0.9
# 11.0434
# Predictions with confidence:  0.4  iou:  0.9500000000000001
# 10.9887
# Predictions with confidence:  0.4  iou:  1.0
# 11.219
# Predictions with confidence:  0.45  iou:  0.0
# 10.8425
# Predictions with confidence:  0.45  iou:  0.05
# 11.1299
# Predictions with confidence:  0.45  iou:  0.1
# 10.8683
# Predictions with confidence:  0.45  iou:  0.15000000000000002
# 10.9887
# Predictions with confidence:  0.45  iou:  0.2
# 11.0847
# Predictions with confidence:  0.45  iou:  0.25
# 10.8967
# Predictions with confidence:  0.45  iou:  0.30000000000000004
# 11.0387
# Predictions with confidence:  0.45  iou:  0.35000000000000003
# 11.0776
# Predictions with confidence:  0.45  iou:  0.4
# 10.9349
# Predictions with confidence:  0.45  iou:  0.45
# 11.087
# Predictions with confidence:  0.45  iou:  0.5
# 10.949
# Predictions with confidence:  0.45  iou:  0.55
# 10.9193
# Predictions with confidence:  0.45  iou:  0.6000000000000001
# 11.132
# Predictions with confidence:  0.45  iou:  0.65
# 10.9391
# Predictions with confidence:  0.45  iou:  0.7000000000000001
# 10.9947
# Predictions with confidence:  0.45  iou:  0.75
# 11.085
# Predictions with confidence:  0.45  iou:  0.8
# 11.0133
# Predictions with confidence:  0.45  iou:  0.8500000000000001
# 11.1712
# Predictions with confidence:  0.45  iou:  0.9
# 10.9192
# Predictions with confidence:  0.45  iou:  0.9500000000000001
# 10.809
# Predictions with confidence:  0.45  iou:  1.0
# 11.1017
# Predictions with confidence:  0.5  iou:  0.0
# 11.079
# Predictions with confidence:  0.5  iou:  0.05
# 11.0526
# Predictions with confidence:  0.5  iou:  0.1
# 10.9067
# Predictions with confidence:  0.5  iou:  0.15000000000000002
# 10.8833
# Predictions with confidence:  0.5  iou:  0.2
# 11.2319
# Predictions with confidence:  0.5  iou:  0.25
# 10.9953
# Predictions with confidence:  0.5  iou:  0.30000000000000004
# 10.8798
# Predictions with confidence:  0.5  iou:  0.35000000000000003
# 11.1232
# Predictions with confidence:  0.5  iou:  0.4
# 10.953
# Predictions with confidence:  0.5  iou:  0.45
# 10.9028
# Predictions with confidence:  0.5  iou:  0.5
# 11.182
# Predictions with confidence:  0.5  iou:  0.55
# 10.9334
# Predictions with confidence:  0.5  iou:  0.6000000000000001
# 11.1402
# Predictions with confidence:  0.5  iou:  0.65
# 11.018
# Predictions with confidence:  0.5  iou:  0.7000000000000001
# 10.8672
# Predictions with confidence:  0.5  iou:  0.75
# 11.2428
# Predictions with confidence:  0.5  iou:  0.8
# 10.9515
# Predictions with confidence:  0.5  iou:  0.8500000000000001
# 10.9197
# Predictions with confidence:  0.5  iou:  0.9
# 11.1272
# Predictions with confidence:  0.5  iou:  0.9500000000000001
# 10.9524
# Predictions with confidence:  0.5  iou:  1.0
# 11.1604
# Predictions with confidence:  0.55  iou:  0.0
# 10.9533
# Predictions with confidence:  0.55  iou:  0.05
# 10.8461
# Predictions with confidence:  0.55  iou:  0.1
# 11.2008
# Predictions with confidence:  0.55  iou:  0.15000000000000002
# 10.9882
# Predictions with confidence:  0.55  iou:  0.2
# 10.8659
# Predictions with confidence:  0.55  iou:  0.25
# 11.101
# Predictions with confidence:  0.55  iou:  0.30000000000000004
# 10.9075
# Predictions with confidence:  0.55  iou:  0.35000000000000003
# 11.1257
# Predictions with confidence:  0.55  iou:  0.4
# 10.9902
# Predictions with confidence:  0.55  iou:  0.45
# 10.8763
# Predictions with confidence:  0.55  iou:  0.5
# 11.1162
# Predictions with confidence:  0.55  iou:  0.55
# 11.0266
# Predictions with confidence:  0.55  iou:  0.6000000000000001
# 10.8738
# Predictions with confidence:  0.55  iou:  0.65
# 11.1143
# Predictions with confidence:  0.55  iou:  0.7000000000000001
# 10.9742
# Predictions with confidence:  0.55  iou:  0.75
# 10.8589
# Predictions with confidence:  0.55  iou:  0.8
# 11.1398
# Predictions with confidence:  0.55  iou:  0.8500000000000001
# 10.9731
# Predictions with confidence:  0.55  iou:  0.9
# 10.8718
# Predictions with confidence:  0.55  iou:  0.9500000000000001
# 11.0953
# Predictions with confidence:  0.55  iou:  1.0
# 10.9769
# Predictions with confidence:  0.6000000000000001  iou:  0.0
# 11.0967
# Predictions with confidence:  0.6000000000000001  iou:  0.05
# 10.9731
# Predictions with confidence:  0.6000000000000001  iou:  0.1
# 10.9579
# Predictions with confidence:  0.6000000000000001  iou:  0.15000000000000002
# 11.1621
# Predictions with confidence:  0.6000000000000001  iou:  0.2
# 10.8709
# Predictions with confidence:  0.6000000000000001  iou:  0.25
# 10.9537
# Predictions with confidence:  0.6000000000000001  iou:  0.30000000000000004
# 11.0934
# Predictions with confidence:  0.6000000000000001  iou:  0.35000000000000003
# 10.9387
# Predictions with confidence:  0.6000000000000001  iou:  0.4
# 10.8937
# Predictions with confidence:  0.6000000000000001  iou:  0.45
# 11.1346
# Predictions with confidence:  0.6000000000000001  iou:  0.5
# 10.874
# Predictions with confidence:  0.6000000000000001  iou:  0.55
# 11.0865
# Predictions with confidence:  0.6000000000000001  iou:  0.6000000000000001
# 11.0675
# Predictions with confidence:  0.6000000000000001  iou:  0.65
# 10.9439
# Predictions with confidence:  0.6000000000000001  iou:  0.7000000000000001
# 11.2421
# Predictions with confidence:  0.6000000000000001  iou:  0.75
# 10.9421
# Predictions with confidence:  0.6000000000000001  iou:  0.8
# 10.9742
# Predictions with confidence:  0.6000000000000001  iou:  0.8500000000000001
# 11.2242
# Predictions with confidence:  0.6000000000000001  iou:  0.9
# 10.9669
# Predictions with confidence:  0.6000000000000001  iou:  0.9500000000000001
# 10.9748
# Predictions with confidence:  0.6000000000000001  iou:  1.0
# 11.1737
# Predictions with confidence:  0.65  iou:  0.0
# 10.9593
# Predictions with confidence:  0.65  iou:  0.05
# 10.9346
# Predictions with confidence:  0.65  iou:  0.1
# 11.2233
# Predictions with confidence:  0.65  iou:  0.15000000000000002
# 10.9248
# Predictions with confidence:  0.65  iou:  0.2
# 10.9768
# Predictions with confidence:  0.65  iou:  0.25
# 11.1966
# Predictions with confidence:  0.65  iou:  0.30000000000000004
# 10.8866
# Predictions with confidence:  0.65  iou:  0.35000000000000003
# 10.8668
# Predictions with confidence:  0.65  iou:  0.4
# 11.2411
# Predictions with confidence:  0.65  iou:  0.45
# 10.8934
# Predictions with confidence:  0.65  iou:  0.5
# 10.9608
# Predictions with confidence:  0.65  iou:  0.55
# 11.1913
# Predictions with confidence:  0.65  iou:  0.6000000000000001
# 10.9334
# Predictions with confidence:  0.65  iou:  0.65
# 10.8709
# Predictions with confidence:  0.65  iou:  0.7000000000000001
# 11.1009
# Predictions with confidence:  0.65  iou:  0.75
# 10.9817
# Predictions with confidence:  0.65  iou:  0.8
# 10.8734
# Predictions with confidence:  0.65  iou:  0.8500000000000001
# 11.1844
# Predictions with confidence:  0.65  iou:  0.9
# 10.9339
# Predictions with confidence:  0.65  iou:  0.9500000000000001
# 10.9482
# Predictions with confidence:  0.65  iou:  1.0
# 11.151
# Predictions with confidence:  0.7000000000000001  iou:  0.0
# 11.1295
# Predictions with confidence:  0.7000000000000001  iou:  0.05
# 10.9076
# Predictions with confidence:  0.7000000000000001  iou:  0.1
# 11.0683
# Predictions with confidence:  0.7000000000000001  iou:  0.15000000000000002
# 10.8815
# Predictions with confidence:  0.7000000000000001  iou:  0.2
# 10.8176
# Predictions with confidence:  0.7000000000000001  iou:  0.25
# 11.2347
# Predictions with confidence:  0.7000000000000001  iou:  0.30000000000000004
# 10.8496
# Predictions with confidence:  0.7000000000000001  iou:  0.35000000000000003
# 10.7886
# Predictions with confidence:  0.7000000000000001  iou:  0.4
# 11.2009
# Predictions with confidence:  0.7000000000000001  iou:  0.45
# 10.933
# Predictions with confidence:  0.7000000000000001  iou:  0.5
# 10.8642
# Predictions with confidence:  0.7000000000000001  iou:  0.55
# 11.0973
# Predictions with confidence:  0.7000000000000001  iou:  0.6000000000000001
# 10.8666
# Predictions with confidence:  0.7000000000000001  iou:  0.65
# 10.9116
# Predictions with confidence:  0.7000000000000001  iou:  0.7000000000000001
# 11.1092
# Predictions with confidence:  0.7000000000000001  iou:  0.75
# 10.9027
# Predictions with confidence:  0.7000000000000001  iou:  0.8
# 10.817
# Predictions with confidence:  0.7000000000000001  iou:  0.8500000000000001
# 11.1054
# Predictions with confidence:  0.7000000000000001  iou:  0.9
# 10.8499
# Predictions with confidence:  0.7000000000000001  iou:  0.9500000000000001
# 10.8393
# Predictions with confidence:  0.7000000000000001  iou:  1.0
# 11.1591
# Predictions with confidence:  0.75  iou:  0.0
# 10.965
# Predictions with confidence:  0.75  iou:  0.05
# 10.8464
# Predictions with confidence:  0.75  iou:  0.1
# 11.0838
# Predictions with confidence:  0.75  iou:  0.15000000000000002
# 10.8328
# Predictions with confidence:  0.75  iou:  0.2
# 10.93
# Predictions with confidence:  0.75  iou:  0.25
# 11.1289
# Predictions with confidence:  0.75  iou:  0.30000000000000004
# 10.8642
# Predictions with confidence:  0.75  iou:  0.35000000000000003
# 10.8244
# Predictions with confidence:  0.75  iou:  0.4
# 11.0295
# Predictions with confidence:  0.75  iou:  0.45
# 10.8707
# Predictions with confidence:  0.75  iou:  0.5
# 10.8886
# Predictions with confidence:  0.75  iou:  0.55
# 10.8082
# Predictions with confidence:  0.75  iou:  0.6000000000000001
# 11.0394
# Predictions with confidence:  0.75  iou:  0.65
# 10.9366
# Predictions with confidence:  0.75  iou:  0.7000000000000001
# 10.9456
# Predictions with confidence:  0.75  iou:  0.75
# 11.1058
# Predictions with confidence:  0.75  iou:  0.8
# 10.8588
# Predictions with confidence:  0.75  iou:  0.8500000000000001
# 11.0558
# Predictions with confidence:  0.75  iou:  0.9
# 10.84
# Predictions with confidence:  0.75  iou:  0.9500000000000001
# 10.8612
# Predictions with confidence:  0.75  iou:  1.0
# 10.8365
# Predictions with confidence:  0.8  iou:  0.0
# 11.1445
# Predictions with confidence:  0.8  iou:  0.05
# 10.836
# Predictions with confidence:  0.8  iou:  0.1
# 10.8163
# Predictions with confidence:  0.8  iou:  0.15000000000000002
# 11.1012
# Predictions with confidence:  0.8  iou:  0.2
# 10.8738
# Predictions with confidence:  0.8  iou:  0.25
# 11.0362
# Predictions with confidence:  0.8  iou:  0.30000000000000004
# 10.9275
# Predictions with confidence:  0.8  iou:  0.35000000000000003
# 10.919
# Predictions with confidence:  0.8  iou:  0.4
# 10.9372
# Predictions with confidence:  0.8  iou:  0.45
# 11.0707
# Predictions with confidence:  0.8  iou:  0.5
# 10.8031
# Predictions with confidence:  0.8  iou:  0.55
# 10.8893
# Predictions with confidence:  0.8  iou:  0.6000000000000001
# 11.0757
# Predictions with confidence:  0.8  iou:  0.65
# 10.91
# Predictions with confidence:  0.8  iou:  0.7000000000000001
# 10.8815
# Predictions with confidence:  0.8  iou:  0.75
# 11.1547
# Predictions with confidence:  0.8  iou:  0.8
# 10.8748
# Predictions with confidence:  0.8  iou:  0.8500000000000001
# 10.801
# Predictions with confidence:  0.8  iou:  0.9
# 11.142
# Predictions with confidence:  0.8  iou:  0.9500000000000001
# 10.872
# Predictions with confidence:  0.8  iou:  1.0
# 10.7948
# Predictions with confidence:  0.8500000000000001  iou:  0.0
# 11.1218
# Predictions with confidence:  0.8500000000000001  iou:  0.05
# 10.8839
# Predictions with confidence:  0.8500000000000001  iou:  0.1
# 10.8488
# Predictions with confidence:  0.8500000000000001  iou:  0.15000000000000002
# 11.1752
# Predictions with confidence:  0.8500000000000001  iou:  0.2
# 10.9013
# Predictions with confidence:  0.8500000000000001  iou:  0.25
# 10.8115
# Predictions with confidence:  0.8500000000000001  iou:  0.30000000000000004
# 11.0784
# Predictions with confidence:  0.8500000000000001  iou:  0.35000000000000003
# 10.8749
# Predictions with confidence:  0.8500000000000001  iou:  0.4
# 10.8152
# Predictions with confidence:  0.8500000000000001  iou:  0.45
# 10.852
# Predictions with confidence:  0.8500000000000001  iou:  0.5
# 11.1299
# Predictions with confidence:  0.8500000000000001  iou:  0.55
# 10.8641
# Predictions with confidence:  0.8500000000000001  iou:  0.6000000000000001
# 10.9342
# Predictions with confidence:  0.8500000000000001  iou:  0.65
# 11.1931
# Predictions with confidence:  0.8500000000000001  iou:  0.7000000000000001
# 10.9523
# Predictions with confidence:  0.8500000000000001  iou:  0.75
# 10.8303
# Predictions with confidence:  0.8500000000000001  iou:  0.8
# 11.0869
# Predictions with confidence:  0.8500000000000001  iou:  0.8500000000000001
# 10.8923
# Predictions with confidence:  0.8500000000000001  iou:  0.9
# 10.9353
# Predictions with confidence:  0.8500000000000001  iou:  0.9500000000000001
# 11.126
# Predictions with confidence:  0.8500000000000001  iou:  1.0
# 10.8642
# Predictions with confidence:  0.9  iou:  0.0
# 10.86
# Predictions with confidence:  0.9  iou:  0.05
# 11.1243
# Predictions with confidence:  0.9  iou:  0.1
# 10.936
# Predictions with confidence:  0.9  iou:  0.15000000000000002
# 10.9089
# Predictions with confidence:  0.9  iou:  0.2
# 10.9032
# Predictions with confidence:  0.9  iou:  0.25
# 11.1039
# Predictions with confidence:  0.9  iou:  0.30000000000000004
# 10.9637
# Predictions with confidence:  0.9  iou:  0.35000000000000003
# 10.8118
# Predictions with confidence:  0.9  iou:  0.4
# 11.1693
# Predictions with confidence:  0.9  iou:  0.45
# 10.868
# Predictions with confidence:  0.9  iou:  0.5
# 10.8335
# Predictions with confidence:  0.9  iou:  0.55
# 10.9685
# Predictions with confidence:  0.9  iou:  0.6000000000000001
# 11.1969
# Predictions with confidence:  0.9  iou:  0.65
# 10.8605
# Predictions with confidence:  0.9  iou:  0.7000000000000001
# 10.8388
# Predictions with confidence:  0.9  iou:  0.75
# 11.1974
# Predictions with confidence:  0.9  iou:  0.8
# 10.949
# Predictions with confidence:  0.9  iou:  0.8500000000000001
# 10.9941
# Predictions with confidence:  0.9  iou:  0.9
# 10.9063
# Predictions with confidence:  0.9  iou:  0.9500000000000001
# 11.1668
# Predictions with confidence:  0.9  iou:  1.0
# 10.9168
# Predictions with confidence:  0.9500000000000001  iou:  0.0
# 10.9035
# Predictions with confidence:  0.9500000000000001  iou:  0.05
# 10.8377
# Predictions with confidence:  0.9500000000000001  iou:  0.1
# 11.049
# Predictions with confidence:  0.9500000000000001  iou:  0.15000000000000002
# 10.879
# Predictions with confidence:  0.9500000000000001  iou:  0.2
# 10.9875
# Predictions with confidence:  0.9500000000000001  iou:  0.25
# 11.1005
# Predictions with confidence:  0.9500000000000001  iou:  0.30000000000000004
# 10.9784
# Predictions with confidence:  0.9500000000000001  iou:  0.35000000000000003
# 10.8777
# Predictions with confidence:  0.9500000000000001  iou:  0.4
# 11.067
# Predictions with confidence:  0.9500000000000001  iou:  0.45
# 10.8987
# Predictions with confidence:  0.9500000000000001  iou:  0.5
# 10.8558
# Predictions with confidence:  0.9500000000000001  iou:  0.55
# 11.0488
# Predictions with confidence:  0.9500000000000001  iou:  0.6000000000000001
# 10.8458
# Predictions with confidence:  0.9500000000000001  iou:  0.65
# 10.9102
# Predictions with confidence:  0.9500000000000001  iou:  0.7000000000000001
# 10.9288
# Predictions with confidence:  0.9500000000000001  iou:  0.75
# 10.909
# Predictions with confidence:  0.9500000000000001  iou:  0.8
# 11.0725
# Predictions with confidence:  0.9500000000000001  iou:  0.8500000000000001
# 10.8408
# Predictions with confidence:  0.9500000000000001  iou:  0.9
# 11.1246
# Predictions with confidence:  0.9500000000000001  iou:  0.9500000000000001
# 10.9721
# Predictions with confidence:  0.9500000000000001  iou:  1.0
# 10.8985
# Predictions with confidence:  1.0  iou:  0.0
# 10.8829
# Predictions with confidence:  1.0  iou:  0.05
# 11.0684
# Predictions with confidence:  1.0  iou:  0.1
# 10.8235
# Predictions with confidence:  1.0  iou:  0.15000000000000002
# 10.9518
# Predictions with confidence:  1.0  iou:  0.2
# 10.8575
# Predictions with confidence:  1.0  iou:  0.25
# 10.828
# Predictions with confidence:  1.0  iou:  0.30000000000000004
# 11.0871
# Predictions with confidence:  1.0  iou:  0.35000000000000003
# 10.8604
# Predictions with confidence:  1.0  iou:  0.4
# 10.8571
# Predictions with confidence:  1.0  iou:  0.45
# 11.0797
# Predictions with confidence:  1.0  iou:  0.5
# 10.8411
# Predictions with confidence:  1.0  iou:  0.55
# 10.8001
# Predictions with confidence:  1.0  iou:  0.6000000000000001
# 11.0847
# Predictions with confidence:  1.0  iou:  0.65
# 10.9504
# Predictions with confidence:  1.0  iou:  0.7000000000000001
# 10.8826
# Predictions with confidence:  1.0  iou:  0.75
# 10.8166
# Predictions with confidence:  1.0  iou:  0.8
# 11.1265
# Predictions with confidence:  1.0  iou:  0.8500000000000001
# 10.8812
# Predictions with confidence:  1.0  iou:  0.9
# 10.9376
# Predictions with confidence:  1.0  iou:  0.9500000000000001
# 11.0603
# Predictions with confidence:  1.0  iou:  1.0
# 11.0137

# %% [markdown]
# ## Some predictions with different confidence and iou

# %%
preds = helper.get_coordinates(pred_data.iloc[200]['Predictions'])

# %%
one_pred = helper.normilize_to_pixel(preds, 300, 300)

# %%
helper.show_image_bb(train_img[115], one_pred[115])

# %% [markdown]
# ## Search for optimal parameters by calculating f1 score

# %%
label_training = np.load(path_root + '/label_train.npy')

# %%
# Iterate over all predictions and calculate the metrics
performance = []

for idx_pred in list(range(pred_data.shape[0])):
    print('Calculating metrics for:', idx_pred + 1, 'from:', pred_data.shape[0])
    
    pred = pred_data.iloc[idx_pred]['Predictions']
    pred = helper.get_coordinates(pred)
    confidence = pred_data.iloc[idx_pred]['Conficence']
    iou = pred_data.iloc[idx_pred]['IOU']
    # Calculate metrics
    presicion, recall, f1_score = helper.cal_performance(label_training, pred, False)
    performance.append([confidence, iou, presicion, recall, f1_score])

# Create DataFrame with all metrics
columns = ['Confidence', 'IOU', 'Presicion', 'Recall', 'F1 score']
performance_frame = pd.DataFrame(np.array(performance), columns=columns)
# Out:
# Calculating metrics for: 1 from: 441
# Calculating metrics for: 2 from: 441
# Calculating metrics for: 3 from: 441
# Calculating metrics for: 4 from: 441
# Calculating metrics for: 5 from: 441
# Calculating metrics for: 6 from: 441
# Calculating metrics for: 7 from: 441
# Calculating metrics for: 8 from: 441
# Calculating metrics for: 439 from: 441
# Calculating metrics for: 440 from: 441
# Calculating metrics for: 441 from: 441

# %%
performance_frame.head()
# Out:
#    Confidence   IOU  Presicion    Recall  F1 score
# 0         0.0  0.00   0.014166  0.596882  0.027674
# 1         0.0  0.05   0.012391  0.620320  0.024296
# 2         0.0  0.10   0.011766  0.636342  0.023104
# 3         0.0  0.15   0.011825  0.648414  0.023226
# 4         0.0  0.20   0.012277  0.656203  0.024103

# %%
performance_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 5 columns):
# Confidence    441 non-null float64
# IOU           441 non-null float64
# Presicion     441 non-null float64
# Recall        441 non-null float64
# F1 score      441 non-null float64
# dtypes: float64(5)
# memory usage: 17.3 KB

# %%
performance_frame.describe()
# Out:
#        Confidence         IOU   Presicion      Recall    F1 score
# count  441.000000  441.000000  441.000000  441.000000  441.000000
# mean     0.500000    0.500000    0.650016    0.446393    0.491963
# std      0.303109    0.303109    0.223445    0.152296    0.166172
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.250000    0.250000    0.650390    0.377272    0.492315
# 50%      0.500000    0.500000    0.729880    0.463077    0.550748
# 75%      0.750000    0.750000    0.773426    0.545713    0.589005
# max      1.000000    1.000000    0.841141    0.777113    0.662483

# %%
print(performance_frame.iloc[performance_frame['Presicion'].argmax()], end='\n\n')
print(performance_frame.iloc[performance_frame['Recall'].argmax()], end='\n\n')
print(performance_frame.iloc[performance_frame['F1 score'].argmax()], end='\n\n')
# Out:
# Confidence    0.950000
# IOU           1.000000
# Presicion     0.841141
# Recall        0.238598
# F1 score      0.371747
# Name: 419, dtype: float64
#
# Confidence    0.000000
# IOU           1.000000
# Presicion     0.032325
# Recall        0.777113
# F1 score      0.062068
# Name: 20, dtype: float64
#
# Confidence    0.150000
# IOU           1.000000
# Presicion     0.701340
# Recall        0.627705
# F1 score      0.662483
# Name: 83, dtype: float64
# /home/aldopedraza/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   if __name__ == '__main__':
# /home/aldopedraza/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   from ipykernel import kernelapp as app
# /home/aldopedraza/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   app.launch_new_instance()

# %%
import seaborn as sns
presicion = performance_frame['Presicion']
recall =  performance_frame['Recall']
f1_score = performance_frame['F1 score']
iou = performance_frame['IOU']
confidence = performance_frame['Confidence']

fig = plt.figure(figsize=(18,6))

# fig = plt.figure()
ax = fig.add_subplot(131, projection='3d')
ax.scatter(iou, confidence, presicion, c=presicion, cmap='coolwarm', linewidth=1.0)
ax.set_zlim(0, 1)
ax.set_xlabel('IOU')
ax.set_ylabel('Confidence')
ax.set_zlabel('Presicion')
ax.view_init(30, 15)
# ax.plot_trisurf(iou, confidence, f1_score)

ax = fig.add_subplot(132, projection='3d')
ax.scatter(iou, confidence, recall, c=recall, cmap='coolwarm', linewidth=1.0)
ax.set_zlim(0, 1)
ax.set_xlabel('IOU')
ax.set_ylabel('Confidence')
ax.set_zlabel('Recall')
ax.view_init(30, 15)


ax = fig.add_subplot(133, projection='3d')
ax.scatter(iou, confidence, f1_score, c=f1_score, cmap='coolwarm', linewidth=1.0)
ax.set_zlim(0, 1)
ax.set_xlabel('IOU')
ax.set_ylabel('Confidence')
ax.set_zlabel('F1 score')
ax.view_init(30, 15)


fig.tight_layout()
