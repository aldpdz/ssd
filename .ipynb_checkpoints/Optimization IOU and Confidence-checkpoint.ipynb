# %% [markdown]
# # Optimization IOU and Confidence over SSD300

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import time
import json
import os.path

from keras import backend as K
from keras.models import load_model
from keras.preprocessing import image
from keras.optimizers import Adam
from imageio import imread
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D

from models.keras_ssd300 import ssd_300
from models.keras_ssd512 import ssd_512
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

from extra_files import helper

# config = tf.ConfigProto()
 
# # Don't pre-allocate memory; allocate as-needed
# config.gpu_options.allow_growth = True
 
# # Only allow a total of half the GPU memory to be allocated
# config.gpu_options.per_process_gpu_memory_fraction = 0.5
 
# # Create a session with the above options specified.
# k.tensorflow_backend.set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.
# /home/aldo/Documents/ssd/data_generator/object_detection_2d_data_generator.py:43: UserWarning: 'BeautifulSoup' module is missing. The XML-parser will be unavailable.
#   warnings.warn("'BeautifulSoup' module is missing. The XML-parser will be unavailable.")

# %% [markdown]
# ## 1. Load a trained SSD

# %% [markdown]
# ### Build the model and load trained weights into it wih parameters confidence and iou threshold

# %%
model_pascal_voc_07_plus_12_300x300 = '../weights/pascal_voc/pascal_voc_07_12_coco_300x300.h5'

# %%
# def load_model(model_path, confidence_thresh, iou_threshold):
#     '''
#     model_path: path to the weight's model
#     conficence_thresh: confidence threshold needed to keep a predition
#     iou: iou threshold to remove multiple bounding boxes
#     return keras model
#     '''
#     # 1: Build the Keras model
#     K.clear_session() # Clear previous models from memory.

#     model = ssd_300(image_size=(300, 300, 3),
#                     n_classes=20,
#                     mode='training',
#                     l2_regularization=0.0005,
#                     scales=[0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05],
#                     aspect_ratios_per_layer=[[1.0, 2.0, 0.5],
#                                              [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
#                                              [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
#                                              [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
#                                              [1.0, 2.0, 0.5],
#                                              [1.0, 2.0, 0.5]],
#                     two_boxes_for_ar1=True,
#                     steps=[8, 16, 32, 64, 100, 300],
#                     offsets=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
#                     clip_boxes=False,
#                     variances=[0.1, 0.1, 0.2, 0.2],
#                     normalize_coords=True,
#                     subtract_mean=[123, 117, 104],
#                     swap_channels=[2, 1, 0],
#                     confidence_thresh=confidence_thresh,
#                     iou_threshold=iou_threshold,
#                     top_k=9000,
#                     nms_max_output_size=9000)

#     # 2: Load the trained weights into the model.
#     # TODO: Set the path of the trained weights.
#     model.load_weights(model_path, by_name=True)

#     # 3: Compile the model so that Keras won't complain the next time you load it.

#     adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

#     ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

#     model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
    
#     return model


model = ssd_300(image_size=(300, 300, 3),
                n_classes=20,
                mode='training',
                l2_regularization=0.0005,
                scales=[0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05],
                aspect_ratios_per_layer=[[1.0, 2.0, 0.5],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                                         [1.0, 2.0, 0.5],
                                         [1.0, 2.0, 0.5]],
                two_boxes_for_ar1=True,
                steps=[8, 16, 32, 64, 100, 300],
                offsets=[0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
                clip_boxes=False,
                variances=[0.1, 0.1, 0.2, 0.2],
                normalize_coords=True,
                subtract_mean=[123, 117, 104],
                swap_channels=[2, 1, 0],
                confidence_thresh=0.0,
                iou_threshold=0.0,
                top_k=9000,
                nms_max_output_size=9000)

# 2: Load the trained weights into the model.
# TODO: Set the path of the trained weights.
model.load_weights(model_pascal_voc_07_plus_12_300x300, by_name=True)

# 3: Compile the model so that Keras won't complain the next time you load it.

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %% [markdown]
#   ## 2. Load Images
#
# Load some images for which you'd like the model to make predictions.

# %%
path_root = '/home/aldo/Documents/data-cic/preprocess_data'
path_save = path_root + '/predictions/'
train_img = np.load(path_root + '/images_train_300x300.npy')

# %% [markdown]
# ## 3. Make predictions

# %%
model_pascal_voc_07_plus_12_300x300 = '../weights/pascal_voc/pascal_voc_07_12_coco_300x300.h5'

# %%
def get_predictions(model, batch_size, images_list, confidence, iou):
    '''
    Make predictions from a model
    path_model: the path to the weights' model
    batch_size: size of the batch
    images_list: list of images to make predictions
    confidence: confidence threshold
    iou: iou threshold
    return predictions
    '''
    # Create variable to store predictions
#     predictions = np.zeros(shape=(1, 9000, 6))
    predictions = []
    
#     model = load_model(path_model, confidence, iou)

    for batch in helper.get_batch(batch_size, images_list):
        pred = model.predict(batch)
        y_decoded = decode_detections(pred,
                                      confidence_thresh=confidence,
                                      iou_threshold=iou,
                                      top_k=9000,
                                      normalize_coords=False,
                                      img_height=300, 
                                      img_width=300)
#         print(np.expand_dims(np.array(y_decoded), axis=1).shape)
        for bb in y_decoded:
            predictions.append(bb)
            
#         predictions = np.append(predictions, y_decoded, axis=0)
#         predictions = y_decoded[1:] # delete empty item
    predictions = np.array(predictions)
    clean_pre = helper.clean_predictions(predictions)
    adjust_pre = helper.adjust_predictions(clean_pre)
    return adjust_pre

# %%
# Make predictions of the models
# pascal 07+12+coco
predictions_list = []
confidence_list = np.arange(0.05, 1.05, 0.05)
iou_list= np.arange(0.05, 1.05, 0.05)

columns = ['Conficence', 'IOU', 'Predictions']

for conf in confidence_list:
    for iou in iou_list:
        print('Predictions with confidence: ', conf, ' iou: ', iou)
        start = time.time()

        pred = get_predictions(model, 32, train_img, conf.item(), iou.item())
        predictions_list.append([conf, iou, pred])
        
        end = time.time()
        print(round(end - start, 4))

predictions_list = np.array(predictions_list)

# Create DataFrame with all predictions
pred_data = pd.DataFrame(predictions_list, columns=columns)
pred_data.to_csv(path_save + 'optimization_pred.csv')
# Out:
# Predictions with confidence:  0.05  iou:  0.05
# 7.1005
# Predictions with confidence:  0.05  iou:  0.1
# 3.2203
# Predictions with confidence:  0.05  iou:  0.15000000000000002
# 3.1808
# Predictions with confidence:  0.05  iou:  0.2
# 3.2538
# Predictions with confidence:  0.05  iou:  0.25
# 3.1933
# Predictions with confidence:  0.05  iou:  0.3
# 3.194
# Predictions with confidence:  0.05  iou:  0.35000000000000003
# 3.2193
# Predictions with confidence:  0.05  iou:  0.4
# 3.2557
# Predictions with confidence:  0.05  iou:  0.45
# 3.2988
# Predictions with confidence:  0.05  iou:  0.5
# 3.3293
# Predictions with confidence:  0.05  iou:  0.55
# 3.3865
# Predictions with confidence:  0.05  iou:  0.6000000000000001
# 3.4696
# Predictions with confidence:  0.05  iou:  0.6500000000000001
# 3.5558
# Predictions with confidence:  0.05  iou:  0.7000000000000001
# 3.6753
# Predictions with confidence:  0.05  iou:  0.7500000000000001
# 3.7769
# Predictions with confidence:  0.05  iou:  0.8
# 3.9338
# Predictions with confidence:  0.05  iou:  0.8500000000000001
# 4.051
# Predictions with confidence:  0.05  iou:  0.9000000000000001
# 4.1808
# Predictions with confidence:  0.05  iou:  0.9500000000000001
# 4.276
# Predictions with confidence:  0.05  iou:  1.0
# 4.3131
# Predictions with confidence:  0.1  iou:  0.05
# 3.0981
# Predictions with confidence:  0.1  iou:  0.1
# 3.0844
# Predictions with confidence:  0.1  iou:  0.15000000000000002
# 3.1164
# Predictions with confidence:  0.1  iou:  0.2
# 3.1297
# Predictions with confidence:  0.1  iou:  0.25
# 3.0909
# Predictions with confidence:  0.1  iou:  0.3
# 3.1117
# Predictions with confidence:  0.1  iou:  0.35000000000000003
# 3.1256
# Predictions with confidence:  0.1  iou:  0.4
# 3.1226
# Predictions with confidence:  0.1  iou:  0.45
# 3.1148
# Predictions with confidence:  0.1  iou:  0.5
# 3.1323
# Predictions with confidence:  0.1  iou:  0.55
# 3.1246
# Predictions with confidence:  0.1  iou:  0.6000000000000001
# 3.0974
# Predictions with confidence:  0.1  iou:  0.6500000000000001
# 3.1161
# Predictions with confidence:  0.1  iou:  0.7000000000000001
# 3.1268
# Predictions with confidence:  0.1  iou:  0.7500000000000001
# 3.166
# Predictions with confidence:  0.1  iou:  0.8
# 3.1977
# Predictions with confidence:  0.1  iou:  0.8500000000000001
# 3.248
# Predictions with confidence:  0.1  iou:  0.9000000000000001
# 3.3108
# Predictions with confidence:  0.1  iou:  0.9500000000000001
# 3.3563
# Predictions with confidence:  0.1  iou:  1.0
# 3.4217
# Predictions with confidence:  0.15000000000000002  iou:  0.05
# 3.0963
# Predictions with confidence:  0.15000000000000002  iou:  0.1
# 3.0905
# Predictions with confidence:  0.15000000000000002  iou:  0.15000000000000002
# 3.0904
# Predictions with confidence:  0.15000000000000002  iou:  0.2
# 3.0694
# Predictions with confidence:  0.15000000000000002  iou:  0.25
# 3.0728
# Predictions with confidence:  0.15000000000000002  iou:  0.3
# 3.0737
# Predictions with confidence:  0.15000000000000002  iou:  0.35000000000000003
# 3.0743
# Predictions with confidence:  0.15000000000000002  iou:  0.4
# 3.0705
# Predictions with confidence:  0.15000000000000002  iou:  0.45
# 3.0756
# Predictions with confidence:  0.15000000000000002  iou:  0.5
# 3.0951
# Predictions with confidence:  0.15000000000000002  iou:  0.55
# 3.0894
# Predictions with confidence:  0.15000000000000002  iou:  0.6000000000000001
# 3.0696
# Predictions with confidence:  0.15000000000000002  iou:  0.6500000000000001
# 3.0647
# Predictions with confidence:  0.15000000000000002  iou:  0.7000000000000001
# 3.0788
# Predictions with confidence:  0.15000000000000002  iou:  0.7500000000000001
# 3.1042
# Predictions with confidence:  0.15000000000000002  iou:  0.8
# 3.1233
# Predictions with confidence:  0.15000000000000002  iou:  0.8500000000000001
# 3.1413
# Predictions with confidence:  0.15000000000000002  iou:  0.9000000000000001
# 3.1819
# Predictions with confidence:  0.15000000000000002  iou:  0.9500000000000001
# 3.2522
# Predictions with confidence:  0.15000000000000002  iou:  1.0
# 3.2424
# Predictions with confidence:  0.2  iou:  0.05
# 3.082
# Predictions with confidence:  0.2  iou:  0.1
# 3.0756
# Predictions with confidence:  0.2  iou:  0.15000000000000002
# 3.0436
# Predictions with confidence:  0.2  iou:  0.2
# 3.0696
# Predictions with confidence:  0.2  iou:  0.25
# 3.0787
# Predictions with confidence:  0.2  iou:  0.3
# 3.0869
# Predictions with confidence:  0.2  iou:  0.35000000000000003
# 3.0497
# Predictions with confidence:  0.2  iou:  0.4
# 3.0755
# Predictions with confidence:  0.2  iou:  0.45
# 3.0934
# Predictions with confidence:  0.2  iou:  0.5
# 3.075
# Predictions with confidence:  0.2  iou:  0.55
# 3.075
# Predictions with confidence:  0.2  iou:  0.6000000000000001
# 3.0582
# Predictions with confidence:  0.2  iou:  0.6500000000000001
# 3.0492
# Predictions with confidence:  0.2  iou:  0.7000000000000001
# 3.0452
# Predictions with confidence:  0.2  iou:  0.7500000000000001
# 3.0996
# Predictions with confidence:  0.2  iou:  0.8
# 3.1106
# Predictions with confidence:  0.2  iou:  0.8500000000000001
# 3.1379
# Predictions with confidence:  0.2  iou:  0.9000000000000001
# 3.1396
# Predictions with confidence:  0.2  iou:  0.9500000000000001
# 3.1874
# Predictions with confidence:  0.2  iou:  1.0
# 3.1911
# Predictions with confidence:  0.25  iou:  0.05
# 3.0584
# Predictions with confidence:  0.25  iou:  0.1
# 3.083
# Predictions with confidence:  0.25  iou:  0.15000000000000002
# 3.0829
# Predictions with confidence:  0.25  iou:  0.2
# 3.0718
# Predictions with confidence:  0.25  iou:  0.25
# 3.0741
# Predictions with confidence:  0.25  iou:  0.3
# 3.0637
# Predictions with confidence:  0.25  iou:  0.35000000000000003
# 3.0636
# Predictions with confidence:  0.25  iou:  0.4
# 3.0967
# Predictions with confidence:  0.25  iou:  0.45
# 3.0893
# Predictions with confidence:  0.25  iou:  0.5
# 3.0977
# Predictions with confidence:  0.25  iou:  0.55
# 3.0847
# Predictions with confidence:  0.25  iou:  0.6000000000000001
# 3.0653
# Predictions with confidence:  0.25  iou:  0.6500000000000001
# 3.0829
# Predictions with confidence:  0.25  iou:  0.7000000000000001
# 3.065
# Predictions with confidence:  0.25  iou:  0.7500000000000001
# 3.0798
# Predictions with confidence:  0.25  iou:  0.8
# 3.0911
# Predictions with confidence:  0.25  iou:  0.8500000000000001
# 3.1041
# Predictions with confidence:  0.25  iou:  0.9000000000000001
# 3.1061
# Predictions with confidence:  0.25  iou:  0.9500000000000001
# 3.1358
# Predictions with confidence:  0.25  iou:  1.0
# 3.17
# Predictions with confidence:  0.3  iou:  0.05
# 3.0866
# Predictions with confidence:  0.3  iou:  0.1
# 3.0649
# Predictions with confidence:  0.3  iou:  0.15000000000000002
# 3.0848
# Predictions with confidence:  0.3  iou:  0.2
# 3.077
# Predictions with confidence:  0.3  iou:  0.25
# 3.0648
# Predictions with confidence:  0.3  iou:  0.3
# 3.0417
# Predictions with confidence:  0.3  iou:  0.35000000000000003
# 3.0437
# Predictions with confidence:  0.3  iou:  0.4
# 3.0486
# Predictions with confidence:  0.3  iou:  0.45
# 3.0526
# Predictions with confidence:  0.3  iou:  0.5
# 3.0643
# Predictions with confidence:  0.3  iou:  0.55
# 3.0566
# Predictions with confidence:  0.3  iou:  0.6000000000000001
# 3.0615
# Predictions with confidence:  0.3  iou:  0.6500000000000001
# 3.0838
# Predictions with confidence:  0.3  iou:  0.7000000000000001
# 3.0673
# Predictions with confidence:  0.3  iou:  0.7500000000000001
# 3.0607
# Predictions with confidence:  0.3  iou:  0.8
# 3.069
# Predictions with confidence:  0.3  iou:  0.8500000000000001
# 3.0712
# Predictions with confidence:  0.3  iou:  0.9000000000000001
# 3.0884
# Predictions with confidence:  0.3  iou:  0.9500000000000001
# 3.1371
# Predictions with confidence:  0.3  iou:  1.0
# 3.1793
# Predictions with confidence:  0.35000000000000003  iou:  0.05
# 3.0532
# Predictions with confidence:  0.35000000000000003  iou:  0.1
# 3.0501
# Predictions with confidence:  0.35000000000000003  iou:  0.15000000000000002
# 3.0501
# Predictions with confidence:  0.35000000000000003  iou:  0.2
# 3.0485
# Predictions with confidence:  0.35000000000000003  iou:  0.25
# 3.0777
# Predictions with confidence:  0.35000000000000003  iou:  0.3
# 3.0519
# Predictions with confidence:  0.35000000000000003  iou:  0.35000000000000003
# 3.0449
# Predictions with confidence:  0.35000000000000003  iou:  0.4
# 3.0578
# Predictions with confidence:  0.35000000000000003  iou:  0.45
# 3.0876
# Predictions with confidence:  0.35000000000000003  iou:  0.5
# 3.084
# Predictions with confidence:  0.35000000000000003  iou:  0.55
# 3.0738
# Predictions with confidence:  0.35000000000000003  iou:  0.6000000000000001
# 3.1073
# Predictions with confidence:  0.35000000000000003  iou:  0.6500000000000001
# 3.0728
# Predictions with confidence:  0.35000000000000003  iou:  0.7000000000000001
# 3.0823
# Predictions with confidence:  0.35000000000000003  iou:  0.7500000000000001
# 3.1087
# Predictions with confidence:  0.35000000000000003  iou:  0.8
# 3.069
# Predictions with confidence:  0.35000000000000003  iou:  0.8500000000000001
# 3.0927
# Predictions with confidence:  0.35000000000000003  iou:  0.9000000000000001
# 3.1031
# Predictions with confidence:  0.35000000000000003  iou:  0.9500000000000001
# 3.1219
# Predictions with confidence:  0.35000000000000003  iou:  1.0
# 3.1842
# Predictions with confidence:  0.4  iou:  0.05
# 3.0868
# Predictions with confidence:  0.4  iou:  0.1
# 3.0652
# Predictions with confidence:  0.4  iou:  0.15000000000000002
# 3.0776
# Predictions with confidence:  0.4  iou:  0.2
# 3.093
# Predictions with confidence:  0.4  iou:  0.25
# 3.1131
# Predictions with confidence:  0.4  iou:  0.3
# 3.0562
# Predictions with confidence:  0.4  iou:  0.35000000000000003
# 3.0531
# Predictions with confidence:  0.4  iou:  0.4
# 3.1811
# Predictions with confidence:  0.4  iou:  0.45
# 3.1064
# Predictions with confidence:  0.4  iou:  0.5
# 3.1109
# Predictions with confidence:  0.4  iou:  0.55
# 3.0813
# Predictions with confidence:  0.4  iou:  0.6000000000000001
# 3.0674
# Predictions with confidence:  0.4  iou:  0.6500000000000001
# 3.1074
# Predictions with confidence:  0.4  iou:  0.7000000000000001
# 3.0756
# Predictions with confidence:  0.4  iou:  0.7500000000000001
# 3.0545
# Predictions with confidence:  0.4  iou:  0.8
# 3.0603
# Predictions with confidence:  0.4  iou:  0.8500000000000001
# 3.0846
# Predictions with confidence:  0.4  iou:  0.9000000000000001
# 3.093
# Predictions with confidence:  0.4  iou:  0.9500000000000001
# 3.1314
# Predictions with confidence:  0.4  iou:  1.0
# 3.1087
# Predictions with confidence:  0.45  iou:  0.05
# 3.0468
# Predictions with confidence:  0.45  iou:  0.1
# 3.0634
# Predictions with confidence:  0.45  iou:  0.15000000000000002
# 3.0673
# Predictions with confidence:  0.45  iou:  0.2
# 3.0498
# Predictions with confidence:  0.45  iou:  0.25
# 3.0402
# Predictions with confidence:  0.45  iou:  0.3
# 3.0393
# Predictions with confidence:  0.45  iou:  0.35000000000000003
# 3.0163
# Predictions with confidence:  0.45  iou:  0.4
# 3.0157
# Predictions with confidence:  0.45  iou:  0.45
# 3.0189
# Predictions with confidence:  0.45  iou:  0.5
# 3.0302
# Predictions with confidence:  0.45  iou:  0.55
# 3.015
# Predictions with confidence:  0.45  iou:  0.6000000000000001
# 3.0271
# Predictions with confidence:  0.45  iou:  0.6500000000000001
# 3.04
# Predictions with confidence:  0.45  iou:  0.7000000000000001
# 3.0472
# Predictions with confidence:  0.45  iou:  0.7500000000000001
# 3.0601
# Predictions with confidence:  0.45  iou:  0.8
# 3.0726
# Predictions with confidence:  0.45  iou:  0.8500000000000001
# 3.062
# Predictions with confidence:  0.45  iou:  0.9000000000000001
# 3.09
# Predictions with confidence:  0.45  iou:  0.9500000000000001
# 3.112
# Predictions with confidence:  0.45  iou:  1.0
# 3.0953
# Predictions with confidence:  0.5  iou:  0.05
# 3.0793
# Predictions with confidence:  0.5  iou:  0.1
# 3.0948
# Predictions with confidence:  0.5  iou:  0.15000000000000002
# 3.0742
# Predictions with confidence:  0.5  iou:  0.2
# 3.0922
# Predictions with confidence:  0.5  iou:  0.25
# 3.0686
# Predictions with confidence:  0.5  iou:  0.3
# 3.0813
# Predictions with confidence:  0.5  iou:  0.35000000000000003
# 3.0682
# Predictions with confidence:  0.5  iou:  0.4
# 3.0796
# Predictions with confidence:  0.5  iou:  0.45
# 3.0747
# Predictions with confidence:  0.5  iou:  0.5
# 3.073
# Predictions with confidence:  0.5  iou:  0.55
# 3.0865
# Predictions with confidence:  0.5  iou:  0.6000000000000001
# 3.0946
# Predictions with confidence:  0.5  iou:  0.6500000000000001
# 3.0902
# Predictions with confidence:  0.5  iou:  0.7000000000000001
# 3.1101
# Predictions with confidence:  0.5  iou:  0.7500000000000001
# 3.0806
# Predictions with confidence:  0.5  iou:  0.8
# 3.0956
# Predictions with confidence:  0.5  iou:  0.8500000000000001
# 3.083
# Predictions with confidence:  0.5  iou:  0.9000000000000001
# 3.1015
# Predictions with confidence:  0.5  iou:  0.9500000000000001
# 3.1168
# Predictions with confidence:  0.5  iou:  1.0
# 3.1386
# Predictions with confidence:  0.55  iou:  0.05
# 3.0883
# Predictions with confidence:  0.55  iou:  0.1
# 3.0793
# Predictions with confidence:  0.55  iou:  0.15000000000000002
# 3.0918
# Predictions with confidence:  0.55  iou:  0.2
# 3.0867
# Predictions with confidence:  0.55  iou:  0.25
# 3.07
# Predictions with confidence:  0.55  iou:  0.3
# 3.0859
# Predictions with confidence:  0.55  iou:  0.35000000000000003
# 3.0978
# Predictions with confidence:  0.55  iou:  0.4
# 3.0623
# Predictions with confidence:  0.55  iou:  0.45
# 3.0863
# Predictions with confidence:  0.55  iou:  0.5
# 3.0655
# Predictions with confidence:  0.55  iou:  0.55
# 3.0863
# Predictions with confidence:  0.55  iou:  0.6000000000000001
# 3.0925
# Predictions with confidence:  0.55  iou:  0.6500000000000001
# 3.0866
# Predictions with confidence:  0.55  iou:  0.7000000000000001
# 3.0845
# Predictions with confidence:  0.55  iou:  0.7500000000000001
# 3.1017
# Predictions with confidence:  0.55  iou:  0.8
# 3.092
# Predictions with confidence:  0.55  iou:  0.8500000000000001
# 3.1107
# Predictions with confidence:  0.55  iou:  0.9000000000000001
# 3.1073
# Predictions with confidence:  0.55  iou:  0.9500000000000001
# 3.1063
# Predictions with confidence:  0.55  iou:  1.0
# 3.1261
# Predictions with confidence:  0.6000000000000001  iou:  0.05
# 3.0755
# Predictions with confidence:  0.6000000000000001  iou:  0.1
# 3.0911
# Predictions with confidence:  0.6000000000000001  iou:  0.15000000000000002
# 3.0819
# Predictions with confidence:  0.6000000000000001  iou:  0.2
# 3.1106
# Predictions with confidence:  0.6000000000000001  iou:  0.25
# 3.1035
# Predictions with confidence:  0.6000000000000001  iou:  0.3
# 3.0982
# Predictions with confidence:  0.6000000000000001  iou:  0.35000000000000003
# 3.0949
# Predictions with confidence:  0.6000000000000001  iou:  0.4
# 3.1014
# Predictions with confidence:  0.6000000000000001  iou:  0.45
# 3.0817
# Predictions with confidence:  0.6000000000000001  iou:  0.5
# 3.104
# Predictions with confidence:  0.6000000000000001  iou:  0.55
# 3.0971
# Predictions with confidence:  0.6000000000000001  iou:  0.6000000000000001
# 3.1002
# Predictions with confidence:  0.6000000000000001  iou:  0.6500000000000001
# 3.0573
# Predictions with confidence:  0.6000000000000001  iou:  0.7000000000000001
# 3.0748
# Predictions with confidence:  0.6000000000000001  iou:  0.7500000000000001
# 3.0604
# Predictions with confidence:  0.6000000000000001  iou:  0.8
# 3.0605
# Predictions with confidence:  0.6000000000000001  iou:  0.8500000000000001
# 3.0702
# Predictions with confidence:  0.6000000000000001  iou:  0.9000000000000001
# 3.0681
# Predictions with confidence:  0.6000000000000001  iou:  0.9500000000000001
# 3.0863
# Predictions with confidence:  0.6000000000000001  iou:  1.0
# 3.1282
# Predictions with confidence:  0.6500000000000001  iou:  0.05
# 3.0834
# Predictions with confidence:  0.6500000000000001  iou:  0.1
# 3.0533
# Predictions with confidence:  0.6500000000000001  iou:  0.15000000000000002
# 3.0526
# Predictions with confidence:  0.6500000000000001  iou:  0.2
# 3.0698
# Predictions with confidence:  0.6500000000000001  iou:  0.25
# 3.1034
# Predictions with confidence:  0.6500000000000001  iou:  0.3
# 3.0874
# Predictions with confidence:  0.6500000000000001  iou:  0.35000000000000003
# 3.096
# Predictions with confidence:  0.6500000000000001  iou:  0.4
# 3.0841
# Predictions with confidence:  0.6500000000000001  iou:  0.45
# 3.0704
# Predictions with confidence:  0.6500000000000001  iou:  0.5
# 3.0791
# Predictions with confidence:  0.6500000000000001  iou:  0.55
# 3.1128
# Predictions with confidence:  0.6500000000000001  iou:  0.6000000000000001
# 3.087
# Predictions with confidence:  0.6500000000000001  iou:  0.6500000000000001
# 3.0764
# Predictions with confidence:  0.6500000000000001  iou:  0.7000000000000001
# 3.0908
# Predictions with confidence:  0.6500000000000001  iou:  0.7500000000000001
# 3.0761
# Predictions with confidence:  0.6500000000000001  iou:  0.8
# 3.0904
# Predictions with confidence:  0.6500000000000001  iou:  0.8500000000000001
# 3.126
# Predictions with confidence:  0.6500000000000001  iou:  0.9000000000000001
# 3.0985
# Predictions with confidence:  0.6500000000000001  iou:  0.9500000000000001
# 3.1087
# Predictions with confidence:  0.6500000000000001  iou:  1.0
# 3.1191
# Predictions with confidence:  0.7000000000000001  iou:  0.05
# 3.0871
# Predictions with confidence:  0.7000000000000001  iou:  0.1
# 3.0972
# Predictions with confidence:  0.7000000000000001  iou:  0.15000000000000002
# 3.0515
# Predictions with confidence:  0.7000000000000001  iou:  0.2
# 3.081
# Predictions with confidence:  0.7000000000000001  iou:  0.25
# 3.0895
# Predictions with confidence:  0.7000000000000001  iou:  0.3
# 3.0896
# Predictions with confidence:  0.7000000000000001  iou:  0.35000000000000003
# 3.0982
# Predictions with confidence:  0.7000000000000001  iou:  0.4
# 3.0833
# Predictions with confidence:  0.7000000000000001  iou:  0.45
# 3.0892
# Predictions with confidence:  0.7000000000000001  iou:  0.5
# 3.0677
# Predictions with confidence:  0.7000000000000001  iou:  0.55
# 3.0726
# Predictions with confidence:  0.7000000000000001  iou:  0.6000000000000001
# 3.0844
# Predictions with confidence:  0.7000000000000001  iou:  0.6500000000000001
# 3.0771
# Predictions with confidence:  0.7000000000000001  iou:  0.7000000000000001
# 3.0743
# Predictions with confidence:  0.7000000000000001  iou:  0.7500000000000001
# 3.0701
# Predictions with confidence:  0.7000000000000001  iou:  0.8
# 3.0825
# Predictions with confidence:  0.7000000000000001  iou:  0.8500000000000001
# 3.0636
# Predictions with confidence:  0.7000000000000001  iou:  0.9000000000000001
# 3.0684
# Predictions with confidence:  0.7000000000000001  iou:  0.9500000000000001
# 3.0817
# Predictions with confidence:  0.7000000000000001  iou:  1.0
# 3.1077
# Predictions with confidence:  0.7500000000000001  iou:  0.05
# 3.0696
# Predictions with confidence:  0.7500000000000001  iou:  0.1
# 3.0884
# Predictions with confidence:  0.7500000000000001  iou:  0.15000000000000002
# 3.0652
# Predictions with confidence:  0.7500000000000001  iou:  0.2
# 3.054
# Predictions with confidence:  0.7500000000000001  iou:  0.25
# 3.0697
# Predictions with confidence:  0.7500000000000001  iou:  0.3
# 3.0612
# Predictions with confidence:  0.7500000000000001  iou:  0.35000000000000003
# 3.0646
# Predictions with confidence:  0.7500000000000001  iou:  0.4
# 3.0971
# Predictions with confidence:  0.7500000000000001  iou:  0.45
# 3.0795
# Predictions with confidence:  0.7500000000000001  iou:  0.5
# 3.062
# Predictions with confidence:  0.7500000000000001  iou:  0.55
# 3.0709
# Predictions with confidence:  0.7500000000000001  iou:  0.6000000000000001
# 3.0651
# Predictions with confidence:  0.7500000000000001  iou:  0.6500000000000001
# 3.0574
# Predictions with confidence:  0.7500000000000001  iou:  0.7000000000000001
# 3.052
# Predictions with confidence:  0.7500000000000001  iou:  0.7500000000000001
# 3.0752
# Predictions with confidence:  0.7500000000000001  iou:  0.8
# 3.0938
# Predictions with confidence:  0.7500000000000001  iou:  0.8500000000000001
# 3.0688
# Predictions with confidence:  0.7500000000000001  iou:  0.9000000000000001
# 3.072
# Predictions with confidence:  0.7500000000000001  iou:  0.9500000000000001
# 3.0907
# Predictions with confidence:  0.7500000000000001  iou:  1.0
# 3.1018
# Predictions with confidence:  0.8  iou:  0.05
# 3.075
# Predictions with confidence:  0.8  iou:  0.1
# 3.07
# Predictions with confidence:  0.8  iou:  0.15000000000000002
# 3.0689
# Predictions with confidence:  0.8  iou:  0.2
# 3.0717
# Predictions with confidence:  0.8  iou:  0.25
# 3.0748
# Predictions with confidence:  0.8  iou:  0.3
# 3.0801
# Predictions with confidence:  0.8  iou:  0.35000000000000003
# 3.1039
# Predictions with confidence:  0.8  iou:  0.4
# 3.1027
# Predictions with confidence:  0.8  iou:  0.45
# 3.0655
# Predictions with confidence:  0.8  iou:  0.5
# 3.0945
# Predictions with confidence:  0.8  iou:  0.55
# 3.3278
# Predictions with confidence:  0.8  iou:  0.6000000000000001
# 3.576
# Predictions with confidence:  0.8  iou:  0.6500000000000001
# 3.5762
# Predictions with confidence:  0.8  iou:  0.7000000000000001
# 3.3121
# Predictions with confidence:  0.8  iou:  0.7500000000000001
# 3.3668
# Predictions with confidence:  0.8  iou:  0.8
# 3.1778
# Predictions with confidence:  0.8  iou:  0.8500000000000001
# 3.1808
# Predictions with confidence:  0.8  iou:  0.9000000000000001
# 3.4457
# Predictions with confidence:  0.8  iou:  0.9500000000000001
# 3.2214
# Predictions with confidence:  0.8  iou:  1.0
# 3.5454
# Predictions with confidence:  0.8500000000000001  iou:  0.05
# 3.1287
# Predictions with confidence:  0.8500000000000001  iou:  0.1
# 3.5212
# Predictions with confidence:  0.8500000000000001  iou:  0.15000000000000002
# 3.2244
# Predictions with confidence:  0.8500000000000001  iou:  0.2
# 3.136
# Predictions with confidence:  0.8500000000000001  iou:  0.25
# 3.1189
# Predictions with confidence:  0.8500000000000001  iou:  0.3
# 3.144
# Predictions with confidence:  0.8500000000000001  iou:  0.35000000000000003
# 3.0575
# Predictions with confidence:  0.8500000000000001  iou:  0.4
# 3.0636
# Predictions with confidence:  0.8500000000000001  iou:  0.45
# 3.0683
# Predictions with confidence:  0.8500000000000001  iou:  0.5
# 3.117
# Predictions with confidence:  0.8500000000000001  iou:  0.55
# 3.1242
# Predictions with confidence:  0.8500000000000001  iou:  0.6000000000000001
# 3.3501
# Predictions with confidence:  0.8500000000000001  iou:  0.6500000000000001
# 3.4159
# Predictions with confidence:  0.8500000000000001  iou:  0.7000000000000001
# 3.3094
# Predictions with confidence:  0.8500000000000001  iou:  0.7500000000000001
# 3.241
# Predictions with confidence:  0.8500000000000001  iou:  0.8
# 3.2602
# Predictions with confidence:  0.8500000000000001  iou:  0.8500000000000001
# 3.2921
# Predictions with confidence:  0.8500000000000001  iou:  0.9000000000000001
# 3.2522
# Predictions with confidence:  0.8500000000000001  iou:  0.9500000000000001
# 3.3591
# Predictions with confidence:  0.8500000000000001  iou:  1.0
# 3.3951
# Predictions with confidence:  0.9000000000000001  iou:  0.05
# 3.425
# Predictions with confidence:  0.9000000000000001  iou:  0.1
# 3.2377
# Predictions with confidence:  0.9000000000000001  iou:  0.15000000000000002
# 3.3504
# Predictions with confidence:  0.9000000000000001  iou:  0.2
# 3.3171
# Predictions with confidence:  0.9000000000000001  iou:  0.25
# 3.1828
# Predictions with confidence:  0.9000000000000001  iou:  0.3
# 3.1117
# Predictions with confidence:  0.9000000000000001  iou:  0.35000000000000003
# 3.0536
# Predictions with confidence:  0.9000000000000001  iou:  0.4
# 3.0402
# Predictions with confidence:  0.9000000000000001  iou:  0.45
# 3.0429
# Predictions with confidence:  0.9000000000000001  iou:  0.5
# 3.0672
# Predictions with confidence:  0.9000000000000001  iou:  0.55
# 3.0605
# Predictions with confidence:  0.9000000000000001  iou:  0.6000000000000001
# 3.0498
# Predictions with confidence:  0.9000000000000001  iou:  0.6500000000000001
# 3.0555
# Predictions with confidence:  0.9000000000000001  iou:  0.7000000000000001
# 3.0928
# Predictions with confidence:  0.9000000000000001  iou:  0.7500000000000001
# 3.0981
# Predictions with confidence:  0.9000000000000001  iou:  0.8
# 3.188
# Predictions with confidence:  0.9000000000000001  iou:  0.8500000000000001
# 3.1219
# Predictions with confidence:  0.9000000000000001  iou:  0.9000000000000001
# 3.2905
# Predictions with confidence:  0.9000000000000001  iou:  0.9500000000000001
# 3.1304
# Predictions with confidence:  0.9000000000000001  iou:  1.0
# 3.1178
# Predictions with confidence:  0.9500000000000001  iou:  0.05
# 3.3833
# Predictions with confidence:  0.9500000000000001  iou:  0.1
# 3.2684
# Predictions with confidence:  0.9500000000000001  iou:  0.15000000000000002
# 3.234
# Predictions with confidence:  0.9500000000000001  iou:  0.2
# 3.0802
# Predictions with confidence:  0.9500000000000001  iou:  0.25
# 3.0788
# Predictions with confidence:  0.9500000000000001  iou:  0.3
# 3.1651
# Predictions with confidence:  0.9500000000000001  iou:  0.35000000000000003
# 3.0691
# Predictions with confidence:  0.9500000000000001  iou:  0.4
# 3.0692
# Predictions with confidence:  0.9500000000000001  iou:  0.45
# 3.1747
# Predictions with confidence:  0.9500000000000001  iou:  0.5
# 3.1975
# Predictions with confidence:  0.9500000000000001  iou:  0.55
# 3.0979
# Predictions with confidence:  0.9500000000000001  iou:  0.6000000000000001
# 3.0236
# Predictions with confidence:  0.9500000000000001  iou:  0.6500000000000001
# 3.0351
# Predictions with confidence:  0.9500000000000001  iou:  0.7000000000000001
# 3.0731
# Predictions with confidence:  0.9500000000000001  iou:  0.7500000000000001
# 3.0793
# Predictions with confidence:  0.9500000000000001  iou:  0.8
# 3.1326
# Predictions with confidence:  0.9500000000000001  iou:  0.8500000000000001
# 3.0978
# Predictions with confidence:  0.9500000000000001  iou:  0.9000000000000001
# 3.1181
# Predictions with confidence:  0.9500000000000001  iou:  0.9500000000000001
# 3.1192
# Predictions with confidence:  0.9500000000000001  iou:  1.0
# 3.1208
# Predictions with confidence:  1.0  iou:  0.05
# 3.2826
# Predictions with confidence:  1.0  iou:  0.1
# 3.2671
# Predictions with confidence:  1.0  iou:  0.15000000000000002
# 3.2064
# Predictions with confidence:  1.0  iou:  0.2
# 3.3491
# Predictions with confidence:  1.0  iou:  0.25
# 3.2057
# Predictions with confidence:  1.0  iou:  0.3
# 3.295
# Predictions with confidence:  1.0  iou:  0.35000000000000003
# 3.1101
# Predictions with confidence:  1.0  iou:  0.4
# 3.1831
# Predictions with confidence:  1.0  iou:  0.45
# 3.1896
# Predictions with confidence:  1.0  iou:  0.5
# 3.0427
# Predictions with confidence:  1.0  iou:  0.55
# 3.0385
# Predictions with confidence:  1.0  iou:  0.6000000000000001
# 3.0353
# Predictions with confidence:  1.0  iou:  0.6500000000000001
# 3.0308
# Predictions with confidence:  1.0  iou:  0.7000000000000001
# 3.1409
# Predictions with confidence:  1.0  iou:  0.7500000000000001
# 3.2798
# Predictions with confidence:  1.0  iou:  0.8
# 3.0612
# Predictions with confidence:  1.0  iou:  0.8500000000000001
# 3.0393
# Predictions with confidence:  1.0  iou:  0.9000000000000001
# 3.0391
# Predictions with confidence:  1.0  iou:  0.9500000000000001
# 3.0569
# Predictions with confidence:  1.0  iou:  1.0
# 3.0372

# %% [markdown]
# ## Some predictions with different confidence and iou

# %%
preds = helper.get_coordinates(pred_data.iloc[200]['Predictions'])

# %%
one_pred = helper.normilize_to_pixel(preds, 300, 300)

# %%
helper.show_image_bb(train_img[115], one_pred[115])

# %% [markdown]
# ## Search for optimal parameters by calculating f1 score

# %%
label_training = np.load(path_root + '/label_train.npy')

# %%
# Iterate over all predictions and calculate the metrics
performance = []

for idx_pred in list(range(pred_data.shape[0])):
    print('Calculating metrics for:', idx_pred + 1, 'from:', pred_data.shape[0])
    
    pred = pred_data.iloc[idx_pred]['Predictions']
    pred = helper.get_coordinates(pred)
    confidence = pred_data.iloc[idx_pred]['Conficence']
    iou = pred_data.iloc[idx_pred]['IOU']
    # Calculate metrics
    presicion, recall, f1_score = helper.cal_performance(label_training, pred, False)
    performance.append([confidence, iou, presicion, recall, f1_score])

# Create DataFrame with all metrics
columns = ['Confidence', 'IOU', 'Presicion', 'Recall', 'F1 score']
performance_frame = pd.DataFrame(np.array(performance), columns=columns)
# Out:
# Calculating metrics for: 1 from: 400
# Calculating metrics for: 2 from: 400
# Calculating metrics for: 3 from: 400
# Calculating metrics for: 4 from: 400
# Calculating metrics for: 5 from: 400
# Calculating metrics for: 6 from: 400
# Calculating metrics for: 7 from: 400
# Calculating metrics for: 8 from: 400
# Calculating metrics for: 9 from: 400
# Calculating metrics for: 10 from: 400
# Calculating metrics for: 11 from: 400
# Calculating metrics for: 12 from: 400
# Calculating metrics for: 13 from: 400
# Calculating metrics for: 14 from: 400
# Calculating metrics for: 15 from: 400
# Calculating metrics for: 16 from: 400
# Calculating metrics for: 17 from: 400
# Calculating metrics for: 18 from: 400
# Calculating metrics for: 19 from: 400
# Calculating metrics for: 20 from: 400
# Calculating metrics for: 21 from: 400
# Calculating metrics for: 22 from: 400
# Calculating metrics for: 23 from: 400
# Calculating metrics for: 24 from: 400
# Calculating metrics for: 25 from: 400
# Calculating metrics for: 26 from: 400
# Calculating metrics for: 27 from: 400
# Calculating metrics for: 28 from: 400
# Calculating metrics for: 29 from: 400
# Calculating metrics for: 30 from: 400
# Calculating metrics for: 31 from: 400
# Calculating metrics for: 32 from: 400
# Calculating metrics for: 33 from: 400
# Calculating metrics for: 34 from: 400
# Calculating metrics for: 35 from: 400
# Calculating metrics for: 36 from: 400
# Calculating metrics for: 37 from: 400
# Calculating metrics for: 38 from: 400
# Calculating metrics for: 39 from: 400
# Calculating metrics for: 40 from: 400
# Calculating metrics for: 41 from: 400
# Calculating metrics for: 42 from: 400
# Calculating metrics for: 43 from: 400
# Calculating metrics for: 44 from: 400
# Calculating metrics for: 45 from: 400
# Calculating metrics for: 46 from: 400
# Calculating metrics for: 47 from: 400
# Calculating metrics for: 48 from: 400
# Calculating metrics for: 49 from: 400
# Calculating metrics for: 50 from: 400
# Calculating metrics for: 51 from: 400
# Calculating metrics for: 52 from: 400
# Calculating metrics for: 53 from: 400
# Calculating metrics for: 54 from: 400
# Calculating metrics for: 55 from: 400
# Calculating metrics for: 56 from: 400
# Calculating metrics for: 57 from: 400
# Calculating metrics for: 58 from: 400
# Calculating metrics for: 59 from: 400
# Calculating metrics for: 60 from: 400
# Calculating metrics for: 61 from: 400
# Calculating metrics for: 62 from: 400
# Calculating metrics for: 63 from: 400
# Calculating metrics for: 64 from: 400
# Calculating metrics for: 65 from: 400
# Calculating metrics for: 66 from: 400
# Calculating metrics for: 67 from: 400
# Calculating metrics for: 68 from: 400
# Calculating metrics for: 69 from: 400
# Calculating metrics for: 70 from: 400
# Calculating metrics for: 71 from: 400
# Calculating metrics for: 72 from: 400
# Calculating metrics for: 73 from: 400
# Calculating metrics for: 74 from: 400
# Calculating metrics for: 75 from: 400
# Calculating metrics for: 76 from: 400
# Calculating metrics for: 77 from: 400
# Calculating metrics for: 78 from: 400
# Calculating metrics for: 79 from: 400
# Calculating metrics for: 80 from: 400
# Calculating metrics for: 81 from: 400
# Calculating metrics for: 82 from: 400
# Calculating metrics for: 83 from: 400
# Calculating metrics for: 84 from: 400
# Calculating metrics for: 85 from: 400
# Calculating metrics for: 86 from: 400
# Calculating metrics for: 87 from: 400
# Calculating metrics for: 88 from: 400
# Calculating metrics for: 89 from: 400
# Calculating metrics for: 90 from: 400
# Calculating metrics for: 91 from: 400
# Calculating metrics for: 92 from: 400
# Calculating metrics for: 93 from: 400
# Calculating metrics for: 94 from: 400
# Calculating metrics for: 95 from: 400
# Calculating metrics for: 96 from: 400
# Calculating metrics for: 97 from: 400
# Calculating metrics for: 98 from: 400
# Calculating metrics for: 99 from: 400
# Calculating metrics for: 100 from: 400
# Calculating metrics for: 101 from: 400
# Calculating metrics for: 102 from: 400
# Calculating metrics for: 103 from: 400
# Calculating metrics for: 104 from: 400
# Calculating metrics for: 105 from: 400
# Calculating metrics for: 106 from: 400
# Calculating metrics for: 107 from: 400
# Calculating metrics for: 108 from: 400
# Calculating metrics for: 109 from: 400
# Calculating metrics for: 110 from: 400
# Calculating metrics for: 111 from: 400
# Calculating metrics for: 112 from: 400
# Calculating metrics for: 113 from: 400
# Calculating metrics for: 114 from: 400
# Calculating metrics for: 115 from: 400
# Calculating metrics for: 116 from: 400
# Calculating metrics for: 117 from: 400
# Calculating metrics for: 118 from: 400
# Calculating metrics for: 119 from: 400
# Calculating metrics for: 120 from: 400
# Calculating metrics for: 121 from: 400
# Calculating metrics for: 122 from: 400
# Calculating metrics for: 123 from: 400
# Calculating metrics for: 124 from: 400
# Calculating metrics for: 125 from: 400
# Calculating metrics for: 126 from: 400
# Calculating metrics for: 127 from: 400
# Calculating metrics for: 128 from: 400
# Calculating metrics for: 129 from: 400
# Calculating metrics for: 130 from: 400
# Calculating metrics for: 131 from: 400
# Calculating metrics for: 132 from: 400
# Calculating metrics for: 133 from: 400
# Calculating metrics for: 134 from: 400
# Calculating metrics for: 135 from: 400
# Calculating metrics for: 136 from: 400
# Calculating metrics for: 137 from: 400
# Calculating metrics for: 138 from: 400
# Calculating metrics for: 139 from: 400
# Calculating metrics for: 140 from: 400
# Calculating metrics for: 141 from: 400
# Calculating metrics for: 142 from: 400
# Calculating metrics for: 143 from: 400
# Calculating metrics for: 144 from: 400
# Calculating metrics for: 145 from: 400
# Calculating metrics for: 146 from: 400
# Calculating metrics for: 147 from: 400
# Calculating metrics for: 148 from: 400
# Calculating metrics for: 149 from: 400
# Calculating metrics for: 150 from: 400
# Calculating metrics for: 151 from: 400
# Calculating metrics for: 152 from: 400
# Calculating metrics for: 153 from: 400
# Calculating metrics for: 154 from: 400
# Calculating metrics for: 155 from: 400
# Calculating metrics for: 156 from: 400
# Calculating metrics for: 157 from: 400
# Calculating metrics for: 158 from: 400
# Calculating metrics for: 159 from: 400
# Calculating metrics for: 160 from: 400
# Calculating metrics for: 161 from: 400
# Calculating metrics for: 162 from: 400
# Calculating metrics for: 163 from: 400
# Calculating metrics for: 164 from: 400
# Calculating metrics for: 165 from: 400
# Calculating metrics for: 166 from: 400
# Calculating metrics for: 167 from: 400
# Calculating metrics for: 168 from: 400
# Calculating metrics for: 169 from: 400
# Calculating metrics for: 170 from: 400
# Calculating metrics for: 171 from: 400
# Calculating metrics for: 172 from: 400
# Calculating metrics for: 173 from: 400
# Calculating metrics for: 174 from: 400
# Calculating metrics for: 175 from: 400
# Calculating metrics for: 176 from: 400
# Calculating metrics for: 177 from: 400
# Calculating metrics for: 178 from: 400
# Calculating metrics for: 179 from: 400
# Calculating metrics for: 180 from: 400
# Calculating metrics for: 181 from: 400
# Calculating metrics for: 182 from: 400
# Calculating metrics for: 183 from: 400
# Calculating metrics for: 184 from: 400
# Calculating metrics for: 185 from: 400
# Calculating metrics for: 186 from: 400
# Calculating metrics for: 187 from: 400
# Calculating metrics for: 188 from: 400
# Calculating metrics for: 189 from: 400
# Calculating metrics for: 190 from: 400
# Calculating metrics for: 191 from: 400
# Calculating metrics for: 192 from: 400
# Calculating metrics for: 193 from: 400
# Calculating metrics for: 194 from: 400
# Calculating metrics for: 195 from: 400
# Calculating metrics for: 196 from: 400
# Calculating metrics for: 197 from: 400
# Calculating metrics for: 198 from: 400
# Calculating metrics for: 199 from: 400
# Calculating metrics for: 200 from: 400
# Calculating metrics for: 201 from: 400
# Calculating metrics for: 202 from: 400
# Calculating metrics for: 203 from: 400
# Calculating metrics for: 204 from: 400
# Calculating metrics for: 205 from: 400
# Calculating metrics for: 206 from: 400
# Calculating metrics for: 207 from: 400
# Calculating metrics for: 208 from: 400
# Calculating metrics for: 209 from: 400
# Calculating metrics for: 210 from: 400
# Calculating metrics for: 211 from: 400
# Calculating metrics for: 212 from: 400
# Calculating metrics for: 213 from: 400
# Calculating metrics for: 214 from: 400
# Calculating metrics for: 215 from: 400
# Calculating metrics for: 216 from: 400
# Calculating metrics for: 217 from: 400
# Calculating metrics for: 218 from: 400
# Calculating metrics for: 219 from: 400
# Calculating metrics for: 220 from: 400
# Calculating metrics for: 221 from: 400
# Calculating metrics for: 222 from: 400
# Calculating metrics for: 223 from: 400
# Calculating metrics for: 224 from: 400
# Calculating metrics for: 225 from: 400
# Calculating metrics for: 226 from: 400
# Calculating metrics for: 227 from: 400
# Calculating metrics for: 228 from: 400
# Calculating metrics for: 229 from: 400
# Calculating metrics for: 230 from: 400
# Calculating metrics for: 231 from: 400
# Calculating metrics for: 232 from: 400
# Calculating metrics for: 233 from: 400
# Calculating metrics for: 234 from: 400
# Calculating metrics for: 235 from: 400
# Calculating metrics for: 236 from: 400
# Calculating metrics for: 237 from: 400
# Calculating metrics for: 238 from: 400
# Calculating metrics for: 239 from: 400
# Calculating metrics for: 240 from: 400
# Calculating metrics for: 241 from: 400
# Calculating metrics for: 242 from: 400
# Calculating metrics for: 243 from: 400
# Calculating metrics for: 244 from: 400
# Calculating metrics for: 245 from: 400
# Calculating metrics for: 246 from: 400
# Calculating metrics for: 247 from: 400
# Calculating metrics for: 248 from: 400
# Calculating metrics for: 249 from: 400
# Calculating metrics for: 250 from: 400
# Calculating metrics for: 251 from: 400
# Calculating metrics for: 252 from: 400
# Calculating metrics for: 253 from: 400
# Calculating metrics for: 254 from: 400
# Calculating metrics for: 255 from: 400
# Calculating metrics for: 256 from: 400
# Calculating metrics for: 257 from: 400
# Calculating metrics for: 258 from: 400
# Calculating metrics for: 259 from: 400
# Calculating metrics for: 260 from: 400
# Calculating metrics for: 261 from: 400
# Calculating metrics for: 262 from: 400
# Calculating metrics for: 263 from: 400
# Calculating metrics for: 264 from: 400
# Calculating metrics for: 265 from: 400
# Calculating metrics for: 266 from: 400
# Calculating metrics for: 267 from: 400
# Calculating metrics for: 268 from: 400
# Calculating metrics for: 269 from: 400
# Calculating metrics for: 270 from: 400
# Calculating metrics for: 271 from: 400
# Calculating metrics for: 272 from: 400
# Calculating metrics for: 273 from: 400
# Calculating metrics for: 274 from: 400
# Calculating metrics for: 275 from: 400
# Calculating metrics for: 276 from: 400
# Calculating metrics for: 277 from: 400
# Calculating metrics for: 278 from: 400
# Calculating metrics for: 279 from: 400
# Calculating metrics for: 280 from: 400
# Calculating metrics for: 281 from: 400
# Calculating metrics for: 282 from: 400
# Calculating metrics for: 283 from: 400
# Calculating metrics for: 284 from: 400
# Calculating metrics for: 285 from: 400
# Calculating metrics for: 286 from: 400
# Calculating metrics for: 287 from: 400
# Calculating metrics for: 288 from: 400
# Calculating metrics for: 289 from: 400
# Calculating metrics for: 290 from: 400
# Calculating metrics for: 291 from: 400
# Calculating metrics for: 292 from: 400
# Calculating metrics for: 293 from: 400
# Calculating metrics for: 294 from: 400
# Calculating metrics for: 295 from: 400
# Calculating metrics for: 296 from: 400
# Calculating metrics for: 297 from: 400
# Calculating metrics for: 298 from: 400
# Calculating metrics for: 299 from: 400
# Calculating metrics for: 300 from: 400
# Calculating metrics for: 301 from: 400
# Calculating metrics for: 302 from: 400
# Calculating metrics for: 303 from: 400
# Calculating metrics for: 304 from: 400
# Calculating metrics for: 305 from: 400
# Calculating metrics for: 306 from: 400
# Calculating metrics for: 307 from: 400
# Calculating metrics for: 308 from: 400
# Calculating metrics for: 309 from: 400
# Calculating metrics for: 310 from: 400
# Calculating metrics for: 311 from: 400
# Calculating metrics for: 312 from: 400
# Calculating metrics for: 313 from: 400
# Calculating metrics for: 314 from: 400
# Calculating metrics for: 315 from: 400
# Calculating metrics for: 316 from: 400
# Calculating metrics for: 317 from: 400
# Calculating metrics for: 318 from: 400
# Calculating metrics for: 319 from: 400
# Calculating metrics for: 320 from: 400
# Calculating metrics for: 321 from: 400
# Calculating metrics for: 322 from: 400
# Calculating metrics for: 323 from: 400
# Calculating metrics for: 324 from: 400
# Calculating metrics for: 325 from: 400
# Calculating metrics for: 326 from: 400
# Calculating metrics for: 327 from: 400
# Calculating metrics for: 328 from: 400
# Calculating metrics for: 329 from: 400
# Calculating metrics for: 330 from: 400
# Calculating metrics for: 331 from: 400
# Calculating metrics for: 332 from: 400
# Calculating metrics for: 333 from: 400
# Calculating metrics for: 334 from: 400
# Calculating metrics for: 335 from: 400
# Calculating metrics for: 336 from: 400
# Calculating metrics for: 337 from: 400
# Calculating metrics for: 338 from: 400
# Calculating metrics for: 339 from: 400
# Calculating metrics for: 340 from: 400
# Calculating metrics for: 341 from: 400
# Calculating metrics for: 342 from: 400
# Calculating metrics for: 343 from: 400
# Calculating metrics for: 344 from: 400
# Calculating metrics for: 345 from: 400
# Calculating metrics for: 346 from: 400
# Calculating metrics for: 347 from: 400
# Calculating metrics for: 348 from: 400
# Calculating metrics for: 349 from: 400
# Calculating metrics for: 350 from: 400
# Calculating metrics for: 351 from: 400
# Calculating metrics for: 352 from: 400
# Calculating metrics for: 353 from: 400
# Calculating metrics for: 354 from: 400
# Calculating metrics for: 355 from: 400
# Calculating metrics for: 356 from: 400
# Calculating metrics for: 357 from: 400
# Calculating metrics for: 358 from: 400
# Calculating metrics for: 359 from: 400
# Calculating metrics for: 360 from: 400
# Calculating metrics for: 361 from: 400
# Calculating metrics for: 362 from: 400
# Calculating metrics for: 363 from: 400
# Calculating metrics for: 364 from: 400
# Calculating metrics for: 365 from: 400
# Calculating metrics for: 366 from: 400
# Calculating metrics for: 367 from: 400
# Calculating metrics for: 368 from: 400
# Calculating metrics for: 369 from: 400
# Calculating metrics for: 370 from: 400
# Calculating metrics for: 371 from: 400
# Calculating metrics for: 372 from: 400
# Calculating metrics for: 373 from: 400
# Calculating metrics for: 374 from: 400
# Calculating metrics for: 375 from: 400
# Calculating metrics for: 376 from: 400
# Calculating metrics for: 377 from: 400
# Calculating metrics for: 378 from: 400
# Calculating metrics for: 379 from: 400
# Calculating metrics for: 380 from: 400
# Calculating metrics for: 381 from: 400
# Calculating metrics for: 382 from: 400
# Calculating metrics for: 383 from: 400
# Calculating metrics for: 384 from: 400
# Calculating metrics for: 385 from: 400
# Calculating metrics for: 386 from: 400
# Calculating metrics for: 387 from: 400
# Calculating metrics for: 388 from: 400
# Calculating metrics for: 389 from: 400
# Calculating metrics for: 390 from: 400
# Calculating metrics for: 391 from: 400
# Calculating metrics for: 392 from: 400
# Calculating metrics for: 393 from: 400
# Calculating metrics for: 394 from: 400
# Calculating metrics for: 395 from: 400
# Calculating metrics for: 396 from: 400
# Calculating metrics for: 397 from: 400
# Calculating metrics for: 398 from: 400
# Calculating metrics for: 399 from: 400
# Calculating metrics for: 400 from: 400

# %%
performance_frame.head()
# Out:
#    Confidence   IOU  Presicion    Recall  F1 score
# 0        0.05  0.05   0.397097  0.623638  0.485229
# 1        0.05  0.10   0.360359  0.638662  0.460746
# 2        0.05  0.15   0.334764  0.647754  0.441406
# 3        0.05  0.20   0.314244  0.654105  0.424534
# 4        0.05  0.25   0.304303  0.660198  0.416589

# %%
performance_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
# Confidence    400 non-null float64
# IOU           400 non-null float64
# Presicion     400 non-null float64
# Recall        400 non-null float64
# F1 score      400 non-null float64
# dtypes: float64(5)
# memory usage: 15.7 KB

# %%
performance_frame.describe()
# Out:
#        Confidence         IOU   Presicion      Recall    F1 score
# count  400.000000  400.000000  400.000000  400.000000  400.000000
# mean     0.525000    0.525000    0.704730    0.458455    0.532139
# std      0.288675    0.288675    0.197930    0.164739    0.148093
# min      0.050000    0.050000    0.000000    0.000000    0.000000
# 25%      0.287500    0.287500    0.703959    0.365917    0.490686
# 50%      0.525000    0.525000    0.769084    0.476223    0.573773
# 75%      0.762500    0.762500    0.808078    0.587246    0.635358
# max      1.000000    1.000000    0.868011    0.744673    0.696716

# %%
print(performance_frame.iloc[performance_frame['Presicion'].argmax()], end='\n\n')
print(performance_frame.iloc[performance_frame['Recall'].argmax()], end='\n\n')
print(performance_frame.iloc[performance_frame['F1 score'].argmax()], end='\n\n')
# Out:
# Confidence    0.950000
# IOU           1.000000
# Presicion     0.868011
# Recall        0.227327
# F1 score      0.360295
# Name: 379, dtype: float64
#
# Confidence    0.050000
# IOU           1.000000
# Presicion     0.457112
# Recall        0.744673
# F1 score      0.566489
# Name: 19, dtype: float64
#
# Confidence    0.150000
# IOU           1.000000
# Presicion     0.714720
# Recall        0.679596
# F1 score      0.696716
# Name: 59, dtype: float64
# /home/aldo/anaconda3/envs/test2/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# /home/aldo/anaconda3/envs/test2/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#
# /home/aldo/anaconda3/envs/test2/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(performance_frame.iloc[performance_frame['Presicion'].argmax()], end='\n\n')
print(performance_frame.iloc[performance_frame['Recall'].argmax()], end='\n\n')
print(performance_frame.iloc[performance_frame['F1 score'].argmax()], end='\n\n')
# Out:
# Confidence    0.950000
# IOU           1.000000
# Presicion     0.868011
# Recall        0.227327
# F1 score      0.360295
# Name: 379, dtype: float64
#
# Confidence    0.050000
# IOU           1.000000
# Presicion     0.457112
# Recall        0.744673
# F1 score      0.566489
# Name: 19, dtype: float64
#
# Confidence    0.150000
# IOU           1.000000
# Presicion     0.714720
# Recall        0.679596
# F1 score      0.696716
# Name: 59, dtype: float64
# /home/aldo/anaconda3/envs/test2/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# /home/aldo/anaconda3/envs/test2/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#
# /home/aldo/anaconda3/envs/test2/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import seaborn as sns
presicion = performance_frame['Presicion']
recall =  performance_frame['Recall']
f1_score = performance_frame['F1 score']
iou = performance_frame['IOU']
confidence = performance_frame['Confidence']

fig = plt.figure(figsize=(18,6))

# fig = plt.figure()
ax = fig.add_subplot(131, projection='3d')
ax.scatter(iou, confidence, presicion, c=presicion, cmap='coolwarm', linewidth=1.0)
ax.set_zlim(0, 1)
ax.set_xlabel('IOU')
ax.set_ylabel('Confidence')
ax.set_zlabel('Presicion')
ax.view_init(30, 15)
# ax.plot_trisurf(iou, confidence, f1_score)

ax = fig.add_subplot(132, projection='3d')
ax.scatter(iou, confidence, recall, c=recall, cmap='coolwarm', linewidth=1.0)
ax.set_zlim(0, 1)
ax.set_xlabel('IOU')
ax.set_ylabel('Confidence')
ax.set_zlabel('Recall')
ax.view_init(30, 15)


ax = fig.add_subplot(133, projection='3d')
ax.scatter(iou, confidence, f1_score, c=f1_score, cmap='coolwarm', linewidth=1.0)
ax.set_zlim(0, 1)
ax.set_xlabel('IOU')
ax.set_ylabel('Confidence')
ax.set_zlabel('F1 score')
ax.view_init(30, 15)


fig.tight_layout()
