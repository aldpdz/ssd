# %%
# libraries
import os
import json
import numpy as np
import pandas as pd
from extra_files import helper as hp
from imageio import imwrite, imread
from skimage.transform import resize

# %%
# File paths
data_path = '/home/aldo/Documents/data-cic/'
preprocess_path = data_path + 'preprocess_data'

# %% [markdown]
# ## Training SSDLite300

# %%
from keras.optimizers import Adam, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssdlite320_coordconv import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

from extra_files.f1_callback import F1_callback as f1_call
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /home/aldo/Documents/ssd/data_generator/object_detection_2d_data_generator.py:43: UserWarning: 'BeautifulSoup' module is missing. The XML-parser will be unavailable.
#   warnings.warn("'BeautifulSoup' module is missing. The XML-parser will be unavailable.")

# %% [markdown]
# ### Parameters (original SSD300 architecture)

# %%
## Parameteres needed for ssd_300() and SSDInputEncoder()

img_height = 320 # Height of the model input images
img_width = 320 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [-1., -1., -1.] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
divide_by_stddev = [127.5, 127.5, 127.5]
swap_channels = False # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 1 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
new_scales = [0.15, 0.33, 0.47, 0.61, 0.76, 0.90, 1.05]
scales = new_scales
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [16, 32, 64, 107, 160, 320] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %% [markdown]
# ## Create new model with SSD weights

# %%
# 1: Build the Keras model.

# K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                divide_by_stddev=divide_by_stddev,
                swap_channels=swap_channels)

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load.
# weights_path = '../weights/models/ssdlite320_mobilenetv1/ssdlite320_mobilenetv1_pascal.h5'
# model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

# rmsprop = RMSprop(lr=0.001)
adam = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
# sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 320, 320, 3)  0
# __________________________________________________________________________________________________
# identity_layer (Lambda)         (None, 320, 320, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# input_stddev_normalization (Lam (None, 320, 320, 3)  0           identity_layer[0][0]
# __________________________________________________________________________________________________
# input_mean_normalization (Lambd (None, 320, 320, 3)  0           input_stddev_normalization[0][0]
# __________________________________________________________________________________________________
# input_coord_conv (Lambda)       (None, 320, 320, 5)  0           input_mean_normalization[0][0]
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 322, 322, 5)  0           input_coord_conv[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 160, 160, 32) 1440        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 160, 160, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 160, 160, 32) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# mobl0_conv_expand (Conv2D)      (None, 160, 160, 32) 1024        conv1_relu[0][0]
# __________________________________________________________________________________________________
# bn0_conv_bn_expand (BatchNormal (None, 160, 160, 32) 128         mobl0_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_0_relu (Activation)        (None, 160, 160, 32) 0           bn0_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl0_conv_depthwise (Depthwise (None, 160, 160, 32) 288         conv_0_relu[0][0]
# __________________________________________________________________________________________________
# bn0_conv_depthwise (BatchNormal (None, 160, 160, 32) 128         mobl0_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_0_relu (Activation)     (None, 160, 160, 32) 0           bn0_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl0_conv_project (Conv2D)     (None, 160, 160, 16) 512         conv_dw_0_relu[0][0]
# __________________________________________________________________________________________________
# bn0_conv_bn_project (BatchNorma (None, 160, 160, 16) 64          mobl0_conv_project[0][0]
# __________________________________________________________________________________________________
# mobl1_conv_expand (Conv2D)      (None, 160, 160, 96) 1536        bn0_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# bn1_conv_bn_expand (BatchNormal (None, 160, 160, 96) 384         mobl1_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_1_relu (Activation)        (None, 160, 160, 96) 0           bn1_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl1_conv_depthwise (Depthwise (None, 80, 80, 96)   864         conv_1_relu[0][0]
# __________________________________________________________________________________________________
# bn1_conv_depthwise (BatchNormal (None, 80, 80, 96)   384         mobl1_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_relu (Activation)     (None, 80, 80, 96)   0           bn1_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl1_conv_project (Conv2D)     (None, 80, 80, 24)   2304        conv_dw_1_relu[0][0]
# __________________________________________________________________________________________________
# bn1_conv_bn_project (BatchNorma (None, 80, 80, 24)   96          mobl1_conv_project[0][0]
# __________________________________________________________________________________________________
# mobl2_conv_expand (Conv2D)      (None, 80, 80, 144)  3456        bn1_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# bn2_conv_bn_expand (BatchNormal (None, 80, 80, 144)  576         mobl2_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_2_relu (Activation)        (None, 80, 80, 144)  0           bn2_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl2_conv_depthwise (Depthwise (None, 80, 80, 144)  1296        conv_2_relu[0][0]
# __________________________________________________________________________________________________
# bn2_conv_depthwise (BatchNormal (None, 80, 80, 144)  576         mobl2_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_relu (Activation)     (None, 80, 80, 144)  0           bn2_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl2_conv_project (Conv2D)     (None, 80, 80, 24)   3456        conv_dw_2_relu[0][0]
# __________________________________________________________________________________________________
# bn2_conv_bn_project (BatchNorma (None, 80, 80, 24)   96          mobl2_conv_project[0][0]
# __________________________________________________________________________________________________
# res_connect_2 (Add)             (None, 80, 80, 24)   0           bn1_conv_bn_project[0][0]
#                                                                  bn2_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# mobl3_conv_expand (Conv2D)      (None, 80, 80, 144)  3456        res_connect_2[0][0]
# __________________________________________________________________________________________________
# bn3_conv_bn_expand (BatchNormal (None, 80, 80, 144)  576         mobl3_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_3_relu (Activation)        (None, 80, 80, 144)  0           bn3_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl3_conv_depthwise (Depthwise (None, 40, 40, 144)  1296        conv_3_relu[0][0]
# __________________________________________________________________________________________________
# bn3_conv_depthwise (BatchNormal (None, 40, 40, 144)  576         mobl3_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_relu (Activation)     (None, 40, 40, 144)  0           bn3_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl3_conv_project (Conv2D)     (None, 40, 40, 32)   4608        conv_dw_3_relu[0][0]
# __________________________________________________________________________________________________
# bn3_conv_bn_project (BatchNorma (None, 40, 40, 32)   128         mobl3_conv_project[0][0]
# __________________________________________________________________________________________________
# mobl4_conv_expand (Conv2D)      (None, 40, 40, 192)  6144        bn3_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# bn4_conv_bn_expand (BatchNormal (None, 40, 40, 192)  768         mobl4_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_4_relu (Activation)        (None, 40, 40, 192)  0           bn4_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl4_conv_depthwise (Depthwise (None, 40, 40, 192)  1728        conv_4_relu[0][0]
# __________________________________________________________________________________________________
# bn4_conv_depthwise (BatchNormal (None, 40, 40, 192)  768         mobl4_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_relu (Activation)     (None, 40, 40, 192)  0           bn4_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl4_conv_project (Conv2D)     (None, 40, 40, 32)   6144        conv_dw_4_relu[0][0]
# __________________________________________________________________________________________________
# bn4_conv_bn_project (BatchNorma (None, 40, 40, 32)   128         mobl4_conv_project[0][0]
# __________________________________________________________________________________________________
# res_connect_4 (Add)             (None, 40, 40, 32)   0           bn3_conv_bn_project[0][0]
#                                                                  bn4_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# mobl5_conv_expand (Conv2D)      (None, 40, 40, 192)  6144        res_connect_4[0][0]
# __________________________________________________________________________________________________
# bn5_conv_bn_expand (BatchNormal (None, 40, 40, 192)  768         mobl5_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_5_relu (Activation)        (None, 40, 40, 192)  0           bn5_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl5_conv_depthwise (Depthwise (None, 40, 40, 192)  1728        conv_5_relu[0][0]
# __________________________________________________________________________________________________
# bn5_conv_depthwise (BatchNormal (None, 40, 40, 192)  768         mobl5_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_relu (Activation)     (None, 40, 40, 192)  0           bn5_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl5_conv_project (Conv2D)     (None, 40, 40, 32)   6144        conv_dw_5_relu[0][0]
# __________________________________________________________________________________________________
# bn5_conv_bn_project (BatchNorma (None, 40, 40, 32)   128         mobl5_conv_project[0][0]
# __________________________________________________________________________________________________
# res_connect_5 (Add)             (None, 40, 40, 32)   0           res_connect_4[0][0]
#                                                                  bn5_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# mobl6_conv_expand (Conv2D)      (None, 40, 40, 192)  6144        res_connect_5[0][0]
# __________________________________________________________________________________________________
# bn6_conv_bn_expand (BatchNormal (None, 40, 40, 192)  768         mobl6_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_6_relu (Activation)        (None, 40, 40, 192)  0           bn6_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl6_conv_depthwise (Depthwise (None, 20, 20, 192)  1728        conv_6_relu[0][0]
# __________________________________________________________________________________________________
# bn6_conv_depthwise (BatchNormal (None, 20, 20, 192)  768         mobl6_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_relu (Activation)     (None, 20, 20, 192)  0           bn6_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl6_conv_project (Conv2D)     (None, 20, 20, 64)   12288       conv_dw_6_relu[0][0]
# __________________________________________________________________________________________________
# bn6_conv_bn_project (BatchNorma (None, 20, 20, 64)   256         mobl6_conv_project[0][0]
# __________________________________________________________________________________________________
# mobl7_conv_expand (Conv2D)      (None, 20, 20, 384)  24576       bn6_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# bn7_conv_bn_expand (BatchNormal (None, 20, 20, 384)  1536        mobl7_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_7_relu (Activation)        (None, 20, 20, 384)  0           bn7_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl7_conv_depthwise (Depthwise (None, 20, 20, 384)  3456        conv_7_relu[0][0]
# __________________________________________________________________________________________________
# bn7_conv_depthwise (BatchNormal (None, 20, 20, 384)  1536        mobl7_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_relu (Activation)     (None, 20, 20, 384)  0           bn7_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl7_conv_project (Conv2D)     (None, 20, 20, 64)   24576       conv_dw_7_relu[0][0]
# __________________________________________________________________________________________________
# bn7_conv_bn_project (BatchNorma (None, 20, 20, 64)   256         mobl7_conv_project[0][0]
# __________________________________________________________________________________________________
# res_connect_7 (Add)             (None, 20, 20, 64)   0           bn6_conv_bn_project[0][0]
#                                                                  bn7_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# mobl8_conv_expand (Conv2D)      (None, 20, 20, 384)  24576       res_connect_7[0][0]
# __________________________________________________________________________________________________
# bn8_conv_bn_expand (BatchNormal (None, 20, 20, 384)  1536        mobl8_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_8_relu (Activation)        (None, 20, 20, 384)  0           bn8_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl8_conv_depthwise (Depthwise (None, 20, 20, 384)  3456        conv_8_relu[0][0]
# __________________________________________________________________________________________________
# bn8_conv_depthwise (BatchNormal (None, 20, 20, 384)  1536        mobl8_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_relu (Activation)     (None, 20, 20, 384)  0           bn8_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl8_conv_project (Conv2D)     (None, 20, 20, 64)   24576       conv_dw_8_relu[0][0]
# __________________________________________________________________________________________________
# bn8_conv_bn_project (BatchNorma (None, 20, 20, 64)   256         mobl8_conv_project[0][0]
# __________________________________________________________________________________________________
# res_connect_8 (Add)             (None, 20, 20, 64)   0           res_connect_7[0][0]
#                                                                  bn8_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# mobl9_conv_expand (Conv2D)      (None, 20, 20, 384)  24576       res_connect_8[0][0]
# __________________________________________________________________________________________________
# bn9_conv_bn_expand (BatchNormal (None, 20, 20, 384)  1536        mobl9_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_9_relu (Activation)        (None, 20, 20, 384)  0           bn9_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl9_conv_depthwise (Depthwise (None, 20, 20, 384)  3456        conv_9_relu[0][0]
# __________________________________________________________________________________________________
# bn9_conv_depthwise (BatchNormal (None, 20, 20, 384)  1536        mobl9_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_relu (Activation)     (None, 20, 20, 384)  0           bn9_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl9_conv_project (Conv2D)     (None, 20, 20, 64)   24576       conv_dw_9_relu[0][0]
# __________________________________________________________________________________________________
# bn9_conv_bn_project (BatchNorma (None, 20, 20, 64)   256         mobl9_conv_project[0][0]
# __________________________________________________________________________________________________
# res_connect_9 (Add)             (None, 20, 20, 64)   0           res_connect_8[0][0]
#                                                                  bn9_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# mobl10_conv_expand (Conv2D)     (None, 20, 20, 384)  24576       res_connect_9[0][0]
# __________________________________________________________________________________________________
# bn10_conv_bn_expand (BatchNorma (None, 20, 20, 384)  1536        mobl10_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_10_relu (Activation)       (None, 20, 20, 384)  0           bn10_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl10_conv_depthwise (Depthwis (None, 20, 20, 384)  3456        conv_10_relu[0][0]
# __________________________________________________________________________________________________
# bn10_conv_depthwise (BatchNorma (None, 20, 20, 384)  1536        mobl10_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_relu (Activation)    (None, 20, 20, 384)  0           bn10_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl10_conv_project (Conv2D)    (None, 20, 20, 96)   36864       conv_dw_10_relu[0][0]
# __________________________________________________________________________________________________
# bn10_conv_bn_project (BatchNorm (None, 20, 20, 96)   384         mobl10_conv_project[0][0]
# __________________________________________________________________________________________________
# mobl11_conv_expand (Conv2D)     (None, 20, 20, 576)  55296       bn10_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# bn11_conv_bn_expand (BatchNorma (None, 20, 20, 576)  2304        mobl11_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_11_relu (Activation)       (None, 20, 20, 576)  0           bn11_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl11_conv_depthwise (Depthwis (None, 20, 20, 576)  5184        conv_11_relu[0][0]
# __________________________________________________________________________________________________
# bn11_conv_depthwise (BatchNorma (None, 20, 20, 576)  2304        mobl11_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_relu (Activation)    (None, 20, 20, 576)  0           bn11_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl11_conv_project (Conv2D)    (None, 20, 20, 96)   55296       conv_dw_11_relu[0][0]
# __________________________________________________________________________________________________
# bn11_conv_bn_project (BatchNorm (None, 20, 20, 96)   384         mobl11_conv_project[0][0]
# __________________________________________________________________________________________________
# res_connect_11 (Add)            (None, 20, 20, 96)   0           bn10_conv_bn_project[0][0]
#                                                                  bn11_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# mobl12_conv_expand (Conv2D)     (None, 20, 20, 576)  55296       res_connect_11[0][0]
# __________________________________________________________________________________________________
# bn12_conv_bn_expand (BatchNorma (None, 20, 20, 576)  2304        mobl12_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_12_relu (Activation)       (None, 20, 20, 576)  0           bn12_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl12_conv_depthwise (Depthwis (None, 20, 20, 576)  5184        conv_12_relu[0][0]
# __________________________________________________________________________________________________
# bn12_conv_depthwise (BatchNorma (None, 20, 20, 576)  2304        mobl12_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_relu (Activation)    (None, 20, 20, 576)  0           bn12_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl12_conv_project (Conv2D)    (None, 20, 20, 96)   55296       conv_dw_12_relu[0][0]
# __________________________________________________________________________________________________
# bn12_conv_bn_project (BatchNorm (None, 20, 20, 96)   384         mobl12_conv_project[0][0]
# __________________________________________________________________________________________________
# res_connect_12 (Add)            (None, 20, 20, 96)   0           res_connect_11[0][0]
#                                                                  bn12_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# mobl13_conv_expand (Conv2D)     (None, 20, 20, 576)  55296       res_connect_12[0][0]
# __________________________________________________________________________________________________
# bn13_conv_bn_expand (BatchNorma (None, 20, 20, 576)  2304        mobl13_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_13_relu (Activation)       (None, 20, 20, 576)  0           bn13_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl13_conv_depthwise (Depthwis (None, 20, 20, 576)  5184        conv_13_relu[0][0]
# __________________________________________________________________________________________________
# bn13_conv_depthwise (BatchNorma (None, 20, 20, 576)  2304        mobl13_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_relu (Activation)    (None, 20, 20, 576)  0           bn13_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl13_conv_project (Conv2D)    (None, 20, 20, 160)  92160       conv_dw_13_relu[0][0]
# __________________________________________________________________________________________________
# bn13_conv_bn_project (BatchNorm (None, 20, 20, 160)  640         mobl13_conv_project[0][0]
# __________________________________________________________________________________________________
# mobl14_conv_expand (Conv2D)     (None, 20, 20, 960)  153600      bn13_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# bn14_conv_bn_expand (BatchNorma (None, 20, 20, 960)  3840        mobl14_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_14_relu (Activation)       (None, 20, 20, 960)  0           bn14_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl14_conv_depthwise (Depthwis (None, 20, 20, 960)  8640        conv_14_relu[0][0]
# __________________________________________________________________________________________________
# bn14_conv_depthwise (BatchNorma (None, 20, 20, 960)  3840        mobl14_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_14_relu (Activation)    (None, 20, 20, 960)  0           bn14_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl14_conv_project (Conv2D)    (None, 20, 20, 160)  153600      conv_dw_14_relu[0][0]
# __________________________________________________________________________________________________
# bn14_conv_bn_project (BatchNorm (None, 20, 20, 160)  640         mobl14_conv_project[0][0]
# __________________________________________________________________________________________________
# res_connect_14 (Add)            (None, 20, 20, 160)  0           bn13_conv_bn_project[0][0]
#                                                                  bn14_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# mobl15_conv_expand (Conv2D)     (None, 20, 20, 960)  153600      res_connect_14[0][0]
# __________________________________________________________________________________________________
# bn15_conv_bn_expand (BatchNorma (None, 20, 20, 960)  3840        mobl15_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_15_relu (Activation)       (None, 20, 20, 960)  0           bn15_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl15_conv_depthwise (Depthwis (None, 20, 20, 960)  8640        conv_15_relu[0][0]
# __________________________________________________________________________________________________
# bn15_conv_depthwise (BatchNorma (None, 20, 20, 960)  3840        mobl15_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_15_relu (Activation)    (None, 20, 20, 960)  0           bn15_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl15_conv_project (Conv2D)    (None, 20, 20, 160)  153600      conv_dw_15_relu[0][0]
# __________________________________________________________________________________________________
# bn15_conv_bn_project (BatchNorm (None, 20, 20, 160)  640         mobl15_conv_project[0][0]
# __________________________________________________________________________________________________
# res_connect_15 (Add)            (None, 20, 20, 160)  0           res_connect_14[0][0]
#                                                                  bn15_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# mobl16_conv_expand (Conv2D)     (None, 20, 20, 960)  153600      res_connect_15[0][0]
# __________________________________________________________________________________________________
# bn16_conv_bn_expand (BatchNorma (None, 20, 20, 960)  3840        mobl16_conv_expand[0][0]
# __________________________________________________________________________________________________
# conv_16_relu (Activation)       (None, 20, 20, 960)  0           bn16_conv_bn_expand[0][0]
# __________________________________________________________________________________________________
# mobl16_conv_depthwise (Depthwis (None, 20, 20, 960)  8640        conv_16_relu[0][0]
# __________________________________________________________________________________________________
# bn16_conv_depthwise (BatchNorma (None, 20, 20, 960)  3840        mobl16_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# conv_dw_16_relu (Activation)    (None, 20, 20, 960)  0           bn16_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# mobl16_conv_project (Conv2D)    (None, 20, 20, 320)  307200      conv_dw_16_relu[0][0]
# __________________________________________________________________________________________________
# bn16_conv_bn_project (BatchNorm (None, 20, 20, 320)  1280        mobl16_conv_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 10, 10, 1280) 409600      bn16_conv_bn_project[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 10, 10, 1280) 5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# Conv_1_relu (Activation)        (None, 10, 10, 1280) 0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# 18_pwconv1 (Conv2D)             (None, 10, 10, 256)  327680      Conv_1_relu[0][0]
# __________________________________________________________________________________________________
# 18_conv_coord (Lambda)          (None, 10, 10, 258)  0           18_pwconv1[0][0]
# __________________________________________________________________________________________________
# 18_pwconv1_bn (BatchNormalizati (None, 10, 10, 258)  1032        18_conv_coord[0][0]
# __________________________________________________________________________________________________
# 18_pwconv1_act (Activation)     (None, 10, 10, 258)  0           18_pwconv1_bn[0][0]
# __________________________________________________________________________________________________
# 18_dwconv2 (DepthwiseConv2D)    (None, 5, 5, 258)    2322        18_pwconv1_act[0][0]
# __________________________________________________________________________________________________
# 18_sepconv2_bn (BatchNormalizat (None, 5, 5, 258)    1032        18_dwconv2[0][0]
# __________________________________________________________________________________________________
# 18_sepconv2_act (Activation)    (None, 5, 5, 258)    0           18_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# 18_pwconv3 (Conv2D)             (None, 5, 5, 512)    132096      18_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# 18_pwconv3_bn (BatchNormalizati (None, 5, 5, 512)    2048        18_pwconv3[0][0]
# __________________________________________________________________________________________________
# 18_pwconv3_act (Activation)     (None, 5, 5, 512)    0           18_pwconv3_bn[0][0]
# __________________________________________________________________________________________________
# 19_pwconv1 (Conv2D)             (None, 5, 5, 128)    65536       18_pwconv3_act[0][0]
# __________________________________________________________________________________________________
# 19_conv_coord (Lambda)          (None, 5, 5, 130)    0           19_pwconv1[0][0]
# __________________________________________________________________________________________________
# 19_pwconv1_bn (BatchNormalizati (None, 5, 5, 130)    520         19_conv_coord[0][0]
# __________________________________________________________________________________________________
# 19_pwconv1_act (Activation)     (None, 5, 5, 130)    0           19_pwconv1_bn[0][0]
# __________________________________________________________________________________________________
# 19_dwconv2 (DepthwiseConv2D)    (None, 3, 3, 130)    1170        19_pwconv1_act[0][0]
# __________________________________________________________________________________________________
# 19_sepconv2_bn (BatchNormalizat (None, 3, 3, 130)    520         19_dwconv2[0][0]
# __________________________________________________________________________________________________
# 19_sepconv2_act (Activation)    (None, 3, 3, 130)    0           19_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# 19_pwconv3 (Conv2D)             (None, 3, 3, 256)    33280       19_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# 19_pwconv3_bn (BatchNormalizati (None, 3, 3, 256)    1024        19_pwconv3[0][0]
# __________________________________________________________________________________________________
# 19_pwconv3_act (Activation)     (None, 3, 3, 256)    0           19_pwconv3_bn[0][0]
# __________________________________________________________________________________________________
# 20_pwconv1 (Conv2D)             (None, 3, 3, 128)    32768       19_pwconv3_act[0][0]
# __________________________________________________________________________________________________
# 20_conv_coord (Lambda)          (None, 3, 3, 130)    0           20_pwconv1[0][0]
# __________________________________________________________________________________________________
# 20_pwconv1_bn (BatchNormalizati (None, 3, 3, 130)    520         20_conv_coord[0][0]
# __________________________________________________________________________________________________
# 20_pwconv1_act (Activation)     (None, 3, 3, 130)    0           20_pwconv1_bn[0][0]
# __________________________________________________________________________________________________
# 20_dwconv2 (DepthwiseConv2D)    (None, 2, 2, 130)    1170        20_pwconv1_act[0][0]
# __________________________________________________________________________________________________
# 20_sepconv2_bn (BatchNormalizat (None, 2, 2, 130)    520         20_dwconv2[0][0]
# __________________________________________________________________________________________________
# 20_sepconv2_act (Activation)    (None, 2, 2, 130)    0           20_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# 20_pwconv3 (Conv2D)             (None, 2, 2, 256)    33280       20_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# 20_pwconv3_bn (BatchNormalizati (None, 2, 2, 256)    1024        20_pwconv3[0][0]
# __________________________________________________________________________________________________
# 20_pwconv3_act (Activation)     (None, 2, 2, 256)    0           20_pwconv3_bn[0][0]
# __________________________________________________________________________________________________
# 21_pwconv1 (Conv2D)             (None, 2, 2, 64)     16384       20_pwconv3_act[0][0]
# __________________________________________________________________________________________________
# 21_conv_coord (Lambda)          (None, 2, 2, 66)     0           21_pwconv1[0][0]
# __________________________________________________________________________________________________
# 21_pwconv1_bn (BatchNormalizati (None, 2, 2, 66)     264         21_conv_coord[0][0]
# __________________________________________________________________________________________________
# 21_pwconv1_act (Activation)     (None, 2, 2, 66)     0           21_pwconv1_bn[0][0]
# __________________________________________________________________________________________________
# 21_dwconv2 (DepthwiseConv2D)    (None, 1, 1, 66)     594         21_pwconv1_act[0][0]
# __________________________________________________________________________________________________
# 21_sepconv2_bn (BatchNormalizat (None, 1, 1, 66)     264         21_dwconv2[0][0]
# __________________________________________________________________________________________________
# 21_sepconv2_act (Activation)    (None, 1, 1, 66)     0           21_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# coord_conv_conv13 (Lambda)      (None, 20, 20, 578)  0           mobl13_conv_expand[0][0]
# __________________________________________________________________________________________________
# coord_conv_conv17 (Lambda)      (None, 10, 10, 1282) 0           Conv_1[0][0]
# __________________________________________________________________________________________________
# 21_pwconv3 (Conv2D)             (None, 1, 1, 128)    8448        21_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_conf (Conv2D)       (None, 20, 20, 8)    41624       coord_conv_conv13[0][0]
# __________________________________________________________________________________________________
# conv17_mbox_conf (Conv2D)       (None, 10, 10, 12)   138468      coord_conv_conv17[0][0]
# __________________________________________________________________________________________________
# conv18_2_mbox_conf (Conv2D)     (None, 5, 5, 12)     55308       18_pwconv3[0][0]
# __________________________________________________________________________________________________
# conv19_2_mbox_conf (Conv2D)     (None, 3, 3, 12)     27660       19_pwconv3[0][0]
# __________________________________________________________________________________________________
# conv20_2_mbox_conf (Conv2D)     (None, 2, 2, 8)      18440       20_pwconv3[0][0]
# __________________________________________________________________________________________________
# conv21_2_mbox_conf (Conv2D)     (None, 1, 1, 8)      9224        21_pwconv3[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_loc (Conv2D)        (None, 20, 20, 16)   83248       coord_conv_conv13[0][0]
# __________________________________________________________________________________________________
# conv17_mbox_loc (Conv2D)        (None, 10, 10, 24)   276936      coord_conv_conv17[0][0]
# __________________________________________________________________________________________________
# conv18_2_mbox_loc (Conv2D)      (None, 5, 5, 24)     110616      18_pwconv3[0][0]
# __________________________________________________________________________________________________
# conv19_2_mbox_loc (Conv2D)      (None, 3, 3, 24)     55320       19_pwconv3[0][0]
# __________________________________________________________________________________________________
# conv20_2_mbox_loc (Conv2D)      (None, 2, 2, 16)     36880       20_pwconv3[0][0]
# __________________________________________________________________________________________________
# conv21_2_mbox_loc (Conv2D)      (None, 1, 1, 16)     18448       21_pwconv3[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_conf_reshape (Resha (None, 1600, 2)      0           conv13_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_conf_reshape (Resha (None, 600, 2)       0           conv17_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_conf_reshape (Res (None, 150, 2)       0           conv18_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_conf_reshape (Res (None, 54, 2)        0           conv19_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_conf_reshape (Res (None, 16, 2)        0           conv20_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_conf_reshape (Res (None, 4, 2)         0           conv21_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_priorbox (AnchorBox (None, 20, 20, 4, 8) 0           conv13_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv17_mbox_priorbox (AnchorBox (None, 10, 10, 6, 8) 0           conv17_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv18_2_mbox_priorbox (AnchorB (None, 5, 5, 6, 8)   0           conv18_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv19_2_mbox_priorbox (AnchorB (None, 3, 3, 6, 8)   0           conv19_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv20_2_mbox_priorbox (AnchorB (None, 2, 2, 4, 8)   0           conv20_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv21_2_mbox_priorbox (AnchorB (None, 1, 1, 4, 8)   0           conv21_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (None, 2424, 2)      0           conv11_mbox_conf_reshape[0][0]
#                                                                  conv13_mbox_conf_reshape[0][0]
#                                                                  conv14_2_mbox_conf_reshape[0][0]
#                                                                  conv15_2_mbox_conf_reshape[0][0]
#                                                                  conv16_2_mbox_conf_reshape[0][0]
#                                                                  conv17_2_mbox_conf_reshape[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_loc_reshape (Reshap (None, 1600, 4)      0           conv13_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_loc_reshape (Reshap (None, 600, 4)       0           conv17_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_loc_reshape (Resh (None, 150, 4)       0           conv18_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_loc_reshape (Resh (None, 54, 4)        0           conv19_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_loc_reshape (Resh (None, 16, 4)        0           conv20_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_loc_reshape (Resh (None, 4, 4)         0           conv21_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_priorbox_reshape (R (None, 1600, 8)      0           conv13_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv17_mbox_priorbox_reshape (R (None, 600, 8)       0           conv17_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv18_2_mbox_priorbox_reshape  (None, 150, 8)       0           conv18_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv19_2_mbox_priorbox_reshape  (None, 54, 8)        0           conv19_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv20_2_mbox_priorbox_reshape  (None, 16, 8)        0           conv20_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv21_2_mbox_priorbox_reshape  (None, 4, 8)         0           conv21_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# mbox_conf_softmax (Activation)  (None, 2424, 2)      0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (None, 2424, 4)      0           conv11_mbox_loc_reshape[0][0]
#                                                                  conv13_mbox_loc_reshape[0][0]
#                                                                  conv14_2_mbox_loc_reshape[0][0]
#                                                                  conv15_2_mbox_loc_reshape[0][0]
#                                                                  conv16_2_mbox_loc_reshape[0][0]
#                                                                  conv17_2_mbox_loc_reshape[0][0]
# __________________________________________________________________________________________________
# mbox_priorbox (Concatenate)     (None, 2424, 8)      0           conv13_mbox_priorbox_reshape[0][0
#                                                                  conv17_mbox_priorbox_reshape[0][0
#                                                                  conv18_2_mbox_priorbox_reshape[0]
#                                                                  conv19_2_mbox_priorbox_reshape[0]
#                                                                  conv20_2_mbox_priorbox_reshape[0]
#                                                                  conv21_2_mbox_priorbox_reshape[0]
# __________________________________________________________________________________________________
# predictions (Concatenate)       (None, 2424, 14)     0           mbox_conf_softmax[0][0]
#                                                                  mbox_loc[0][0]
#                                                                  mbox_priorbox[0][0]
# ==================================================================================================
# Total params: 3,795,380
# Trainable params: 3,756,820
# Non-trainable params: 38,560
# __________________________________________________________________________________________________
# None

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
# images_dir = data_path + 'udacity_driving_datasets'
images_dir = data_path + 'pascal_dataset'
# images_dir = data_path + 'images'

# Ground truth
# train_labels_filename = preprocess_path + '/udc.csv'
# train_labels_filename = preprocess_path + '/cic_pascal_train.csv'
# val_labels_filename   = preprocess_path + '/cic_pascal_val.csv'
train_labels_filename = preprocess_path + '/pascal_train.csv'
val_labels_filename   = preprocess_path + '/pascal_val.csv'
# train_labels_filename = preprocess_path + '/cic_train.csv'
# val_labels_filename   = preprocess_path + '/cic_val.csv'

train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

# train_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_train.h5',
#                                   resize=False,
#                                   variable_image_size=True,
#                                   verbose=True)

# val_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_val.h5',
#                                 resize=False,
#                                 variable_image_size=True,
#                                 verbose=True)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Loading images into memory: 100%|██████████| 6469/6469 [00:27<00:00, 239.29it/s]
# Loading images into memory: 100%|██████████| 2097/2097 [00:08<00:00, 255.40it/s]
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  2097

# %%
# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv13_mbox_conf').output_shape[1:3],
                   model.get_layer('conv17_mbox_conf').output_shape[1:3],
                   model.get_layer('conv18_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv19_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv20_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv21_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  2097

# %% [markdown]
# ## Remaining training parameters

# %%
label_val = np.load('../data-cic/preprocess_data/label_val_320.npy')
val_images_320 = np.load('../data-cic/preprocess_data/images_val_320x320.npy')

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='/home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_n.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)

csv_logger = CSVLogger(filename=data_path + 'history/ssdlite320coordconv/ssdlite320coordconv_pascal_n.csv',
                       separator=',',
                       append=True)

early_stopping = EarlyStopping(monitor='val_loss',
                               min_delta=0.0,
                               patience=12,
                               verbose=1)

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.5,
                                         patience=10,
                                         verbose=1,
                                         min_delta=0.001,
                                         cooldown=0,
                                         min_lr=0.000001)

f1_callback = f1_call(0.20, 
                      0.45, 
                      200, 
                      normalize_coords, 
                      img_height, 
                      img_width, 
                      val_images_320, 
                      label_val, (1, 2424, 14),
                      data_path + 'history/ssdlite320coordconv/ssdlite320coordconv_pascal_f1_n.csv')

# learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule, verbose=1)


callbacks = [model_checkpoint,
             csv_logger,
             early_stopping,
#              learning_rate_scheduler]
             reduce_learning_rate,
             f1_callback]

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
## Apply coordconv before lite convolution

initial_epoch   = 0
final_epoch     = 1000
steps_per_epoch = 400

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/1000
# 400/400 [==============================] - 243s 607ms/step - loss: 6.1376 - val_loss: 5.3156
#
# Epoch 00001: val_loss improved from inf to 5.31556, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_n.h5
# Number of images: 45
# Presicion: 0.0413
# Recall: 0.4184
# F1 score: 0.0752
# Improve F1 score from -inf to 0.07520690474837062
# Epoch 2/1000
# 400/400 [==============================] - 230s 575ms/step - loss: 4.9835 - val_loss: 4.9533
#
# Epoch 00002: val_loss improved from 5.31556 to 4.95332, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_n.h5
# Number of images: 45
# Presicion: 0.0564
# Recall: 0.4618
# F1 score: 0.1006
# Improve F1 score from 0.07520690474837062 to 0.10058347217138512
# Epoch 3/1000
# 400/400 [==============================] - 231s 576ms/step - loss: 4.7532 - val_loss: 5.1385
#
# Epoch 00003: val_loss did not improve from 4.95332
# Number of images: 45
# Presicion: 0.0523
# Recall: 0.4897
# F1 score: 0.0945
# Epoch 4/1000
# 400/400 [==============================] - 227s 569ms/step - loss: 4.8062 - val_loss: 6.4710
#
# Epoch 00004: val_loss did not improve from 4.95332
# Number of images: 45
# Presicion: 0.1065
# Recall: 0.2054
# F1 score: 0.1403
# Improve F1 score from 0.10058347217138512 to 0.1402597016105485
# Epoch 5/1000
# 400/400 [==============================] - 227s 568ms/step - loss: 4.5688 - val_loss: 5.3405
#
# Epoch 00005: val_loss did not improve from 4.95332
# Number of images: 45
# Presicion: 0.0432
# Recall: 0.4517
# F1 score: 0.0788
# Epoch 6/1000
# 400/400 [==============================] - 229s 573ms/step - loss: 4.4549 - val_loss: 5.4735
#
# Epoch 00006: val_loss did not improve from 4.95332
# Number of images: 45
# Presicion: 0.0306
# Recall: 0.37
# F1 score: 0.0565
# Epoch 7/1000
# 400/400 [==============================] - 226s 566ms/step - loss: 4.4313 - val_loss: 5.2037
#
# Epoch 00007: val_loss did not improve from 4.95332
# Number of images: 45
# Presicion: 0.0413
# Recall: 0.4353
# F1 score: 0.0755
# Epoch 8/1000
# 400/400 [==============================] - 227s 568ms/step - loss: 4.3239 - val_loss: 4.5563
#
# Epoch 00008: val_loss improved from 4.95332 to 4.55634, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_n.h5
# Number of images: 45
# Presicion: 0.0317
# Recall: 0.4778
# F1 score: 0.0594
# Epoch 9/1000
# 400/400 [==============================] - 228s 570ms/step - loss: 4.5830 - val_loss: 13.1448
#
# Epoch 00009: val_loss did not improve from 4.55634
# Number of images: 45
# Presicion: 0.0514
# Recall: 0.1806
# F1 score: 0.0801
# Epoch 10/1000
# 400/400 [==============================] - 227s 569ms/step - loss: 4.2440 - val_loss: 6.2252
#
# Epoch 00010: val_loss did not improve from 4.55634
# Number of images: 45
# Presicion: 0.0717
# Recall: 0.3839
# F1 score: 0.1209
# Epoch 11/1000
# 400/400 [==============================] - 229s 574ms/step - loss: 4.1944 - val_loss: 4.6367
#
# Epoch 00011: val_loss did not improve from 4.55634
# Number of images: 45
# Presicion: 0.0413
# Recall: 0.4972
# F1 score: 0.0763
# Epoch 12/1000
# 400/400 [==============================] - 229s 572ms/step - loss: 4.1920 - val_loss: 5.1716
#
# Epoch 00012: val_loss did not improve from 4.55634
# Number of images: 45
# Presicion: 0.0365
# Recall: 0.379
# F1 score: 0.0665
# Epoch 13/1000
# 400/400 [==============================] - 226s 564ms/step - loss: 4.0945 - val_loss: 4.6289
#
# Epoch 00013: val_loss did not improve from 4.55634
# Number of images: 45
# Presicion: 0.0629
# Recall: 0.484
# F1 score: 0.1114
# Epoch 14/1000
# 400/400 [==============================] - 228s 571ms/step - loss: 4.1179 - val_loss: 4.6893
#
# Epoch 00014: val_loss did not improve from 4.55634
# Number of images: 45
# Presicion: 0.0378
# Recall: 0.4753
# F1 score: 0.07
# Epoch 15/1000
# 400/400 [==============================] - 229s 572ms/step - loss: 4.0680 - val_loss: 4.7259
#
# Epoch 00015: val_loss did not improve from 4.55634
# Number of images: 45
# Presicion: 0.0358
# Recall: 0.4582
# F1 score: 0.0664
# Epoch 16/1000
# 400/400 [==============================] - 228s 570ms/step - loss: 5.4397 - val_loss: 93.8584
#
# Epoch 00016: val_loss did not improve from 4.55634
# Number of images: 45
# Presicion: 0.0325
# Recall: 0.0622
# F1 score: 0.0427
# Epoch 17/1000
# 400/400 [==============================] - 231s 578ms/step - loss: 4.2087 - val_loss: 9.5999
#
# Epoch 00017: val_loss did not improve from 4.55634
# Number of images: 45
# Presicion: 0.054
# Recall: 0.2142
# F1 score: 0.0863
# Epoch 18/1000
# 400/400 [==============================] - 229s 573ms/step - loss: 4.0596 - val_loss: 5.0252
#
# Epoch 00018: val_loss did not improve from 4.55634
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Number of images: 45
# Presicion: 0.1281
# Recall: 0.2552
# F1 score: 0.1705
# Improve F1 score from 0.1402597016105485 to 0.17054322833347718
# Epoch 19/1000
# 400/400 [==============================] - 232s 580ms/step - loss: 3.9717 - val_loss: 4.9208
#
# Epoch 00019: val_loss did not improve from 4.55634
# Number of images: 45
# Presicion: 0.0448
# Recall: 0.2013
# F1 score: 0.0732
# Epoch 20/1000
# 400/400 [==============================] - 230s 574ms/step - loss: 3.9564 - val_loss: 4.2146
#
# Epoch 00020: val_loss improved from 4.55634 to 4.21458, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_n.h5
# Number of images: 45
# Presicion: 0.0688
# Recall: 0.4257
# F1 score: 0.1184
# Epoch 21/1000
# 368/400 [==========================>...] - ETA: 17s - loss: 3.8814

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
## Apply coordconv before lite convolution

initial_epoch   = 0
final_epoch     = 1000
steps_per_epoch = 400

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/1000
# 400/400 [==============================] - 250s 624ms/step - loss: 6.2195 - val_loss: 5.6632
#
# Epoch 00001: val_loss improved from inf to 5.66325, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.0516
# Recall: 0.4669
# F1 score: 0.0929
# Improve F1 score from -inf to 0.09288484482274267
# Epoch 2/1000
# 400/400 [==============================] - 231s 577ms/step - loss: 5.0568 - val_loss: 5.7642
#
# Epoch 00002: val_loss did not improve from 5.66325
# Number of images: 45
# Presicion: 0.0881
# Recall: 0.252
# F1 score: 0.1306
# Improve F1 score from 0.09288484482274267 to 0.13060113479517962
# Epoch 3/1000
# 400/400 [==============================] - 237s 593ms/step - loss: 4.7994 - val_loss: 5.2723
#
# Epoch 00003: val_loss improved from 5.66325 to 5.27226, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.0603
# Recall: 0.4608
# F1 score: 0.1067
# Epoch 4/1000
# 400/400 [==============================] - 232s 580ms/step - loss: 4.6678 - val_loss: 5.0585
#
# Epoch 00004: val_loss improved from 5.27226 to 5.05850, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.0419
# Recall: 0.4621
# F1 score: 0.0768
# Epoch 5/1000
# 400/400 [==============================] - 236s 589ms/step - loss: 4.9329 - val_loss: 42.1622
#
# Epoch 00005: val_loss did not improve from 5.05850
# Number of images: 45
# Presicion: 0.0391
# Recall: 0.4245
# F1 score: 0.0716
# Epoch 6/1000
# 400/400 [==============================] - 229s 572ms/step - loss: 4.5790 - val_loss: 10.8913
#
# Epoch 00006: val_loss did not improve from 5.05850
# Number of images: 45
# Presicion: 0.024
# Recall: 0.2991
# F1 score: 0.0444
# Epoch 7/1000
# 400/400 [==============================] - 228s 571ms/step - loss: 4.4248 - val_loss: 5.3020
#
# Epoch 00007: val_loss did not improve from 5.05850
# Number of images: 45
# Presicion: 0.0439
# Recall: 0.4909
# F1 score: 0.0806
# Epoch 8/1000
# 400/400 [==============================] - 227s 568ms/step - loss: 4.3549 - val_loss: 5.1606
#
# Epoch 00008: val_loss did not improve from 5.05850
# Number of images: 45
# Presicion: 0.0379
# Recall: 0.4845
# F1 score: 0.0702
# Epoch 9/1000
# 400/400 [==============================] - 229s 573ms/step - loss: 4.2565 - val_loss: 5.1807
#
# Epoch 00009: val_loss did not improve from 5.05850
# Number of images: 45
# Presicion: 0.0274
# Recall: 0.4405
# F1 score: 0.0515
# Epoch 10/1000
# 400/400 [==============================] - 230s 575ms/step - loss: 4.3034 - val_loss: 7.9761
#
# Epoch 00010: val_loss did not improve from 5.05850
# Number of images: 45
# Presicion: 0.0423
# Recall: 0.1107
# F1 score: 0.0612
# Epoch 11/1000
# 400/400 [==============================] - 228s 571ms/step - loss: 4.9696 - val_loss: 139.6628
#
# Epoch 00011: val_loss did not improve from 5.05850
# Number of images: 45
# Presicion: 0.0121
# Recall: 0.1799
# F1 score: 0.0227
# Epoch 12/1000
# 400/400 [==============================] - 229s 571ms/step - loss: 4.2234 - val_loss: 8.0932
#
# Epoch 00012: val_loss did not improve from 5.05850
# Number of images: 45
# Presicion: 0.0713
# Recall: 0.3287
# F1 score: 0.1171
# Epoch 13/1000
# 400/400 [==============================] - 239s 597ms/step - loss: 4.4947 - val_loss: 7.5233
#
# Epoch 00013: val_loss did not improve from 5.05850
# Number of images: 45
# Presicion: 0.0703
# Recall: 0.231
# F1 score: 0.1078
# Epoch 14/1000
# 400/400 [==============================] - 248s 620ms/step - loss: 4.1528 - val_loss: 5.0581
#
# Epoch 00014: val_loss improved from 5.05850 to 5.05813, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Number of images: 45
# Presicion: 0.0429
# Recall: 0.3075
# F1 score: 0.0753
# Epoch 15/1000
# 400/400 [==============================] - 229s 572ms/step - loss: 4.0359 - val_loss: 4.5496
#
# Epoch 00015: val_loss improved from 5.05813 to 4.54963, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.0373
# Recall: 0.5191
# F1 score: 0.0695
# Epoch 16/1000
# 400/400 [==============================] - 235s 588ms/step - loss: 3.9776 - val_loss: 4.2302
#
# Epoch 00016: val_loss improved from 4.54963 to 4.23023, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.0356
# Recall: 0.5021
# F1 score: 0.0665
# Epoch 17/1000
# 400/400 [==============================] - 231s 576ms/step - loss: 3.9738 - val_loss: 4.0839
#
# Epoch 00017: val_loss improved from 4.23023 to 4.08393, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.0394
# Recall: 0.5484
# F1 score: 0.0735
# Epoch 18/1000
# 400/400 [==============================] - 230s 575ms/step - loss: 3.9343 - val_loss: 4.0462
#
# Epoch 00018: val_loss improved from 4.08393 to 4.04619, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.0422
# Recall: 0.5459
# F1 score: 0.0784
# Epoch 19/1000
# 400/400 [==============================] - 229s 572ms/step - loss: 3.8961 - val_loss: 3.9982
#
# Epoch 00019: val_loss improved from 4.04619 to 3.99824, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.0333
# Recall: 0.5289
# F1 score: 0.0627
# Epoch 20/1000
# 400/400 [==============================] - 227s 567ms/step - loss: 3.8706 - val_loss: 4.0859
#
# Epoch 00020: val_loss did not improve from 3.99824
# Number of images: 45
# Presicion: 0.0561
# Recall: 0.4912
# F1 score: 0.1006
# Epoch 21/1000
# 400/400 [==============================] - 228s 570ms/step - loss: 3.8563 - val_loss: 3.9464
#
# Epoch 00021: val_loss improved from 3.99824 to 3.94636, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.0516
# Recall: 0.5191
# F1 score: 0.0938
# Epoch 22/1000
# 400/400 [==============================] - 225s 563ms/step - loss: 3.8397 - val_loss: 4.0793
#
# Epoch 00022: val_loss did not improve from 3.94636
# Number of images: 45
# Presicion: 0.0642
# Recall: 0.4337
# F1 score: 0.1118
# Epoch 23/1000
# 400/400 [==============================] - 238s 594ms/step - loss: 3.8265 - val_loss: 4.0009
#
# Epoch 00023: val_loss did not improve from 3.94636
# Number of images: 45
# Presicion: 0.1011
# Recall: 0.4891
# F1 score: 0.1675
# Improve F1 score from 0.13060113479517962 to 0.1675211032102738
# Epoch 24/1000
# 400/400 [==============================] - 229s 572ms/step - loss: 3.7735 - val_loss: 3.9857
#
# Epoch 00024: val_loss did not improve from 3.94636
# Number of images: 45
# Presicion: 0.1088
# Recall: 0.3044
# F1 score: 0.1603
# Epoch 25/1000
# 400/400 [==============================] - 232s 580ms/step - loss: 3.7662 - val_loss: 3.9405
#
# Epoch 00025: val_loss improved from 3.94636 to 3.94050, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.157
# Recall: 0.4197
# F1 score: 0.2285
# Improve F1 score from 0.1675211032102738 to 0.22849378193305167
# Epoch 26/1000
# 400/400 [==============================] - 230s 575ms/step - loss: 3.7470 - val_loss: 3.8283
#
# Epoch 00026: val_loss improved from 3.94050 to 3.82831, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.0637
# Recall: 0.3434
# F1 score: 0.1075
# Epoch 27/1000
# 400/400 [==============================] - 237s 593ms/step - loss: 3.7082 - val_loss: 3.7366
#
# Epoch 00027: val_loss improved from 3.82831 to 3.73656, saving model to /home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_w2.h5
# Number of images: 45
# Presicion: 0.2106
# Recall: 0.3791
# F1 score: 0.2708
# Improve F1 score from 0.22849378193305167 to 0.27079545507241487
# Epoch 28/1000
# 400/400 [==============================] - 242s 604ms/step - loss: 3.7297 - val_loss: 3.7842
#
# Epoch 00028: val_loss did not improve from 3.73656
# Number of images: 45
# Presicion: 0.278
# Recall: 0.2652
# F1 score: 0.2714
# Improve F1 score from 0.27079545507241487 to 0.27144787610868615
# Epoch 29/1000
# 400/400 [==============================] - 236s 590ms/step - loss: 3.6730 - val_loss: 3.8252
#
# Epoch 00029: val_loss did not improve from 3.73656
# Number of images: 45
# Presicion: 0.2243
# Recall: 0.3992
# F1 score: 0.2872
# Improve F1 score from 0.27144787610868615 to 0.2872317706861698
# Epoch 30/1000
#  72/400 [====>.........................] - ETA: 3:03 - loss: 3.6367

# %%
210-216

# %%
# Reset learning rate to 0.001
adam = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
# images_dir = data_path + 'udacity_driving_datasets'
# images_dir = data_path + 'pascal_dataset'
images_dir = data_path + 'images'

# Ground truth
# train_labels_filename = preprocess_path + '/udc.csv'
# train_labels_filename = preprocess_path + '/cic_pascal_train.csv'
# val_labels_filename   = preprocess_path + '/cic_pascal_val.csv'
# train_labels_filename = preprocess_path + '/pascal_train.csv'
# val_labels_filename   = preprocess_path + '/pascal_val.csv'
train_labels_filename = preprocess_path + '/cic_train.csv'
val_labels_filename   = preprocess_path + '/cic_val.csv'

train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

# train_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_train.h5',
#                                   resize=False,
#                                   variable_image_size=True,
#                                   verbose=True)

# val_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_val.h5',
#                                 resize=False,
#                                 variable_image_size=True,
#                                 verbose=True)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))

# %%
# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv13_mbox_conf').output_shape[1:3],
                   model.get_layer('conv17_mbox_conf').output_shape[1:3],
                   model.get_layer('conv18_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv19_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv20_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv21_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='/home/aldo/Documents/weights/models/ssdlite320coordconv/ssdlite320coordconv_pascal_cic_w2.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
# model_checkpoint.best = 2.567152314715915

csv_logger = CSVLogger(filename=data_path + 'history/ssdlite320coordconv/ssdlite320coordconv_pascal_cic_w2.csv',
                       separator=',',
                       append=True)

early_stopping = EarlyStopping(monitor='val_loss',
                               min_delta=0.0,
                               patience=12,
                               verbose=1)

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.5,
                                         patience=10,
                                         verbose=1,
                                         min_delta=0.001,
                                         cooldown=0,
                                         min_lr=0.000001)

f1_callback = f1_call(0.20, 
                      0.45, 
                      200, 
                      normalize_coords, 
                      img_height, 
                      img_width, 
                      val_images_320, 
                      label_val, (1, 2424, 14),
                      data_path + 'history/ssdlite320coordconv/ssdlite320coordconv_pascal_cic_f1_w2.csv')

# learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule, verbose=1)


callbacks = [model_checkpoint,
             csv_logger,
             early_stopping,
#              learning_rate_scheduler]
             reduce_learning_rate,
             f1_callback]

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 1000
steps_per_epoch = 15

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)

# %%
45-44
