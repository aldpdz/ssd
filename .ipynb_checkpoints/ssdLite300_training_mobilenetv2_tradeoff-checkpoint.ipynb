# %%
# libraries
import os
import json
import numpy as np
import pandas as pd
from extra_files import helper as hp
from imageio import imwrite, imread
from skimage.transform import resize

# %%
# File paths
data_path = '/home/aldo/Documents/data-cic/'
preprocess_path = data_path + 'preprocess_data'

# %% [markdown]
# ## Training SSDLite300

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, EarlyStopping, ReduceLROnPlateau, TensorBoard
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssdlite320_mobilenetv2 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

from extra_files.f1_callback import F1_callback as f1_call
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /home/aldo/Documents/ssd/data_generator/object_detection_2d_data_generator.py:43: UserWarning: 'BeautifulSoup' module is missing. The XML-parser will be unavailable.
#   warnings.warn("'BeautifulSoup' module is missing. The XML-parser will be unavailable.")

# %% [markdown]
# ### Parameters (original SSD300 architecture)

# %%
## Parameteres needed for ssd_300() and SSDInputEncoder()

img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [1., 1., 1.] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
divide_by_stddev = [127.5, 127.5, 127.5]
swap_channels = False # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 1 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
new_scales = [0.15, 0.33, 0.47, 0.61, 0.76, 0.90, 1.05]
scales = new_scales
aspect_ratios = [[1.0, 0.5, 2.0/3.0],
                 [1.0, 0.5, 2.0/3.0, 1.0/3.0, 3.0/4.0],
                 [1.0, 2.0, 0.5, 2.0/3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 2.0/3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [16, 30, 60, 100, 150, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True
list_alpha = [1.0, 0.35]
list_expansion = [1]

# %% [markdown]
# ## Data generator for the training

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset_pascal = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset_pascal = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
images_dir = data_path + 'pascal_dataset'

# Ground truth
train_labels_filename = preprocess_path + '/pascal_train.csv'
val_labels_filename   = preprocess_path + '/pascal_val.csv'

train_dataset_pascal.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset_pascal.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Get the number of samples in the training and validations datasets.
train_dataset_size_pascal = train_dataset_pascal.get_dataset_size()
val_dataset_size_pascal   = val_dataset_pascal.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size_pascal))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size_pascal))

# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [(18, 18),
                   (9, 9),
                   (5, 5),
                   (3, 3),
                   (2, 2),
                   (1, 1)]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.6,
                                    neg_iou_limit=0.3,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator_pascal = train_dataset_pascal.generate(batch_size=batch_size,
                                              shuffle=True,
                                              transformations=[ssd_data_augmentation],
                                              label_encoder=ssd_input_encoder,
                                              returns={'processed_images',
                                                       'encoded_labels'},
                                              keep_images_without_gt=False)

val_generator_pascal = val_dataset_pascal.generate(batch_size=batch_size,
                                          shuffle=False,
                                          transformations=[convert_to_3_channels,
                                                           resize],
                                          label_encoder=ssd_input_encoder,
                                          returns={'processed_images',
                                                   'encoded_labels'},
                                          keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size_pascal = train_dataset_pascal.get_dataset_size()
val_dataset_size_pascal   = val_dataset_pascal.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size_pascal))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size_pascal))
# Out:
# Loading images into memory: 100%|██████████| 6469/6469 [00:25<00:00, 250.61it/s]
# Loading images into memory: 100%|██████████| 2097/2097 [00:08<00:00, 255.91it/s]
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  2097
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  2097

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset_cic = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset_cic = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
images_dir = data_path + 'images'

# Ground truth
train_labels_filename = preprocess_path + '/cic_train.csv'
val_labels_filename   = preprocess_path + '/cic_val.csv'

train_dataset_cic.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset_cic.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Get the number of samples in the training and validations datasets.
train_dataset_size_cic = train_dataset_cic.get_dataset_size()
val_dataset_size_cic   = val_dataset_cic.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size_cic))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size_cic))

# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [(18, 18),
                   (9, 9),
                   (5, 5),
                   (3, 3),
                   (2, 2),
                   (1, 1)]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.6,
                                    neg_iou_limit=0.3,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator_cic = train_dataset_cic.generate(batch_size=batch_size,
                                            shuffle=True,
                                            transformations=[ssd_data_augmentation],
                                            label_encoder=ssd_input_encoder,
                                            returns={'processed_images',
                                                     'encoded_labels'},
                                            keep_images_without_gt=False)

val_generator_cic = val_dataset_cic.generate(batch_size=batch_size,
                                        shuffle=False,
                                        transformations=[convert_to_3_channels,
                                                         resize],
                                        label_encoder=ssd_input_encoder,
                                        returns={'processed_images',
                                                 'encoded_labels'},
                                        keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size_cic = train_dataset_cic.get_dataset_size()
val_dataset_size_cic   = val_dataset_cic.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size_cic))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size_cic))
# Out:
# Loading images into memory: 100%|██████████| 210/210 [00:07<00:00, 28.64it/s]
# Loading images into memory: 100%|██████████| 45/45 [00:01<00:00, 28.62it/s]
# Number of images in the training dataset:	   210
# Number of images in the validation dataset:	    45
# Number of images in the training dataset:	   210
# Number of images in the validation dataset:	    45

# %%
label_val = np.load('../data-cic/preprocess_data/label_val.npy')
val_images_300 = np.load('../data-cic/preprocess_data/images_val_300x300.npy')

# %%
def return_callbacks(path_weights, name_weights, path_logger, path_tensorboard, path_f1, save_f1):
    
    # Define model callbacks.
    # TODO: Set the filepath under which you want to save the model.
    model_checkpoint = ModelCheckpoint(filepath=path_weights + name_weights,
                                       monitor='val_loss',
                                       verbose=1,
                                       save_best_only=True,
                                       save_weights_only=False,
                                       mode='auto',
                                       period=1)

    csv_logger = CSVLogger(filename= path_logger,
                           separator=',',
                           append=True)

    reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                             factor=0.5,
                                             patience=10,
                                             verbose=1,
                                             min_delta=0.001,
                                             cooldown=0,
                                             min_lr=0.000001)
    
    tbCallBack = TensorBoard(log_dir=path_tensorboard, 
                                       histogram_freq=0, 
                                       write_graph=False, 
                                       write_images=False,
                                       update_freq='epoch')


    f1_callback = f1_call(0.20, 
                          0.45, 
                          200, 
                          normalize_coords, 
                          img_height, 
                          img_width, 
                          val_images_300, 
                          label_val, (1, 2006, 14),
                          path_f1,
                          save_f1)

    callbacks = [model_checkpoint,
                 csv_logger,
                 reduce_learning_rate,
                 f1_callback,
                 tbCallBack]
    return callbacks

# %% [markdown]
# ## Loop to train different models

# %%
for alpha in list_alpha:
    for expansion in list_expansion:
        # 1: Build the Keras model.

        K.clear_session() # Clear previous models from memory.

        model = ssd_300(image_size=(img_height, img_width, img_channels),
                        n_classes=n_classes,
                        alpha=alpha,
                        expansion=expansion,
                        mode='training',
                        scales=scales,
                        aspect_ratios_per_layer=aspect_ratios,
                        two_boxes_for_ar1=two_boxes_for_ar1,
                        steps=steps,
                        offsets=offsets,
                        clip_boxes=clip_boxes,
                        variances=variances,
                        normalize_coords=normalize_coords,
                        subtract_mean=mean_color,
                        divide_by_stddev=divide_by_stddev,
                        swap_channels=swap_channels)

        print('\n---->Training model with alpha', alpha, 'and expansion', expansion, 'with pascal')
        print('Number of parameters:', model.count_params())
        
        # Train over pascal
        adam = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
        ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
        model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
        
        # set callbacks
        str_alpha = str(alpha)
        str_exp = str(expansion)
        callbacks_pascal =  return_callbacks('/home/aldo/Documents/weights/models/last_models/', 
                              '2pos_4_alpha_1.5_pascal_' + str_alpha + '_exp_' + str_exp + '.h5',
                              data_path + 'history/last_models/2pos_4_alpha_1.5_pascal_alpha_' + str_alpha + '_exp_' + str_exp + '.csv',
                              data_path + 'history/last_models/tensorboard/pascal/2pos_4_alpha_1.5' + str_alpha + '_exp_' + str_exp +'/pascal_' + str_alpha + '_exp_' + str_exp,
                              data_path + 'history/last_models/2pos_4_alpha_1.5_pascal_f1_' + str_alpha + '_exp_' + str_exp + '.csv',
                              '/home/aldo/Documents/weights/models/last_models/' + '2pos_4_alpha_1.5_pascal_f1_' + str_alpha + '_exp_' + str_exp + '.h5' )
        # If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
        initial_epoch   = 0
        final_epoch     = 20
        steps_per_epoch = 400

        history = model.fit_generator(generator=train_generator_pascal,
                                      steps_per_epoch=steps_per_epoch,
                                      epochs=final_epoch,
                                      callbacks=callbacks_pascal,
                                      validation_data=val_generator_pascal,
                                      validation_steps=ceil(val_dataset_size_pascal/batch_size),
                                      initial_epoch=initial_epoch)
            
        print('\n---->Training model with alpha', alpha, 'and expansion', expansion, 'with cic')
        # Train over cic
        # Reset learning rate to 0.0005
        adam = Adam(lr=0.0005, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
        ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
        model.compile(optimizer=adam, loss=ssd_loss.compute_loss)
        
        callbacks_cic =  return_callbacks('/home/aldo/Documents/weights/models/last_models/', 
                              '2pos_4_alpha_1.5_pascal_cic_' + str_alpha + '_exp_' + str_exp + '.h5',
                              data_path + 'history/last_models/2pos_4_alpha_1.5_pascal_cic_alpha_' + str_alpha + '_exp_' + str_exp + '.csv',
                              data_path + 'history/last_models/tensorboard/cic/2pos_4_alpha_1.5' + str_alpha + '_exp_' + str_exp +'/cic' + str_alpha + '_exp_' + str_exp,                              
                              data_path + 'history/last_models/2pos_4_alpha_1.5_pascal_cic_f1_' + str_alpha + '_exp_' + str_exp + '.csv',
                              '/home/aldo/Documents/weights/models/last_models/' + '2pos_4_alpha_1.5_pascal_cic_f1_' + str_alpha + '_exp_' + str_exp + '.h5')
        
        initial_epoch   = 0
        final_epoch     = 20
        steps_per_epoch = 15

        history = model.fit_generator(generator=train_generator_cic,
                                      steps_per_epoch=steps_per_epoch,
                                      epochs=final_epoch,
                                      callbacks=callbacks_cic,
                                      validation_data=val_generator_cic,
                                      validation_steps=ceil(val_dataset_size_cic/batch_size),
                                      initial_epoch=initial_epoch)
# Out:
# ---->Training model with alpha 1.0 and expansion 1 with pascal
# Number of parameters: 2618612
# Epoch 1/120
# 400/400 [==============================] - 233s 581ms/step - loss: 7.8071 - val_loss: 6.9436
#
# Epoch 00001: val_loss improved from inf to 6.94358, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.2600360294784438
# Improve F1 score from -inf to 0.2600360294784438
# Epoch 2/120
# 400/400 [==============================] - 219s 546ms/step - loss: 5.0734 - val_loss: 5.1796
#
# Epoch 00002: val_loss improved from 6.94358 to 5.17960, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.3614644025716871
# Improve F1 score from 0.2600360294784438 to 0.3614644025716871
# Epoch 3/120
# 400/400 [==============================] - 218s 546ms/step - loss: 4.6504 - val_loss: 5.1730
#
# Epoch 00003: val_loss improved from 5.17960 to 5.17299, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.3839787633534686
# Improve F1 score from 0.3614644025716871 to 0.3839787633534686
# Epoch 4/120
# 400/400 [==============================] - 226s 566ms/step - loss: 4.5424 - val_loss: 5.1031
#
# Epoch 00004: val_loss improved from 5.17299 to 5.10312, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.413578671209931
# Improve F1 score from 0.3839787633534686 to 0.413578671209931
# Epoch 5/120
# 400/400 [==============================] - 219s 549ms/step - loss: 4.3635 - val_loss: 4.6836
#
# Epoch 00005: val_loss improved from 5.10312 to 4.68355, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.41464209194930574
# Improve F1 score from 0.413578671209931 to 0.41464209194930574
# Epoch 6/120
# 400/400 [==============================] - 221s 552ms/step - loss: 4.2601 - val_loss: 5.1670
#
# Epoch 00006: val_loss did not improve from 4.68355
# F1 score: 0.3657243118198325
# Epoch 7/120
# 400/400 [==============================] - 221s 552ms/step - loss: 4.1599 - val_loss: 5.1061
#
# Epoch 00007: val_loss did not improve from 4.68355
# F1 score: 0.37429651357125315
# Epoch 8/120
# 400/400 [==============================] - 219s 548ms/step - loss: 4.0457 - val_loss: 4.7025
#
# Epoch 00008: val_loss did not improve from 4.68355
# F1 score: 0.403319900139776
# Epoch 9/120
# 400/400 [==============================] - 220s 551ms/step - loss: 4.0387 - val_loss: 4.7436
#
# Epoch 00009: val_loss did not improve from 4.68355
# F1 score: 0.39255204555089634
# Epoch 10/120
# 400/400 [==============================] - 222s 554ms/step - loss: 3.9810 - val_loss: 5.1809
#
# Epoch 00010: val_loss did not improve from 4.68355
# F1 score: 0.41624284598961714
# Improve F1 score from 0.41464209194930574 to 0.41624284598961714
# Epoch 11/120
# 400/400 [==============================] - 221s 553ms/step - loss: 3.9353 - val_loss: 5.2413
#
# Epoch 00011: val_loss did not improve from 4.68355
# F1 score: 0.3721236672082692
# Epoch 12/120
# 400/400 [==============================] - 222s 554ms/step - loss: 3.8645 - val_loss: 5.2937
#
# Epoch 00012: val_loss did not improve from 4.68355
# F1 score: 0.3359291303749626
# Epoch 13/120
# 400/400 [==============================] - 222s 555ms/step - loss: 3.8680 - val_loss: 4.2980
#
# Epoch 00013: val_loss improved from 4.68355 to 4.29800, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.4266038390623433
# Improve F1 score from 0.41624284598961714 to 0.4266038390623433
# Epoch 14/120
# 400/400 [==============================] - 223s 558ms/step - loss: 3.7939 - val_loss: 4.8451
#
# Epoch 00014: val_loss did not improve from 4.29800
# F1 score: 0.3671975222116458
# Epoch 15/120
# 400/400 [==============================] - 221s 552ms/step - loss: 3.7647 - val_loss: 4.1432
#
# Epoch 00015: val_loss improved from 4.29800 to 4.14321, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.49343207489138374
# Improve F1 score from 0.4266038390623433 to 0.49343207489138374
# Epoch 16/120
# 400/400 [==============================] - 220s 551ms/step - loss: 3.7278 - val_loss: 4.2277
#
# Epoch 00016: val_loss did not improve from 4.14321
# F1 score: 0.4538562928516904
# Epoch 17/120
# 400/400 [==============================] - 221s 553ms/step - loss: 3.7084 - val_loss: 4.1461
#
# Epoch 00017: val_loss did not improve from 4.14321
# F1 score: 0.46003287116606917
# Epoch 18/120
# 400/400 [==============================] - 222s 554ms/step - loss: 3.6876 - val_loss: 4.1953
#
# Epoch 00018: val_loss did not improve from 4.14321
# F1 score: 0.40191331315291257
# Epoch 19/120
# 400/400 [==============================] - 221s 553ms/step - loss: 3.6440 - val_loss: 4.0488
#
# Epoch 00019: val_loss improved from 4.14321 to 4.04877, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.43407262918264905
# Epoch 20/120
# 400/400 [==============================] - 219s 549ms/step - loss: 3.6743 - val_loss: 3.9929
#
# Epoch 00020: val_loss improved from 4.04877 to 3.99293, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.46960197720106306
# Epoch 21/120
# 400/400 [==============================] - 226s 564ms/step - loss: 3.6323 - val_loss: 3.8333
#
# Epoch 00021: val_loss improved from 3.99293 to 3.83333, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.43901218331315267
# Epoch 22/120
# 400/400 [==============================] - 222s 554ms/step - loss: 3.6331 - val_loss: 3.8231
#
# Epoch 00022: val_loss improved from 3.83333 to 3.82305, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.47313984944429693
# Epoch 23/120
# 400/400 [==============================] - 222s 554ms/step - loss: 3.5419 - val_loss: 3.7354
#
# Epoch 00023: val_loss improved from 3.82305 to 3.73541, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.49574626320687426
# Improve F1 score from 0.49343207489138374 to 0.49574626320687426
# Epoch 24/120
# 400/400 [==============================] - 222s 555ms/step - loss: 3.5113 - val_loss: 3.7380
#
# Epoch 00024: val_loss did not improve from 3.73541
# F1 score: 0.4788062439745872
# Epoch 25/120
# 400/400 [==============================] - 223s 558ms/step - loss: 3.5445 - val_loss: 3.8926
#
# Epoch 00025: val_loss did not improve from 3.73541
# F1 score: 0.4471595566467776
# Epoch 26/120
# 400/400 [==============================] - 222s 554ms/step - loss: 3.5090 - val_loss: 4.4229
#
# Epoch 00026: val_loss did not improve from 3.73541
# F1 score: 0.44208752288114606
# Epoch 27/120
# 400/400 [==============================] - 221s 553ms/step - loss: 3.5230 - val_loss: 3.9834
#
# Epoch 00027: val_loss did not improve from 3.73541
# F1 score: 0.46497804219694605
# Epoch 28/120
# 400/400 [==============================] - 221s 552ms/step - loss: 3.4641 - val_loss: 3.9327
#
# Epoch 00028: val_loss did not improve from 3.73541
# F1 score: 0.46465385756131466
# Epoch 29/120
# 400/400 [==============================] - 225s 561ms/step - loss: 3.4673 - val_loss: 3.9091
#
# Epoch 00029: val_loss did not improve from 3.73541
# F1 score: 0.4601445520768953
# Epoch 30/120
# 400/400 [==============================] - 223s 557ms/step - loss: 3.4844 - val_loss: 3.9781
#
# Epoch 00030: val_loss did not improve from 3.73541
# F1 score: 0.4482538655520305
# Epoch 31/120
# 400/400 [==============================] - 222s 556ms/step - loss: 3.4200 - val_loss: 4.0618
#
# Epoch 00031: val_loss did not improve from 3.73541
# F1 score: 0.4487036917958085
# Epoch 32/120
# 400/400 [==============================] - 219s 549ms/step - loss: 3.4269 - val_loss: 4.1266
#
# Epoch 00032: val_loss did not improve from 3.73541
# F1 score: 0.46572237720503906
# Epoch 33/120
# 400/400 [==============================] - 222s 554ms/step - loss: 3.3632 - val_loss: 3.7277
#
# Epoch 00033: val_loss improved from 3.73541 to 3.72767, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.46378993631133236
# Epoch 34/120
# 400/400 [==============================] - 220s 550ms/step - loss: 3.4066 - val_loss: 3.7974
#
# Epoch 00034: val_loss did not improve from 3.72767
# F1 score: 0.4681049918831889
# Epoch 35/120
# 400/400 [==============================] - 221s 552ms/step - loss: 3.3571 - val_loss: 3.6439
#
# Epoch 00035: val_loss improved from 3.72767 to 3.64395, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.48232635392401
# Epoch 36/120
# 400/400 [==============================] - 220s 551ms/step - loss: 3.3894 - val_loss: 3.5870
#
# Epoch 00036: val_loss improved from 3.64395 to 3.58700, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.495902215882527
# Improve F1 score from 0.49574626320687426 to 0.495902215882527
# Epoch 37/120
# 400/400 [==============================] - 221s 554ms/step - loss: 3.3282 - val_loss: 3.6139
#
# Epoch 00037: val_loss did not improve from 3.58700
# F1 score: 0.47823273492716056
# Epoch 38/120
# 400/400 [==============================] - 222s 556ms/step - loss: 3.3174 - val_loss: 3.5985
#
# Epoch 00038: val_loss did not improve from 3.58700
# F1 score: 0.4798717295882907
# Epoch 39/120
# 400/400 [==============================] - 221s 553ms/step - loss: 3.3463 - val_loss: 3.5472
#
# Epoch 00039: val_loss improved from 3.58700 to 3.54719, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.4730112532762176
# Epoch 40/120
# 400/400 [==============================] - 219s 549ms/step - loss: 3.3012 - val_loss: 3.7335
#
# Epoch 00040: val_loss did not improve from 3.54719
# F1 score: 0.4914839082435692
# Epoch 41/120
# 400/400 [==============================] - 221s 553ms/step - loss: 3.2860 - val_loss: 3.4641
#
# Epoch 00041: val_loss improved from 3.54719 to 3.46405, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.47789002255890917
# Epoch 42/120
# 400/400 [==============================] - 220s 551ms/step - loss: 3.2858 - val_loss: 3.7509
#
# Epoch 00042: val_loss did not improve from 3.46405
# F1 score: 0.4973285033752248
# Improve F1 score from 0.495902215882527 to 0.4973285033752248
# Epoch 43/120
# 400/400 [==============================] - 221s 552ms/step - loss: 3.3072 - val_loss: 3.7017
#
# Epoch 00043: val_loss did not improve from 3.46405
# F1 score: 0.4769909767938187
# Epoch 44/120
# 400/400 [==============================] - 221s 551ms/step - loss: 3.2547 - val_loss: 3.6454
#
# Epoch 00044: val_loss did not improve from 3.46405
# F1 score: 0.48846105408731966
# Epoch 45/120
# 400/400 [==============================] - 222s 555ms/step - loss: 3.2510 - val_loss: 3.4698
#
# Epoch 00045: val_loss did not improve from 3.46405
# F1 score: 0.5143711760427191
# Improve F1 score from 0.4973285033752248 to 0.5143711760427191
# Epoch 46/120
# 400/400 [==============================] - 219s 548ms/step - loss: 3.2137 - val_loss: 3.5808
#
# Epoch 00046: val_loss did not improve from 3.46405
# F1 score: 0.48555229994863264
# Epoch 47/120
# 400/400 [==============================] - 218s 546ms/step - loss: 3.2000 - val_loss: 3.6715
#
# Epoch 00047: val_loss did not improve from 3.46405
# F1 score: 0.4685181586098178
# Epoch 48/120
# 400/400 [==============================] - 221s 554ms/step - loss: 3.2205 - val_loss: 3.6503
#
# Epoch 00048: val_loss did not improve from 3.46405
# F1 score: 0.48548663550812504
# Epoch 49/120
# 400/400 [==============================] - 221s 552ms/step - loss: 3.2521 - val_loss: 3.5571
#
# Epoch 00049: val_loss did not improve from 3.46405
# F1 score: 0.49128300795545055
# Epoch 50/120
# 400/400 [==============================] - 220s 551ms/step - loss: 3.1909 - val_loss: 3.5805
#
# Epoch 00050: val_loss did not improve from 3.46405
# F1 score: 0.48303800314673906
# Epoch 51/120
# 400/400 [==============================] - 223s 558ms/step - loss: 3.1460 - val_loss: 3.4867
#
# Epoch 00051: val_loss did not improve from 3.46405
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# F1 score: 0.46786387490013603
# Epoch 52/120
# 400/400 [==============================] - 220s 551ms/step - loss: 3.0444 - val_loss: 3.2308
#
# Epoch 00052: val_loss improved from 3.46405 to 3.23080, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.5182439103045001
# Improve F1 score from 0.5143711760427191 to 0.5182439103045001
# Epoch 53/120
# 400/400 [==============================] - 219s 548ms/step - loss: 2.9878 - val_loss: 3.1869
#
# Epoch 00053: val_loss improved from 3.23080 to 3.18691, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.5209810868080071
# Improve F1 score from 0.5182439103045001 to 0.5209810868080071
# Epoch 54/120
# 400/400 [==============================] - 219s 549ms/step - loss: 2.9711 - val_loss: 3.2090
#
# Epoch 00054: val_loss did not improve from 3.18691
# F1 score: 0.5303658528021975
# Improve F1 score from 0.5209810868080071 to 0.5303658528021975
# Epoch 55/120
# 400/400 [==============================] - 219s 546ms/step - loss: 2.9624 - val_loss: 3.2651
#
# Epoch 00055: val_loss did not improve from 3.18691
# F1 score: 0.5112260245084558
# Epoch 56/120
# 400/400 [==============================] - 222s 556ms/step - loss: 2.9126 - val_loss: 3.2788
#
# Epoch 00056: val_loss did not improve from 3.18691
# F1 score: 0.5121832660826814
# Epoch 57/120
# 400/400 [==============================] - 223s 557ms/step - loss: 2.9188 - val_loss: 3.1802
#
# Epoch 00057: val_loss improved from 3.18691 to 3.18017, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.5059300092468777
# Epoch 58/120
# 400/400 [==============================] - 218s 546ms/step - loss: 2.9101 - val_loss: 3.2584
#
# Epoch 00058: val_loss did not improve from 3.18017
# F1 score: 0.5162171287153275
# Epoch 59/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.9071 - val_loss: 3.2178
#
# Epoch 00059: val_loss did not improve from 3.18017
# F1 score: 0.5087738553146686
# Epoch 60/120
# 400/400 [==============================] - 220s 551ms/step - loss: 2.9342 - val_loss: 3.2048
#
# Epoch 00060: val_loss did not improve from 3.18017
# F1 score: 0.5206978738379108
# Epoch 61/120
# 400/400 [==============================] - 224s 559ms/step - loss: 2.8810 - val_loss: 3.1765
#
# Epoch 00061: val_loss improved from 3.18017 to 3.17652, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.515938581032926
# Epoch 62/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.8703 - val_loss: 3.2482
#
# Epoch 00062: val_loss did not improve from 3.17652
# F1 score: 0.4938806614586228
# Epoch 63/120
# 400/400 [==============================] - 220s 551ms/step - loss: 2.8901 - val_loss: 3.1917
#
# Epoch 00063: val_loss did not improve from 3.17652
# F1 score: 0.5176617886185765
# Epoch 64/120
# 400/400 [==============================] - 222s 555ms/step - loss: 2.8499 - val_loss: 3.1842
#
# Epoch 00064: val_loss did not improve from 3.17652
# F1 score: 0.49508984843917253
# Epoch 65/120
# 400/400 [==============================] - 218s 546ms/step - loss: 2.8625 - val_loss: 3.2691
#
# Epoch 00065: val_loss did not improve from 3.17652
# F1 score: 0.5035410286719099
# Epoch 66/120
# 400/400 [==============================] - 221s 551ms/step - loss: 2.8343 - val_loss: 3.2311
#
# Epoch 00066: val_loss did not improve from 3.17652
# F1 score: 0.5112294998562038
# Epoch 67/120
# 400/400 [==============================] - 221s 551ms/step - loss: 2.8508 - val_loss: 3.1685
#
# Epoch 00067: val_loss improved from 3.17652 to 3.16851, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.5157444511125707
# Epoch 68/120
# 400/400 [==============================] - 221s 552ms/step - loss: 2.8562 - val_loss: 3.1914
#
# Epoch 00068: val_loss did not improve from 3.16851
# F1 score: 0.5158369472219617
# Epoch 69/120
# 400/400 [==============================] - 221s 552ms/step - loss: 2.8415 - val_loss: 3.1924
#
# Epoch 00069: val_loss did not improve from 3.16851
# F1 score: 0.5333407811051746
# Improve F1 score from 0.5303658528021975 to 0.5333407811051746
# Epoch 70/120
# 400/400 [==============================] - 222s 555ms/step - loss: 2.8153 - val_loss: 3.2082
#
# Epoch 00070: val_loss did not improve from 3.16851
# F1 score: 0.5144649369311013
# Epoch 71/120
# 400/400 [==============================] - 221s 552ms/step - loss: 2.8017 - val_loss: 3.1865
#
# Epoch 00071: val_loss did not improve from 3.16851
# F1 score: 0.5116538330784294
# Epoch 72/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.8315 - val_loss: 3.2897
#
# Epoch 00072: val_loss did not improve from 3.16851
# F1 score: 0.5228215838162843
# Epoch 73/120
# 400/400 [==============================] - 222s 554ms/step - loss: 2.8071 - val_loss: 3.2700
#
# Epoch 00073: val_loss did not improve from 3.16851
# F1 score: 0.5164191219598586
# Epoch 74/120
# 400/400 [==============================] - 221s 553ms/step - loss: 2.8120 - val_loss: 3.1887
#
# Epoch 00074: val_loss did not improve from 3.16851
# F1 score: 0.5187014107592586
# Epoch 75/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.8355 - val_loss: 3.1689
#
# Epoch 00075: val_loss did not improve from 3.16851
# F1 score: 0.514885576641929
# Epoch 76/120
# 400/400 [==============================] - 223s 557ms/step - loss: 2.7793 - val_loss: 3.1665
#
# Epoch 00076: val_loss improved from 3.16851 to 3.16655, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.5321870570223456
# Epoch 77/120
# 400/400 [==============================] - 221s 552ms/step - loss: 2.7871 - val_loss: 3.1659
#
# Epoch 00077: val_loss improved from 3.16655 to 3.16589, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.5163953594294202
# Epoch 78/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.7615 - val_loss: 3.1974
#
# Epoch 00078: val_loss did not improve from 3.16589
# F1 score: 0.5155132573738328
# Epoch 79/120
# 400/400 [==============================] - 222s 555ms/step - loss: 2.7809 - val_loss: 3.1830
#
# Epoch 00079: val_loss did not improve from 3.16589
# F1 score: 0.5010069898675641
# Epoch 80/120
# 400/400 [==============================] - 218s 546ms/step - loss: 2.8044 - val_loss: 3.1999
#
# Epoch 00080: val_loss did not improve from 3.16589
# F1 score: 0.5192279093222347
# Epoch 81/120
# 400/400 [==============================] - 220s 549ms/step - loss: 2.7686 - val_loss: 3.2768
#
# Epoch 00081: val_loss did not improve from 3.16589
# F1 score: 0.5025490364920696
# Epoch 82/120
# 400/400 [==============================] - 222s 555ms/step - loss: 2.7739 - val_loss: 3.1876
#
# Epoch 00082: val_loss did not improve from 3.16589
# F1 score: 0.5033736964410847
# Epoch 83/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.7549 - val_loss: 3.2199
#
# Epoch 00083: val_loss did not improve from 3.16589
# F1 score: 0.5146176179363952
# Epoch 84/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.7789 - val_loss: 3.1635
#
# Epoch 00084: val_loss improved from 3.16589 to 3.16345, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.49884022673406464
# Epoch 85/120
# 400/400 [==============================] - 221s 553ms/step - loss: 2.7658 - val_loss: 3.1720
#
# Epoch 00085: val_loss did not improve from 3.16345
# F1 score: 0.505925155253929
# Epoch 86/120
# 400/400 [==============================] - 220s 549ms/step - loss: 2.6933 - val_loss: 3.2328
#
# Epoch 00086: val_loss did not improve from 3.16345
# F1 score: 0.5273514282586855
# Epoch 87/120
# 400/400 [==============================] - 221s 553ms/step - loss: 2.7570 - val_loss: 3.1576
#
# Epoch 00087: val_loss improved from 3.16345 to 3.15757, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.5078693608632321
# Epoch 88/120
# 400/400 [==============================] - 221s 553ms/step - loss: 2.7248 - val_loss: 3.2079
#
# Epoch 00088: val_loss did not improve from 3.15757
# F1 score: 0.5148859694517447
# Epoch 89/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.7502 - val_loss: 3.2310
#
# Epoch 00089: val_loss did not improve from 3.15757
# F1 score: 0.5028074493698343
# Epoch 90/120
# 400/400 [==============================] - 220s 549ms/step - loss: 2.7274 - val_loss: 3.2132
#
# Epoch 00090: val_loss did not improve from 3.15757
# F1 score: 0.5123353318707516
# Epoch 91/120
# 400/400 [==============================] - 224s 561ms/step - loss: 2.7425 - val_loss: 3.1871
#
# Epoch 00091: val_loss did not improve from 3.15757
# F1 score: 0.5109779905353296
# Epoch 92/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.7044 - val_loss: 3.2462
#
# Epoch 00092: val_loss did not improve from 3.15757
# F1 score: 0.5091434493228575
# Epoch 93/120
# 400/400 [==============================] - 221s 553ms/step - loss: 2.7037 - val_loss: 3.2583
#
# Epoch 00093: val_loss did not improve from 3.15757
# F1 score: 0.5085457178555672
# Epoch 94/120
# 400/400 [==============================] - 220s 551ms/step - loss: 2.6806 - val_loss: 3.3304
#
# Epoch 00094: val_loss did not improve from 3.15757
# F1 score: 0.516531190693603
# Epoch 95/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.7453 - val_loss: 3.1593
#
# Epoch 00095: val_loss did not improve from 3.15757
# F1 score: 0.498853751074818
# Epoch 96/120
# 400/400 [==============================] - 222s 556ms/step - loss: 2.6868 - val_loss: 3.1905
#
# Epoch 00096: val_loss did not improve from 3.15757
# F1 score: 0.5153342987413431
# Epoch 97/120
# 400/400 [==============================] - 220s 549ms/step - loss: 2.7229 - val_loss: 3.2087
#
# Epoch 00097: val_loss did not improve from 3.15757
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# F1 score: 0.5102793282088965
# Epoch 98/120
# 400/400 [==============================] - 222s 555ms/step - loss: 2.6123 - val_loss: 3.0944
#
# Epoch 00098: val_loss improved from 3.15757 to 3.09439, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.5235627770245443
# Epoch 99/120
# 400/400 [==============================] - 220s 551ms/step - loss: 2.5953 - val_loss: 3.0896
#
# Epoch 00099: val_loss improved from 3.09439 to 3.08958, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.5123835564778166
# Epoch 100/120
# 400/400 [==============================] - 221s 553ms/step - loss: 2.6152 - val_loss: 3.0415
#
# Epoch 00100: val_loss improved from 3.08958 to 3.04146, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.49356018936469803
# Epoch 101/120
# 400/400 [==============================] - 221s 553ms/step - loss: 2.6166 - val_loss: 3.0711
#
# Epoch 00101: val_loss did not improve from 3.04146
# F1 score: 0.5089667624870211
# Epoch 102/120
# 400/400 [==============================] - 220s 551ms/step - loss: 2.5738 - val_loss: 3.0742
#
# Epoch 00102: val_loss did not improve from 3.04146
# F1 score: 0.504404014281928
# Epoch 103/120
# 400/400 [==============================] - 223s 557ms/step - loss: 2.5710 - val_loss: 3.0740
#
# Epoch 00103: val_loss did not improve from 3.04146
# F1 score: 0.5022809449351489
# Epoch 104/120
# 400/400 [==============================] - 223s 557ms/step - loss: 2.5497 - val_loss: 3.0854
#
# Epoch 00104: val_loss did not improve from 3.04146
# F1 score: 0.5155636385952568
# Epoch 105/120
# 400/400 [==============================] - 220s 549ms/step - loss: 2.5575 - val_loss: 3.0643
#
# Epoch 00105: val_loss did not improve from 3.04146
# F1 score: 0.5149237194589796
# Epoch 106/120
# 400/400 [==============================] - 222s 555ms/step - loss: 2.5663 - val_loss: 3.0118
#
# Epoch 00106: val_loss improved from 3.04146 to 3.01175, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_1.0_exp_1.h5
# F1 score: 0.5108311994873895
# Epoch 107/120
# 400/400 [==============================] - 222s 554ms/step - loss: 2.5580 - val_loss: 3.0663
#
# Epoch 00107: val_loss did not improve from 3.01175
# F1 score: 0.5001369579475677
# Epoch 108/120
# 400/400 [==============================] - 221s 552ms/step - loss: 2.5528 - val_loss: 3.0540
#
# Epoch 00108: val_loss did not improve from 3.01175
# F1 score: 0.5170482207455049
# Epoch 109/120
# 400/400 [==============================] - 222s 555ms/step - loss: 2.5397 - val_loss: 3.0457
#
# Epoch 00109: val_loss did not improve from 3.01175
# F1 score: 0.501469545463985
# Epoch 110/120
# 400/400 [==============================] - 218s 544ms/step - loss: 2.5446 - val_loss: 3.0907
#
# Epoch 00110: val_loss did not improve from 3.01175
# F1 score: 0.5027259014697482
# Epoch 111/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.5268 - val_loss: 3.1060
#
# Epoch 00111: val_loss did not improve from 3.01175
# F1 score: 0.5066584575358609
# Epoch 112/120
# 400/400 [==============================] - 221s 553ms/step - loss: 2.5335 - val_loss: 3.0318
#
# Epoch 00112: val_loss did not improve from 3.01175
# F1 score: 0.5132708366847178
# Epoch 113/120
# 400/400 [==============================] - 220s 551ms/step - loss: 2.5296 - val_loss: 3.0333
#
# Epoch 00113: val_loss did not improve from 3.01175
# F1 score: 0.5233174664145739
# Epoch 114/120
# 400/400 [==============================] - 220s 551ms/step - loss: 2.5200 - val_loss: 3.0321
#
# Epoch 00114: val_loss did not improve from 3.01175
# F1 score: 0.5260148071556329
# Epoch 115/120
# 400/400 [==============================] - 221s 552ms/step - loss: 2.5078 - val_loss: 3.0432
#
# Epoch 00115: val_loss did not improve from 3.01175
# F1 score: 0.5192056491156436
# Epoch 116/120
# 400/400 [==============================] - 222s 555ms/step - loss: 2.5191 - val_loss: 3.0875
#
# Epoch 00116: val_loss did not improve from 3.01175
#
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# F1 score: 0.5083365638909725
# Epoch 117/120
# 400/400 [==============================] - 217s 543ms/step - loss: 2.4807 - val_loss: 3.0326
#
# Epoch 00117: val_loss did not improve from 3.01175
# F1 score: 0.5138384207786955
# Epoch 118/120
# 400/400 [==============================] - 223s 557ms/step - loss: 2.4952 - val_loss: 3.0355
#
# Epoch 00118: val_loss did not improve from 3.01175
# F1 score: 0.5148156424557373
# Epoch 119/120
# 400/400 [==============================] - 219s 549ms/step - loss: 2.4474 - val_loss: 3.0304
#
# Epoch 00119: val_loss did not improve from 3.01175
# F1 score: 0.5164332315579234
# Epoch 120/120
# 400/400 [==============================] - 220s 550ms/step - loss: 2.4569 - val_loss: 3.0393
#
# Epoch 00120: val_loss did not improve from 3.01175
# F1 score: 0.5222293197208369
#
# ---->Training model with alpha 1.0 and expansion 1 with cic
# Epoch 1/100
# 15/15 [==============================] - 68s 5s/step - loss: 3.8019 - val_loss: 77.5526
#
# Epoch 00001: val_loss improved from inf to 77.55255, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.02495554528466036
# Improve F1 score from -inf to 0.02495554528466036
# Epoch 2/100
# 15/15 [==============================] - 59s 4s/step - loss: 3.2224 - val_loss: 66.5987
#
# Epoch 00002: val_loss improved from 77.55255 to 66.59874, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.023240475854332733
# Epoch 3/100
# 15/15 [==============================] - 61s 4s/step - loss: 2.9410 - val_loss: 82.6570
#
# Epoch 00003: val_loss did not improve from 66.59874
# F1 score: 0.02711643044986968
# Improve F1 score from 0.02495554528466036 to 0.02711643044986968
# Epoch 4/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.8368 - val_loss: 61.1733
#
# Epoch 00004: val_loss improved from 66.59874 to 61.17327, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.03262573161415439
# Improve F1 score from 0.02711643044986968 to 0.03262573161415439
# Epoch 5/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.7554 - val_loss: 52.5507
#
# Epoch 00005: val_loss improved from 61.17327 to 52.55073, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.047103404275727706
# Improve F1 score from 0.03262573161415439 to 0.047103404275727706
# Epoch 6/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.6208 - val_loss: 52.5053
#
# Epoch 00006: val_loss improved from 52.55073 to 52.50530, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.04895927694835064
# Improve F1 score from 0.047103404275727706 to 0.04895927694835064
# Epoch 7/100
# 15/15 [==============================] - 61s 4s/step - loss: 2.5695 - val_loss: 58.0825
#
# Epoch 00007: val_loss did not improve from 52.50530
# F1 score: 0.03563805925166217
# Epoch 8/100
# 15/15 [==============================] - 61s 4s/step - loss: 2.5183 - val_loss: 58.9613
#
# Epoch 00008: val_loss did not improve from 52.50530
# F1 score: 0.03108398970107041
# Epoch 9/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.5983 - val_loss: 54.5356
#
# Epoch 00009: val_loss did not improve from 52.50530
# F1 score: 0.04130172824337713
# Epoch 10/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.5124 - val_loss: 48.0515
#
# Epoch 00010: val_loss improved from 52.50530 to 48.05149, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.042176084957889194
# Epoch 11/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.3751 - val_loss: 48.9477
#
# Epoch 00011: val_loss did not improve from 48.05149
# F1 score: 0.044244295719725525
# Epoch 12/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.3938 - val_loss: 43.1296
#
# Epoch 00012: val_loss improved from 48.05149 to 43.12956, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.04362680936209043
# Epoch 13/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.3719 - val_loss: 40.0588
#
# Epoch 00013: val_loss improved from 43.12956 to 40.05875, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.04998612747112919
# Improve F1 score from 0.04895927694835064 to 0.04998612747112919
# Epoch 14/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.2815 - val_loss: 39.6616
#
# Epoch 00014: val_loss improved from 40.05875 to 39.66158, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.057535214991089
# Improve F1 score from 0.04998612747112919 to 0.057535214991089
# Epoch 15/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.3302 - val_loss: 38.5341
#
# Epoch 00015: val_loss improved from 39.66158 to 38.53405, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.05085860359745791
# Epoch 16/100
# 15/15 [==============================] - 60s 4s/step - loss: 2.0841 - val_loss: 35.0758
#
# Epoch 00016: val_loss improved from 38.53405 to 35.07577, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.05660598694141004
# Epoch 17/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.1710 - val_loss: 32.1038
#
# Epoch 00017: val_loss improved from 35.07577 to 32.10380, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.05772840968368042
# Improve F1 score from 0.057535214991089 to 0.05772840968368042
# Epoch 18/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.3044 - val_loss: 32.5400
#
# Epoch 00018: val_loss did not improve from 32.10380
# F1 score: 0.060499021136509665
# Improve F1 score from 0.05772840968368042 to 0.060499021136509665
# Epoch 19/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.3234 - val_loss: 32.6772
#
# Epoch 00019: val_loss did not improve from 32.10380
# F1 score: 0.08175420320993824
# Improve F1 score from 0.060499021136509665 to 0.08175420320993824
# Epoch 20/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.2231 - val_loss: 30.9805
#
# Epoch 00020: val_loss improved from 32.10380 to 30.98050, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.07814988747563344
# Epoch 21/100
# 15/15 [==============================] - 59s 4s/step - loss: 2.0156 - val_loss: 26.6649
#
# Epoch 00021: val_loss improved from 30.98050 to 26.66486, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.085645334777416
# Improve F1 score from 0.08175420320993824 to 0.085645334777416
# Epoch 22/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.1673 - val_loss: 26.4793
#
# Epoch 00022: val_loss improved from 26.66486 to 26.47932, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.08465156965819241
# Epoch 23/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.2381 - val_loss: 25.4204
#
# Epoch 00023: val_loss improved from 26.47932 to 25.42036, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.08400266537007246
# Epoch 24/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.0154 - val_loss: 24.6089
#
# Epoch 00024: val_loss improved from 25.42036 to 24.60890, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.07833569300103123
# Epoch 25/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.9430 - val_loss: 22.3530
#
# Epoch 00025: val_loss improved from 24.60890 to 22.35303, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.0830136089261068
# Epoch 26/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.0376 - val_loss: 22.5039
#
# Epoch 00026: val_loss did not improve from 22.35303
# F1 score: 0.07992120867890493
# Epoch 27/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.9463 - val_loss: 21.8541
#
# Epoch 00027: val_loss improved from 22.35303 to 21.85409, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.08731893361353216
# Improve F1 score from 0.085645334777416 to 0.08731893361353216
# Epoch 28/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.0664 - val_loss: 20.0594
#
# Epoch 00028: val_loss improved from 21.85409 to 20.05937, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.08510661064229964
# Epoch 29/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.0747 - val_loss: 18.2644
#
# Epoch 00029: val_loss improved from 20.05937 to 18.26437, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.09422717579506223
# Improve F1 score from 0.08731893361353216 to 0.09422717579506223
# Epoch 30/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.9677 - val_loss: 19.9701
#
# Epoch 00030: val_loss did not improve from 18.26437
# F1 score: 0.10361513555928122
# Improve F1 score from 0.09422717579506223 to 0.10361513555928122
# Epoch 31/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.0859 - val_loss: 18.6072
#
# Epoch 00031: val_loss did not improve from 18.26437
# F1 score: 0.11185231231320773
# Improve F1 score from 0.10361513555928122 to 0.11185231231320773
# Epoch 32/100
# 15/15 [==============================] - 61s 4s/step - loss: 2.1474 - val_loss: 16.6361
#
# Epoch 00032: val_loss improved from 18.26437 to 16.63606, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.11943322408516208
# Improve F1 score from 0.11185231231320773 to 0.11943322408516208
# Epoch 33/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.9596 - val_loss: 15.8809
#
# Epoch 00033: val_loss improved from 16.63606 to 15.88094, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.1202896339847836
# Improve F1 score from 0.11943322408516208 to 0.1202896339847836
# Epoch 34/100
# 15/15 [==============================] - 59s 4s/step - loss: 1.8005 - val_loss: 16.3375
#
# Epoch 00034: val_loss did not improve from 15.88094
# F1 score: 0.1184785043426427
# Epoch 35/100
# 15/15 [==============================] - 61s 4s/step - loss: 2.0135 - val_loss: 15.9428
#
# Epoch 00035: val_loss did not improve from 15.88094
# F1 score: 0.12290074523887201
# Improve F1 score from 0.1202896339847836 to 0.12290074523887201
# Epoch 36/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.9369 - val_loss: 16.7367
#
# Epoch 00036: val_loss did not improve from 15.88094
# F1 score: 0.11964586895449278
# Epoch 37/100
# 15/15 [==============================] - 66s 4s/step - loss: 1.9678 - val_loss: 16.4600
#
# Epoch 00037: val_loss did not improve from 15.88094
# F1 score: 0.11365035995508285
# Epoch 38/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.9229 - val_loss: 15.8699
#
# Epoch 00038: val_loss improved from 15.88094 to 15.86994, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.12019964335353303
# Epoch 39/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8390 - val_loss: 16.3084
#
# Epoch 00039: val_loss did not improve from 15.86994
# F1 score: 0.11564795452517997
# Epoch 40/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.9259 - val_loss: 14.9408
#
# Epoch 00040: val_loss improved from 15.86994 to 14.94083, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.11775340250752298
# Epoch 41/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8511 - val_loss: 14.3352
#
# Epoch 00041: val_loss improved from 14.94083 to 14.33519, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.12170321767242177
# Epoch 42/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.9414 - val_loss: 14.2225
#
# Epoch 00042: val_loss improved from 14.33519 to 14.22248, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.1254552143965838
# Improve F1 score from 0.12290074523887201 to 0.1254552143965838
# Epoch 43/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.8159 - val_loss: 14.2078
#
# Epoch 00043: val_loss improved from 14.22248 to 14.20784, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.12387990111049411
# Epoch 44/100
# 15/15 [==============================] - 66s 4s/step - loss: 1.9143 - val_loss: 13.6563
#
# Epoch 00044: val_loss improved from 14.20784 to 13.65635, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.12313984079565356
# Epoch 45/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.8532 - val_loss: 14.3737
#
# Epoch 00045: val_loss did not improve from 13.65635
# F1 score: 0.12137875150788728
# Epoch 46/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8082 - val_loss: 13.3078
#
# Epoch 00046: val_loss improved from 13.65635 to 13.30782, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.12601670670279533
# Improve F1 score from 0.1254552143965838 to 0.12601670670279533
# Epoch 47/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.8077 - val_loss: 13.0171
#
# Epoch 00047: val_loss improved from 13.30782 to 13.01713, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.12685598340457516
# Improve F1 score from 0.12601670670279533 to 0.12685598340457516
# Epoch 48/100
# 15/15 [==============================] - 66s 4s/step - loss: 1.8649 - val_loss: 13.5882
#
# Epoch 00048: val_loss did not improve from 13.01713
# F1 score: 0.12647880924712143
# Epoch 49/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.8247 - val_loss: 12.5834
#
# Epoch 00049: val_loss improved from 13.01713 to 12.58341, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.1287381061700491
# Improve F1 score from 0.12685598340457516 to 0.1287381061700491
# Epoch 50/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.8729 - val_loss: 12.6256
#
# Epoch 00050: val_loss did not improve from 12.58341
# F1 score: 0.1289838445965162
# Improve F1 score from 0.1287381061700491 to 0.1289838445965162
# Epoch 51/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.8351 - val_loss: 13.2910
#
# Epoch 00051: val_loss did not improve from 12.58341
# F1 score: 0.1277176352350265
# Epoch 52/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.8718 - val_loss: 13.0515
#
# Epoch 00052: val_loss did not improve from 12.58341
# F1 score: 0.13057026853002343
# Improve F1 score from 0.1289838445965162 to 0.13057026853002343
# Epoch 53/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7201 - val_loss: 12.5389
#
# Epoch 00053: val_loss improved from 12.58341 to 12.53887, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.14682172583971856
# Improve F1 score from 0.13057026853002343 to 0.14682172583971856
# Epoch 54/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.9813 - val_loss: 11.8179
#
# Epoch 00054: val_loss improved from 12.53887 to 11.81793, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.1497338840205476
# Improve F1 score from 0.14682172583971856 to 0.1497338840205476
# Epoch 55/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.7939 - val_loss: 10.8897
#
# Epoch 00055: val_loss improved from 11.81793 to 10.88970, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.1566488743372944
# Improve F1 score from 0.1497338840205476 to 0.1566488743372944
# Epoch 56/100
# 15/15 [==============================] - 60s 4s/step - loss: 1.6184 - val_loss: 10.4894
#
# Epoch 00056: val_loss improved from 10.88970 to 10.48940, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.17033294571460697
# Improve F1 score from 0.1566488743372944 to 0.17033294571460697
# Epoch 57/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7533 - val_loss: 10.5230
#
# Epoch 00057: val_loss did not improve from 10.48940
# F1 score: 0.16762679229467148
# Epoch 58/100
# 15/15 [==============================] - 67s 4s/step - loss: 1.8127 - val_loss: 10.3931
#
# Epoch 00058: val_loss improved from 10.48940 to 10.39307, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.16735268807675446
# Epoch 59/100
# 15/15 [==============================] - 60s 4s/step - loss: 1.6945 - val_loss: 9.5994
#
# Epoch 00059: val_loss improved from 10.39307 to 9.59935, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.173791184978317
# Improve F1 score from 0.17033294571460697 to 0.173791184978317
# Epoch 60/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.7058 - val_loss: 9.7834
#
# Epoch 00060: val_loss did not improve from 9.59935
# F1 score: 0.18204194830704146
# Improve F1 score from 0.173791184978317 to 0.18204194830704146
# Epoch 61/100
# 15/15 [==============================] - 66s 4s/step - loss: 1.6210 - val_loss: 9.2976
#
# Epoch 00061: val_loss improved from 9.59935 to 9.29764, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.18604412714559002
# Improve F1 score from 0.18204194830704146 to 0.18604412714559002
# Epoch 62/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.6638 - val_loss: 8.9080
#
# Epoch 00062: val_loss improved from 9.29764 to 8.90799, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.2029420551089528
# Improve F1 score from 0.18604412714559002 to 0.2029420551089528
# Epoch 63/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.6759 - val_loss: 9.1177
#
# Epoch 00063: val_loss did not improve from 8.90799
# F1 score: 0.2212704050237407
# Improve F1 score from 0.2029420551089528 to 0.2212704050237407
# Epoch 64/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.7376 - val_loss: 9.2330
#
# Epoch 00064: val_loss did not improve from 8.90799
# F1 score: 0.19657178727405888
# Epoch 65/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.6894 - val_loss: 9.4363
#
# Epoch 00065: val_loss did not improve from 8.90799
# F1 score: 0.18848781795042646
# Epoch 66/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.6960 - val_loss: 8.9934
#
# Epoch 00066: val_loss did not improve from 8.90799
# F1 score: 0.20245679380563283
# Epoch 67/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.7396 - val_loss: 8.6948
#
# Epoch 00067: val_loss improved from 8.90799 to 8.69479, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.20677349545166346
# Epoch 68/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.7734 - val_loss: 8.2644
#
# Epoch 00068: val_loss improved from 8.69479 to 8.26441, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.19616523605824635
# Epoch 69/100
# 15/15 [==============================] - 63s 4s/step - loss: 1.5801 - val_loss: 8.5699
#
# Epoch 00069: val_loss did not improve from 8.26441
# F1 score: 0.20838596696187173
# Epoch 70/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.8091 - val_loss: 9.0860
#
# Epoch 00070: val_loss did not improve from 8.26441
# F1 score: 0.19683717562955674
# Epoch 71/100
# 15/15 [==============================] - 62s 4s/step - loss: 1.6552 - val_loss: 9.5202
#
# Epoch 00071: val_loss did not improve from 8.26441
# F1 score: 0.1933392253750384
# Epoch 72/100
# 15/15 [==============================] - 65s 4s/step - loss: 1.8059 - val_loss: 9.7647
#
# Epoch 00072: val_loss did not improve from 8.26441
# F1 score: 0.19772569240236823
# Epoch 73/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.6454 - val_loss: 9.2351
#
# Epoch 00073: val_loss did not improve from 8.26441
# F1 score: 0.19480056045316532
# Epoch 74/100
# 15/15 [==============================] - 66s 4s/step - loss: 1.7942 - val_loss: 8.6103
#
# Epoch 00074: val_loss did not improve from 8.26441
# F1 score: 0.21599582088759545
# Epoch 75/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.6472 - val_loss: 7.9259
#
# Epoch 00075: val_loss improved from 8.26441 to 7.92586, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_cic_1.0_exp_1.h5
# F1 score: 0.23264359103063503
# Improve F1 score from 0.2212704050237407 to 0.23264359103063503
# Epoch 76/100
# 15/15 [==============================] - 64s 4s/step - loss: 1.7295 - val_loss: 8.0445
#
# Epoch 00076: val_loss did not improve from 7.92586
# F1 score: 0.23720298505337292
# Improve F1 score from 0.23264359103063503 to 0.23720298505337292
# Epoch 77/100
# 15/15 [==============================] - 61s 4s/step - loss: 1.6193 - val_loss: 7.9666
#
# ...
# F1 score: 0.3765280862056856
# Improve F1 score from 0.37489780016884006 to 0.3765280862056856
# Epoch 26/120
# 400/400 [==============================] - 218s 545ms/step - loss: 4.3046 - val_loss: 4.5658
#
# Epoch 00026: val_loss did not improve from 4.43100
# F1 score: 0.34579648167268723
# Epoch 27/120
# 400/400 [==============================] - 217s 542ms/step - loss: 4.2556 - val_loss: 4.9169
#
# Epoch 00027: val_loss did not improve from 4.43100
# F1 score: 0.3110900726364165
# Epoch 28/120
# 400/400 [==============================] - 218s 546ms/step - loss: 4.2776 - val_loss: 4.4521
#
# Epoch 00028: val_loss did not improve from 4.43100
# F1 score: 0.36856471218061565
# Epoch 29/120
# 400/400 [==============================] - 216s 541ms/step - loss: 4.2683 - val_loss: 5.4806
#
# Epoch 00029: val_loss did not improve from 4.43100
# F1 score: 0.2695168091175482
# Epoch 30/120
# 400/400 [==============================] - 218s 545ms/step - loss: 4.2631 - val_loss: 4.6652
#
# Epoch 00030: val_loss did not improve from 4.43100
# F1 score: 0.36131685250827916
# Epoch 31/120
# 400/400 [==============================] - 217s 541ms/step - loss: 4.2227 - val_loss: 4.5876
#
# Epoch 00031: val_loss did not improve from 4.43100
# F1 score: 0.3276314122298193
# Epoch 32/120
# 400/400 [==============================] - 217s 542ms/step - loss: 4.1891 - val_loss: 4.3063
#
# Epoch 00032: val_loss improved from 4.43100 to 4.30626, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.3750257900907868
# Epoch 33/120
# 400/400 [==============================] - 217s 543ms/step - loss: 4.2052 - val_loss: 4.3233
#
# Epoch 00033: val_loss did not improve from 4.30626
# F1 score: 0.380283326808091
# Improve F1 score from 0.3765280862056856 to 0.380283326808091
# Epoch 34/120
# 400/400 [==============================] - 217s 542ms/step - loss: 4.2312 - val_loss: 4.2936
#
# Epoch 00034: val_loss improved from 4.30626 to 4.29359, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.3557473423583315
# Epoch 35/120
# 400/400 [==============================] - 215s 537ms/step - loss: 4.1656 - val_loss: 4.2213
#
# Epoch 00035: val_loss improved from 4.29359 to 4.22129, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.41429847201144715
# Improve F1 score from 0.380283326808091 to 0.41429847201144715
# Epoch 36/120
# 400/400 [==============================] - 218s 545ms/step - loss: 4.1655 - val_loss: 4.4035
#
# Epoch 00036: val_loss did not improve from 4.22129
# F1 score: 0.36386974338681466
# Epoch 37/120
# 400/400 [==============================] - 217s 543ms/step - loss: 4.1718 - val_loss: 4.2168
#
# Epoch 00037: val_loss improved from 4.22129 to 4.21677, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.38641203558699755
# Epoch 38/120
# 400/400 [==============================] - 216s 541ms/step - loss: 4.1346 - val_loss: 4.3606
#
# Epoch 00038: val_loss did not improve from 4.21677
# F1 score: 0.39250008006167625
# Epoch 39/120
# 400/400 [==============================] - 218s 544ms/step - loss: 4.1284 - val_loss: 4.6355
#
# Epoch 00039: val_loss did not improve from 4.21677
# F1 score: 0.34993160068277507
# Epoch 40/120
# 400/400 [==============================] - 216s 540ms/step - loss: 4.1224 - val_loss: 4.2318
#
# Epoch 00040: val_loss did not improve from 4.21677
# F1 score: 0.4221128728975207
# Improve F1 score from 0.41429847201144715 to 0.4221128728975207
# Epoch 41/120
# 400/400 [==============================] - 220s 550ms/step - loss: 4.1299 - val_loss: 4.2630
#
# Epoch 00041: val_loss did not improve from 4.21677
# F1 score: 0.4077788820164689
# Epoch 42/120
# 400/400 [==============================] - 218s 546ms/step - loss: 4.0805 - val_loss: 4.2291
#
# Epoch 00042: val_loss did not improve from 4.21677
# F1 score: 0.39069485129778203
# Epoch 43/120
# 400/400 [==============================] - 218s 546ms/step - loss: 4.1289 - val_loss: 4.2195
#
# Epoch 00043: val_loss did not improve from 4.21677
# F1 score: 0.38284120682864303
# Epoch 44/120
# 400/400 [==============================] - 219s 548ms/step - loss: 4.0866 - val_loss: 4.1617
#
# Epoch 00044: val_loss improved from 4.21677 to 4.16169, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.408458891153211
# Epoch 45/120
# 400/400 [==============================] - 215s 537ms/step - loss: 4.0635 - val_loss: 4.2618
#
# Epoch 00045: val_loss did not improve from 4.16169
# F1 score: 0.4200869356776069
# Epoch 46/120
# 400/400 [==============================] - 217s 542ms/step - loss: 4.0429 - val_loss: 4.2442
#
# Epoch 00046: val_loss did not improve from 4.16169
# F1 score: 0.3972365500097289
# Epoch 47/120
# 400/400 [==============================] - 218s 544ms/step - loss: 4.0529 - val_loss: 4.4368
#
# Epoch 00047: val_loss did not improve from 4.16169
# F1 score: 0.37239135003810664
# Epoch 48/120
# 400/400 [==============================] - 218s 545ms/step - loss: 4.0488 - val_loss: 4.6266
#
# Epoch 00048: val_loss did not improve from 4.16169
# F1 score: 0.3254572909227213
# Epoch 49/120
# 400/400 [==============================] - 217s 542ms/step - loss: 4.0182 - val_loss: 4.2501
#
# Epoch 00049: val_loss did not improve from 4.16169
# F1 score: 0.3643825678567249
# Epoch 50/120
# 400/400 [==============================] - 216s 541ms/step - loss: 4.0244 - val_loss: 4.3852
#
# Epoch 00050: val_loss did not improve from 4.16169
# F1 score: 0.35352027596639485
# Epoch 51/120
# 400/400 [==============================] - 218s 544ms/step - loss: 4.0410 - val_loss: 4.1684
#
# Epoch 00051: val_loss did not improve from 4.16169
# F1 score: 0.35203077103226316
# Epoch 52/120
# 400/400 [==============================] - 215s 539ms/step - loss: 3.9883 - val_loss: 4.4066
#
# Epoch 00052: val_loss did not improve from 4.16169
# F1 score: 0.365331305825671
# Epoch 53/120
# 400/400 [==============================] - 215s 537ms/step - loss: 4.0295 - val_loss: 4.2879
#
# Epoch 00053: val_loss did not improve from 4.16169
# F1 score: 0.3637545401296827
# Epoch 54/120
# 400/400 [==============================] - 217s 541ms/step - loss: 4.0184 - val_loss: 4.1361
#
# Epoch 00054: val_loss improved from 4.16169 to 4.13605, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.41771663021239924
# Epoch 55/120
# 400/400 [==============================] - 217s 542ms/step - loss: 3.9996 - val_loss: 4.0362
#
# Epoch 00055: val_loss improved from 4.13605 to 4.03618, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.42305170829564753
# Improve F1 score from 0.4221128728975207 to 0.42305170829564753
# Epoch 56/120
# 400/400 [==============================] - 217s 542ms/step - loss: 3.9703 - val_loss: 4.1323
#
# Epoch 00056: val_loss did not improve from 4.03618
# F1 score: 0.4158935080788116
# Epoch 57/120
# 400/400 [==============================] - 216s 541ms/step - loss: 3.9834 - val_loss: 4.2158
#
# Epoch 00057: val_loss did not improve from 4.03618
# F1 score: 0.3927206921629962
# Epoch 58/120
# 400/400 [==============================] - 217s 542ms/step - loss: 3.9652 - val_loss: 4.1012
#
# Epoch 00058: val_loss did not improve from 4.03618
# F1 score: 0.43232554545624763
# Improve F1 score from 0.42305170829564753 to 0.43232554545624763
# Epoch 59/120
# 400/400 [==============================] - 216s 540ms/step - loss: 3.9713 - val_loss: 3.9715
#
# Epoch 00059: val_loss improved from 4.03618 to 3.97153, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.40159856947466205
# Epoch 60/120
# 400/400 [==============================] - 217s 543ms/step - loss: 4.0022 - val_loss: 4.0918
#
# Epoch 00060: val_loss did not improve from 3.97153
# F1 score: 0.383942678015028
# Epoch 61/120
# 400/400 [==============================] - 218s 544ms/step - loss: 3.9523 - val_loss: 4.1364
#
# Epoch 00061: val_loss did not improve from 3.97153
# F1 score: 0.4168811120324344
# Epoch 62/120
# 400/400 [==============================] - 215s 537ms/step - loss: 3.9337 - val_loss: 4.2490
#
# Epoch 00062: val_loss did not improve from 3.97153
# F1 score: 0.3764825607963636
# Epoch 63/120
# 400/400 [==============================] - 216s 541ms/step - loss: 3.9694 - val_loss: 4.1935
#
# Epoch 00063: val_loss did not improve from 3.97153
# F1 score: 0.361086014578571
# Epoch 64/120
# 400/400 [==============================] - 217s 541ms/step - loss: 3.9544 - val_loss: 3.9506
#
# Epoch 00064: val_loss improved from 3.97153 to 3.95065, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.41147886954280927
# Epoch 65/120
# 400/400 [==============================] - 218s 545ms/step - loss: 3.9359 - val_loss: 4.3791
#
# Epoch 00065: val_loss did not improve from 3.95065
# F1 score: 0.3893294974137708
# Epoch 66/120
# 400/400 [==============================] - 216s 540ms/step - loss: 3.9374 - val_loss: 4.3591
#
# Epoch 00066: val_loss did not improve from 3.95065
# F1 score: 0.3644846576901379
# Epoch 67/120
# 400/400 [==============================] - 220s 550ms/step - loss: 3.9108 - val_loss: 4.1114
#
# Epoch 00067: val_loss did not improve from 3.95065
# F1 score: 0.4238331222726676
# Epoch 68/120
# 400/400 [==============================] - 219s 548ms/step - loss: 3.9661 - val_loss: 4.2174
#
# Epoch 00068: val_loss did not improve from 3.95065
# F1 score: 0.41298932772354663
# Epoch 69/120
# 400/400 [==============================] - 218s 545ms/step - loss: 3.9153 - val_loss: 4.2159
#
# Epoch 00069: val_loss did not improve from 3.95065
# F1 score: 0.36137733292745566
# Epoch 70/120
# 400/400 [==============================] - 217s 542ms/step - loss: 3.9252 - val_loss: 4.0212
#
# Epoch 00070: val_loss did not improve from 3.95065
# F1 score: 0.41069985511573187
# Epoch 71/120
# 400/400 [==============================] - 217s 543ms/step - loss: 3.9017 - val_loss: 4.1600
#
# Epoch 00071: val_loss did not improve from 3.95065
# F1 score: 0.383758350437633
# Epoch 72/120
# 400/400 [==============================] - 215s 538ms/step - loss: 3.8761 - val_loss: 4.0062
#
# Epoch 00072: val_loss did not improve from 3.95065
# F1 score: 0.433695411705125
# Improve F1 score from 0.43232554545624763 to 0.433695411705125
# Epoch 73/120
# 400/400 [==============================] - 217s 542ms/step - loss: 3.9172 - val_loss: 4.1820
#
# Epoch 00073: val_loss did not improve from 3.95065
# F1 score: 0.3678982809835053
# Epoch 74/120
# 400/400 [==============================] - 216s 540ms/step - loss: 3.9122 - val_loss: 3.9582
#
# Epoch 00074: val_loss did not improve from 3.95065
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# F1 score: 0.43953531110773464
# Improve F1 score from 0.433695411705125 to 0.43953531110773464
# Epoch 75/120
# 400/400 [==============================] - 216s 539ms/step - loss: 3.7909 - val_loss: 3.8911
#
# Epoch 00075: val_loss improved from 3.95065 to 3.89110, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.4397058903546845
# Improve F1 score from 0.43953531110773464 to 0.4397058903546845
# Epoch 76/120
# 400/400 [==============================] - 216s 540ms/step - loss: 3.7646 - val_loss: 3.8772
#
# Epoch 00076: val_loss improved from 3.89110 to 3.87722, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.4191352976958934
# Epoch 77/120
# 400/400 [==============================] - 216s 540ms/step - loss: 3.7609 - val_loss: 3.8155
#
# Epoch 00077: val_loss improved from 3.87722 to 3.81553, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.41623790961936924
# Epoch 78/120
# 400/400 [==============================] - 219s 546ms/step - loss: 3.7619 - val_loss: 3.8340
#
# Epoch 00078: val_loss did not improve from 3.81553
# F1 score: 0.4340894020333489
# Epoch 79/120
# 400/400 [==============================] - 218s 546ms/step - loss: 3.7300 - val_loss: 3.8793
#
# Epoch 00079: val_loss did not improve from 3.81553
# F1 score: 0.4309696569753479
# Epoch 80/120
# 400/400 [==============================] - 217s 542ms/step - loss: 3.7661 - val_loss: 3.7985
#
# Epoch 00080: val_loss improved from 3.81553 to 3.79849, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.46495891484334495
# Improve F1 score from 0.4397058903546845 to 0.46495891484334495
# Epoch 81/120
# 400/400 [==============================] - 216s 540ms/step - loss: 3.7477 - val_loss: 3.8014
#
# Epoch 00081: val_loss did not improve from 3.79849
# F1 score: 0.4784689357974834
# Improve F1 score from 0.46495891484334495 to 0.4784689357974834
# Epoch 82/120
# 400/400 [==============================] - 217s 542ms/step - loss: 3.7862 - val_loss: 3.8161
#
# Epoch 00082: val_loss did not improve from 3.79849
# F1 score: 0.47171883228285216
# Epoch 83/120
# 400/400 [==============================] - 221s 553ms/step - loss: 3.7427 - val_loss: 3.8060
#
# Epoch 00083: val_loss did not improve from 3.79849
# F1 score: 0.47524623225098883
# Epoch 84/120
# 400/400 [==============================] - 225s 561ms/step - loss: 3.7411 - val_loss: 3.7935
#
# Epoch 00084: val_loss improved from 3.79849 to 3.79351, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.45639449396476395
# Epoch 85/120
# 400/400 [==============================] - 229s 573ms/step - loss: 3.7483 - val_loss: 3.8034
#
# Epoch 00085: val_loss did not improve from 3.79351
# F1 score: 0.46692151531012255
# Epoch 86/120
# 400/400 [==============================] - 226s 566ms/step - loss: 3.7166 - val_loss: 3.7595
#
# Epoch 00086: val_loss improved from 3.79351 to 3.75950, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.46949706367740307
# Epoch 87/120
# 400/400 [==============================] - 230s 575ms/step - loss: 3.7194 - val_loss: 3.7778
#
# Epoch 00087: val_loss did not improve from 3.75950
# F1 score: 0.4531491446803124
# Epoch 88/120
# 400/400 [==============================] - 220s 551ms/step - loss: 3.7080 - val_loss: 3.7539
#
# Epoch 00088: val_loss improved from 3.75950 to 3.75388, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.46712715412800615
# Epoch 89/120
# 400/400 [==============================] - 225s 563ms/step - loss: 3.7135 - val_loss: 3.8300
#
# Epoch 00089: val_loss did not improve from 3.75388
# F1 score: 0.43125644198488844
# Epoch 90/120
# 400/400 [==============================] - 230s 574ms/step - loss: 3.7385 - val_loss: 3.7700
#
# Epoch 00090: val_loss did not improve from 3.75388
# F1 score: 0.46245557078669386
# Epoch 91/120
# 400/400 [==============================] - 229s 572ms/step - loss: 3.7195 - val_loss: 3.8785
#
# Epoch 00091: val_loss did not improve from 3.75388
# F1 score: 0.4383722266505596
# Epoch 92/120
# 400/400 [==============================] - 221s 553ms/step - loss: 3.6931 - val_loss: 3.9513
#
# Epoch 00092: val_loss did not improve from 3.75388
# F1 score: 0.43932560106048485
# Epoch 93/120
# 400/400 [==============================] - 219s 546ms/step - loss: 3.7178 - val_loss: 3.8181
#
# Epoch 00093: val_loss did not improve from 3.75388
# F1 score: 0.4388548577346563
# Epoch 94/120
# 400/400 [==============================] - 217s 543ms/step - loss: 3.6787 - val_loss: 3.7666
#
# Epoch 00094: val_loss did not improve from 3.75388
# F1 score: 0.4663230513933481
# Epoch 95/120
# 400/400 [==============================] - 218s 546ms/step - loss: 3.6891 - val_loss: 3.7113
#
# Epoch 00095: val_loss improved from 3.75388 to 3.71131, saving model to /home/aldo/Documents/weights/models/last_models/pos_4_alpha_1.5_pascal_0.35_exp_1.h5
# F1 score: 0.4761835342237236
# Epoch 96/120
# 400/400 [==============================] - 226s 565ms/step - loss: 3.6937 - val_loss: 3.8002
#
# Epoch 00096: val_loss did not improve from 3.71131
# F1 score: 0.46348503715027106
# Epoch 97/120
# 195/400 [=============>................] - ETA: 1:50 - loss: 3.6684
