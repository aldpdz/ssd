# %%
# libraries
import os
import json
import numpy as np
import pandas as pd
from extra_files import helper as hp
from imageio import imwrite, imread
from skimage.transform import resize

# %%
# File paths
data_path = '/home/aldo/Documents/data-cic/'
preprocess_path = data_path + 'preprocess_data'

# %% [markdown]
# ## Training SSD300 trained with vgg16 backbone trained

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300_mobilenetv1 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

from extra_files.f1_callback import F1_callback as f1_call
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /home/aldo/Documents/ssd/data_generator/object_detection_2d_data_generator.py:43: UserWarning: 'BeautifulSoup' module is missing. The XML-parser will be unavailable.
#   warnings.warn("'BeautifulSoup' module is missing. The XML-parser will be unavailable.")

# %% [markdown]
# ### Parameters (original SSD300 architecture)

# %%
## Parameteres needed for ssd_300() and SSDInputEncoder()

img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [127, 127, 127] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
swap_channels = False # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 1 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
new_scales = [0.15, 0.33, 0.47, 0.61, 0.76, 0.90, 1.05]
scales = new_scales
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [16, 30, 60, 100, 150, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %% [markdown]
# ## Create new model with SSD weights

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load.
# weights_path = '/home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal_comp3.h5'
# model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
# sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 300, 300, 3)  0
# __________________________________________________________________________________________________
# identity_layer (Lambda)         (None, 300, 300, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# input_mean_normalization (Lambd (None, 300, 300, 3)  0           identity_layer[0][0]
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 302, 302, 3)  0           input_mean_normalization[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 32) 864         conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 150, 150, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 150, 150, 32) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_1 (ZeroPadding2D)      (None, 152, 152, 32) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)     (None, 150, 150, 32) 288         conv_pad_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_bn (BatchNormalizatio (None, 150, 150, 32) 128         conv_dw_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_relu (Activation)     (None, 150, 150, 32) 0           conv_dw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_1 (Conv2D)              (None, 150, 150, 64) 2048        conv_dw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_bn (BatchNormalizatio (None, 150, 150, 64) 256         conv_pw_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_relu (Activation)     (None, 150, 150, 64) 0           conv_pw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_2 (ZeroPadding2D)      (None, 152, 152, 64) 0           conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)     (None, 75, 75, 64)   576         conv_pad_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_bn (BatchNormalizatio (None, 75, 75, 64)   256         conv_dw_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_relu (Activation)     (None, 75, 75, 64)   0           conv_dw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_2 (Conv2D)              (None, 75, 75, 128)  8192        conv_dw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_bn (BatchNormalizatio (None, 75, 75, 128)  512         conv_pw_2[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_relu (Activation)     (None, 75, 75, 128)  0           conv_pw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_3 (ZeroPadding2D)      (None, 77, 77, 128)  0           conv_pw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)     (None, 75, 75, 128)  1152        conv_pad_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_bn (BatchNormalizatio (None, 75, 75, 128)  512         conv_dw_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_relu (Activation)     (None, 75, 75, 128)  0           conv_dw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_3 (Conv2D)              (None, 75, 75, 128)  16384       conv_dw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_bn (BatchNormalizatio (None, 75, 75, 128)  512         conv_pw_3[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_relu (Activation)     (None, 75, 75, 128)  0           conv_pw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_4 (ZeroPadding2D)      (None, 77, 77, 128)  0           conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)     (None, 38, 38, 128)  1152        conv_pad_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_bn (BatchNormalizatio (None, 38, 38, 128)  512         conv_dw_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_relu (Activation)     (None, 38, 38, 128)  0           conv_dw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_4 (Conv2D)              (None, 38, 38, 256)  32768       conv_dw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_bn (BatchNormalizatio (None, 38, 38, 256)  1024        conv_pw_4[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_relu (Activation)     (None, 38, 38, 256)  0           conv_pw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_5 (ZeroPadding2D)      (None, 40, 40, 256)  0           conv_pw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)     (None, 38, 38, 256)  2304        conv_pad_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_bn (BatchNormalizatio (None, 38, 38, 256)  1024        conv_dw_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_relu (Activation)     (None, 38, 38, 256)  0           conv_dw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_5 (Conv2D)              (None, 38, 38, 256)  65536       conv_dw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_bn (BatchNormalizatio (None, 38, 38, 256)  1024        conv_pw_5[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_relu (Activation)     (None, 38, 38, 256)  0           conv_pw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_6 (ZeroPadding2D)      (None, 40, 40, 256)  0           conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)     (None, 19, 19, 256)  2304        conv_pad_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_bn (BatchNormalizatio (None, 19, 19, 256)  1024        conv_dw_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_relu (Activation)     (None, 19, 19, 256)  0           conv_dw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_6 (Conv2D)              (None, 19, 19, 512)  131072      conv_dw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_pw_6[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_relu (Activation)     (None, 19, 19, 512)  0           conv_pw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_7 (ZeroPadding2D)      (None, 21, 21, 512)  0           conv_pw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)     (None, 19, 19, 512)  4608        conv_pad_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_dw_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_relu (Activation)     (None, 19, 19, 512)  0           conv_dw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_7 (Conv2D)              (None, 19, 19, 512)  262144      conv_dw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_pw_7[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_relu (Activation)     (None, 19, 19, 512)  0           conv_pw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_8 (ZeroPadding2D)      (None, 21, 21, 512)  0           conv_pw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)     (None, 19, 19, 512)  4608        conv_pad_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_dw_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_relu (Activation)     (None, 19, 19, 512)  0           conv_dw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_8 (Conv2D)              (None, 19, 19, 512)  262144      conv_dw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_pw_8[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_relu (Activation)     (None, 19, 19, 512)  0           conv_pw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_9 (ZeroPadding2D)      (None, 21, 21, 512)  0           conv_pw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)     (None, 19, 19, 512)  4608        conv_pad_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_dw_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_relu (Activation)     (None, 19, 19, 512)  0           conv_dw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_9 (Conv2D)              (None, 19, 19, 512)  262144      conv_dw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_pw_9[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_relu (Activation)     (None, 19, 19, 512)  0           conv_pw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_10 (ZeroPadding2D)     (None, 21, 21, 512)  0           conv_pw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_10 (DepthwiseConv2D)    (None, 19, 19, 512)  4608        conv_pad_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_bn (BatchNormalizati (None, 19, 19, 512)  2048        conv_dw_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_relu (Activation)    (None, 19, 19, 512)  0           conv_dw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_10 (Conv2D)             (None, 19, 19, 512)  262144      conv_dw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_bn (BatchNormalizati (None, 19, 19, 512)  2048        conv_pw_10[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_relu (Activation)    (None, 19, 19, 512)  0           conv_pw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_11 (ZeroPadding2D)     (None, 21, 21, 512)  0           conv_pw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_11 (DepthwiseConv2D)    (None, 19, 19, 512)  4608        conv_pad_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_bn (BatchNormalizati (None, 19, 19, 512)  2048        conv_dw_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_relu (Activation)    (None, 19, 19, 512)  0           conv_dw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv__11 (Conv2D)               (None, 19, 19, 512)  262144      conv_dw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_11_bn (BatchNormalization) (None, 19, 19, 512)  2048        conv__11[0][0]
# __________________________________________________________________________________________________
# conv_11_relu (Activation)       (None, 19, 19, 512)  0           conv_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_12 (ZeroPadding2D)     (None, 21, 21, 512)  0           conv_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_12 (DepthwiseConv2D)    (None, 10, 10, 512)  4608        conv_pad_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_bn (BatchNormalizati (None, 10, 10, 512)  2048        conv_dw_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_relu (Activation)    (None, 10, 10, 512)  0           conv_dw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_12 (Conv2D)             (None, 10, 10, 1024) 524288      conv_dw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_bn (BatchNormalizati (None, 10, 10, 1024) 4096        conv_pw_12[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_relu (Activation)    (None, 10, 10, 1024) 0           conv_pw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_13 (ZeroPadding2D)     (None, 12, 12, 1024) 0           conv_pw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_13 (DepthwiseConv2D)    (None, 10, 10, 1024) 9216        conv_pad_13[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_bn (BatchNormalizati (None, 10, 10, 1024) 4096        conv_dw_13[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_relu (Activation)    (None, 10, 10, 1024) 0           conv_dw_13_bn[0][0]
# __________________________________________________________________________________________________
# conv__13 (Conv2D)               (None, 10, 10, 1024) 1048576     conv_dw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv_13_bn (BatchNormalization) (None, 10, 10, 1024) 4096        conv__13[0][0]
# __________________________________________________________________________________________________
# conv_13_relu (Activation)       (None, 10, 10, 1024) 0           conv_13_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_14_1 (ZeroPadding2D)   (None, 12, 12, 1024) 0           conv_13_relu[0][0]
# __________________________________________________________________________________________________
# conv__14_1 (Conv2D)             (None, 12, 12, 256)  262144      conv_pad_14_1[0][0]
# __________________________________________________________________________________________________
# conv_14_bn_1 (BatchNormalizatio (None, 12, 12, 256)  1024        conv__14_1[0][0]
# __________________________________________________________________________________________________
# conv_14_relu_1 (Activation)     (None, 12, 12, 256)  0           conv_14_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__14_2 (Conv2D)             (None, 5, 5, 512)    1179648     conv_14_relu_1[0][0]
# __________________________________________________________________________________________________
# conv_14_bn_2 (BatchNormalizatio (None, 5, 5, 512)    2048        conv__14_2[0][0]
# __________________________________________________________________________________________________
# conv_14_relu_2 (Activation)     (None, 5, 5, 512)    0           conv_14_bn_2[0][0]
# __________________________________________________________________________________________________
# conv_pad_15_1 (ZeroPadding2D)   (None, 7, 7, 512)    0           conv_14_relu_2[0][0]
# __________________________________________________________________________________________________
# conv__15_1 (Conv2D)             (None, 7, 7, 128)    65536       conv_pad_15_1[0][0]
# __________________________________________________________________________________________________
# conv_15_bn_1 (BatchNormalizatio (None, 7, 7, 128)    512         conv__15_1[0][0]
# __________________________________________________________________________________________________
# conv_15_relu_1 (Activation)     (None, 7, 7, 128)    0           conv_15_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__15_2 (Conv2D)             (None, 3, 3, 256)    294912      conv_15_relu_1[0][0]
# __________________________________________________________________________________________________
# conv_15_bn_2 (BatchNormalizatio (None, 3, 3, 256)    1024        conv__15_2[0][0]
# __________________________________________________________________________________________________
# conv_15_relu_2 (Activation)     (None, 3, 3, 256)    0           conv_15_bn_2[0][0]
# __________________________________________________________________________________________________
# conv_pad_16_1 (ZeroPadding2D)   (None, 5, 5, 256)    0           conv_15_relu_2[0][0]
# __________________________________________________________________________________________________
# conv__16_1 (Conv2D)             (None, 5, 5, 128)    32768       conv_pad_16_1[0][0]
# __________________________________________________________________________________________________
# conv_16_bn_1 (BatchNormalizatio (None, 5, 5, 128)    512         conv__16_1[0][0]
# __________________________________________________________________________________________________
# conv_16_relu_1 (Activation)     (None, 5, 5, 128)    0           conv_16_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__16_2 (Conv2D)             (None, 2, 2, 256)    294912      conv_16_relu_1[0][0]
# __________________________________________________________________________________________________
# conv_16_bn_2 (BatchNormalizatio (None, 2, 2, 256)    1024        conv__16_2[0][0]
# __________________________________________________________________________________________________
# conv_16_relu_2 (Activation)     (None, 2, 2, 256)    0           conv_16_bn_2[0][0]
# __________________________________________________________________________________________________
# conv_pad_17_1 (ZeroPadding2D)   (None, 4, 4, 256)    0           conv_16_relu_2[0][0]
# __________________________________________________________________________________________________
# conv__17_1 (Conv2D)             (None, 4, 4, 64)     16384       conv_pad_17_1[0][0]
# __________________________________________________________________________________________________
# conv_17_bn_1 (BatchNormalizatio (None, 4, 4, 64)     256         conv__17_1[0][0]
# __________________________________________________________________________________________________
# conv_17_relu_1 (Activation)     (None, 4, 4, 64)     0           conv_17_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__17_2 (Conv2D)             (None, 1, 1, 128)    73728       conv_17_relu_1[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_conf (Conv2D)       (None, 19, 19, 8)    36872       conv__11[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_conf (Conv2D)       (None, 10, 10, 12)   110604      conv__13[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_conf (Conv2D)     (None, 5, 5, 12)     55308       conv__14_2[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_conf (Conv2D)     (None, 3, 3, 12)     27660       conv__15_2[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_conf (Conv2D)     (None, 2, 2, 8)      18440       conv__16_2[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_conf (Conv2D)     (None, 1, 1, 8)      9224        conv__17_2[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_loc (Conv2D)        (None, 19, 19, 16)   73744       conv__11[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_loc (Conv2D)        (None, 10, 10, 24)   221208      conv__13[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_loc (Conv2D)      (None, 5, 5, 24)     110616      conv__14_2[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_loc (Conv2D)      (None, 3, 3, 24)     55320       conv__15_2[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_loc (Conv2D)      (None, 2, 2, 16)     36880       conv__16_2[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_loc (Conv2D)      (None, 1, 1, 16)     18448       conv__17_2[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_conf_reshape (Resha (None, 1444, 2)      0           conv11_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_conf_reshape (Resha (None, 600, 2)       0           conv13_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_conf_reshape (Res (None, 150, 2)       0           conv14_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_conf_reshape (Res (None, 54, 2)        0           conv15_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_conf_reshape (Res (None, 16, 2)        0           conv16_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_conf_reshape (Res (None, 4, 2)         0           conv17_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_priorbox (AnchorBox (None, 19, 19, 4, 8) 0           conv11_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_priorbox (AnchorBox (None, 10, 10, 6, 8) 0           conv13_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_priorbox (AnchorB (None, 5, 5, 6, 8)   0           conv14_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_priorbox (AnchorB (None, 3, 3, 6, 8)   0           conv15_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_priorbox (AnchorB (None, 2, 2, 4, 8)   0           conv16_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_priorbox (AnchorB (None, 1, 1, 4, 8)   0           conv17_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (None, 2268, 2)      0           conv11_mbox_conf_reshape[0][0]
#                                                                  conv13_mbox_conf_reshape[0][0]
#                                                                  conv14_2_mbox_conf_reshape[0][0]
#                                                                  conv15_2_mbox_conf_reshape[0][0]
#                                                                  conv16_2_mbox_conf_reshape[0][0]
#                                                                  conv17_2_mbox_conf_reshape[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_loc_reshape (Reshap (None, 1444, 4)      0           conv11_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_loc_reshape (Reshap (None, 600, 4)       0           conv13_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_loc_reshape (Resh (None, 150, 4)       0           conv14_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_loc_reshape (Resh (None, 54, 4)        0           conv15_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_loc_reshape (Resh (None, 16, 4)        0           conv16_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_loc_reshape (Resh (None, 4, 4)         0           conv17_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_priorbox_reshape (R (None, 1444, 8)      0           conv11_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_priorbox_reshape (R (None, 600, 8)       0           conv13_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_priorbox_reshape  (None, 150, 8)       0           conv14_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_priorbox_reshape  (None, 54, 8)        0           conv15_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_priorbox_reshape  (None, 16, 8)        0           conv16_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_priorbox_reshape  (None, 4, 8)         0           conv17_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# mbox_conf_softmax (Activation)  (None, 2268, 2)      0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (None, 2268, 4)      0           conv11_mbox_loc_reshape[0][0]
#                                                                  conv13_mbox_loc_reshape[0][0]
#                                                                  conv14_2_mbox_loc_reshape[0][0]
#                                                                  conv15_2_mbox_loc_reshape[0][0]
#                                                                  conv16_2_mbox_loc_reshape[0][0]
#                                                                  conv17_2_mbox_loc_reshape[0][0]
# __________________________________________________________________________________________________
# mbox_priorbox (Concatenate)     (None, 2268, 8)      0           conv11_mbox_priorbox_reshape[0][0
#                                                                  conv13_mbox_priorbox_reshape[0][0
#                                                                  conv14_2_mbox_priorbox_reshape[0]
#                                                                  conv15_2_mbox_priorbox_reshape[0]
#                                                                  conv16_2_mbox_priorbox_reshape[0]
#                                                                  conv17_2_mbox_priorbox_reshape[0]
# __________________________________________________________________________________________________
# predictions (Concatenate)       (None, 2268, 14)     0           mbox_conf_softmax[0][0]
#                                                                  mbox_loc[0][0]
#                                                                  mbox_priorbox[0][0]
# ==================================================================================================
# Total params: 6,229,620
# Trainable params: 6,204,532
# Non-trainable params: 25,088
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Data generator for the training

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
# images_dir = data_path + 'udacity_driving_datasets'
images_dir = data_path + 'pascal_dataset'
# images_dir = data_path + 'images'

# Ground truth
# train_labels_filename = preprocess_path + '/udc.csv'
# train_labels_filename = preprocess_path + '/cic_pascal_train.csv'
# val_labels_filename   = preprocess_path + '/cic_pascal_val.csv'
train_labels_filename = preprocess_path + '/pascal_train.csv'
val_labels_filename   = preprocess_path + '/pascal_val.csv'
# train_labels_filename = preprocess_path + '/cic_train.csv'
# val_labels_filename   = preprocess_path + '/cic_val.csv'

train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

# train_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_train.h5',
#                                   resize=False,
#                                   variable_image_size=True,
#                                   verbose=True)

# val_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_val.h5',
#                                 resize=False,
#                                 variable_image_size=True,
#                                 verbose=True)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Loading images into memory: 100%|██████████| 6469/6469 [00:28<00:00, 227.27it/s]
# Loading images into memory: 100%|██████████| 2097/2097 [00:08<00:00, 244.03it/s]
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  2097

# %%
# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv11_mbox_conf').output_shape[1:3],
                   model.get_layer('conv13_mbox_conf').output_shape[1:3],
                   model.get_layer('conv14_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv15_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv16_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv17_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  2097

# %% [markdown]
# ## Remaining training parameters

# %%
label_val = np.load('../data-cic/preprocess_data/label_val.npy')
val_images_300 = np.load('../data-cic/preprocess_data/images_val_300x300.npy')

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='/home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
# model_checkpoint.best = 2.567152314715915

csv_logger = CSVLogger(filename=data_path + 'history/ssd300_mobilenetv1/ssd300_mobilenetv1_pascal.csv',
                       separator=',',
                       append=True)

early_stopping = EarlyStopping(monitor='val_loss',
                               min_delta=0.0,
                               patience=10,
                               verbose=1)

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.5,
                                         patience=8,
                                         verbose=1,
                                         min_delta=0.001,
                                         cooldown=0,
                                         min_lr=0.00001)

f1_callback = f1_call(0.20, 
                      0.45, 
                      200, 
                      normalize_coords, 
                      img_height, 
                      img_width, 
                      val_images_300,
                      label_val, 
                      (1, 2268, 14),
                      data_path + 'history/ssd300_mobilenetv1/ssd300_mobilenetv1_pascal_f1.csv')

# learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule, verbose=1)


callbacks = [model_checkpoint,
             csv_logger,
             early_stopping,
#              learning_rate_scheduler]
             reduce_learning_rate,
             f1_callback]

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 1000
steps_per_epoch = 400

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/1000
# 400/400 [==============================] - 238s 595ms/step - loss: 5.8093 - val_loss: 4.9274
#
# Epoch 00001: val_loss improved from inf to 4.92743, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.0613
# Recall: 0.4302
# F1 score: 0.1073
# Improve F1 score from -inf to 0.10727705679183018
# Epoch 2/1000
# 400/400 [==============================] - 231s 576ms/step - loss: 4.8265 - val_loss: 4.8158
#
# Epoch 00002: val_loss improved from 4.92743 to 4.81581, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.0543
# Recall: 0.4548
# F1 score: 0.097
# Epoch 3/1000
# 400/400 [==============================] - 232s 580ms/step - loss: 4.7166 - val_loss: 4.6259
#
# Epoch 00003: val_loss improved from 4.81581 to 4.62591, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.0585
# Recall: 0.4648
# F1 score: 0.1039
# Epoch 4/1000
# 400/400 [==============================] - 234s 586ms/step - loss: 4.5562 - val_loss: 4.4809
#
# Epoch 00004: val_loss improved from 4.62591 to 4.48087, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.0558
# Recall: 0.4926
# F1 score: 0.1003
# Epoch 5/1000
# 400/400 [==============================] - 235s 587ms/step - loss: 4.4503 - val_loss: 4.6879
#
# Epoch 00005: val_loss did not improve from 4.48087
# Number of images: 45
# Presicion: 0.0462
# Recall: 0.4825
# F1 score: 0.0842
# Epoch 6/1000
# 400/400 [==============================] - 237s 592ms/step - loss: 4.3313 - val_loss: 4.2741
#
# Epoch 00006: val_loss improved from 4.48087 to 4.27412, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.0471
# Recall: 0.4995
# F1 score: 0.0862
# Epoch 7/1000
# 400/400 [==============================] - 232s 580ms/step - loss: 4.2340 - val_loss: 4.2835
#
# Epoch 00007: val_loss did not improve from 4.27412
# Number of images: 45
# Presicion: 0.0544
# Recall: 0.5026
# F1 score: 0.0982
# Epoch 8/1000
# 400/400 [==============================] - 234s 584ms/step - loss: 4.2289 - val_loss: 4.1768
#
# Epoch 00008: val_loss improved from 4.27412 to 4.17677, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.0545
# Recall: 0.5379
# F1 score: 0.0989
# Epoch 9/1000
# 400/400 [==============================] - 231s 577ms/step - loss: 4.1752 - val_loss: 4.1656
#
# Epoch 00009: val_loss improved from 4.17677 to 4.16555, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.0476
# Recall: 0.4851
# F1 score: 0.0868
# Epoch 10/1000
# 400/400 [==============================] - 233s 582ms/step - loss: 4.1086 - val_loss: 4.1359
#
# Epoch 00010: val_loss improved from 4.16555 to 4.13590, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.0482
# Recall: 0.5195
# F1 score: 0.0882
# Epoch 11/1000
# 400/400 [==============================] - 231s 578ms/step - loss: 4.0521 - val_loss: 3.9851
#
# Epoch 00011: val_loss improved from 4.13590 to 3.98506, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.0493
# Recall: 0.5283
# F1 score: 0.0902
# Epoch 12/1000
# 400/400 [==============================] - 233s 583ms/step - loss: 3.9941 - val_loss: 4.0776
#
# Epoch 00012: val_loss did not improve from 3.98506
# Number of images: 45
# Presicion: 0.0741
# Recall: 0.5012
# F1 score: 0.1291
# Improve F1 score from 0.10727705679183018 to 0.12912588337524683
# Epoch 13/1000
# 400/400 [==============================] - 249s 624ms/step - loss: 3.9768 - val_loss: 3.9286
#
# Epoch 00013: val_loss improved from 3.98506 to 3.92865, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.0586
# Recall: 0.5117
# F1 score: 0.1052
# Epoch 14/1000
# 400/400 [==============================] - 232s 581ms/step - loss: 3.9800 - val_loss: 4.2752
#
# Epoch 00014: val_loss did not improve from 3.92865
# Number of images: 45
# Presicion: 0.0346
# Recall: 0.483
# F1 score: 0.0645
# Epoch 15/1000
# 400/400 [==============================] - 228s 570ms/step - loss: 3.9666 - val_loss: 4.0033
#
# Epoch 00015: val_loss did not improve from 3.92865
# Number of images: 45
# Presicion: 0.0715
# Recall: 0.5324
# F1 score: 0.126
# Epoch 16/1000
# 400/400 [==============================] - 228s 571ms/step - loss: 3.8942 - val_loss: 3.8278
#
# Epoch 00016: val_loss improved from 3.92865 to 3.82785, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.15
# Recall: 0.454
# F1 score: 0.2254
# Improve F1 score from 0.12912588337524683 to 0.22544457777204244
# Epoch 17/1000
# 400/400 [==============================] - 229s 573ms/step - loss: 3.8967 - val_loss: 3.8793
#
# Epoch 00017: val_loss did not improve from 3.82785
# Number of images: 45
# Presicion: 0.1222
# Recall: 0.4099
# F1 score: 0.1882
# Epoch 18/1000
# 400/400 [==============================] - 229s 572ms/step - loss: 3.8156 - val_loss: 3.8975
#
# Epoch 00018: val_loss did not improve from 3.82785
# Number of images: 45
# Presicion: 0.1255
# Recall: 0.4158
# F1 score: 0.1929
# Epoch 19/1000
# 400/400 [==============================] - 229s 573ms/step - loss: 3.7630 - val_loss: 3.8574
#
# Epoch 00019: val_loss did not improve from 3.82785
# Number of images: 45
# Presicion: 0.0929
# Recall: 0.4374
# F1 score: 0.1532
# Epoch 20/1000
# 400/400 [==============================] - 232s 580ms/step - loss: 3.7304 - val_loss: 3.7528
#
# Epoch 00020: val_loss improved from 3.82785 to 3.75278, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.1977
# Recall: 0.4073
# F1 score: 0.2662
# Improve F1 score from 0.22544457777204244 to 0.26621207765795857
# Epoch 21/1000
# 400/400 [==============================] - 241s 603ms/step - loss: 3.7025 - val_loss: 3.6372
#
# Epoch 00021: val_loss improved from 3.75278 to 3.63724, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.2023
# Recall: 0.3036
# F1 score: 0.2428
# Epoch 22/1000
# 400/400 [==============================] - 229s 573ms/step - loss: 3.6931 - val_loss: 3.7589
#
# Epoch 00022: val_loss did not improve from 3.63724
# Number of images: 45
# Presicion: 0.2981
# Recall: 0.2602
# F1 score: 0.2778
# Improve F1 score from 0.26621207765795857 to 0.27783797856089065
# Epoch 23/1000
# 400/400 [==============================] - 229s 574ms/step - loss: 3.6341 - val_loss: 3.6423
#
# Epoch 00023: val_loss did not improve from 3.63724
# Number of images: 45
# Presicion: 0.2418
# Recall: 0.3898
# F1 score: 0.2985
# Improve F1 score from 0.27783797856089065 to 0.2984996527438265
# Epoch 24/1000
# 400/400 [==============================] - 229s 573ms/step - loss: 3.6495 - val_loss: 3.6839
#
# Epoch 00024: val_loss did not improve from 3.63724
# Number of images: 45
# Presicion: 0.3898
# Recall: 0.2958
# F1 score: 0.3364
# Improve F1 score from 0.2984996527438265 to 0.3363683658234097
# Epoch 25/1000
# 400/400 [==============================] - 232s 579ms/step - loss: 3.6105 - val_loss: 3.6830
#
# Epoch 00025: val_loss did not improve from 3.63724
# Number of images: 45
# Presicion: 0.476
# Recall: 0.2638
# F1 score: 0.3395
# Improve F1 score from 0.3363683658234097 to 0.3394723830015499
# Epoch 26/1000
# 400/400 [==============================] - 231s 576ms/step - loss: 3.5752 - val_loss: 6.5497
#
# Epoch 00026: val_loss did not improve from 3.63724
# Number of images: 45
# Presicion: 0.0597
# Recall: 0.4003
# F1 score: 0.1039
# Epoch 27/1000
# 400/400 [==============================] - 231s 577ms/step - loss: 3.5467 - val_loss: 3.9689
#
# Epoch 00027: val_loss did not improve from 3.63724
# Number of images: 45
# Presicion: 0.138
# Recall: 0.3802
# F1 score: 0.2025
# Epoch 28/1000
# 400/400 [==============================] - 228s 569ms/step - loss: 3.7111 - val_loss: 5.6020
#
# Epoch 00028: val_loss did not improve from 3.63724
# Number of images: 45
# Presicion: 0.0282
# Recall: 0.3653
# F1 score: 0.0523
# Epoch 29/1000
# 400/400 [==============================] - 230s 576ms/step - loss: 3.7509 - val_loss: 3.6825
#
# Epoch 00029: val_loss did not improve from 3.63724
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Number of images: 45
# Presicion: 0.375
# Recall: 0.2009
# F1 score: 0.2616
# Epoch 30/1000
# 400/400 [==============================] - 230s 575ms/step - loss: 3.5745 - val_loss: 3.4864
#
# Epoch 00030: val_loss improved from 3.63724 to 3.48638, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4065
# Recall: 0.2767
# F1 score: 0.3292
# Epoch 31/1000
# 400/400 [==============================] - 231s 578ms/step - loss: 3.5115 - val_loss: 3.4277
#
# Epoch 00031: val_loss improved from 3.48638 to 3.42773, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.43
# Recall: 0.2711
# F1 score: 0.3326
# Epoch 32/1000
# 400/400 [==============================] - 238s 595ms/step - loss: 3.4550 - val_loss: 3.4151
#
# Epoch 00032: val_loss improved from 3.42773 to 3.41513, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4046
# Recall: 0.2949
# F1 score: 0.3412
# Improve F1 score from 0.3394723830015499 to 0.34117447636118303
# Epoch 33/1000
# 400/400 [==============================] - 236s 589ms/step - loss: 3.4372 - val_loss: 3.4317
#
# Epoch 00033: val_loss did not improve from 3.41513
# Number of images: 45
# Presicion: 0.3475
# Recall: 0.2898
# F1 score: 0.316
# Epoch 34/1000
# 400/400 [==============================] - 244s 609ms/step - loss: 3.4190 - val_loss: 3.3920
#
# Epoch 00034: val_loss improved from 3.41513 to 3.39196, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4377
# Recall: 0.2957
# F1 score: 0.3529
# Improve F1 score from 0.34117447636118303 to 0.3529292792616116
# Epoch 35/1000
# 400/400 [==============================] - 248s 621ms/step - loss: 3.3817 - val_loss: 3.3747
#
# Epoch 00035: val_loss improved from 3.39196 to 3.37471, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4868
# Recall: 0.3153
# F1 score: 0.3827
# Improve F1 score from 0.3529292792616116 to 0.38273069820210287
# Epoch 36/1000
# 400/400 [==============================] - 244s 610ms/step - loss: 3.3661 - val_loss: 3.4605
#
# Epoch 00036: val_loss did not improve from 3.37471
# Number of images: 45
# Presicion: 0.4203
# Recall: 0.2738
# F1 score: 0.3316
# Epoch 37/1000
# 400/400 [==============================] - 242s 605ms/step - loss: 3.3644 - val_loss: 3.4655
#
# Epoch 00037: val_loss did not improve from 3.37471
# Number of images: 45
# Presicion: 0.4124
# Recall: 0.3237
# F1 score: 0.3627
# Epoch 38/1000
# 400/400 [==============================] - 251s 627ms/step - loss: 3.3156 - val_loss: 3.3213
#
# Epoch 00038: val_loss improved from 3.37471 to 3.32132, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4659
# Recall: 0.3504
# F1 score: 0.4
# Improve F1 score from 0.38273069820210287 to 0.3999915424929873
# Epoch 39/1000
# 400/400 [==============================] - 249s 622ms/step - loss: 3.3077 - val_loss: 3.3056
#
# Epoch 00039: val_loss improved from 3.32132 to 3.30564, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4655
# Recall: 0.3294
# F1 score: 0.3858
# Epoch 40/1000
# 400/400 [==============================] - 245s 613ms/step - loss: 3.3111 - val_loss: 3.2873
#
# Epoch 00040: val_loss improved from 3.30564 to 3.28725, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4763
# Recall: 0.3132
# F1 score: 0.3779
# Epoch 41/1000
# 400/400 [==============================] - 244s 610ms/step - loss: 3.3099 - val_loss: 3.2783
#
# Epoch 00041: val_loss improved from 3.28725 to 3.27831, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4542
# Recall: 0.3837
# F1 score: 0.416
# Improve F1 score from 0.3999915424929873 to 0.415991598947708
# Epoch 42/1000
# 400/400 [==============================] - 244s 609ms/step - loss: 3.2688 - val_loss: 3.3104
#
# Epoch 00042: val_loss did not improve from 3.27831
# Number of images: 45
# Presicion: 0.474
# Recall: 0.3497
# F1 score: 0.4025
# Epoch 43/1000
# 400/400 [==============================] - 241s 603ms/step - loss: 3.2486 - val_loss: 3.2602
#
# Epoch 00043: val_loss improved from 3.27831 to 3.26024, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4933
# Recall: 0.3993
# F1 score: 0.4413
# Improve F1 score from 0.415991598947708 to 0.4413291513539767
# Epoch 44/1000
# 400/400 [==============================] - 252s 629ms/step - loss: 3.2498 - val_loss: 3.2215
#
# Epoch 00044: val_loss improved from 3.26024 to 3.22147, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.482
# Recall: 0.3546
# F1 score: 0.4086
# Epoch 45/1000
# 400/400 [==============================] - 244s 610ms/step - loss: 3.2334 - val_loss: 3.1967
#
# Epoch 00045: val_loss improved from 3.22147 to 3.19671, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4579
# Recall: 0.376
# F1 score: 0.4129
# Epoch 46/1000
# 400/400 [==============================] - 245s 612ms/step - loss: 3.2227 - val_loss: 3.2345
#
# Epoch 00046: val_loss did not improve from 3.19671
# Number of images: 45
# Presicion: 0.4893
# Recall: 0.3805
# F1 score: 0.4281
# Epoch 47/1000
# 400/400 [==============================] - 244s 610ms/step - loss: 3.2312 - val_loss: 3.2300
#
# Epoch 00047: val_loss did not improve from 3.19671
# Number of images: 45
# Presicion: 0.5259
# Recall: 0.3215
# F1 score: 0.399
# Epoch 48/1000
# 400/400 [==============================] - 243s 608ms/step - loss: 3.2074 - val_loss: 3.2226
#
# Epoch 00048: val_loss did not improve from 3.19671
# Number of images: 45
# Presicion: 0.4392
# Recall: 0.3661
# F1 score: 0.3993
# Epoch 49/1000
# 400/400 [==============================] - 244s 611ms/step - loss: 3.1875 - val_loss: 3.2590
#
# Epoch 00049: val_loss did not improve from 3.19671
# Number of images: 45
# Presicion: 0.4856
# Recall: 0.3139
# F1 score: 0.3813
# Epoch 50/1000
# 400/400 [==============================] - 243s 607ms/step - loss: 3.1911 - val_loss: 3.2302
#
# Epoch 00050: val_loss did not improve from 3.19671
# Number of images: 45
# Presicion: 0.4848
# Recall: 0.3545
# F1 score: 0.4096
# Epoch 51/1000
# 400/400 [==============================] - 244s 611ms/step - loss: 3.1754 - val_loss: 3.2399
#
# Epoch 00051: val_loss did not improve from 3.19671
# Number of images: 45
# Presicion: 0.513
# Recall: 0.3336
# F1 score: 0.4043
# Epoch 52/1000
# 400/400 [==============================] - 245s 612ms/step - loss: 3.1758 - val_loss: 3.1758
#
# Epoch 00052: val_loss improved from 3.19671 to 3.17583, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5087
# Recall: 0.3262
# F1 score: 0.3975
# Epoch 53/1000
# 400/400 [==============================] - 252s 631ms/step - loss: 3.1474 - val_loss: 3.1575
#
# Epoch 00053: val_loss improved from 3.17583 to 3.15753, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5285
# Recall: 0.3018
# F1 score: 0.3842
# Epoch 54/1000
# 400/400 [==============================] - 249s 622ms/step - loss: 3.1542 - val_loss: 3.1720
#
# Epoch 00054: val_loss did not improve from 3.15753
# Number of images: 45
# Presicion: 0.5132
# Recall: 0.3371
# F1 score: 0.4069
# Epoch 55/1000
# 400/400 [==============================] - 247s 618ms/step - loss: 3.1344 - val_loss: 3.2141
#
# Epoch 00055: val_loss did not improve from 3.15753
# Number of images: 45
# Presicion: 0.5227
# Recall: 0.3418
# F1 score: 0.4133
# Epoch 56/1000
# 400/400 [==============================] - 246s 616ms/step - loss: 3.1205 - val_loss: 3.2430
#
# Epoch 00056: val_loss did not improve from 3.15753
# Number of images: 45
# Presicion: 0.4752
# Recall: 0.3189
# F1 score: 0.3817
# Epoch 57/1000
# 400/400 [==============================] - 244s 609ms/step - loss: 3.1156 - val_loss: 3.1683
#
# Epoch 00057: val_loss did not improve from 3.15753
# Number of images: 45
# Presicion: 0.4875
# Recall: 0.36
# F1 score: 0.4142
# Epoch 58/1000
# 400/400 [==============================] - 250s 626ms/step - loss: 3.1205 - val_loss: 3.1808
#
# Epoch 00058: val_loss did not improve from 3.15753
# Number of images: 45
# Presicion: 0.4987
# Recall: 0.3688
# F1 score: 0.424
# Epoch 59/1000
# 400/400 [==============================] - 251s 627ms/step - loss: 3.1138 - val_loss: 3.1792
#
# Epoch 00059: val_loss did not improve from 3.15753
# Number of images: 45
# Presicion: 0.4824
# Recall: 0.3658
# F1 score: 0.4161
# Epoch 60/1000
# 400/400 [==============================] - 248s 619ms/step - loss: 3.1085 - val_loss: 3.1767
#
# Epoch 00060: val_loss did not improve from 3.15753
# Number of images: 45
# Presicion: 0.477
# Recall: 0.3653
# F1 score: 0.4137
# Epoch 61/1000
# 400/400 [==============================] - 252s 631ms/step - loss: 3.0905 - val_loss: 3.1087
#
# Epoch 00061: val_loss improved from 3.15753 to 3.10871, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4907
# Recall: 0.3682
# F1 score: 0.4207
# Epoch 62/1000
# 400/400 [==============================] - 252s 631ms/step - loss: 3.0793 - val_loss: 3.1090
#
# Epoch 00062: val_loss did not improve from 3.10871
# Number of images: 45
# Presicion: 0.4737
# Recall: 0.3839
# F1 score: 0.4241
# Epoch 63/1000
# 400/400 [==============================] - 248s 621ms/step - loss: 3.0802 - val_loss: 3.1684
#
# Epoch 00063: val_loss did not improve from 3.10871
# Number of images: 45
# Presicion: 0.4527
# Recall: 0.3578
# F1 score: 0.3997
# Epoch 64/1000
# 400/400 [==============================] - 244s 611ms/step - loss: 3.0665 - val_loss: 3.1522
#
# Epoch 00064: val_loss did not improve from 3.10871
# Number of images: 45
# Presicion: 0.4721
# Recall: 0.391
# F1 score: 0.4277
# Epoch 65/1000
# 400/400 [==============================] - 233s 582ms/step - loss: 3.0579 - val_loss: 3.0924
#
# Epoch 00065: val_loss improved from 3.10871 to 3.09237, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5055
# Recall: 0.3663
# F1 score: 0.4248
# Epoch 66/1000
# 400/400 [==============================] - 231s 577ms/step - loss: 3.0716 - val_loss: 3.2318
#
# Epoch 00066: val_loss did not improve from 3.09237
# Number of images: 45
# Presicion: 0.5019
# Recall: 0.3277
# F1 score: 0.3965
# Epoch 67/1000
# 400/400 [==============================] - 230s 574ms/step - loss: 3.0674 - val_loss: 3.1508
#
# Epoch 00067: val_loss did not improve from 3.09237
# Number of images: 45
# Presicion: 0.4954
# Recall: 0.3584
# F1 score: 0.4159
# Epoch 68/1000
# 400/400 [==============================] - 242s 605ms/step - loss: 3.0437 - val_loss: 3.1510
#
# Epoch 00068: val_loss did not improve from 3.09237
# Number of images: 45
# Presicion: 0.5502
# Recall: 0.374
# F1 score: 0.4453
# Improve F1 score from 0.4413291513539767 to 0.44529283428490257
# Epoch 69/1000
# 400/400 [==============================] - 257s 643ms/step - loss: 3.0435 - val_loss: 3.1242
#
# Epoch 00069: val_loss did not improve from 3.09237
# Number of images: 45
# Presicion: 0.5549
# Recall: 0.3398
# F1 score: 0.4215
# Epoch 70/1000
# 400/400 [==============================] - 253s 633ms/step - loss: 3.0388 - val_loss: 3.0734
#
# Epoch 00070: val_loss improved from 3.09237 to 3.07336, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5505
# Recall: 0.3548
# F1 score: 0.4315
# Epoch 71/1000
# 400/400 [==============================] - 250s 626ms/step - loss: 3.0096 - val_loss: 3.0879
#
# Epoch 00071: val_loss did not improve from 3.07336
# Number of images: 45
# Presicion: 0.5665
# Recall: 0.3941
# F1 score: 0.4648
# Improve F1 score from 0.44529283428490257 to 0.4648489917907044
# Epoch 72/1000
# 400/400 [==============================] - 246s 615ms/step - loss: 3.0224 - val_loss: 3.0558
#
# Epoch 00072: val_loss improved from 3.07336 to 3.05576, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5283
# Recall: 0.3764
# F1 score: 0.4396
# Epoch 73/1000
# 400/400 [==============================] - 250s 625ms/step - loss: 3.0094 - val_loss: 3.1576
#
# Epoch 00073: val_loss did not improve from 3.05576
# Number of images: 45
# Presicion: 0.5226
# Recall: 0.3192
# F1 score: 0.3964
# Epoch 74/1000
# 400/400 [==============================] - 244s 611ms/step - loss: 3.0004 - val_loss: 3.0548
#
# Epoch 00074: val_loss improved from 3.05576 to 3.05484, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.4875
# Recall: 0.4067
# F1 score: 0.4434
# Epoch 75/1000
# 400/400 [==============================] - 243s 607ms/step - loss: 2.9803 - val_loss: 3.1537
#
# Epoch 00075: val_loss did not improve from 3.05484
# Number of images: 45
# Presicion: 0.5417
# Recall: 0.3616
# F1 score: 0.4337
# Epoch 76/1000
# 400/400 [==============================] - 248s 620ms/step - loss: 2.9994 - val_loss: 3.0297
#
# Epoch 00076: val_loss improved from 3.05484 to 3.02970, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5283
# Recall: 0.4068
# F1 score: 0.4597
# Epoch 77/1000
# 400/400 [==============================] - 250s 624ms/step - loss: 2.9824 - val_loss: 3.1705
#
# Epoch 00077: val_loss did not improve from 3.02970
# Number of images: 45
# Presicion: 0.5313
# Recall: 0.3582
# F1 score: 0.4279
# Epoch 78/1000
# 400/400 [==============================] - 250s 624ms/step - loss: 2.9910 - val_loss: 3.0758
#
# Epoch 00078: val_loss did not improve from 3.02970
# Number of images: 45
# Presicion: 0.5021
# Recall: 0.3803
# F1 score: 0.4328
# Epoch 79/1000
# 400/400 [==============================] - 248s 620ms/step - loss: 2.9743 - val_loss: 3.1305
#
# Epoch 00079: val_loss did not improve from 3.02970
# Number of images: 45
# Presicion: 0.4762
# Recall: 0.3666
# F1 score: 0.4143
# Epoch 80/1000
# 400/400 [==============================] - 250s 624ms/step - loss: 2.9793 - val_loss: 3.1025
#
# Epoch 00080: val_loss did not improve from 3.02970
# Number of images: 45
# Presicion: 0.4701
# Recall: 0.3635
# F1 score: 0.41
# Epoch 81/1000
# 400/400 [==============================] - 233s 583ms/step - loss: 2.9529 - val_loss: 3.0141
#
# Epoch 00081: val_loss improved from 3.02970 to 3.01412, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5556
# Recall: 0.3407
# F1 score: 0.4224
# Epoch 82/1000
# 400/400 [==============================] - 232s 580ms/step - loss: 2.9395 - val_loss: 3.0306
#
# Epoch 00082: val_loss did not improve from 3.01412
# Number of images: 45
# Presicion: 0.586
# Recall: 0.358
# F1 score: 0.4444
# Epoch 83/1000
# 400/400 [==============================] - 235s 588ms/step - loss: 2.9603 - val_loss: 3.1542
#
# Epoch 00083: val_loss did not improve from 3.01412
# Number of images: 45
# Presicion: 0.4933
# Recall: 0.3631
# F1 score: 0.4183
# Epoch 84/1000
# 400/400 [==============================] - 233s 582ms/step - loss: 2.9456 - val_loss: 3.0346
#
# Epoch 00084: val_loss did not improve from 3.01412
# Number of images: 45
# Presicion: 0.4815
# Recall: 0.4072
# F1 score: 0.4413
# Epoch 85/1000
# 400/400 [==============================] - 233s 583ms/step - loss: 2.9541 - val_loss: 3.0154
#
# Epoch 00085: val_loss did not improve from 3.01412
# Number of images: 45
# Presicion: 0.5614
# Recall: 0.4034
# F1 score: 0.4695
# Improve F1 score from 0.4648489917907044 to 0.4694634445434372
# Epoch 86/1000
# 400/400 [==============================] - 232s 581ms/step - loss: 2.9349 - val_loss: 3.0505
#
# Epoch 00086: val_loss did not improve from 3.01412
# Number of images: 45
# Presicion: 0.5176
# Recall: 0.3885
# F1 score: 0.4439
# Epoch 87/1000
# 400/400 [==============================] - 234s 584ms/step - loss: 2.9250 - val_loss: 3.0433
#
# Epoch 00087: val_loss did not improve from 3.01412
# Number of images: 45
# Presicion: 0.5314
# Recall: 0.3472
# F1 score: 0.42
# Epoch 88/1000
# 400/400 [==============================] - 236s 590ms/step - loss: 2.9288 - val_loss: 3.0159
# Epoch 00088: val_loss did not improve from 3.01412
# Number of images: 45
# Presicion: 0.5153
# Recall: 0.4002
# F1 score: 0.4505
# Epoch 89/1000
# 400/400 [==============================] - 234s 586ms/step - loss: 2.9254 - val_loss: 3.2246
#
# Epoch 00089: val_loss did not improve from 3.01412
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Number of images: 45
# Presicion: 0.5226
# Recall: 0.3772
# F1 score: 0.4382
# Epoch 90/1000
# 400/400 [==============================] - 233s 582ms/step - loss: 2.8705 - val_loss: 2.9453
#
# Epoch 00090: val_loss improved from 3.01412 to 2.94526, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5522
# Recall: 0.4147
# F1 score: 0.4737
# Improve F1 score from 0.4694634445434372 to 0.47365262974967065
# Epoch 91/1000
# 400/400 [==============================] - 236s 591ms/step - loss: 2.8459 - val_loss: 2.9485
#
# Epoch 00091: val_loss did not improve from 2.94526
# Number of images: 45
# Presicion: 0.5421
# Recall: 0.4082
# F1 score: 0.4657
# Epoch 92/1000
# 400/400 [==============================] - 237s 592ms/step - loss: 2.8094 - val_loss: 2.9488
#
# Epoch 00092: val_loss did not improve from 2.94526
# Number of images: 45
# Presicion: 0.535
# Recall: 0.4076
# F1 score: 0.4627
# Epoch 93/1000
# 400/400 [==============================] - 244s 610ms/step - loss: 2.8365 - val_loss: 2.9197
#
# Epoch 00093: val_loss improved from 2.94526 to 2.91972, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5703
# Recall: 0.4023
# F1 score: 0.4718
# Epoch 94/1000
# 400/400 [==============================] - 239s 598ms/step - loss: 2.8177 - val_loss: 2.9092
#
# Epoch 00094: val_loss improved from 2.91972 to 2.90923, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5226
# Recall: 0.4095
# F1 score: 0.4592
# Epoch 95/1000
# 400/400 [==============================] - 236s 589ms/step - loss: 2.8019 - val_loss: 2.9311
#
# Epoch 00095: val_loss did not improve from 2.90923
# Number of images: 45
# Presicion: 0.5463
# Recall: 0.387
# F1 score: 0.4531
# Epoch 96/1000
# 400/400 [==============================] - 248s 619ms/step - loss: 2.8047 - val_loss: 2.9461
#
# Epoch 00096: val_loss did not improve from 2.90923
# Number of images: 45
# Presicion: 0.5121
# Recall: 0.4212
# F1 score: 0.4622
# Epoch 97/1000
# 400/400 [==============================] - 237s 592ms/step - loss: 2.8231 - val_loss: 2.9309
#
# Epoch 00097: val_loss did not improve from 2.90923
# Number of images: 45
# Presicion: 0.5106
# Recall: 0.4154
# F1 score: 0.4581
# Epoch 98/1000
# 400/400 [==============================] - 233s 583ms/step - loss: 2.8003 - val_loss: 2.9353
#
# Epoch 00098: val_loss did not improve from 2.90923
# Number of images: 45
# Presicion: 0.5258
# Recall: 0.4258
# F1 score: 0.4705
# Epoch 99/1000
# 400/400 [==============================] - 231s 579ms/step - loss: 2.7889 - val_loss: 2.9225
#
# Epoch 00099: val_loss did not improve from 2.90923
# Number of images: 45
# Presicion: 0.5771
# Recall: 0.4
# F1 score: 0.4725
# Epoch 100/1000
# 400/400 [==============================] - 231s 578ms/step - loss: 2.7849 - val_loss: 2.9117
#
# Epoch 00100: val_loss did not improve from 2.90923
# Number of images: 45
# Presicion: 0.5428
# Recall: 0.4072
# F1 score: 0.4653
# Epoch 101/1000
# 400/400 [==============================] - 233s 582ms/step - loss: 2.7754 - val_loss: 2.8983
#
# Epoch 00101: val_loss improved from 2.90923 to 2.89830, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.549
# Recall: 0.403
# F1 score: 0.4648
# Epoch 102/1000
# 400/400 [==============================] - 230s 575ms/step - loss: 2.7764 - val_loss: 2.9040
#
# Epoch 00102: val_loss did not improve from 2.89830
# Number of images: 45
# Presicion: 0.5699
# Recall: 0.4097
# F1 score: 0.4767
# Improve F1 score from 0.47365262974967065 to 0.47669440144241854
# Epoch 103/1000
# 400/400 [==============================] - 230s 574ms/step - loss: 2.7765 - val_loss: 2.9064
#
# Epoch 00103: val_loss did not improve from 2.89830
# Number of images: 45
# Presicion: 0.5584
# Recall: 0.3861
# F1 score: 0.4566
# Epoch 104/1000
# 400/400 [==============================] - 232s 581ms/step - loss: 2.7674 - val_loss: 2.8892
#
# Epoch 00104: val_loss improved from 2.89830 to 2.88922, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5734
# Recall: 0.3911
# F1 score: 0.465
# Epoch 105/1000
# 400/400 [==============================] - 232s 580ms/step - loss: 2.7629 - val_loss: 2.8995
#
# Epoch 00105: val_loss did not improve from 2.88922
# Number of images: 45
# Presicion: 0.5242
# Recall: 0.4132
# F1 score: 0.4621
# Epoch 106/1000
# 400/400 [==============================] - 231s 578ms/step - loss: 2.7527 - val_loss: 2.9162
#
# Epoch 00106: val_loss did not improve from 2.88922
# Number of images: 45
# Presicion: 0.536
# Recall: 0.4072
# F1 score: 0.4628
# Epoch 107/1000
# 400/400 [==============================] - 231s 578ms/step - loss: 2.7587 - val_loss: 2.9145
#
# Epoch 00107: val_loss did not improve from 2.88922
# Number of images: 45
# Presicion: 0.5473
# Recall: 0.3843
# F1 score: 0.4515
# Epoch 108/1000
# 400/400 [==============================] - 230s 576ms/step - loss: 2.7598 - val_loss: 2.8930
#
# Epoch 00108: val_loss did not improve from 2.88922
# Number of images: 45
# Presicion: 0.5236
# Recall: 0.3988
# F1 score: 0.4527
# Epoch 109/1000
# 400/400 [==============================] - 232s 580ms/step - loss: 2.7464 - val_loss: 2.9524
#
# Epoch 00109: val_loss did not improve from 2.88922
# Number of images: 45
# Presicion: 0.5548
# Recall: 0.3798
# F1 score: 0.4509
# Epoch 110/1000
# 400/400 [==============================] - 234s 584ms/step - loss: 2.7450 - val_loss: 2.9121
#
# Epoch 00110: val_loss did not improve from 2.88922
# Number of images: 45
# Presicion: 0.5332
# Recall: 0.4166
# F1 score: 0.4677
# Epoch 111/1000
# 400/400 [==============================] - 231s 578ms/step - loss: 2.7226 - val_loss: 2.9162
#
# Epoch 00111: val_loss did not improve from 2.88922
# Number of images: 45
# Presicion: 0.538
# Recall: 0.4012
# F1 score: 0.4596
# Epoch 112/1000
# 400/400 [==============================] - 231s 578ms/step - loss: 2.7548 - val_loss: 2.9023
#
# Epoch 00112: val_loss did not improve from 2.88922
#
# Epoch 00112: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Number of images: 45
# Presicion: 0.5161
# Recall: 0.4277
# F1 score: 0.4678
# Epoch 113/1000
# 400/400 [==============================] - 231s 576ms/step - loss: 2.7218 - val_loss: 2.8860
#
# Epoch 00113: val_loss improved from 2.88922 to 2.88601, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5484
# Recall: 0.4025
# F1 score: 0.4642
# Epoch 114/1000
# 400/400 [==============================] - 233s 583ms/step - loss: 2.7106 - val_loss: 2.8774
#
# Epoch 00114: val_loss improved from 2.88601 to 2.87742, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5356
# Recall: 0.3968
# F1 score: 0.4559
# Epoch 115/1000
# 400/400 [==============================] - 230s 575ms/step - loss: 2.6868 - val_loss: 2.8786
#
# Epoch 00115: val_loss did not improve from 2.87742
# Number of images: 45
# Presicion: 0.5556
# Recall: 0.4068
# F1 score: 0.4697
# Epoch 116/1000
# 400/400 [==============================] - 232s 581ms/step - loss: 2.6728 - val_loss: 2.8835
#
# Epoch 00116: val_loss did not improve from 2.87742
# Number of images: 45
# Presicion: 0.5082
# Recall: 0.4065
# F1 score: 0.4517
# Epoch 117/1000
# 400/400 [==============================] - 230s 576ms/step - loss: 2.6790 - val_loss: 2.8744
#
# Epoch 00117: val_loss improved from 2.87742 to 2.87439, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5615
# Recall: 0.3936
# F1 score: 0.4628
# Epoch 118/1000
# 400/400 [==============================] - 231s 576ms/step - loss: 2.6692 - val_loss: 2.8711
#
# Epoch 00118: val_loss improved from 2.87439 to 2.87112, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5182
# Recall: 0.4085
# F1 score: 0.4568
# Epoch 119/1000
# 400/400 [==============================] - 230s 575ms/step - loss: 2.6791 - val_loss: 2.8887
#
# Epoch 00119: val_loss did not improve from 2.87112
# Number of images: 45
# Presicion: 0.5598
# Recall: 0.3955
# F1 score: 0.4635
# Epoch 120/1000
# 400/400 [==============================] - 233s 583ms/step - loss: 2.6889 - val_loss: 2.8650
#
# Epoch 00120: val_loss improved from 2.87112 to 2.86502, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5384
# Recall: 0.398
# F1 score: 0.4577
# Epoch 121/1000
# 400/400 [==============================] - 230s 576ms/step - loss: 2.6572 - val_loss: 2.9006
#
# Epoch 00121: val_loss did not improve from 2.86502
# Number of images: 45
# Presicion: 0.5392
# Recall: 0.4002
# F1 score: 0.4594
# Epoch 122/1000
# 400/400 [==============================] - 230s 576ms/step - loss: 2.6701 - val_loss: 2.8848
#
# Epoch 00122: val_loss did not improve from 2.86502
# Number of images: 45
# Presicion: 0.5678
# Recall: 0.402
# F1 score: 0.4708
# Epoch 123/1000
# 400/400 [==============================] - 230s 574ms/step - loss: 2.6677 - val_loss: 2.8708
#
# Epoch 00123: val_loss did not improve from 2.86502
# Number of images: 45
# Presicion: 0.5482
# Recall: 0.4049
# F1 score: 0.4658
# Epoch 124/1000
# 400/400 [==============================] - 237s 593ms/step - loss: 2.6656 - val_loss: 2.8758
#
# Epoch 00124: val_loss did not improve from 2.86502
# Number of images: 45
# Presicion: 0.534
# Recall: 0.4015
# F1 score: 0.4584
# Epoch 125/1000
# 400/400 [==============================] - 227s 568ms/step - loss: 2.6760 - val_loss: 2.8676
#
# Epoch 00125: val_loss did not improve from 2.86502
# Number of images: 45
# Presicion: 0.559
# Recall: 0.3974
# F1 score: 0.4646
# Epoch 126/1000
# 400/400 [==============================] - 238s 594ms/step - loss: 2.6643 - val_loss: 2.8741
#
# Epoch 00126: val_loss did not improve from 2.86502
# Number of images: 45
# Presicion: 0.5756
# Recall: 0.394
# F1 score: 0.4678
# Epoch 127/1000
# 400/400 [==============================] - 233s 583ms/step - loss: 2.6631 - val_loss: 2.8739
#
# Epoch 00127: val_loss did not improve from 2.86502
# Number of images: 45
# Presicion: 0.5335
# Recall: 0.407
# F1 score: 0.4618
# Epoch 128/1000
# 400/400 [==============================] - 231s 576ms/step - loss: 2.6534 - val_loss: 2.8789
#
# Epoch 00128: val_loss did not improve from 2.86502
#
# Epoch 00128: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Number of images: 45
# Presicion: 0.5682
# Recall: 0.4008
# F1 score: 0.47
# Epoch 129/1000
# 400/400 [==============================] - 238s 596ms/step - loss: 2.6230 - val_loss: 2.8592
#
# Epoch 00129: val_loss improved from 2.86502 to 2.85918, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5561
# Recall: 0.4003
# F1 score: 0.4655
# Epoch 130/1000
# 400/400 [==============================] - 229s 573ms/step - loss: 2.6268 - val_loss: 2.8539
#
# Epoch 00130: val_loss improved from 2.85918 to 2.85394, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5657
# Recall: 0.3968
# F1 score: 0.4664
# Epoch 131/1000
# 400/400 [==============================] - 238s 595ms/step - loss: 2.6451 - val_loss: 2.8554
#
# Epoch 00131: val_loss did not improve from 2.85394
# Number of images: 45
# Presicion: 0.5557
# Recall: 0.4045
# F1 score: 0.4682
# Epoch 132/1000
# 400/400 [==============================] - 230s 574ms/step - loss: 2.6128 - val_loss: 2.8445
#
# Epoch 00132: val_loss improved from 2.85394 to 2.84448, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.556
# Recall: 0.4006
# F1 score: 0.4657
# Epoch 133/1000
# 400/400 [==============================] - 235s 589ms/step - loss: 2.6055 - val_loss: 2.8471
#
# Epoch 00133: val_loss did not improve from 2.84448
# Number of images: 45
# Presicion: 0.5617
# Recall: 0.4099
# F1 score: 0.4739
# Epoch 134/1000
# 400/400 [==============================] - 236s 590ms/step - loss: 2.6260 - val_loss: 2.8636
#
# Epoch 00134: val_loss did not improve from 2.84448
# Number of images: 45
# Presicion: 0.5499
# Recall: 0.4037
# F1 score: 0.4656
# Epoch 135/1000
# 400/400 [==============================] - 238s 594ms/step - loss: 2.6152 - val_loss: 2.8397
#
# Epoch 00135: val_loss improved from 2.84448 to 2.83969, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal.h5
# Number of images: 45
# Presicion: 0.5492
# Recall: 0.4058
# F1 score: 0.4668
# Epoch 136/1000
# 400/400 [==============================] - 236s 590ms/step - loss: 2.5947 - val_loss: 2.8534
#
# Epoch 00136: val_loss did not improve from 2.83969
# Number of images: 45
# Presicion: 0.5506
# Recall: 0.4036
# F1 score: 0.4658
# Epoch 137/1000
# 400/400 [==============================] - 230s 574ms/step - loss: 2.6347 - val_loss: 2.8487
#
# Epoch 00137: val_loss did not improve from 2.83969
# Number of images: 45
# Presicion: 0.5374
# Recall: 0.4043
# F1 score: 0.4615
# Epoch 138/1000
# 400/400 [==============================] - 229s 573ms/step - loss: 2.6051 - val_loss: 2.8501
#
# Epoch 00138: val_loss did not improve from 2.83969
# Number of images: 45
# Presicion: 0.5773
# Recall: 0.4036
# F1 score: 0.475
# Epoch 139/1000
# 400/400 [==============================] - 231s 577ms/step - loss: 2.6100 - val_loss: 2.8591
#
# Epoch 00139: val_loss did not improve from 2.83969
# Number of images: 45
# Presicion: 0.5616
# Recall: 0.4149
# F1 score: 0.4772
# Improve F1 score from 0.47669440144241854 to 0.4772201313228807
# Epoch 140/1000
# 400/400 [==============================] - 236s 591ms/step - loss: 2.6046 - val_loss: 2.8626
#
# Epoch 00140: val_loss did not improve from 2.83969
# Number of images: 45
# Presicion: 0.5435
# Recall: 0.4178
# F1 score: 0.4724
# Epoch 141/1000
# 400/400 [==============================] - 231s 578ms/step - loss: 2.6167 - val_loss: 2.8462
#
# Epoch 00141: val_loss did not improve from 2.83969
# Number of images: 45
# Presicion: 0.5588
# Recall: 0.4026
# F1 score: 0.468
# Epoch 142/1000
# 400/400 [==============================] - 238s 594ms/step - loss: 2.5940 - val_loss: 2.8503
#
# Epoch 00142: val_loss did not improve from 2.83969
# Number of images: 45
# Presicion: 0.5567
# Recall: 0.4063
# F1 score: 0.4697
# Epoch 143/1000
# 400/400 [==============================] - 239s 599ms/step - loss: 2.5931 - val_loss: 2.8402
#
# Epoch 00143: val_loss did not improve from 2.83969
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Number of images: 45
# Presicion: 0.5655
# Recall: 0.4072
# F1 score: 0.4735
# Epoch 144/1000
# 400/400 [==============================] - 238s 595ms/step - loss: 2.6190 - val_loss: 2.8423
#
# Epoch 00144: val_loss did not improve from 2.83969
# Number of images: 45
# Presicion: 0.5485
# Recall: 0.4098
# F1 score: 0.4691
# Epoch 145/1000
# 400/400 [==============================] - 236s 590ms/step - loss: 2.6111 - val_loss: 2.8418
#
# Epoch 00145: val_loss did not improve from 2.83969
# Number of images: 45
# Presicion: 0.5568
# Recall: 0.4108
# F1 score: 0.4728
# Epoch 00145: early stopping

# %%
adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
# sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
# images_dir = data_path + 'udacity_driving_datasets'
# images_dir = data_path + 'pascal_dataset'
images_dir = data_path + 'images'

# Ground truth
# train_labels_filename = preprocess_path + '/udc.csv'
# train_labels_filename = preprocess_path + '/cic_pascal_train.csv'
# val_labels_filename   = preprocess_path + '/cic_pascal_val.csv'
# train_labels_filename = preprocess_path + '/pascal_train.csv'
# val_labels_filename   = preprocess_path + '/pascal_val.csv'
train_labels_filename = preprocess_path + '/cic_train.csv'
val_labels_filename   = preprocess_path + '/cic_val.csv'

train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

# train_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_train.h5',
#                                   resize=False,
#                                   variable_image_size=True,
#                                   verbose=True)

# val_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_val.h5',
#                                 resize=False,
#                                 variable_image_size=True,
#                                 verbose=True)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Loading images into memory: 100%|██████████| 210/210 [00:07<00:00, 26.26it/s]
# Loading images into memory: 100%|██████████| 45/45 [00:01<00:00, 26.98it/s]
# Number of images in the training dataset:	   210
# Number of images in the validation dataset:	    45

# %%
# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv11_mbox_conf').output_shape[1:3],
                   model.get_layer('conv13_mbox_conf').output_shape[1:3],
                   model.get_layer('conv14_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv15_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv16_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv17_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	   210
# Number of images in the validation dataset:	    45

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='/home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal_cic.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
# model_checkpoint.best = 2.567152314715915

csv_logger = CSVLogger(filename=data_path + 'history/ssd300_mobilenetv1/ssd300_mobilenetv1_pascal_cic.csv',
                       separator=',',
                       append=True)

early_stopping = EarlyStopping(monitor='val_loss',
                               min_delta=0.0,
                               patience=10,
                               verbose=1)

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.5,
                                         patience=8,
                                         verbose=1,
                                         min_delta=0.001,
                                         cooldown=0,
                                         min_lr=0.00001)

f1_callback = f1_call(0.20, 
                      0.45, 
                      200, 
                      normalize_coords, 
                      img_height,
                      img_width,
                      val_images_300,
                      label_val, (1, 2268, 14),
                      data_path + 'history/ssd300_mobilenetv1/ssd300_mobilenetv1_pascal_cic_f1.csv')

# learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule, verbose=1)


callbacks = [model_checkpoint,
             csv_logger,
             early_stopping,
#              learning_rate_scheduler]
             reduce_learning_rate,
             f1_callback]

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 1000
steps_per_epoch = 15

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/1000
# 15/15 [==============================] - 69s 5s/step - loss: 3.5154 - val_loss: 3.4795
#
# Epoch 00001: val_loss improved from inf to 3.47949, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal_cic.h5
# Number of images: 45
# Presicion: 0.4209
# Recall: 0.5122
# F1 score: 0.4621
# Improve F1 score from -inf to 0.46209192450694697
# Epoch 2/1000
# 15/15 [==============================] - 64s 4s/step - loss: 3.1514 - val_loss: 3.3531
#
# Epoch 00002: val_loss improved from 3.47949 to 3.35309, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal_cic.h5
# Number of images: 45
# Presicion: 0.4568
# Recall: 0.5215
# F1 score: 0.487
# Improve F1 score from 0.46209192450694697 to 0.48696461683436315
# Epoch 3/1000
# 15/15 [==============================] - 85s 6s/step - loss: 3.0950 - val_loss: 3.2786
#
# Epoch 00003: val_loss improved from 3.35309 to 3.27856, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal_cic.h5
# Number of images: 45
# Presicion: 0.4822
# Recall: 0.5252
# F1 score: 0.5028
# Improve F1 score from 0.48696461683436315 to 0.5027882954867688
# Epoch 4/1000
# 15/15 [==============================] - 79s 5s/step - loss: 2.7868 - val_loss: 3.1699
#
# Epoch 00004: val_loss improved from 3.27856 to 3.16987, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal_cic.h5
# Number of images: 45
# Presicion: 0.5995
# Recall: 0.4467
# F1 score: 0.5119
# Improve F1 score from 0.5027882954867688 to 0.5119234165507727
# Epoch 5/1000
# 15/15 [==============================] - 78s 5s/step - loss: 2.8750 - val_loss: 3.2491
#
# Epoch 00005: val_loss did not improve from 3.16987
# Number of images: 45
# Presicion: 0.6414
# Recall: 0.4266
# F1 score: 0.5124
# Improve F1 score from 0.5119234165507727 to 0.5123794416827825
# Epoch 6/1000
# 15/15 [==============================] - 81s 5s/step - loss: 2.7721 - val_loss: 2.8842
#
# Epoch 00006: val_loss improved from 3.16987 to 2.88423, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal_cic.h5
# Number of images: 45
# Presicion: 0.5945
# Recall: 0.5121
# F1 score: 0.5502
# Improve F1 score from 0.5123794416827825 to 0.5502054891968556
# Epoch 7/1000
# 15/15 [==============================] - 77s 5s/step - loss: 2.7513 - val_loss: 2.7386
#
# Epoch 00007: val_loss improved from 2.88423 to 2.73864, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal_cic.h5
# Number of images: 45
# Presicion: 0.5935
# Recall: 0.5389
# F1 score: 0.5648
# Improve F1 score from 0.5502054891968556 to 0.5648424161469624
# Epoch 8/1000
# 15/15 [==============================] - 70s 5s/step - loss: 2.7036 - val_loss: 2.7661
#
# Epoch 00008: val_loss did not improve from 2.73864
# Number of images: 45
# Presicion: 0.6147
# Recall: 0.5136
# F1 score: 0.5597
# Epoch 9/1000
# 15/15 [==============================] - 66s 4s/step - loss: 2.5888 - val_loss: 2.8553
#
# Epoch 00009: val_loss did not improve from 2.73864
# Number of images: 45
# Presicion: 0.603
# Recall: 0.5136
# F1 score: 0.5547
# Epoch 10/1000
# 15/15 [==============================] - 79s 5s/step - loss: 2.6614 - val_loss: 3.0206
#
# Epoch 00010: val_loss did not improve from 2.73864
# Number of images: 45
# Presicion: 0.5997
# Recall: 0.5162
# F1 score: 0.5548
# Epoch 11/1000
# 15/15 [==============================] - 81s 5s/step - loss: 2.6300 - val_loss: 2.7644
#
# Epoch 00011: val_loss did not improve from 2.73864
# Number of images: 45
# Presicion: 0.6199
# Recall: 0.553
# F1 score: 0.5845
# Improve F1 score from 0.5648424161469624 to 0.5845154773591733
# Epoch 12/1000
# 15/15 [==============================] - 80s 5s/step - loss: 2.5557 - val_loss: 2.9826
#
# Epoch 00012: val_loss did not improve from 2.73864
# Number of images: 45
# Presicion: 0.5655
# Recall: 0.5353
# F1 score: 0.55
# Epoch 13/1000
# 15/15 [==============================] - 77s 5s/step - loss: 2.4985 - val_loss: 2.9154
#
# Epoch 00013: val_loss did not improve from 2.73864
# Number of images: 45
# Presicion: 0.5174
# Recall: 0.5646
# F1 score: 0.54
# Epoch 14/1000
# 15/15 [==============================] - 79s 5s/step - loss: 2.5683 - val_loss: 2.8264
#
# Epoch 00014: val_loss did not improve from 2.73864
# Number of images: 45
# Presicion: 0.6271
# Recall: 0.5504
# F1 score: 0.5862
# Improve F1 score from 0.5845154773591733 to 0.5862201049931924
# Epoch 15/1000
# 15/15 [==============================] - 82s 5s/step - loss: 2.6349 - val_loss: 2.8954
#
# Epoch 00015: val_loss did not improve from 2.73864
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Number of images: 45
# Presicion: 0.5783
# Recall: 0.5187
# F1 score: 0.5469
# Epoch 16/1000
# 15/15 [==============================] - 79s 5s/step - loss: 2.4044 - val_loss: 2.8101
#
# Epoch 00016: val_loss did not improve from 2.73864
# Number of images: 45
# Presicion: 0.5839
# Recall: 0.5394
# F1 score: 0.5608
# Epoch 17/1000
# 15/15 [==============================] - 76s 5s/step - loss: 2.4511 - val_loss: 2.7570
#
# Epoch 00017: val_loss did not improve from 2.73864
# Number of images: 45
# Presicion: 0.6146
# Recall: 0.5758
# F1 score: 0.5946
# Improve F1 score from 0.5862201049931924 to 0.5945732629234274
# Epoch 00017: early stopping
