# %%
# libraries
import os
import json
import numpy as np
import pandas as pd
from extra_files import helper as hp
from imageio import imwrite, imread
from skimage.transform import resize

# %%
# File paths
data_path = '/home/aldo/Documents/data-cic/'
preprocess_path = data_path + 'preprocess_data'

# %% [markdown]
# ## Training SSD300 trained with vgg16 backbone trained

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300_mobilenetv1 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /home/aldo/Documents/ssd/data_generator/object_detection_2d_data_generator.py:43: UserWarning: 'BeautifulSoup' module is missing. The XML-parser will be unavailable.
#   warnings.warn("'BeautifulSoup' module is missing. The XML-parser will be unavailable.")

# %% [markdown]
# ### Parameters (original SSD300 architecture)

# %%
## Parameteres needed for ssd_300() and SSDInputEncoder()

img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [127, 127, 127] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
swap_channels = False # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 1 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales = scales_pascal
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %% [markdown]
# ## Create new model with SSD weights

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load.
weights_path = '../weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal_epoch-161_loss-3.4810_val_loss-3.6878.h5'
model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
# sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 300, 300, 3)  0
# __________________________________________________________________________________________________
# identity_layer (Lambda)         (None, 300, 300, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# input_mean_normalization (Lambd (None, 300, 300, 3)  0           identity_layer[0][0]
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 302, 302, 3)  0           input_mean_normalization[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 150, 150, 32) 864         conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 150, 150, 32) 128         conv1[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 150, 150, 32) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_1 (ZeroPadding2D)      (None, 152, 152, 32) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)     (None, 150, 150, 32) 288         conv_pad_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_bn (BatchNormalizatio (None, 150, 150, 32) 128         conv_dw_1[0][0]
# __________________________________________________________________________________________________
# conv_dw_1_relu (Activation)     (None, 150, 150, 32) 0           conv_dw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_1 (Conv2D)              (None, 150, 150, 64) 2048        conv_dw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_bn (BatchNormalizatio (None, 150, 150, 64) 256         conv_pw_1[0][0]
# __________________________________________________________________________________________________
# conv_pw_1_relu (Activation)     (None, 150, 150, 64) 0           conv_pw_1_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_2 (ZeroPadding2D)      (None, 152, 152, 64) 0           conv_pw_1_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)     (None, 75, 75, 64)   576         conv_pad_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_bn (BatchNormalizatio (None, 75, 75, 64)   256         conv_dw_2[0][0]
# __________________________________________________________________________________________________
# conv_dw_2_relu (Activation)     (None, 75, 75, 64)   0           conv_dw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_2 (Conv2D)              (None, 75, 75, 128)  8192        conv_dw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_bn (BatchNormalizatio (None, 75, 75, 128)  512         conv_pw_2[0][0]
# __________________________________________________________________________________________________
# conv_pw_2_relu (Activation)     (None, 75, 75, 128)  0           conv_pw_2_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_3 (ZeroPadding2D)      (None, 77, 77, 128)  0           conv_pw_2_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)     (None, 75, 75, 128)  1152        conv_pad_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_bn (BatchNormalizatio (None, 75, 75, 128)  512         conv_dw_3[0][0]
# __________________________________________________________________________________________________
# conv_dw_3_relu (Activation)     (None, 75, 75, 128)  0           conv_dw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_3 (Conv2D)              (None, 75, 75, 128)  16384       conv_dw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_bn (BatchNormalizatio (None, 75, 75, 128)  512         conv_pw_3[0][0]
# __________________________________________________________________________________________________
# conv_pw_3_relu (Activation)     (None, 75, 75, 128)  0           conv_pw_3_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_4 (ZeroPadding2D)      (None, 77, 77, 128)  0           conv_pw_3_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)     (None, 38, 38, 128)  1152        conv_pad_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_bn (BatchNormalizatio (None, 38, 38, 128)  512         conv_dw_4[0][0]
# __________________________________________________________________________________________________
# conv_dw_4_relu (Activation)     (None, 38, 38, 128)  0           conv_dw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_4 (Conv2D)              (None, 38, 38, 256)  32768       conv_dw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_bn (BatchNormalizatio (None, 38, 38, 256)  1024        conv_pw_4[0][0]
# __________________________________________________________________________________________________
# conv_pw_4_relu (Activation)     (None, 38, 38, 256)  0           conv_pw_4_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_5 (ZeroPadding2D)      (None, 40, 40, 256)  0           conv_pw_4_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)     (None, 38, 38, 256)  2304        conv_pad_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_bn (BatchNormalizatio (None, 38, 38, 256)  1024        conv_dw_5[0][0]
# __________________________________________________________________________________________________
# conv_dw_5_relu (Activation)     (None, 38, 38, 256)  0           conv_dw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_5 (Conv2D)              (None, 38, 38, 256)  65536       conv_dw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_bn (BatchNormalizatio (None, 38, 38, 256)  1024        conv_pw_5[0][0]
# __________________________________________________________________________________________________
# conv_pw_5_relu (Activation)     (None, 38, 38, 256)  0           conv_pw_5_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_6 (ZeroPadding2D)      (None, 40, 40, 256)  0           conv_pw_5_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)     (None, 19, 19, 256)  2304        conv_pad_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_bn (BatchNormalizatio (None, 19, 19, 256)  1024        conv_dw_6[0][0]
# __________________________________________________________________________________________________
# conv_dw_6_relu (Activation)     (None, 19, 19, 256)  0           conv_dw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_6 (Conv2D)              (None, 19, 19, 512)  131072      conv_dw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_pw_6[0][0]
# __________________________________________________________________________________________________
# conv_pw_6_relu (Activation)     (None, 19, 19, 512)  0           conv_pw_6_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_7 (ZeroPadding2D)      (None, 21, 21, 512)  0           conv_pw_6_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)     (None, 19, 19, 512)  4608        conv_pad_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_dw_7[0][0]
# __________________________________________________________________________________________________
# conv_dw_7_relu (Activation)     (None, 19, 19, 512)  0           conv_dw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_7 (Conv2D)              (None, 19, 19, 512)  262144      conv_dw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_pw_7[0][0]
# __________________________________________________________________________________________________
# conv_pw_7_relu (Activation)     (None, 19, 19, 512)  0           conv_pw_7_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_8 (ZeroPadding2D)      (None, 21, 21, 512)  0           conv_pw_7_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)     (None, 19, 19, 512)  4608        conv_pad_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_dw_8[0][0]
# __________________________________________________________________________________________________
# conv_dw_8_relu (Activation)     (None, 19, 19, 512)  0           conv_dw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_8 (Conv2D)              (None, 19, 19, 512)  262144      conv_dw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_pw_8[0][0]
# __________________________________________________________________________________________________
# conv_pw_8_relu (Activation)     (None, 19, 19, 512)  0           conv_pw_8_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_9 (ZeroPadding2D)      (None, 21, 21, 512)  0           conv_pw_8_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)     (None, 19, 19, 512)  4608        conv_pad_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_dw_9[0][0]
# __________________________________________________________________________________________________
# conv_dw_9_relu (Activation)     (None, 19, 19, 512)  0           conv_dw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_9 (Conv2D)              (None, 19, 19, 512)  262144      conv_dw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_bn (BatchNormalizatio (None, 19, 19, 512)  2048        conv_pw_9[0][0]
# __________________________________________________________________________________________________
# conv_pw_9_relu (Activation)     (None, 19, 19, 512)  0           conv_pw_9_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_10 (ZeroPadding2D)     (None, 21, 21, 512)  0           conv_pw_9_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_10 (DepthwiseConv2D)    (None, 19, 19, 512)  4608        conv_pad_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_bn (BatchNormalizati (None, 19, 19, 512)  2048        conv_dw_10[0][0]
# __________________________________________________________________________________________________
# conv_dw_10_relu (Activation)    (None, 19, 19, 512)  0           conv_dw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_10 (Conv2D)             (None, 19, 19, 512)  262144      conv_dw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_bn (BatchNormalizati (None, 19, 19, 512)  2048        conv_pw_10[0][0]
# __________________________________________________________________________________________________
# conv_pw_10_relu (Activation)    (None, 19, 19, 512)  0           conv_pw_10_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_11 (ZeroPadding2D)     (None, 21, 21, 512)  0           conv_pw_10_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_11 (DepthwiseConv2D)    (None, 19, 19, 512)  4608        conv_pad_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_bn (BatchNormalizati (None, 19, 19, 512)  2048        conv_dw_11[0][0]
# __________________________________________________________________________________________________
# conv_dw_11_relu (Activation)    (None, 19, 19, 512)  0           conv_dw_11_bn[0][0]
# __________________________________________________________________________________________________
# conv__11 (Conv2D)               (None, 19, 19, 512)  262144      conv_dw_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_11_bn (BatchNormalization) (None, 19, 19, 512)  2048        conv__11[0][0]
# __________________________________________________________________________________________________
# conv_11_relu (Activation)       (None, 19, 19, 512)  0           conv_11_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_12 (ZeroPadding2D)     (None, 21, 21, 512)  0           conv_11_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_12 (DepthwiseConv2D)    (None, 10, 10, 512)  4608        conv_pad_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_bn (BatchNormalizati (None, 10, 10, 512)  2048        conv_dw_12[0][0]
# __________________________________________________________________________________________________
# conv_dw_12_relu (Activation)    (None, 10, 10, 512)  0           conv_dw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_pw_12 (Conv2D)             (None, 10, 10, 512)  262144      conv_dw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_bn (BatchNormalizati (None, 10, 10, 512)  2048        conv_pw_12[0][0]
# __________________________________________________________________________________________________
# conv_pw_12_relu (Activation)    (None, 10, 10, 512)  0           conv_pw_12_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_13 (ZeroPadding2D)     (None, 12, 12, 512)  0           conv_pw_12_relu[0][0]
# __________________________________________________________________________________________________
# conv_dw_13 (DepthwiseConv2D)    (None, 10, 10, 512)  4608        conv_pad_13[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_bn (BatchNormalizati (None, 10, 10, 512)  2048        conv_dw_13[0][0]
# __________________________________________________________________________________________________
# conv_dw_13_relu (Activation)    (None, 10, 10, 512)  0           conv_dw_13_bn[0][0]
# __________________________________________________________________________________________________
# conv__13 (Conv2D)               (None, 10, 10, 512)  262144      conv_dw_13_relu[0][0]
# __________________________________________________________________________________________________
# conv_13_bn (BatchNormalization) (None, 10, 10, 512)  2048        conv__13[0][0]
# __________________________________________________________________________________________________
# conv_13_relu (Activation)       (None, 10, 10, 512)  0           conv_13_bn[0][0]
# __________________________________________________________________________________________________
# conv_pad_14_1 (ZeroPadding2D)   (None, 12, 12, 512)  0           conv_13_relu[0][0]
# __________________________________________________________________________________________________
# conv__14_1 (Conv2D)             (None, 12, 12, 256)  131072      conv_pad_14_1[0][0]
# __________________________________________________________________________________________________
# conv_14_bn_1 (BatchNormalizatio (None, 12, 12, 256)  1024        conv__14_1[0][0]
# __________________________________________________________________________________________________
# conv_14_relu_1 (Activation)     (None, 12, 12, 256)  0           conv_14_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__14_2 (Conv2D)             (None, 5, 5, 512)    1179648     conv_14_relu_1[0][0]
# __________________________________________________________________________________________________
# conv_14_bn_2 (BatchNormalizatio (None, 5, 5, 512)    2048        conv__14_2[0][0]
# __________________________________________________________________________________________________
# conv_14_relu_2 (Activation)     (None, 5, 5, 512)    0           conv_14_bn_2[0][0]
# __________________________________________________________________________________________________
# conv_pad_15_1 (ZeroPadding2D)   (None, 7, 7, 512)    0           conv_14_relu_2[0][0]
# __________________________________________________________________________________________________
# conv__15_1 (Conv2D)             (None, 7, 7, 128)    65536       conv_pad_15_1[0][0]
# __________________________________________________________________________________________________
# conv_15_bn_1 (BatchNormalizatio (None, 7, 7, 128)    512         conv__15_1[0][0]
# __________________________________________________________________________________________________
# conv_15_relu_1 (Activation)     (None, 7, 7, 128)    0           conv_15_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__15_2 (Conv2D)             (None, 3, 3, 256)    294912      conv_15_relu_1[0][0]
# __________________________________________________________________________________________________
# conv_15_bn_2 (BatchNormalizatio (None, 3, 3, 256)    1024        conv__15_2[0][0]
# __________________________________________________________________________________________________
# conv_15_relu_2 (Activation)     (None, 3, 3, 256)    0           conv_15_bn_2[0][0]
# __________________________________________________________________________________________________
# conv_pad_16_1 (ZeroPadding2D)   (None, 5, 5, 256)    0           conv_15_relu_2[0][0]
# __________________________________________________________________________________________________
# conv__16_1 (Conv2D)             (None, 5, 5, 128)    32768       conv_pad_16_1[0][0]
# __________________________________________________________________________________________________
# conv_16_bn_1 (BatchNormalizatio (None, 5, 5, 128)    512         conv__16_1[0][0]
# __________________________________________________________________________________________________
# conv_16_relu_1 (Activation)     (None, 5, 5, 128)    0           conv_16_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__16_2 (Conv2D)             (None, 2, 2, 256)    294912      conv_16_relu_1[0][0]
# __________________________________________________________________________________________________
# conv_16_bn_2 (BatchNormalizatio (None, 2, 2, 256)    1024        conv__16_2[0][0]
# __________________________________________________________________________________________________
# conv_16_relu_2 (Activation)     (None, 2, 2, 256)    0           conv_16_bn_2[0][0]
# __________________________________________________________________________________________________
# conv_pad_17_1 (ZeroPadding2D)   (None, 4, 4, 256)    0           conv_16_relu_2[0][0]
# __________________________________________________________________________________________________
# conv__17_1 (Conv2D)             (None, 4, 4, 64)     16384       conv_pad_17_1[0][0]
# __________________________________________________________________________________________________
# conv_17_bn_1 (BatchNormalizatio (None, 4, 4, 64)     256         conv__17_1[0][0]
# __________________________________________________________________________________________________
# conv_17_relu_1 (Activation)     (None, 4, 4, 64)     0           conv_17_bn_1[0][0]
# __________________________________________________________________________________________________
# conv__17_2 (Conv2D)             (None, 1, 1, 128)    73728       conv_17_relu_1[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_conf (Conv2D)       (None, 19, 19, 8)    36872       conv__11[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_conf (Conv2D)       (None, 10, 10, 12)   55308       conv__13[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_conf (Conv2D)     (None, 5, 5, 12)     55308       conv__14_2[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_conf (Conv2D)     (None, 3, 3, 12)     27660       conv__15_2[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_conf (Conv2D)     (None, 2, 2, 8)      18440       conv__16_2[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_conf (Conv2D)     (None, 1, 1, 8)      9224        conv__17_2[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_loc (Conv2D)        (None, 19, 19, 16)   73744       conv__11[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_loc (Conv2D)        (None, 10, 10, 24)   110616      conv__13[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_loc (Conv2D)      (None, 5, 5, 24)     110616      conv__14_2[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_loc (Conv2D)      (None, 3, 3, 24)     55320       conv__15_2[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_loc (Conv2D)      (None, 2, 2, 16)     36880       conv__16_2[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_loc (Conv2D)      (None, 1, 1, 16)     18448       conv__17_2[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_conf_reshape (Resha (None, 1444, 2)      0           conv11_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_conf_reshape (Resha (None, 600, 2)       0           conv13_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_conf_reshape (Res (None, 150, 2)       0           conv14_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_conf_reshape (Res (None, 54, 2)        0           conv15_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_conf_reshape (Res (None, 16, 2)        0           conv16_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_conf_reshape (Res (None, 4, 2)         0           conv17_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_priorbox (AnchorBox (None, 19, 19, 4, 8) 0           conv11_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_priorbox (AnchorBox (None, 10, 10, 6, 8) 0           conv13_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_priorbox (AnchorB (None, 5, 5, 6, 8)   0           conv14_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_priorbox (AnchorB (None, 3, 3, 6, 8)   0           conv15_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_priorbox (AnchorB (None, 2, 2, 4, 8)   0           conv16_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_priorbox (AnchorB (None, 1, 1, 4, 8)   0           conv17_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (None, 2268, 2)      0           conv11_mbox_conf_reshape[0][0]
#                                                                  conv13_mbox_conf_reshape[0][0]
#                                                                  conv14_2_mbox_conf_reshape[0][0]
#                                                                  conv15_2_mbox_conf_reshape[0][0]
#                                                                  conv16_2_mbox_conf_reshape[0][0]
#                                                                  conv17_2_mbox_conf_reshape[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_loc_reshape (Reshap (None, 1444, 4)      0           conv11_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_loc_reshape (Reshap (None, 600, 4)       0           conv13_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_loc_reshape (Resh (None, 150, 4)       0           conv14_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_loc_reshape (Resh (None, 54, 4)        0           conv15_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_loc_reshape (Resh (None, 16, 4)        0           conv16_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_loc_reshape (Resh (None, 4, 4)         0           conv17_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv11_mbox_priorbox_reshape (R (None, 1444, 8)      0           conv11_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv13_mbox_priorbox_reshape (R (None, 600, 8)       0           conv13_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv14_2_mbox_priorbox_reshape  (None, 150, 8)       0           conv14_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv15_2_mbox_priorbox_reshape  (None, 54, 8)        0           conv15_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv16_2_mbox_priorbox_reshape  (None, 16, 8)        0           conv16_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv17_2_mbox_priorbox_reshape  (None, 4, 8)         0           conv17_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# mbox_conf_softmax (Activation)  (None, 2268, 2)      0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (None, 2268, 4)      0           conv11_mbox_loc_reshape[0][0]
#                                                                  conv13_mbox_loc_reshape[0][0]
#                                                                  conv14_2_mbox_loc_reshape[0][0]
#                                                                  conv15_2_mbox_loc_reshape[0][0]
#                                                                  conv16_2_mbox_loc_reshape[0][0]
#                                                                  conv17_2_mbox_loc_reshape[0][0]
# __________________________________________________________________________________________________
# mbox_priorbox (Concatenate)     (None, 2268, 8)      0           conv11_mbox_priorbox_reshape[0][0
#                                                                  conv13_mbox_priorbox_reshape[0][0
#                                                                  conv14_2_mbox_priorbox_reshape[0]
#                                                                  conv15_2_mbox_priorbox_reshape[0]
#                                                                  conv16_2_mbox_priorbox_reshape[0]
#                                                                  conv17_2_mbox_priorbox_reshape[0]
# __________________________________________________________________________________________________
# predictions (Concatenate)       (None, 2268, 14)     0           mbox_conf_softmax[0][0]
#                                                                  mbox_loc[0][0]
#                                                                  mbox_priorbox[0][0]
# ==================================================================================================
# Total params: 4,873,332
# Trainable params: 4,851,316
# Non-trainable params: 22,016
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Data generator for the training

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
# images_dir = data_path + 'udacity_driving_datasets'
# images_dir = data_path + 'pascal_dataset'
images_dir = data_path + 'images'

# Ground truth
# train_labels_filename = preprocess_path + '/udc.csv'
# train_labels_filename = preprocess_path + '/cic_pascal_train.csv'
# val_labels_filename   = preprocess_path + '/cic_pascal_val.csv'
# train_labels_filename = preprocess_path + '/pascal_train.csv'
# val_labels_filename   = preprocess_path + '/pascal_val.csv'
train_labels_filename = preprocess_path + '/cic_train.csv'
val_labels_filename   = preprocess_path + '/cic_val.csv'

train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

# train_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_train.h5',
#                                   resize=False,
#                                   variable_image_size=True,
#                                   verbose=True)

# val_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_val.h5',
#                                 resize=False,
#                                 variable_image_size=True,
#                                 verbose=True)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Loading images into memory: 100%|██████████| 210/210 [00:07<00:00, 27.76it/s]
# Loading images into memory: 100%|██████████| 45/45 [00:01<00:00, 23.45it/s]
# Number of images in the training dataset:	   210
# Number of images in the validation dataset:	    45

# %%
# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv11_mbox_conf').output_shape[1:3],
                   model.get_layer('conv13_mbox_conf').output_shape[1:3],
                   model.get_layer('conv14_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv15_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv16_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv17_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	   210
# Number of images in the validation dataset:	    45

# %% [markdown]
# ## Remaining training parameters

# %%
# Define a learning rate schedule.
def lr_schedule(epoch):
    if epoch < 100:
        return 0.0001
    elif epoch < 200:
        return 0.00001

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='/home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
# model_checkpoint.best = 2.567152314715915

csv_logger = CSVLogger(filename=data_path + 'history/ssd300_mobilenetv1/ssd300_vgg_13_pascal_cic.csv',
                       separator=',',
                       append=True)

# early_stopping = EarlyStopping(monitor='val_loss',
#                                min_delta=0.0,
#                                patience=11,
#                                verbose=1)

# reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
#                                          factor=0.2,
#                                          patience=9,
#                                          verbose=1,
#                                          min_delta=0.001,
#                                          cooldown=0,
#                                          min_lr=0.00001)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

# terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
#              early_stopping,
             learning_rate_scheduler]
#              reduce_learning_rate]

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 200
steps_per_epoch = 10

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/200
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.7807 - val_loss: 5.0652
#
# Epoch 00001: val_loss improved from inf to 5.06523, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 2/200
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 40s 4s/step - loss: 4.8566 - val_loss: 4.9677
#
# Epoch 00002: val_loss improved from 5.06523 to 4.96773, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 3/200
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.7016 - val_loss: 4.9288
#
# Epoch 00003: val_loss improved from 4.96773 to 4.92876, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 4/200
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.5004 - val_loss: 4.8929
#
# Epoch 00004: val_loss improved from 4.92876 to 4.89289, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 5/200
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 40s 4s/step - loss: 4.6185 - val_loss: 4.8638
#
# Epoch 00005: val_loss improved from 4.89289 to 4.86376, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 6/200
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.5141 - val_loss: 4.8305
#
# Epoch 00006: val_loss improved from 4.86376 to 4.83046, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 7/200
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 41s 4s/step - loss: 4.6862 - val_loss: 4.8084
#
# Epoch 00007: val_loss improved from 4.83046 to 4.80837, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 8/200
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 5s/step - loss: 4.6208 - val_loss: 4.7769
#
# Epoch 00008: val_loss improved from 4.80837 to 4.77685, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 9/200
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.3098 - val_loss: 4.7570
#
# Epoch 00009: val_loss improved from 4.77685 to 4.75699, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 10/200
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.6926 - val_loss: 4.7322
#
# Epoch 00010: val_loss improved from 4.75699 to 4.73220, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 11/200
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 47s 5s/step - loss: 4.5839 - val_loss: 4.7208
#
# Epoch 00011: val_loss improved from 4.73220 to 4.72085, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 12/200
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.6450 - val_loss: 4.7117
#
# Epoch 00012: val_loss improved from 4.72085 to 4.71172, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 13/200
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.2973 - val_loss: 4.7129
#
# Epoch 00013: val_loss did not improve from 4.71172
# Epoch 14/200
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 41s 4s/step - loss: 4.3010 - val_loss: 4.6794
#
# Epoch 00014: val_loss improved from 4.71172 to 4.67937, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 15/200
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.3414 - val_loss: 4.6495
#
# Epoch 00015: val_loss improved from 4.67937 to 4.64953, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 16/200
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.5849 - val_loss: 4.6388
#
# Epoch 00016: val_loss improved from 4.64953 to 4.63880, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 17/200
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 41s 4s/step - loss: 4.2857 - val_loss: 4.6158
#
# Epoch 00017: val_loss improved from 4.63880 to 4.61575, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 18/200
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.4004 - val_loss: 4.5786
#
# Epoch 00018: val_loss improved from 4.61575 to 4.57863, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 19/200
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 40s 4s/step - loss: 4.4454 - val_loss: 4.5529
#
# Epoch 00019: val_loss improved from 4.57863 to 4.55286, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 20/200
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.2574 - val_loss: 4.5324
#
# Epoch 00020: val_loss improved from 4.55286 to 4.53238, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 21/200
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.3203 - val_loss: 4.5188
#
# Epoch 00021: val_loss improved from 4.53238 to 4.51879, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 22/200
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.3627 - val_loss: 4.5141
#
# Epoch 00022: val_loss improved from 4.51879 to 4.51414, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 23/200
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0953 - val_loss: 4.5119
#
# Epoch 00023: val_loss improved from 4.51414 to 4.51194, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 24/200
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 41s 4s/step - loss: 4.2228 - val_loss: 4.5164
#
# Epoch 00024: val_loss did not improve from 4.51194
# Epoch 25/200
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 47s 5s/step - loss: 4.3245 - val_loss: 4.5125
#
# Epoch 00025: val_loss did not improve from 4.51194
# Epoch 26/200
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.1907 - val_loss: 4.4921
#
# Epoch 00026: val_loss improved from 4.51194 to 4.49211, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 27/200
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.3777 - val_loss: 4.4797
#
# Epoch 00027: val_loss improved from 4.49211 to 4.47968, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 28/200
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 41s 4s/step - loss: 4.2978 - val_loss: 4.4478
#
# Epoch 00028: val_loss improved from 4.47968 to 4.44780, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 29/200
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.3846 - val_loss: 4.4375
#
# Epoch 00029: val_loss improved from 4.44780 to 4.43751, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 30/200
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.2081 - val_loss: 4.4140
#
# Epoch 00030: val_loss improved from 4.43751 to 4.41403, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 31/200
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 40s 4s/step - loss: 4.1881 - val_loss: 4.3932
#
# Epoch 00031: val_loss improved from 4.41403 to 4.39324, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 32/200
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.4798 - val_loss: 4.3696
#
# Epoch 00032: val_loss improved from 4.39324 to 4.36959, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 33/200
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.3636 - val_loss: 4.3651
#
# Epoch 00033: val_loss improved from 4.36959 to 4.36506, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 34/200
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.3075 - val_loss: 4.3684
#
# Epoch 00034: val_loss did not improve from 4.36506
# Epoch 35/200
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.2039 - val_loss: 4.3877
#
# Epoch 00035: val_loss did not improve from 4.36506
# Epoch 36/200
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.3717 - val_loss: 4.3808
#
# Epoch 00036: val_loss did not improve from 4.36506
# Epoch 37/200
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 4s/step - loss: 4.3508 - val_loss: 4.3627
#
# Epoch 00037: val_loss improved from 4.36506 to 4.36265, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 38/200
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.2519 - val_loss: 4.3485
#
# Epoch 00038: val_loss improved from 4.36265 to 4.34845, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 39/200
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 47s 5s/step - loss: 4.4646 - val_loss: 4.3513
#
# Epoch 00039: val_loss did not improve from 4.34845
# Epoch 40/200
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.2262 - val_loss: 4.3554
#
# Epoch 00040: val_loss did not improve from 4.34845
# Epoch 41/200
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.2174 - val_loss: 4.3656
#
# Epoch 00041: val_loss did not improve from 4.34845
# Epoch 42/200
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 41s 4s/step - loss: 4.2298 - val_loss: 4.3633
#
# Epoch 00042: val_loss did not improve from 4.34845
# Epoch 43/200
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.1480 - val_loss: 4.3487
#
# Epoch 00043: val_loss did not improve from 4.34845
# Epoch 44/200
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.0097 - val_loss: 4.3245
#
# Epoch 00044: val_loss improved from 4.34845 to 4.32448, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 45/200
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 40s 4s/step - loss: 4.1200 - val_loss: 4.3051
#
# Epoch 00045: val_loss improved from 4.32448 to 4.30506, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 46/200
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 3.9532 - val_loss: 4.2961
#
# Epoch 00046: val_loss improved from 4.30506 to 4.29608, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 47/200
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.1837 - val_loss: 4.2982
#
# Epoch 00047: val_loss did not improve from 4.29608
# Epoch 48/200
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.0704 - val_loss: 4.3085
#
# Epoch 00048: val_loss did not improve from 4.29608
# Epoch 49/200
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.2604 - val_loss: 4.3087
#
# Epoch 00049: val_loss did not improve from 4.29608
# Epoch 50/200
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.3580 - val_loss: 4.2948
#
# Epoch 00050: val_loss improved from 4.29608 to 4.29481, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 51/200
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 4s/step - loss: 4.1304 - val_loss: 4.2902
#
# Epoch 00051: val_loss improved from 4.29481 to 4.29018, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 52/200
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 41s 4s/step - loss: 4.0517 - val_loss: 4.2901
#
# Epoch 00052: val_loss improved from 4.29018 to 4.29010, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 53/200
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.3839 - val_loss: 4.2935
#
# Epoch 00053: val_loss did not improve from 4.29010
# Epoch 54/200
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 41s 4s/step - loss: 4.1943 - val_loss: 4.2903
#
# Epoch 00054: val_loss did not improve from 4.29010
# Epoch 55/200
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 4s/step - loss: 4.1080 - val_loss: 4.2874
#
# Epoch 00055: val_loss improved from 4.29010 to 4.28737, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 56/200
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.3188 - val_loss: 4.2934
#
# Epoch 00056: val_loss did not improve from 4.28737
# Epoch 57/200
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 5s/step - loss: 4.1518 - val_loss: 4.2943
#
# Epoch 00057: val_loss did not improve from 4.28737
# Epoch 58/200
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.1533 - val_loss: 4.2973
#
# Epoch 00058: val_loss did not improve from 4.28737
# Epoch 59/200
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.2335 - val_loss: 4.2968
#
# Epoch 00059: val_loss did not improve from 4.28737
# Epoch 60/200
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.3309 - val_loss: 4.2816
#
# Epoch 00060: val_loss improved from 4.28737 to 4.28162, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 61/200
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 40s 4s/step - loss: 4.2310 - val_loss: 4.2728
#
# Epoch 00061: val_loss improved from 4.28162 to 4.27276, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 62/200
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.1985 - val_loss: 4.2607
#
# Epoch 00062: val_loss improved from 4.27276 to 4.26071, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 63/200
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.3362 - val_loss: 4.2515
#
# Epoch 00063: val_loss improved from 4.26071 to 4.25147, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 64/200
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.2741 - val_loss: 4.2532
#
# Epoch 00064: val_loss did not improve from 4.25147
# Epoch 65/200
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 49s 5s/step - loss: 3.9328 - val_loss: 4.2373
#
# Epoch 00065: val_loss improved from 4.25147 to 4.23734, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 66/200
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.1738 - val_loss: 4.2160
#
# Epoch 00066: val_loss improved from 4.23734 to 4.21604, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 67/200
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 47s 5s/step - loss: 4.2771 - val_loss: 4.1912
#
# Epoch 00067: val_loss improved from 4.21604 to 4.19119, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 68/200
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.1187 - val_loss: 4.1795
#
# Epoch 00068: val_loss improved from 4.19119 to 4.17947, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 69/200
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.1433 - val_loss: 4.1882
#
# Epoch 00069: val_loss did not improve from 4.17947
# Epoch 70/200
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 41s 4s/step - loss: 3.9488 - val_loss: 4.1919
#
# Epoch 00070: val_loss did not improve from 4.17947
# Epoch 71/200
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 49s 5s/step - loss: 4.3259 - val_loss: 4.1893
#
# Epoch 00071: val_loss did not improve from 4.17947
# Epoch 72/200
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 47s 5s/step - loss: 4.1226 - val_loss: 4.1816
#
# Epoch 00072: val_loss did not improve from 4.17947
# Epoch 73/200
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.2225 - val_loss: 4.1732
#
# Epoch 00073: val_loss improved from 4.17947 to 4.17317, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 74/200
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0603 - val_loss: 4.1658
#
# Epoch 00074: val_loss improved from 4.17317 to 4.16578, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 75/200
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.0400 - val_loss: 4.1650
#
# Epoch 00075: val_loss improved from 4.16578 to 4.16504, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 76/200
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.2627 - val_loss: 4.1642
#
# Epoch 00076: val_loss improved from 4.16504 to 4.16416, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 77/200
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 4.1641 - val_loss: 4.1817
#
# Epoch 00077: val_loss did not improve from 4.16416
# Epoch 78/200
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0242 - val_loss: 4.1757
#
# Epoch 00078: val_loss did not improve from 4.16416
# Epoch 79/200
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 3.9162 - val_loss: 4.1555
#
# Epoch 00079: val_loss improved from 4.16416 to 4.15545, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 80/200
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.2929 - val_loss: 4.1610
#
# Epoch 00080: val_loss did not improve from 4.15545
# Epoch 81/200
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 5s/step - loss: 4.1684 - val_loss: 4.1743
#
# Epoch 00081: val_loss did not improve from 4.15545
# Epoch 82/200
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.0747 - val_loss: 4.1797
#
# Epoch 00082: val_loss did not improve from 4.15545
# Epoch 83/200
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 5s/step - loss: 4.0357 - val_loss: 4.1684
#
# Epoch 00083: val_loss did not improve from 4.15545
# Epoch 84/200
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 44s 4s/step - loss: 4.1891 - val_loss: 4.1573
#
# Epoch 00084: val_loss did not improve from 4.15545
# Epoch 85/200
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 4s/step - loss: 3.9539 - val_loss: 4.1520
#
# Epoch 00085: val_loss improved from 4.15545 to 4.15201, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 86/200
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 4.0584 - val_loss: 4.1594
#
# Epoch 00086: val_loss did not improve from 4.15201
# Epoch 87/200
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 4s/step - loss: 4.1330 - val_loss: 4.1639
# Epoch 00087: val_loss did not improve from 4.15201
# Epoch 88/200
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 3.9497 - val_loss: 4.1472
#
# Epoch 00088: val_loss improved from 4.15201 to 4.14716, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 89/200
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 41s 4s/step - loss: 4.0451 - val_loss: 4.1415
#
# Epoch 00089: val_loss improved from 4.14716 to 4.14150, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 90/200
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.1293 - val_loss: 4.1528
#
# Epoch 00090: val_loss did not improve from 4.14150
# Epoch 91/200
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 42s 4s/step - loss: 3.9333 - val_loss: 4.1590
#
# Epoch 00091: val_loss did not improve from 4.14150
# Epoch 92/200
#
# Epoch 00092: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 3.8839 - val_loss: 4.1607
#
# Epoch 00092: val_loss did not improve from 4.14150
# Epoch 93/200
#
# Epoch 00093: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 5s/step - loss: 4.2458 - val_loss: 4.1697
#
# Epoch 00093: val_loss did not improve from 4.14150
# Epoch 94/200
#
# Epoch 00094: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 40s 4s/step - loss: 3.8231 - val_loss: 4.1576
#
# Epoch 00094: val_loss did not improve from 4.14150
# Epoch 95/200
#
# Epoch 00095: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 45s 5s/step - loss: 4.0572 - val_loss: 4.1438
#
# Epoch 00095: val_loss did not improve from 4.14150
# Epoch 96/200
#
# Epoch 00096: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 39s 4s/step - loss: 3.8363 - val_loss: 4.1425
#
# Epoch 00096: val_loss did not improve from 4.14150
# Epoch 97/200
#
# Epoch 00097: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.0629 - val_loss: 4.1457
#
# Epoch 00097: val_loss did not improve from 4.14150
# Epoch 98/200
#
# Epoch 00098: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 46s 5s/step - loss: 4.1924 - val_loss: 4.1409
#
# Epoch 00098: val_loss improved from 4.14150 to 4.14086, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 99/200
#
# Epoch 00099: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 49s 5s/step - loss: 4.3000 - val_loss: 4.1313
#
# Epoch 00099: val_loss improved from 4.14086 to 4.13125, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 100/200
#
# Epoch 00100: LearningRateScheduler setting learning rate to 0.0001.
# 10/10 [==============================] - 43s 4s/step - loss: 3.8754 - val_loss: 4.1238
#
# Epoch 00100: val_loss improved from 4.13125 to 4.12381, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 101/200
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 41s 4s/step - loss: 3.9337 - val_loss: 4.1214
#
# Epoch 00101: val_loss improved from 4.12381 to 4.12139, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 102/200
#
# Epoch 00102: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 4.1408 - val_loss: 4.1204
#
# Epoch 00102: val_loss improved from 4.12139 to 4.12037, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 103/200
#
# Epoch 00103: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0059 - val_loss: 4.1175
#
# Epoch 00103: val_loss improved from 4.12037 to 4.11753, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 104/200
#
# Epoch 00104: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0993 - val_loss: 4.1158
#
# Epoch 00104: val_loss improved from 4.11753 to 4.11576, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 105/200
#
# Epoch 00105: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 41s 4s/step - loss: 3.8636 - val_loss: 4.1148
#
# Epoch 00105: val_loss improved from 4.11576 to 4.11477, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 106/200
#
# Epoch 00106: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 4.0771 - val_loss: 4.1154
#
# Epoch 00106: val_loss did not improve from 4.11477
# Epoch 107/200
#
# Epoch 00107: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 47s 5s/step - loss: 4.1457 - val_loss: 4.1165
#
# Epoch 00107: val_loss did not improve from 4.11477
# Epoch 108/200
#
# Epoch 00108: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0983 - val_loss: 4.1158
#
# Epoch 00108: val_loss did not improve from 4.11477
# Epoch 109/200
#
# Epoch 00109: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 4.0413 - val_loss: 4.1156
#
# Epoch 00109: val_loss did not improve from 4.11477
# Epoch 110/200
#
# Epoch 00110: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 3.9291 - val_loss: 4.1145
#
# Epoch 00110: val_loss improved from 4.11477 to 4.11449, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 111/200
#
# Epoch 00111: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 4s/step - loss: 3.9802 - val_loss: 4.1139
#
# Epoch 00111: val_loss improved from 4.11449 to 4.11392, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 112/200
#
# Epoch 00112: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 41s 4s/step - loss: 3.9130 - val_loss: 4.1146
#
# Epoch 00112: val_loss did not improve from 4.11392
# Epoch 113/200
#
# Epoch 00113: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 3.9852 - val_loss: 4.1153
#
# Epoch 00113: val_loss did not improve from 4.11392
# Epoch 114/200
#
# Epoch 00114: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0345 - val_loss: 4.1152
#
# Epoch 00114: val_loss did not improve from 4.11392
# Epoch 115/200
#
# Epoch 00115: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 41s 4s/step - loss: 3.9867 - val_loss: 4.1157
#
# Epoch 00115: val_loss did not improve from 4.11392
# Epoch 116/200
#
# Epoch 00116: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 4.1681 - val_loss: 4.1113
#
# Epoch 00116: val_loss improved from 4.11392 to 4.11126, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 117/200
#
# Epoch 00117: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 41s 4s/step - loss: 3.9781 - val_loss: 4.1105
#
# Epoch 00117: val_loss improved from 4.11126 to 4.11046, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 118/200
#
# Epoch 00118: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 3.9456 - val_loss: 4.1093
#
# Epoch 00118: val_loss improved from 4.11046 to 4.10931, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 119/200
#
# Epoch 00119: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 40s 4s/step - loss: 4.0189 - val_loss: 4.1104
#
# Epoch 00119: val_loss did not improve from 4.10931
# Epoch 120/200
#
# Epoch 00120: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 4s/step - loss: 4.0939 - val_loss: 4.1095
#
# Epoch 00120: val_loss did not improve from 4.10931
# Epoch 121/200
#
# Epoch 00121: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 43s 4s/step - loss: 3.9369 - val_loss: 4.1097
#
# Epoch 00121: val_loss did not improve from 4.10931
# Epoch 122/200
#
# Epoch 00122: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 43s 4s/step - loss: 4.0807 - val_loss: 4.1104
#
# Epoch 00122: val_loss did not improve from 4.10931
# Epoch 123/200
#
# Epoch 00123: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0048 - val_loss: 4.1093
#
# Epoch 00123: val_loss improved from 4.10931 to 4.10926, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 124/200
#
# Epoch 00124: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 4s/step - loss: 3.9986 - val_loss: 4.1091
#
# Epoch 00124: val_loss improved from 4.10926 to 4.10908, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 125/200
#
# Epoch 00125: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 47s 5s/step - loss: 4.1057 - val_loss: 4.1100
#
# Epoch 00125: val_loss did not improve from 4.10908
# Epoch 126/200
#
# Epoch 00126: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 3.9838 - val_loss: 4.1096
#
# Epoch 00126: val_loss did not improve from 4.10908
# Epoch 127/200
#
# Epoch 00127: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 4.0237 - val_loss: 4.1085
#
# Epoch 00127: val_loss improved from 4.10908 to 4.10854, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 128/200
#
# Epoch 00128: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 4.1962 - val_loss: 4.1105
#
# Epoch 00128: val_loss did not improve from 4.10854
# Epoch 129/200
#
# Epoch 00129: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 40s 4s/step - loss: 4.0534 - val_loss: 4.1124
#
# Epoch 00129: val_loss did not improve from 4.10854
# Epoch 130/200
#
# Epoch 00130: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 3.9058 - val_loss: 4.1126
#
# Epoch 00130: val_loss did not improve from 4.10854
# Epoch 131/200
#
# Epoch 00131: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 4.3013 - val_loss: 4.1128
#
# Epoch 00131: val_loss did not improve from 4.10854
# Epoch 132/200
#
# Epoch 00132: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 3.9673 - val_loss: 4.1143
#
# Epoch 00132: val_loss did not improve from 4.10854
# Epoch 133/200
#
# Epoch 00133: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 4.1079 - val_loss: 4.1145
#
# Epoch 00133: val_loss did not improve from 4.10854
# Epoch 134/200
#
# Epoch 00134: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0417 - val_loss: 4.1129
#
# Epoch 00134: val_loss did not improve from 4.10854
# Epoch 135/200
#
# Epoch 00135: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 43s 4s/step - loss: 3.9707 - val_loss: 4.1153
#
# Epoch 00135: val_loss did not improve from 4.10854
# Epoch 136/200
#
# Epoch 00136: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 40s 4s/step - loss: 3.9365 - val_loss: 4.1170
#
# Epoch 00136: val_loss did not improve from 4.10854
# Epoch 137/200
#
# Epoch 00137: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 3.9669 - val_loss: 4.1166
#
# Epoch 00137: val_loss did not improve from 4.10854
# Epoch 138/200
#
# Epoch 00138: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 3.8685 - val_loss: 4.1158
#
# Epoch 00138: val_loss did not improve from 4.10854
# Epoch 139/200
#
# Epoch 00139: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 41s 4s/step - loss: 3.9813 - val_loss: 4.1152
#
# Epoch 00139: val_loss did not improve from 4.10854
# Epoch 140/200
#
# Epoch 00140: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 4.0049 - val_loss: 4.1144
#
# Epoch 00140: val_loss did not improve from 4.10854
# Epoch 141/200
#
# Epoch 00141: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 4s/step - loss: 3.9359 - val_loss: 4.1150
#
# Epoch 00141: val_loss did not improve from 4.10854
# Epoch 142/200
#
# Epoch 00142: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 3.9135 - val_loss: 4.1151
#
# Epoch 00142: val_loss did not improve from 4.10854
# Epoch 143/200
#
# Epoch 00143: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 43s 4s/step - loss: 3.8701 - val_loss: 4.1159
#
# Epoch 00143: val_loss did not improve from 4.10854
# Epoch 144/200
#
# Epoch 00144: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 4.0265 - val_loss: 4.1175
#
# Epoch 00144: val_loss did not improve from 4.10854
# Epoch 145/200
#
# Epoch 00145: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 41s 4s/step - loss: 3.9355 - val_loss: 4.1205
#
# Epoch 00145: val_loss did not improve from 4.10854
# Epoch 146/200
#
# Epoch 00146: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 3.8702 - val_loss: 4.1183
#
# Epoch 00146: val_loss did not improve from 4.10854
# Epoch 147/200
#
# Epoch 00147: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 4.1948 - val_loss: 4.1178
#
# Epoch 00147: val_loss did not improve from 4.10854
# Epoch 148/200
#
# Epoch 00148: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 43s 4s/step - loss: 3.9612 - val_loss: 4.1166
#
# Epoch 00148: val_loss did not improve from 4.10854
# Epoch 149/200
#
# Epoch 00149: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 4s/step - loss: 3.9057 - val_loss: 4.1158
#
# Epoch 00149: val_loss did not improve from 4.10854
# Epoch 150/200
#
# Epoch 00150: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 4.0603 - val_loss: 4.1153
#
# Epoch 00150: val_loss did not improve from 4.10854
# Epoch 151/200
#
# Epoch 00151: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 4.0565 - val_loss: 4.1157
#
# Epoch 00151: val_loss did not improve from 4.10854
# Epoch 152/200
#
# Epoch 00152: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 4.0425 - val_loss: 4.1153
#
# Epoch 00152: val_loss did not improve from 4.10854
# Epoch 153/200
#
# Epoch 00153: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 3.9324 - val_loss: 4.1152
#
# Epoch 00153: val_loss did not improve from 4.10854
# Epoch 154/200
#
# Epoch 00154: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 4.2095 - val_loss: 4.1161
#
# Epoch 00154: val_loss did not improve from 4.10854
# Epoch 155/200
#
# Epoch 00155: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 3.9717 - val_loss: 4.1164
#
# Epoch 00155: val_loss did not improve from 4.10854
# Epoch 156/200
#
# Epoch 00156: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 3.9675 - val_loss: 4.1156
#
# Epoch 00156: val_loss did not improve from 4.10854
# Epoch 157/200
#
# Epoch 00157: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 4.0856 - val_loss: 4.1148
#
# Epoch 00157: val_loss did not improve from 4.10854
# Epoch 158/200
#
# Epoch 00158: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 4.1385 - val_loss: 4.1148
#
# Epoch 00158: val_loss did not improve from 4.10854
# Epoch 159/200
#
# Epoch 00159: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 41s 4s/step - loss: 4.0964 - val_loss: 4.1142
#
# Epoch 00159: val_loss did not improve from 4.10854
# Epoch 160/200
#
# Epoch 00160: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 48s 5s/step - loss: 4.1078 - val_loss: 4.1142
#
# Epoch 00160: val_loss did not improve from 4.10854
# Epoch 161/200
#
# Epoch 00161: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 3.8978 - val_loss: 4.1119
#
# Epoch 00161: val_loss did not improve from 4.10854
# Epoch 162/200
#
# Epoch 00162: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 47s 5s/step - loss: 4.1247 - val_loss: 4.1115
#
# Epoch 00162: val_loss did not improve from 4.10854
# Epoch 163/200
#
# Epoch 00163: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 47s 5s/step - loss: 4.0680 - val_loss: 4.1131
#
# Epoch 00163: val_loss did not improve from 4.10854
# Epoch 164/200
#
# Epoch 00164: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 4s/step - loss: 4.0777 - val_loss: 4.1131
#
# Epoch 00164: val_loss did not improve from 4.10854
# Epoch 165/200
#
# Epoch 00165: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0071 - val_loss: 4.1125
#
# Epoch 00165: val_loss did not improve from 4.10854
# Epoch 166/200
#
# Epoch 00166: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0542 - val_loss: 4.1117
#
# Epoch 00166: val_loss did not improve from 4.10854
# Epoch 167/200
#
# Epoch 00167: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 3.9079 - val_loss: 4.1121
#
# Epoch 00167: val_loss did not improve from 4.10854
# Epoch 168/200
#
# Epoch 00168: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 4.1930 - val_loss: 4.1136
#
# Epoch 00168: val_loss did not improve from 4.10854
# Epoch 169/200
#
# Epoch 00169: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 49s 5s/step - loss: 4.1136 - val_loss: 4.1151
#
# Epoch 00169: val_loss did not improve from 4.10854
# Epoch 170/200
#
# Epoch 00170: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 47s 5s/step - loss: 3.9955 - val_loss: 4.1129
#
# Epoch 00170: val_loss did not improve from 4.10854
# Epoch 171/200
#
# Epoch 00171: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.1784 - val_loss: 4.1128
#
# Epoch 00171: val_loss did not improve from 4.10854
# Epoch 172/200
#
# Epoch 00172: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0166 - val_loss: 4.1113
#
# Epoch 00172: val_loss did not improve from 4.10854
# Epoch 173/200
#
# Epoch 00173: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 3.9641 - val_loss: 4.1083
#
# Epoch 00173: val_loss improved from 4.10854 to 4.10826, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 174/200
#
# Epoch 00174: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 4.1752 - val_loss: 4.1091
#
# Epoch 00174: val_loss did not improve from 4.10826
# Epoch 175/200
#
# Epoch 00175: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 41s 4s/step - loss: 4.0269 - val_loss: 4.1104
#
# Epoch 00175: val_loss did not improve from 4.10826
# Epoch 176/200
#
# Epoch 00176: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 4.0163 - val_loss: 4.1105
#
# Epoch 00176: val_loss did not improve from 4.10826
# Epoch 177/200
#
# Epoch 00177: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 47s 5s/step - loss: 3.9529 - val_loss: 4.1102
#
# Epoch 00177: val_loss did not improve from 4.10826
# Epoch 178/200
#
# Epoch 00178: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 46s 5s/step - loss: 4.0552 - val_loss: 4.1108
#
# Epoch 00178: val_loss did not improve from 4.10826
# Epoch 179/200
#
# Epoch 00179: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 50s 5s/step - loss: 4.0732 - val_loss: 4.1106
#
# Epoch 00179: val_loss did not improve from 4.10826
# Epoch 180/200
#
# Epoch 00180: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0023 - val_loss: 4.1096
#
# Epoch 00180: val_loss did not improve from 4.10826
# Epoch 181/200
#
# Epoch 00181: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 4s/step - loss: 3.9401 - val_loss: 4.1087
#
# Epoch 00181: val_loss did not improve from 4.10826
# Epoch 182/200
#
# Epoch 00182: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 41s 4s/step - loss: 3.9966 - val_loss: 4.1084
#
# Epoch 00182: val_loss did not improve from 4.10826
# Epoch 183/200
#
# Epoch 00183: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 43s 4s/step - loss: 4.0359 - val_loss: 4.1097
#
# Epoch 00183: val_loss did not improve from 4.10826
# Epoch 184/200
#
# Epoch 00184: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 47s 5s/step - loss: 3.9750 - val_loss: 4.1087
#
# Epoch 00184: val_loss did not improve from 4.10826
# Epoch 185/200
#
# Epoch 00185: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 3.9703 - val_loss: 4.1087
#
# Epoch 00185: val_loss did not improve from 4.10826
# Epoch 186/200
#
# Epoch 00186: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 4.1232 - val_loss: 4.1084
#
# Epoch 00186: val_loss did not improve from 4.10826
# Epoch 187/200
#
# Epoch 00187: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 4.0670 - val_loss: 4.1070
#
# Epoch 00187: val_loss improved from 4.10826 to 4.10704, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 188/200
#
# Epoch 00188: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 42s 4s/step - loss: 3.8626 - val_loss: 4.1062
#
# Epoch 00188: val_loss improved from 4.10704 to 4.10616, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 189/200
#
# Epoch 00189: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 37s 4s/step - loss: 3.9379 - val_loss: 4.1043
#
# Epoch 00189: val_loss improved from 4.10616 to 4.10435, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 190/200
#
# Epoch 00190: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 4.0437 - val_loss: 4.1045
#
# Epoch 00190: val_loss did not improve from 4.10435
# Epoch 191/200
#
# Epoch 00191: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 5s/step - loss: 4.1793 - val_loss: 4.1041
#
# Epoch 00191: val_loss improved from 4.10435 to 4.10407, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 192/200
#
# Epoch 00192: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 43s 4s/step - loss: 3.9259 - val_loss: 4.1032
#
# Epoch 00192: val_loss improved from 4.10407 to 4.10316, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 193/200
#
# Epoch 00193: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 43s 4s/step - loss: 3.8951 - val_loss: 4.1036
#
# Epoch 00193: val_loss did not improve from 4.10316
# Epoch 194/200
#
# Epoch 00194: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 43s 4s/step - loss: 4.0106 - val_loss: 4.1046
#
# Epoch 00194: val_loss did not improve from 4.10316
# Epoch 195/200
#
# Epoch 00195: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 45s 4s/step - loss: 3.9276 - val_loss: 4.1030
#
# Epoch 00195: val_loss improved from 4.10316 to 4.10299, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 196/200
#
# Epoch 00196: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 3.8366 - val_loss: 4.1027
#
# Epoch 00196: val_loss improved from 4.10299 to 4.10268, saving model to /home/aldo/Documents/weights/models/ssd_mobilenetv1/ssd300_mobilenetv1_pascal-cic.h5
# Epoch 197/200
#
# Epoch 00197: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 43s 4s/step - loss: 4.0181 - val_loss: 4.1037
#
# Epoch 00197: val_loss did not improve from 4.10268
# Epoch 198/200
#
# Epoch 00198: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 44s 4s/step - loss: 4.0345 - val_loss: 4.1054
#
# Epoch 00198: val_loss did not improve from 4.10268
# Epoch 199/200
#
# Epoch 00199: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 40s 4s/step - loss: 3.8854 - val_loss: 4.1063
#
# Epoch 00199: val_loss did not improve from 4.10268
# Epoch 200/200
#
# Epoch 00200: LearningRateScheduler setting learning rate to 1e-05.
# 10/10 [==============================] - 40s 4s/step - loss: 3.9180 - val_loss: 4.1060
#
# Epoch 00200: val_loss did not improve from 4.10268

# %%
model_checkpoint.best
# Out:
# 3.6877621371915468

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(data_path + 'history/ssd300_adam_vgg13_bn/ssd300_vgg_13_pascal.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123 entries, 0 to 122
# Data columns (total 3 columns):
# epoch       123 non-null int64
# loss        123 non-null float64
# val_loss    123 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 3.0 KB

# %%
plt.plot(df['epoch'], df['loss'])
plt.plot(df['epoch'], df['val_loss'])

# %%
model_checkpoint.best
# Out:
# 3.6877621371915468
