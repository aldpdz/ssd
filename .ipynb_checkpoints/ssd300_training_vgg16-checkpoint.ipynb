# %%
# libraries
import os
import json
import numpy as np
import pandas as pd
from extra_files import helper as hp
from imageio import imwrite, imread
from skimage.transform import resize

# %%
# File paths
data_path = '/home/aldo/Documents/data-cic/'
preprocess_path = data_path + 'preprocess_data'

# %% [markdown]
# ## Training SSD300 trained with vgg16 backbone trained

# %%
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.models import load_model
from math import ceil
import numpy as np
from matplotlib import pyplot as plt

from models.keras_ssd300 import ssd_300
from keras_loss_function.keras_ssd_loss import SSDLoss
from keras_layers.keras_layer_AnchorBoxes import AnchorBoxes
from keras_layers.keras_layer_DecodeDetections import DecodeDetections
from keras_layers.keras_layer_DecodeDetectionsFast import DecodeDetectionsFast
from keras_layers.keras_layer_L2Normalization import L2Normalization

from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast

from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

from extra_files.f1_callback import F1_callback as f1_call
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /home/aldo/Documents/ssd/data_generator/object_detection_2d_data_generator.py:43: UserWarning: 'BeautifulSoup' module is missing. The XML-parser will be unavailable.
#   warnings.warn("'BeautifulSoup' module is missing. The XML-parser will be unavailable.")

# %% [markdown]
# ### Parameters (original SSD300 architecture)

# %%
## Parameteres needed for ssd_300() and SSDInputEncoder()

img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 1 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
scales_pascal = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05] # The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales = scales_pascal
aspect_ratios = [[1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters
two_boxes_for_ar1 = True
steps = [8, 16, 32, 64, 100, 300] # The space between two adjacent anchor box center points for each predictor layer.
offsets = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5] # The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %% [markdown]
# ## Create new model with SSD weights

# %%
# 1: Build the Keras model.

K.clear_session() # Clear previous models from memory.

model = ssd_300(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                subtract_mean=mean_color,
                swap_channels=swap_channels)

# 2: Load some weights into the model.

# TODO: Set the path to the weights you want to load.
weights_path = '../weights/VGG_ILSVRC_16_layers_fc_reduced.h5'

model.load_weights(weights_path, by_name=True)

# 3: Instantiate an optimizer and the SSD loss function and compile the model.
#    If you want to follow the original Caffe implementation, use the preset SGD
#    optimizer, otherwise I'd recommend the commented-out Adam optimizer.

adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
# sgd = SGD(lr=0.001, momentum=0.9, decay=0.0, nesterov=False)

ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)

model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 300, 300, 3)  0
# __________________________________________________________________________________________________
# identity_layer (Lambda)         (None, 300, 300, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# input_mean_normalization (Lambd (None, 300, 300, 3)  0           identity_layer[0][0]
# __________________________________________________________________________________________________
# input_channel_swap (Lambda)     (None, 300, 300, 3)  0           input_mean_normalization[0][0]
# __________________________________________________________________________________________________
# conv1_1 (Conv2D)                (None, 300, 300, 64) 1792        input_channel_swap[0][0]
# __________________________________________________________________________________________________
# conv1_2 (Conv2D)                (None, 300, 300, 64) 36928       conv1_1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 150, 150, 64) 0           conv1_2[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv2D)                (None, 150, 150, 128 73856       pool1[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv2D)                (None, 150, 150, 128 147584      conv2_1[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 75, 75, 128)  0           conv2_2[0][0]
# __________________________________________________________________________________________________
# conv3_1 (Conv2D)                (None, 75, 75, 256)  295168      pool2[0][0]
# __________________________________________________________________________________________________
# conv3_2 (Conv2D)                (None, 75, 75, 256)  590080      conv3_1[0][0]
# __________________________________________________________________________________________________
# conv3_3 (Conv2D)                (None, 75, 75, 256)  590080      conv3_2[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 38, 38, 256)  0           conv3_3[0][0]
# __________________________________________________________________________________________________
# conv4_1 (Conv2D)                (None, 38, 38, 512)  1180160     pool3[0][0]
# __________________________________________________________________________________________________
# conv4_2 (Conv2D)                (None, 38, 38, 512)  2359808     conv4_1[0][0]
# __________________________________________________________________________________________________
# conv4_3 (Conv2D)                (None, 38, 38, 512)  2359808     conv4_2[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 19, 19, 512)  0           conv4_3[0][0]
# __________________________________________________________________________________________________
# conv5_1 (Conv2D)                (None, 19, 19, 512)  2359808     pool4[0][0]
# __________________________________________________________________________________________________
# conv5_2 (Conv2D)                (None, 19, 19, 512)  2359808     conv5_1[0][0]
# __________________________________________________________________________________________________
# conv5_3 (Conv2D)                (None, 19, 19, 512)  2359808     conv5_2[0][0]
# __________________________________________________________________________________________________
# pool5 (MaxPooling2D)            (None, 19, 19, 512)  0           conv5_3[0][0]
# __________________________________________________________________________________________________
# fc6 (Conv2D)                    (None, 19, 19, 1024) 4719616     pool5[0][0]
# __________________________________________________________________________________________________
# fc7 (Conv2D)                    (None, 19, 19, 1024) 1049600     fc6[0][0]
# __________________________________________________________________________________________________
# conv6_1 (Conv2D)                (None, 19, 19, 256)  262400      fc7[0][0]
# __________________________________________________________________________________________________
# conv6_padding (ZeroPadding2D)   (None, 21, 21, 256)  0           conv6_1[0][0]
# __________________________________________________________________________________________________
# conv6_2 (Conv2D)                (None, 10, 10, 512)  1180160     conv6_padding[0][0]
# __________________________________________________________________________________________________
# conv7_1 (Conv2D)                (None, 10, 10, 128)  65664       conv6_2[0][0]
# __________________________________________________________________________________________________
# conv7_padding (ZeroPadding2D)   (None, 12, 12, 128)  0           conv7_1[0][0]
# __________________________________________________________________________________________________
# conv7_2 (Conv2D)                (None, 5, 5, 256)    295168      conv7_padding[0][0]
# __________________________________________________________________________________________________
# conv8_1 (Conv2D)                (None, 5, 5, 128)    32896       conv7_2[0][0]
# __________________________________________________________________________________________________
# conv8_2 (Conv2D)                (None, 3, 3, 256)    295168      conv8_1[0][0]
# __________________________________________________________________________________________________
# conv9_1 (Conv2D)                (None, 3, 3, 128)    32896       conv8_2[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm (L2Normalization)  (None, 38, 38, 512)  512         conv4_3[0][0]
# __________________________________________________________________________________________________
# conv9_2 (Conv2D)                (None, 1, 1, 256)    295168      conv9_1[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_conf (Conv2D) (None, 38, 38, 8)    36872       conv4_3_norm[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_conf (Conv2D)          (None, 19, 19, 12)   110604      fc7[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_conf (Conv2D)      (None, 10, 10, 12)   55308       conv6_2[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_conf (Conv2D)      (None, 5, 5, 12)     27660       conv7_2[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_conf (Conv2D)      (None, 3, 3, 8)      18440       conv8_2[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_conf (Conv2D)      (None, 1, 1, 8)      18440       conv9_2[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_loc (Conv2D)  (None, 38, 38, 16)   73744       conv4_3_norm[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_loc (Conv2D)           (None, 19, 19, 24)   221208      fc7[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_loc (Conv2D)       (None, 10, 10, 24)   110616      conv6_2[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_loc (Conv2D)       (None, 5, 5, 24)     55320       conv7_2[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_loc (Conv2D)       (None, 3, 3, 16)     36880       conv8_2[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_loc (Conv2D)       (None, 1, 1, 16)     36880       conv9_2[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_conf_reshape  (None, 5776, 2)      0           conv4_3_norm_mbox_conf[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_conf_reshape (Reshape) (None, 2166, 2)      0           fc7_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_conf_reshape (Resh (None, 600, 2)       0           conv6_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_conf_reshape (Resh (None, 150, 2)       0           conv7_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_conf_reshape (Resh (None, 36, 2)        0           conv8_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_conf_reshape (Resh (None, 4, 2)         0           conv9_2_mbox_conf[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_priorbox (Anc (None, 38, 38, 4, 8) 0           conv4_3_norm_mbox_loc[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_priorbox (AnchorBoxes) (None, 19, 19, 6, 8) 0           fc7_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_priorbox (AnchorBo (None, 10, 10, 6, 8) 0           conv6_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_priorbox (AnchorBo (None, 5, 5, 6, 8)   0           conv7_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_priorbox (AnchorBo (None, 3, 3, 4, 8)   0           conv8_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_priorbox (AnchorBo (None, 1, 1, 4, 8)   0           conv9_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# mbox_conf (Concatenate)         (None, 8732, 2)      0           conv4_3_norm_mbox_conf_reshape[0]
#                                                                  fc7_mbox_conf_reshape[0][0]
#                                                                  conv6_2_mbox_conf_reshape[0][0]
#                                                                  conv7_2_mbox_conf_reshape[0][0]
#                                                                  conv8_2_mbox_conf_reshape[0][0]
#                                                                  conv9_2_mbox_conf_reshape[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_loc_reshape ( (None, 5776, 4)      0           conv4_3_norm_mbox_loc[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_loc_reshape (Reshape)  (None, 2166, 4)      0           fc7_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_loc_reshape (Resha (None, 600, 4)       0           conv6_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_loc_reshape (Resha (None, 150, 4)       0           conv7_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_loc_reshape (Resha (None, 36, 4)        0           conv8_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_loc_reshape (Resha (None, 4, 4)         0           conv9_2_mbox_loc[0][0]
# __________________________________________________________________________________________________
# conv4_3_norm_mbox_priorbox_resh (None, 5776, 8)      0           conv4_3_norm_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# fc7_mbox_priorbox_reshape (Resh (None, 2166, 8)      0           fc7_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv6_2_mbox_priorbox_reshape ( (None, 600, 8)       0           conv6_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv7_2_mbox_priorbox_reshape ( (None, 150, 8)       0           conv7_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv8_2_mbox_priorbox_reshape ( (None, 36, 8)        0           conv8_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# conv9_2_mbox_priorbox_reshape ( (None, 4, 8)         0           conv9_2_mbox_priorbox[0][0]
# __________________________________________________________________________________________________
# mbox_conf_softmax (Activation)  (None, 8732, 2)      0           mbox_conf[0][0]
# __________________________________________________________________________________________________
# mbox_loc (Concatenate)          (None, 8732, 4)      0           conv4_3_norm_mbox_loc_reshape[0][
#                                                                  fc7_mbox_loc_reshape[0][0]
#                                                                  conv6_2_mbox_loc_reshape[0][0]
#                                                                  conv7_2_mbox_loc_reshape[0][0]
#                                                                  conv8_2_mbox_loc_reshape[0][0]
#                                                                  conv9_2_mbox_loc_reshape[0][0]
# __________________________________________________________________________________________________
# mbox_priorbox (Concatenate)     (None, 8732, 8)      0           conv4_3_norm_mbox_priorbox_reshap
#                                                                  fc7_mbox_priorbox_reshape[0][0]
#                                                                  conv6_2_mbox_priorbox_reshape[0][
#                                                                  conv7_2_mbox_priorbox_reshape[0][
#                                                                  conv8_2_mbox_priorbox_reshape[0][
#                                                                  conv9_2_mbox_priorbox_reshape[0][
# __________________________________________________________________________________________________
# predictions (Concatenate)       (None, 8732, 14)     0           mbox_conf_softmax[0][0]
#                                                                  mbox_loc[0][0]
#                                                                  mbox_priorbox[0][0]
# ==================================================================================================
# Total params: 23,745,908
# Trainable params: 23,745,908
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Data generator for the training

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
# images_dir = data_path + 'udacity_driving_datasets'
images_dir = data_path + 'pascal_dataset'
# images_dir = data_path + 'images'

# Ground truth
# train_labels_filename = preprocess_path + '/udc.csv'
# train_labels_filename = preprocess_path + '/cic_pascal_train.csv'
# val_labels_filename   = preprocess_path + '/cic_pascal_val.csv'
train_labels_filename = preprocess_path + '/pascal_train.csv'
val_labels_filename   = preprocess_path + '/pascal_val.csv'
# train_labels_filename = preprocess_path + '/cic_train.csv'
# val_labels_filename   = preprocess_path + '/cic_val.csv'

train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

# train_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_train.h5',
#                                   resize=False,
#                                   variable_image_size=True,
#                                   verbose=True)

# val_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_val.h5',
#                                 resize=False,
#                                 variable_image_size=True,
#                                 verbose=True)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Loading images into memory: 100%|██████████| 6469/6469 [00:27<00:00, 232.89it/s]
# Loading images into memory: 100%|██████████| 2097/2097 [00:08<00:00, 249.40it/s]
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  2097

# %%
# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	  6469
# Number of images in the validation dataset:	  2097

# %%
label_val = np.load('../data-cic/preprocess_data/label_val.npy')
val_images_300 = np.load('../data-cic/preprocess_data/images_val_300x300.npy')

# %% [markdown]
# ## Remaining training parameters

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='/home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)

csv_logger = CSVLogger(filename=data_path + 'history/ssd300_adam_vgg_16/ssd300_vgg_pascal.csv',
                       separator=',',
                       append=True)

early_stopping = EarlyStopping(monitor='val_loss',
                               min_delta=0.0,
                               patience=10,
                               verbose=1)

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.2,
                                         patience=8,
                                         verbose=1,
                                         min_delta=0.001,
                                         cooldown=0,
                                         min_lr=0.00001)


f1_callback = f1_call(0.20, 
                      0.45, 
                      200, 
                      normalize_coords, 
                      img_height, 
                      img_width, 
                      val_images_300,
                      label_val, 
                      (1, 8732, 14),
                      data_path + 'history/ssd300_adam_vgg_16/ssd300_vgg_pascal_f1.csv')

callbacks = [model_checkpoint,
             csv_logger,
             early_stopping,
             reduce_learning_rate,
             f1_callback]

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 1000
steps_per_epoch = 400

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/1000
# 400/400 [==============================] - 349s 872ms/step - loss: 7.8213 - val_loss: 5.8497
#
# Epoch 00001: val_loss improved from inf to 5.84969, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0512
# Recall: 0.4472
# F1 score: 0.0918
# Improve F1 score from -inf to 0.09181537120364458
# Epoch 2/1000
# 400/400 [==============================] - 342s 856ms/step - loss: 5.5616 - val_loss: 5.2898
#
# Epoch 00002: val_loss improved from 5.84969 to 5.28983, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0459
# Recall: 0.4751
# F1 score: 0.0837
# Epoch 3/1000
# 400/400 [==============================] - 338s 846ms/step - loss: 5.0762 - val_loss: 4.9245
#
# Epoch 00003: val_loss improved from 5.28983 to 4.92449, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0446
# Recall: 0.4959
# F1 score: 0.0818
# Epoch 4/1000
# 400/400 [==============================] - 336s 840ms/step - loss: 4.8041 - val_loss: 4.7371
#
# Epoch 00004: val_loss improved from 4.92449 to 4.73708, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0372
# Recall: 0.5049
# F1 score: 0.0694
# Epoch 5/1000
# 400/400 [==============================] - 336s 840ms/step - loss: 4.6451 - val_loss: 4.6057
#
# Epoch 00005: val_loss improved from 4.73708 to 4.60570, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0538
# Recall: 0.4815
# F1 score: 0.0968
# Improve F1 score from 0.09181537120364458 to 0.09681508087832662
# Epoch 6/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 4.4744 - val_loss: 4.4413
#
# Epoch 00006: val_loss improved from 4.60570 to 4.44125, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0666
# Recall: 0.4559
# F1 score: 0.1163
# Improve F1 score from 0.09681508087832662 to 0.11627383414704767
# Epoch 7/1000
# 400/400 [==============================] - 332s 829ms/step - loss: 4.3651 - val_loss: 4.3569
#
# Epoch 00007: val_loss improved from 4.44125 to 4.35693, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0441
# Recall: 0.4981
# F1 score: 0.081
# Epoch 8/1000
# 400/400 [==============================] - 336s 839ms/step - loss: 4.3339 - val_loss: 4.2856
#
# Epoch 00008: val_loss improved from 4.35693 to 4.28562, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0435
# Recall: 0.5173
# F1 score: 0.0803
# Epoch 9/1000
# 400/400 [==============================] - 335s 838ms/step - loss: 4.2291 - val_loss: 4.2464
#
# Epoch 00009: val_loss improved from 4.28562 to 4.24637, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0419
# Recall: 0.5175
# F1 score: 0.0774
# Epoch 10/1000
# 400/400 [==============================] - 333s 832ms/step - loss: 4.1790 - val_loss: 4.1771
#
# Epoch 00010: val_loss improved from 4.24637 to 4.17713, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0735
# Recall: 0.5175
# F1 score: 0.1287
# Improve F1 score from 0.11627383414704767 to 0.12868287771344264
# Epoch 11/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 4.1283 - val_loss: 4.0817
#
# Epoch 00011: val_loss improved from 4.17713 to 4.08167, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0607
# Recall: 0.5471
# F1 score: 0.1092
# Epoch 12/1000
# 400/400 [==============================] - 333s 832ms/step - loss: 4.0803 - val_loss: 4.0891
#
# Epoch 00012: val_loss did not improve from 4.08167
# Number of images: 45
# Presicion: 0.1642
# Recall: 0.3299
# F1 score: 0.2193
# Improve F1 score from 0.12868287771344264 to 0.21925371846724603
# Epoch 13/1000
# 400/400 [==============================] - 335s 837ms/step - loss: 4.0606 - val_loss: 4.0139
#
# Epoch 00013: val_loss improved from 4.08167 to 4.01390, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0895
# Recall: 0.4896
# F1 score: 0.1514
# Epoch 14/1000
# 400/400 [==============================] - 329s 823ms/step - loss: 4.0221 - val_loss: 4.0025
#
# Epoch 00014: val_loss improved from 4.01390 to 4.00250, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.2074
# Recall: 0.4238
# F1 score: 0.2785
# Improve F1 score from 0.21925371846724603 to 0.2784786185548879
# Epoch 15/1000
# 400/400 [==============================] - 336s 840ms/step - loss: 4.0132 - val_loss: 4.0211
#
# Epoch 00015: val_loss did not improve from 4.00250
# Number of images: 45
# Presicion: 0.0478
# Recall: 0.5295
# F1 score: 0.0877
# Epoch 16/1000
# 400/400 [==============================] - 335s 837ms/step - loss: 3.9989 - val_loss: 4.0635
#
# Epoch 00016: val_loss did not improve from 4.00250
# Number of images: 45
# Presicion: 0.0856
# Recall: 0.5414
# F1 score: 0.1478
# Epoch 17/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.9900 - val_loss: 4.0265
#
# Epoch 00017: val_loss did not improve from 4.00250
# Number of images: 45
# Presicion: 0.3008
# Recall: 0.3212
# F1 score: 0.3107
# Improve F1 score from 0.2784786185548879 to 0.3106710143589507
# Epoch 18/1000
# 400/400 [==============================] - 331s 826ms/step - loss: 3.9866 - val_loss: 3.9805
#
# Epoch 00018: val_loss improved from 4.00250 to 3.98049, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.1926
# Recall: 0.4703
# F1 score: 0.2732
# Epoch 19/1000
# 400/400 [==============================] - 335s 836ms/step - loss: 3.9555 - val_loss: 3.9687
#
# Epoch 00019: val_loss improved from 3.98049 to 3.96867, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.2059
# Recall: 0.3471
# F1 score: 0.2585
# Epoch 20/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.9231 - val_loss: 3.8941
#
# Epoch 00020: val_loss improved from 3.96867 to 3.89406, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.2689
# Recall: 0.3327
# F1 score: 0.2974
# Epoch 21/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.9365 - val_loss: 4.0143
#
# Epoch 00021: val_loss did not improve from 3.89406
# Number of images: 45
# Presicion: 0.0929
# Recall: 0.4633
# F1 score: 0.1548
# Epoch 22/1000
# 400/400 [==============================] - 332s 831ms/step - loss: 3.9282 - val_loss: 3.9072
#
# Epoch 00022: val_loss did not improve from 3.89406
# Number of images: 45
# Presicion: 0.3329
# Recall: 0.3732
# F1 score: 0.3519
# Improve F1 score from 0.3106710143589507 to 0.35187489585084775
# Epoch 23/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.9079 - val_loss: 3.8581
#
# Epoch 00023: val_loss improved from 3.89406 to 3.85811, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.0602
# Recall: 0.5417
# F1 score: 0.1084
# Epoch 24/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.9140 - val_loss: 3.8821
#
# Epoch 00024: val_loss did not improve from 3.85811
# Number of images: 45
# Presicion: 0.2101
# Recall: 0.3124
# F1 score: 0.2512
# Epoch 25/1000
# 400/400 [==============================] - 332s 830ms/step - loss: 3.9008 - val_loss: 3.9498
#
# Epoch 00025: val_loss did not improve from 3.85811
# Number of images: 45
# Presicion: 0.1156
# Recall: 0.4919
# F1 score: 0.1872
# Epoch 26/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.8709 - val_loss: 3.8784
#
# Epoch 00026: val_loss did not improve from 3.85811
# Number of images: 45
# Presicion: 0.23
# Recall: 0.3671
# F1 score: 0.2828
# Epoch 27/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.8769 - val_loss: 3.8625
#
# Epoch 00027: val_loss did not improve from 3.85811
# Number of images: 45
# Presicion: 0.3552
# Recall: 0.3946
# F1 score: 0.3739
# Improve F1 score from 0.35187489585084775 to 0.3738585705003954
# Epoch 28/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.8684 - val_loss: 3.8793
#
# Epoch 00028: val_loss did not improve from 3.85811
# Number of images: 45
# Presicion: 0.3129
# Recall: 0.3052
# F1 score: 0.309
# Epoch 29/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.8650 - val_loss: 3.8742
#
# Epoch 00029: val_loss did not improve from 3.85811
# Number of images: 45
# Presicion: 0.3128
# Recall: 0.2784
# F1 score: 0.2946
# Epoch 30/1000
# 400/400 [==============================] - 329s 823ms/step - loss: 3.8409 - val_loss: 3.8908
#
# Epoch 00030: val_loss did not improve from 3.85811
# Number of images: 45
# Presicion: 0.1238
# Recall: 0.4631
# F1 score: 0.1953
# Epoch 31/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.8296 - val_loss: 3.8670
#
# Epoch 00031: val_loss did not improve from 3.85811
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Number of images: 45
# Presicion: 0.2861
# Recall: 0.3307
# F1 score: 0.3068
# Epoch 32/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.6418 - val_loss: 3.6245
#
# Epoch 00032: val_loss improved from 3.85811 to 3.62452, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.4255
# Recall: 0.3454
# F1 score: 0.3813
# Improve F1 score from 0.3738585705003954 to 0.3813106436033629
# Epoch 33/1000
# 400/400 [==============================] - 335s 837ms/step - loss: 3.5966 - val_loss: 3.5868
#
# Epoch 00033: val_loss improved from 3.62452 to 3.58680, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.4596
# Recall: 0.336
# F1 score: 0.3882
# Improve F1 score from 0.3813106436033629 to 0.38818814999536927
# Epoch 34/1000
# 400/400 [==============================] - 336s 839ms/step - loss: 3.5712 - val_loss: 3.5844
#
# Epoch 00034: val_loss improved from 3.58680 to 3.58443, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.4281
# Recall: 0.3699
# F1 score: 0.3969
# Improve F1 score from 0.38818814999536927 to 0.39687182478595767
# Epoch 35/1000
# 400/400 [==============================] - 330s 826ms/step - loss: 3.5202 - val_loss: 3.5985
#
# Epoch 00035: val_loss did not improve from 3.58443
# Number of images: 45
# Presicion: 0.4193
# Recall: 0.3454
# F1 score: 0.3788
# Epoch 36/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.5364 - val_loss: 3.5401
#
# Epoch 00036: val_loss improved from 3.58443 to 3.54006, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.458
# Recall: 0.3369
# F1 score: 0.3882
# Epoch 37/1000
# 400/400 [==============================] - 328s 821ms/step - loss: 3.5150 - val_loss: 3.5335
#
# Epoch 00037: val_loss improved from 3.54006 to 3.53346, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5127
# Recall: 0.3086
# F1 score: 0.3853
# Epoch 38/1000
# 400/400 [==============================] - 332s 830ms/step - loss: 3.5073 - val_loss: 3.5390
#
# Epoch 00038: val_loss did not improve from 3.53346
# Number of images: 45
# Presicion: 0.4712
# Recall: 0.3152
# F1 score: 0.3777
# Epoch 39/1000
# 400/400 [==============================] - 330s 825ms/step - loss: 3.4988 - val_loss: 3.5089
#
# Epoch 00039: val_loss improved from 3.53346 to 3.50893, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.4721
# Recall: 0.3777
# F1 score: 0.4197
# Improve F1 score from 0.39687182478595767 to 0.41966874298080525
# Epoch 40/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.4803 - val_loss: 3.5132
#
# Epoch 00040: val_loss did not improve from 3.50893
# Number of images: 45
# Presicion: 0.4824
# Recall: 0.3446
# F1 score: 0.402
# Epoch 41/1000
# 400/400 [==============================] - 336s 839ms/step - loss: 3.4904 - val_loss: 3.4821
#
# Epoch 00041: val_loss improved from 3.50893 to 3.48212, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.4602
# Recall: 0.3637
# F1 score: 0.4063
# Epoch 42/1000
# 400/400 [==============================] - 335s 838ms/step - loss: 3.4685 - val_loss: 3.4853
#
# Epoch 00042: val_loss did not improve from 3.48212
# Number of images: 45
# Presicion: 0.482
# Recall: 0.3296
# F1 score: 0.3915
# Epoch 43/1000
# 400/400 [==============================] - 335s 838ms/step - loss: 3.4579 - val_loss: 3.4949
#
# Epoch 00043: val_loss did not improve from 3.48212
# Number of images: 45
# Presicion: 0.4699
# Recall: 0.3158
# F1 score: 0.3777
# Epoch 44/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.4569 - val_loss: 3.5226
#
# Epoch 00044: val_loss did not improve from 3.48212
# Number of images: 45
# Presicion: 0.4815
# Recall: 0.3493
# F1 score: 0.4048
# Epoch 45/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.4628 - val_loss: 3.4766
#
# Epoch 00045: val_loss improved from 3.48212 to 3.47655, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.4842
# Recall: 0.3453
# F1 score: 0.4031
# Epoch 46/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.4418 - val_loss: 3.4459
#
# Epoch 00046: val_loss improved from 3.47655 to 3.44588, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.4715
# Recall: 0.3738
# F1 score: 0.417
# Epoch 47/1000
# 400/400 [==============================] - 332s 830ms/step - loss: 3.4352 - val_loss: 3.4911
#
# Epoch 00047: val_loss did not improve from 3.44588
# Number of images: 45
# Presicion: 0.48
# Recall: 0.3088
# F1 score: 0.3758
# Epoch 48/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.4426 - val_loss: 3.4512
#
# Epoch 00048: val_loss did not improve from 3.44588
# Number of images: 45
# Presicion: 0.5129
# Recall: 0.3304
# F1 score: 0.4019
# Epoch 49/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.4516 - val_loss: 3.4515
#
# Epoch 00049: val_loss did not improve from 3.44588
# Number of images: 45
# Presicion: 0.4641
# Recall: 0.397
# F1 score: 0.4279
# Improve F1 score from 0.41966874298080525 to 0.42788864646863767
# Epoch 50/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.4056 - val_loss: 3.4177
#
# Epoch 00050: val_loss improved from 3.44588 to 3.41770, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.4767
# Recall: 0.3475
# F1 score: 0.402
# Epoch 51/1000
# 400/400 [==============================] - 330s 825ms/step - loss: 3.4177 - val_loss: 3.4525
#
# Epoch 00051: val_loss did not improve from 3.41770
# Number of images: 45
# Presicion: 0.4857
# Recall: 0.3503
# F1 score: 0.407
# Epoch 52/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.4293 - val_loss: 3.4338
#
# Epoch 00052: val_loss did not improve from 3.41770
# Number of images: 45
# Presicion: 0.5154
# Recall: 0.3231
# F1 score: 0.3972
# Epoch 53/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.3942 - val_loss: 3.4672
#
# Epoch 00053: val_loss did not improve from 3.41770
# Number of images: 45
# Presicion: 0.4754
# Recall: 0.3545
# F1 score: 0.4061
# Epoch 54/1000
# 400/400 [==============================] - 332s 829ms/step - loss: 3.4024 - val_loss: 3.4194
#
# Epoch 00054: val_loss did not improve from 3.41770
# Number of images: 45
# Presicion: 0.5066
# Recall: 0.3641
# F1 score: 0.4237
# Epoch 55/1000
# 400/400 [==============================] - 330s 825ms/step - loss: 3.4122 - val_loss: 3.4818
#
# Epoch 00055: val_loss did not improve from 3.41770
# Number of images: 45
# Presicion: 0.4799
# Recall: 0.3368
# F1 score: 0.3958
# Epoch 56/1000
# 400/400 [==============================] - 330s 826ms/step - loss: 3.3933 - val_loss: 3.4255
#
# Epoch 00056: val_loss did not improve from 3.41770
# Number of images: 45
# Presicion: 0.5164
# Recall: 0.3377
# F1 score: 0.4084
# Epoch 57/1000
# 400/400 [==============================] - 330s 825ms/step - loss: 3.3916 - val_loss: 3.4048
#
# Epoch 00057: val_loss improved from 3.41770 to 3.40480, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.4912
# Recall: 0.4009
# F1 score: 0.4415
# Improve F1 score from 0.42788864646863767 to 0.4414862303681841
# Epoch 58/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.4027 - val_loss: 3.4824
#
# Epoch 00058: val_loss did not improve from 3.40480
# Number of images: 45
# Presicion: 0.4617
# Recall: 0.3292
# F1 score: 0.3844
# Epoch 59/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.3807 - val_loss: 3.4188
#
# Epoch 00059: val_loss did not improve from 3.40480
# Number of images: 45
# Presicion: 0.4806
# Recall: 0.3479
# F1 score: 0.4036
# Epoch 60/1000
# 400/400 [==============================] - 329s 822ms/step - loss: 3.3891 - val_loss: 3.3826
#
# Epoch 00060: val_loss improved from 3.40480 to 3.38264, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5268
# Recall: 0.3628
# F1 score: 0.4297
# Epoch 61/1000
# 400/400 [==============================] - 333s 834ms/step - loss: 3.3838 - val_loss: 3.4044
#
# Epoch 00061: val_loss did not improve from 3.38264
# Number of images: 45
# Presicion: 0.5195
# Recall: 0.3444
# F1 score: 0.4142
# Epoch 62/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.3648 - val_loss: 3.4245
#
# Epoch 00062: val_loss did not improve from 3.38264
# Number of images: 45
# Presicion: 0.5
# Recall: 0.3305
# F1 score: 0.398
# Epoch 63/1000
# 400/400 [==============================] - 329s 822ms/step - loss: 3.3596 - val_loss: 3.4104
#
# Epoch 00063: val_loss did not improve from 3.38264
# Number of images: 45
# Presicion: 0.5349
# Recall: 0.3868
# F1 score: 0.449
# Improve F1 score from 0.4414862303681841 to 0.44896686252149093
# Epoch 64/1000
# 400/400 [==============================] - 336s 840ms/step - loss: 3.3653 - val_loss: 3.3934
#
# Epoch 00064: val_loss did not improve from 3.38264
# Number of images: 45
# Presicion: 0.5191
# Recall: 0.3532
# F1 score: 0.4204
# Epoch 65/1000
# 400/400 [==============================] - 335s 837ms/step - loss: 3.3757 - val_loss: 3.3923
#
# Epoch 00065: val_loss did not improve from 3.38264
# Number of images: 45
# Presicion: 0.5208
# Recall: 0.3667
# F1 score: 0.4304
# Epoch 66/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.3424 - val_loss: 3.4375
#
# Epoch 00066: val_loss did not improve from 3.38264
# Number of images: 45
# Presicion: 0.5327
# Recall: 0.3507
# F1 score: 0.423
# Epoch 67/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.3648 - val_loss: 3.4023
#
# Epoch 00067: val_loss did not improve from 3.38264
# Number of images: 45
# Presicion: 0.5177
# Recall: 0.3574
# F1 score: 0.4229
# Epoch 68/1000
# 400/400 [==============================] - 335s 836ms/step - loss: 3.3540 - val_loss: 3.4033
#
# Epoch 00068: val_loss did not improve from 3.38264
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Number of images: 45
# Presicion: 0.5321
# Recall: 0.3288
# F1 score: 0.4064
# Epoch 69/1000
# 400/400 [==============================] - 332s 830ms/step - loss: 3.2929 - val_loss: 3.3299
#
# Epoch 00069: val_loss improved from 3.38264 to 3.32991, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5401
# Recall: 0.3581
# F1 score: 0.4307
# Epoch 70/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.2748 - val_loss: 3.3216
#
# Epoch 00070: val_loss improved from 3.32991 to 3.32160, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5479
# Recall: 0.3756
# F1 score: 0.4457
# Epoch 71/1000
# 400/400 [==============================] - 332s 830ms/step - loss: 3.2621 - val_loss: 3.3404
#
# Epoch 00071: val_loss did not improve from 3.32160
# Number of images: 45
# Presicion: 0.5522
# Recall: 0.3791
# F1 score: 0.4496
# Improve F1 score from 0.44896686252149093 to 0.4495979172260103
# Epoch 72/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2674 - val_loss: 3.3128
#
# Epoch 00072: val_loss improved from 3.32160 to 3.31278, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5427
# Recall: 0.369
# F1 score: 0.4393
# Epoch 73/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2775 - val_loss: 3.3021
#
# Epoch 00073: val_loss improved from 3.31278 to 3.30210, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5218
# Recall: 0.3759
# F1 score: 0.437
# Epoch 74/1000
# 400/400 [==============================] - 332s 831ms/step - loss: 3.2548 - val_loss: 3.3108
#
# Epoch 00074: val_loss did not improve from 3.30210
# Number of images: 45
# Presicion: 0.5608
# Recall: 0.355
# F1 score: 0.4348
# Epoch 75/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2740 - val_loss: 3.3323
#
# Epoch 00075: val_loss did not improve from 3.30210
# Number of images: 45
# Presicion: 0.5299
# Recall: 0.3677
# F1 score: 0.4342
# Epoch 76/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2571 - val_loss: 3.2951
#
# Epoch 00076: val_loss improved from 3.30210 to 3.29511, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5546
# Recall: 0.3559
# F1 score: 0.4336
# Epoch 77/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.2302 - val_loss: 3.2878
#
# Epoch 00077: val_loss improved from 3.29511 to 3.28780, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.568
# Recall: 0.3651
# F1 score: 0.4445
# Epoch 78/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2479 - val_loss: 3.2892
#
# Epoch 00078: val_loss did not improve from 3.28780
# Number of images: 45
# Presicion: 0.5471
# Recall: 0.3616
# F1 score: 0.4354
# Epoch 79/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2381 - val_loss: 3.2927
#
# Epoch 00079: val_loss did not improve from 3.28780
# Number of images: 45
# Presicion: 0.5536
# Recall: 0.376
# F1 score: 0.4478
# Epoch 80/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2535 - val_loss: 3.2918
#
# Epoch 00080: val_loss did not improve from 3.28780
# Number of images: 45
# Presicion: 0.5562
# Recall: 0.3585
# F1 score: 0.436
# Epoch 81/1000
# 400/400 [==============================] - 332s 831ms/step - loss: 3.2483 - val_loss: 3.2849
#
# Epoch 00081: val_loss improved from 3.28780 to 3.28491, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5661
# Recall: 0.3648
# F1 score: 0.4437
# Epoch 82/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2558 - val_loss: 3.2982
#
# Epoch 00082: val_loss did not improve from 3.28491
# Number of images: 45
# Presicion: 0.5279
# Recall: 0.3569
# F1 score: 0.4259
# Epoch 83/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2247 - val_loss: 3.2786
#
# Epoch 00083: val_loss improved from 3.28491 to 3.27856, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5751
# Recall: 0.3847
# F1 score: 0.461
# Improve F1 score from 0.4495979172260103 to 0.46103917441921977
# Epoch 84/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2387 - val_loss: 3.2804
#
# Epoch 00084: val_loss did not improve from 3.27856
# Number of images: 45
# Presicion: 0.5448
# Recall: 0.3711
# F1 score: 0.4414
# Epoch 85/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.2401 - val_loss: 3.2841
#
# Epoch 00085: val_loss did not improve from 3.27856
# Number of images: 45
# Presicion: 0.5314
# Recall: 0.3734
# F1 score: 0.4386
# Epoch 86/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2274 - val_loss: 3.2948
#
# Epoch 00086: val_loss did not improve from 3.27856
# Number of images: 45
# Presicion: 0.5239
# Recall: 0.3733
# F1 score: 0.436
# Epoch 87/1000
# 400/400 [==============================] - 336s 840ms/step - loss: 3.2387 - val_loss: 3.2678
#
# Epoch 00087: val_loss improved from 3.27856 to 3.26776, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5625
# Recall: 0.3882
# F1 score: 0.4594
# Epoch 88/1000
# 400/400 [==============================] - 330s 824ms/step - loss: 3.2291 - val_loss: 3.2869
#
# Epoch 00088: val_loss did not improve from 3.26776
# Number of images: 45
# Presicion: 0.5456
# Recall: 0.3679
# F1 score: 0.4395
# Epoch 89/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.2271 - val_loss: 3.2889
#
# Epoch 00089: val_loss did not improve from 3.26776
# Number of images: 45
# Presicion: 0.5277
# Recall: 0.3651
# F1 score: 0.4316
# Epoch 90/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.2256 - val_loss: 3.2756
#
# Epoch 00090: val_loss did not improve from 3.26776
# Number of images: 45
# Presicion: 0.5373
# Recall: 0.3271
# F1 score: 0.4066
# Epoch 91/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.2406 - val_loss: 3.2700
#
# Epoch 00091: val_loss did not improve from 3.26776
# Number of images: 45
# Presicion: 0.5587
# Recall: 0.3798
# F1 score: 0.4522
# Epoch 92/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.2252 - val_loss: 3.2729
#
# Epoch 00092: val_loss did not improve from 3.26776
# Number of images: 45
# Presicion: 0.5413
# Recall: 0.3799
# F1 score: 0.4465
# Epoch 93/1000
# 400/400 [==============================] - 329s 823ms/step - loss: 3.2111 - val_loss: 3.2698
#
# Epoch 00093: val_loss did not improve from 3.26776
# Number of images: 45
# Presicion: 0.5318
# Recall: 0.3503
# F1 score: 0.4224
# Epoch 94/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.2357 - val_loss: 3.3057
#
# Epoch 00094: val_loss did not improve from 3.26776
# Number of images: 45
# Presicion: 0.5272
# Recall: 0.3506
# F1 score: 0.4211
# Epoch 95/1000
# 400/400 [==============================] - 331s 828ms/step - loss: 3.2398 - val_loss: 3.2607
#
# Epoch 00095: val_loss improved from 3.26776 to 3.26069, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5373
# Recall: 0.3531
# F1 score: 0.4262
# Epoch 96/1000
# 400/400 [==============================] - 329s 823ms/step - loss: 3.2226 - val_loss: 3.2690
#
# Epoch 00096: val_loss did not improve from 3.26069
# Number of images: 45
# Presicion: 0.5673
# Recall: 0.3884
# F1 score: 0.4611
# Improve F1 score from 0.46103917441921977 to 0.4611197429456524
# Epoch 97/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.2088 - val_loss: 3.2585
#
# Epoch 00097: val_loss improved from 3.26069 to 3.25846, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5705
# Recall: 0.3809
# F1 score: 0.4568
# Epoch 98/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.2293 - val_loss: 3.2857
#
# Epoch 00098: val_loss did not improve from 3.25846
# Number of images: 45
# Presicion: 0.5301
# Recall: 0.3649
# F1 score: 0.4323
# Epoch 99/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.2332 - val_loss: 3.2847
#
# Epoch 00099: val_loss did not improve from 3.25846
# Number of images: 45
# Presicion: 0.5425
# Recall: 0.3541
# F1 score: 0.4285
# Epoch 100/1000
# 400/400 [==============================] - 332s 830ms/step - loss: 3.2056 - val_loss: 3.2625
#
# Epoch 00100: val_loss did not improve from 3.25846
# Number of images: 45
# Presicion: 0.5748
# Recall: 0.3569
# F1 score: 0.4404
# Epoch 101/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.2177 - val_loss: 3.2790
#
# Epoch 00101: val_loss did not improve from 3.25846
# Number of images: 45
# Presicion: 0.5679
# Recall: 0.3103
# F1 score: 0.4013
# Epoch 102/1000
# 400/400 [==============================] - 331s 827ms/step - loss: 3.2052 - val_loss: 3.2668
#
# Epoch 00102: val_loss did not improve from 3.25846
# Number of images: 45
# Presicion: 0.5639
# Recall: 0.3822
# F1 score: 0.4556
# Epoch 103/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.1975 - val_loss: 3.2501
#
# Epoch 00103: val_loss improved from 3.25846 to 3.25009, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5399
# Recall: 0.3707
# F1 score: 0.4396
# Epoch 104/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.2049 - val_loss: 3.2557
#
# Epoch 00104: val_loss did not improve from 3.25009
# Number of images: 45
# Presicion: 0.5502
# Recall: 0.3907
# F1 score: 0.4569
# Epoch 105/1000
# 400/400 [==============================] - 332s 831ms/step - loss: 3.2038 - val_loss: 3.2476
#
# Epoch 00105: val_loss improved from 3.25009 to 3.24758, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5689
# Recall: 0.377
# F1 score: 0.4535
# Epoch 106/1000
# 400/400 [==============================] - 332s 831ms/step - loss: 3.2140 - val_loss: 3.2659
#
# Epoch 00106: val_loss did not improve from 3.24758
# Number of images: 45
# Presicion: 0.5485
# Recall: 0.3791
# F1 score: 0.4484
# Epoch 107/1000
# 400/400 [==============================] - 330s 825ms/step - loss: 3.1973 - val_loss: 3.2514
#
# Epoch 00107: val_loss did not improve from 3.24758
# Number of images: 45
# Presicion: 0.5879
# Recall: 0.3476
# F1 score: 0.4369
# Epoch 108/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.2049 - val_loss: 3.2732
#
# Epoch 00108: val_loss did not improve from 3.24758
# Number of images: 45
# Presicion: 0.5615
# Recall: 0.3761
# F1 score: 0.4505
# Epoch 109/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.2070 - val_loss: 3.2406
#
# Epoch 00109: val_loss improved from 3.24758 to 3.24063, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.585
# Recall: 0.3999
# F1 score: 0.4751
# Improve F1 score from 0.4611197429456524 to 0.47506582759672294
# Epoch 110/1000
# 400/400 [==============================] - 333s 831ms/step - loss: 3.1945 - val_loss: 3.2893
#
# Epoch 00110: val_loss did not improve from 3.24063
# Number of images: 45
# Presicion: 0.5698
# Recall: 0.3647
# F1 score: 0.4447
# Epoch 111/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.1947 - val_loss: 3.2364
#
# Epoch 00111: val_loss improved from 3.24063 to 3.23640, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.605
# Recall: 0.3731
# F1 score: 0.4616
# Epoch 112/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.2067 - val_loss: 3.2563
#
# Epoch 00112: val_loss did not improve from 3.23640
# Number of images: 45
# Presicion: 0.5835
# Recall: 0.3762
# F1 score: 0.4575
# Epoch 113/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1990 - val_loss: 3.2471
#
# Epoch 00113: val_loss did not improve from 3.23640
# Number of images: 45
# Presicion: 0.5688
# Recall: 0.3821
# F1 score: 0.4571
# Epoch 114/1000
# 400/400 [==============================] - 332s 831ms/step - loss: 3.1938 - val_loss: 3.2446
#
# Epoch 00114: val_loss did not improve from 3.23640
# Number of images: 45
# Presicion: 0.5925
# Recall: 0.3794
# F1 score: 0.4626
# Epoch 115/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.1977 - val_loss: 3.2491
#
# Epoch 00115: val_loss did not improve from 3.23640
# Number of images: 45
# Presicion: 0.5747
# Recall: 0.4052
# F1 score: 0.4753
# Improve F1 score from 0.47506582759672294 to 0.4753090318551012
# Epoch 116/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1939 - val_loss: 3.2488
#
# Epoch 00116: val_loss did not improve from 3.23640
# Number of images: 45
# Presicion: 0.5726
# Recall: 0.3938
# F1 score: 0.4666
# Epoch 117/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.1947 - val_loss: 3.2694
#
# Epoch 00117: val_loss did not improve from 3.23640
# Number of images: 45
# Presicion: 0.6123
# Recall: 0.3761
# F1 score: 0.4659
# Epoch 118/1000
# 400/400 [==============================] - 330s 826ms/step - loss: 3.1938 - val_loss: 3.2458
#
# Epoch 00118: val_loss did not improve from 3.23640
# Number of images: 45
# Presicion: 0.5756
# Recall: 0.4059
# F1 score: 0.4761
# Improve F1 score from 0.4753090318551012 to 0.47605648359269614
# Epoch 119/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.1924 - val_loss: 3.2344
#
# Epoch 00119: val_loss improved from 3.23640 to 3.23443, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5814
# Recall: 0.38
# F1 score: 0.4596
# Epoch 120/1000
# 400/400 [==============================] - 333s 834ms/step - loss: 3.1911 - val_loss: 3.2629
#
# Epoch 00120: val_loss did not improve from 3.23443
# Number of images: 45
# Presicion: 0.5468
# Recall: 0.362
# F1 score: 0.4356
# Epoch 121/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1802 - val_loss: 3.2509
#
# Epoch 00121: val_loss did not improve from 3.23443
# Number of images: 45
# Presicion: 0.5719
# Recall: 0.3582
# F1 score: 0.4405
# Epoch 122/1000
# 400/400 [==============================] - 329s 824ms/step - loss: 3.1910 - val_loss: 3.2429
#
# Epoch 00122: val_loss did not improve from 3.23443
# Number of images: 45
# Presicion: 0.5356
# Recall: 0.395
# F1 score: 0.4547
# Epoch 123/1000
# 400/400 [==============================] - 330s 824ms/step - loss: 3.1853 - val_loss: 3.2326
#
# Epoch 00123: val_loss improved from 3.23443 to 3.23257, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5695
# Recall: 0.3777
# F1 score: 0.4542
# Epoch 124/1000
# 400/400 [==============================] - 335s 836ms/step - loss: 3.1982 - val_loss: 3.2378
#
# Epoch 00124: val_loss did not improve from 3.23257
# Number of images: 45
# Presicion: 0.5491
# Recall: 0.3815
# F1 score: 0.4502
# Epoch 125/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.1744 - val_loss: 3.2296
#
# Epoch 00125: val_loss improved from 3.23257 to 3.22955, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5596
# Recall: 0.3963
# F1 score: 0.464
# Epoch 126/1000
# 400/400 [==============================] - 330s 824ms/step - loss: 3.1846 - val_loss: 3.2335
#
# Epoch 00126: val_loss did not improve from 3.22955
# Number of images: 45
# Presicion: 0.5802
# Recall: 0.371
# F1 score: 0.4526
# Epoch 127/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1895 - val_loss: 3.2417
#
# Epoch 00127: val_loss did not improve from 3.22955
# Number of images: 45
# Presicion: 0.5466
# Recall: 0.3865
# F1 score: 0.4528
# Epoch 128/1000
# 400/400 [==============================] - 329s 823ms/step - loss: 3.1930 - val_loss: 3.2411
#
# Epoch 00128: val_loss did not improve from 3.22955
# Number of images: 45
# Presicion: 0.5336
# Recall: 0.4019
# F1 score: 0.4585
# Epoch 129/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.1749 - val_loss: 3.2385
#
# Epoch 00129: val_loss did not improve from 3.22955
# Number of images: 45
# Presicion: 0.5564
# Recall: 0.3749
# F1 score: 0.448
# Epoch 130/1000
# 400/400 [==============================] - 335s 837ms/step - loss: 3.1797 - val_loss: 3.2620
#
# Epoch 00130: val_loss did not improve from 3.22955
# Number of images: 45
# Presicion: 0.5654
# Recall: 0.383
# F1 score: 0.4566
# Epoch 131/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1801 - val_loss: 3.2528
#
# Epoch 00131: val_loss did not improve from 3.22955
# Number of images: 45
# Presicion: 0.5512
# Recall: 0.4077
# F1 score: 0.4687
# Epoch 132/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1729 - val_loss: 3.2273
#
# Epoch 00132: val_loss improved from 3.22955 to 3.22731, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5849
# Recall: 0.3682
# F1 score: 0.4519
# Epoch 133/1000
# 400/400 [==============================] - 331s 828ms/step - loss: 3.1803 - val_loss: 3.2260
#
# Epoch 00133: val_loss improved from 3.22731 to 3.22600, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5599
# Recall: 0.3838
# F1 score: 0.4554
# Epoch 134/1000
# 400/400 [==============================] - 333s 834ms/step - loss: 3.1771 - val_loss: 3.2250
#
# Epoch 00134: val_loss improved from 3.22600 to 3.22504, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5809
# Recall: 0.384
# F1 score: 0.4623
# Epoch 135/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1868 - val_loss: 3.2341
#
# Epoch 00135: val_loss did not improve from 3.22504
# Number of images: 45
# Presicion: 0.556
# Recall: 0.3797
# F1 score: 0.4512
# Epoch 136/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.1866 - val_loss: 3.2219
#
# Epoch 00136: val_loss improved from 3.22504 to 3.22193, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5745
# Recall: 0.3823
# F1 score: 0.4591
# Epoch 137/1000
# 400/400 [==============================] - 329s 824ms/step - loss: 3.1710 - val_loss: 3.2309
#
# Epoch 00137: val_loss did not improve from 3.22193
# Number of images: 45
# Presicion: 0.5767
# Recall: 0.3827
# F1 score: 0.4601
# Epoch 138/1000
# 400/400 [==============================] - 333s 831ms/step - loss: 3.1688 - val_loss: 3.2296
#
# Epoch 00138: val_loss did not improve from 3.22193
# Number of images: 45
# Presicion: 0.5624
# Recall: 0.3969
# F1 score: 0.4654
# Epoch 139/1000
# 400/400 [==============================] - 329s 824ms/step - loss: 3.1825 - val_loss: 3.2181
#
# Epoch 00139: val_loss improved from 3.22193 to 3.21808, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5911
# Recall: 0.3831
# F1 score: 0.4649
# Epoch 140/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.1639 - val_loss: 3.2261
#
# Epoch 00140: val_loss did not improve from 3.21808
# Number of images: 45
# Presicion: 0.5513
# Recall: 0.3976
# F1 score: 0.462
# Epoch 141/1000
# 400/400 [==============================] - 330s 824ms/step - loss: 3.1628 - val_loss: 3.2487
#
# Epoch 00141: val_loss did not improve from 3.21808
# Number of images: 45
# Presicion: 0.5593
# Recall: 0.3956
# F1 score: 0.4634
# Epoch 142/1000
# 400/400 [==============================] - 332s 829ms/step - loss: 3.1621 - val_loss: 3.2269
#
# Epoch 00142: val_loss did not improve from 3.21808
# Number of images: 45
# Presicion: 0.5837
# Recall: 0.3949
# F1 score: 0.4711
# Epoch 143/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1650 - val_loss: 3.2323
#
# Epoch 00143: val_loss did not improve from 3.21808
# Number of images: 45
# Presicion: 0.5741
# Recall: 0.3927
# F1 score: 0.4664
# Epoch 144/1000
# 400/400 [==============================] - 332s 829ms/step - loss: 3.1687 - val_loss: 3.2058
#
# Epoch 00144: val_loss improved from 3.21808 to 3.20578, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5767
# Recall: 0.3764
# F1 score: 0.4555
# Epoch 145/1000
# 400/400 [==============================] - 331s 829ms/step - loss: 3.1695 - val_loss: 3.2523
#
# Epoch 00145: val_loss did not improve from 3.20578
# Number of images: 45
# Presicion: 0.5781
# Recall: 0.3628
# F1 score: 0.4458
# Epoch 146/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1525 - val_loss: 3.2232
#
# Epoch 00146: val_loss did not improve from 3.20578
# Number of images: 45
# Presicion: 0.573
# Recall: 0.4059
# F1 score: 0.4751
# Epoch 147/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1589 - val_loss: 3.2275
#
# Epoch 00147: val_loss did not improve from 3.20578
# Number of images: 45
# Presicion: 0.5425
# Recall: 0.3882
# F1 score: 0.4526
# Epoch 148/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1554 - val_loss: 3.2435
#
# Epoch 00148: val_loss did not improve from 3.20578
# Number of images: 45
# Presicion: 0.5681
# Recall: 0.3744
# F1 score: 0.4514
# Epoch 149/1000
# 400/400 [==============================] - 329s 824ms/step - loss: 3.1732 - val_loss: 3.2238
#
# Epoch 00149: val_loss did not improve from 3.20578
# Number of images: 45
# Presicion: 0.5578
# Recall: 0.3785
# F1 score: 0.451
# Epoch 150/1000
# 400/400 [==============================] - 331s 828ms/step - loss: 3.1700 - val_loss: 3.2134
#
# Epoch 00150: val_loss did not improve from 3.20578
# Number of images: 45
# Presicion: 0.5899
# Recall: 0.3651
# F1 score: 0.4511
# Epoch 151/1000
# 400/400 [==============================] - 329s 823ms/step - loss: 3.1509 - val_loss: 3.2172
#
# Epoch 00151: val_loss did not improve from 3.20578
# Number of images: 45
# Presicion: 0.5829
# Recall: 0.3678
# F1 score: 0.451
# Epoch 152/1000
# 400/400 [==============================] - 332s 830ms/step - loss: 3.1667 - val_loss: 3.2339
# Epoch 00152: val_loss did not improve from 3.20578
#
# Epoch 00152: ReduceLROnPlateau reducing learning rate to 1e-05.
# Number of images: 45
# Presicion: 0.534
# Recall: 0.3845
# F1 score: 0.4471
# Epoch 153/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1400 - val_loss: 3.1990
#
# Epoch 00153: val_loss improved from 3.20578 to 3.19904, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.574
# Recall: 0.3752
# F1 score: 0.4538
# Epoch 154/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1304 - val_loss: 3.2031
#
# Epoch 00154: val_loss did not improve from 3.19904
# Number of images: 45
# Presicion: 0.5717
# Recall: 0.3581
# F1 score: 0.4404
# Epoch 155/1000
# 400/400 [==============================] - 330s 824ms/step - loss: 3.1523 - val_loss: 3.1947
#
# Epoch 00155: val_loss improved from 3.19904 to 3.19466, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5699
# Recall: 0.3942
# F1 score: 0.466
# Epoch 156/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1421 - val_loss: 3.1996
#
# Epoch 00156: val_loss did not improve from 3.19466
# Number of images: 45
# Presicion: 0.5769
# Recall: 0.3977
# F1 score: 0.4708
# Epoch 157/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1403 - val_loss: 3.2041
#
# Epoch 00157: val_loss did not improve from 3.19466
# Number of images: 45
# Presicion: 0.5768
# Recall: 0.384
# F1 score: 0.4611
# Epoch 158/1000
# 400/400 [==============================] - 329s 823ms/step - loss: 3.1398 - val_loss: 3.1987
#
# Epoch 00158: val_loss did not improve from 3.19466
# Number of images: 45
# Presicion: 0.5922
# Recall: 0.3701
# F1 score: 0.4555
# Epoch 159/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1291 - val_loss: 3.1949
#
# Epoch 00159: val_loss did not improve from 3.19466
# Number of images: 45
# Presicion: 0.5901
# Recall: 0.3957
# F1 score: 0.4737
# Epoch 160/1000
# 400/400 [==============================] - 335s 836ms/step - loss: 3.1402 - val_loss: 3.1961
#
# Epoch 00160: val_loss did not improve from 3.19466
# Number of images: 45
# Presicion: 0.591
# Recall: 0.3862
# F1 score: 0.4671
# Epoch 161/1000
# 400/400 [==============================] - 330s 824ms/step - loss: 3.1285 - val_loss: 3.2062
#
# Epoch 00161: val_loss did not improve from 3.19466
# Number of images: 45
# Presicion: 0.5741
# Recall: 0.3754
# F1 score: 0.454
# Epoch 162/1000
# 400/400 [==============================] - 333s 834ms/step - loss: 3.1285 - val_loss: 3.1956
#
# Epoch 00162: val_loss did not improve from 3.19466
# Number of images: 45
# Presicion: 0.5766
# Recall: 0.3806
# F1 score: 0.4585
# Epoch 163/1000
# 400/400 [==============================] - 329s 824ms/step - loss: 3.1291 - val_loss: 3.1941
#
# Epoch 00163: val_loss improved from 3.19466 to 3.19414, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5858
# Recall: 0.3754
# F1 score: 0.4576
# Epoch 164/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1299 - val_loss: 3.1903
#
# Epoch 00164: val_loss improved from 3.19414 to 3.19033, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5781
# Recall: 0.3814
# F1 score: 0.4596
# Epoch 165/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1470 - val_loss: 3.1982
#
# Epoch 00165: val_loss did not improve from 3.19033
# Number of images: 45
# Presicion: 0.5957
# Recall: 0.3845
# F1 score: 0.4673
# Epoch 166/1000
# 400/400 [==============================] - 333s 834ms/step - loss: 3.1280 - val_loss: 3.1957
#
# Epoch 00166: val_loss did not improve from 3.19033
# Number of images: 45
# Presicion: 0.58
# Recall: 0.3822
# F1 score: 0.4608
# Epoch 167/1000
# 400/400 [==============================] - 334s 836ms/step - loss: 3.1370 - val_loss: 3.1873
#
# Epoch 00167: val_loss improved from 3.19033 to 3.18730, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5879
# Recall: 0.3868
# F1 score: 0.4666
# Epoch 168/1000
# 400/400 [==============================] - 332s 830ms/step - loss: 3.1391 - val_loss: 3.1940
#
# Epoch 00168: val_loss did not improve from 3.18730
# Number of images: 45
# Presicion: 0.5862
# Recall: 0.4
# F1 score: 0.4755
# Epoch 169/1000
# 400/400 [==============================] - 332s 829ms/step - loss: 3.1288 - val_loss: 3.1944
#
# Epoch 00169: val_loss did not improve from 3.18730
# Number of images: 45
# Presicion: 0.5811
# Recall: 0.3838
# F1 score: 0.4623
# Epoch 170/1000
# 400/400 [==============================] - 330s 825ms/step - loss: 3.1086 - val_loss: 3.1891
#
# Epoch 00170: val_loss did not improve from 3.18730
# Number of images: 45
# Presicion: 0.5854
# Recall: 0.383
# F1 score: 0.463
# Epoch 171/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1226 - val_loss: 3.1933
#
# Epoch 00171: val_loss did not improve from 3.18730
# Number of images: 45
# Presicion: 0.5817
# Recall: 0.3803
# F1 score: 0.4599
# Epoch 172/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1402 - val_loss: 3.1891
#
# Epoch 00172: val_loss did not improve from 3.18730
# Number of images: 45
# Presicion: 0.5884
# Recall: 0.4073
# F1 score: 0.4814
# Improve F1 score from 0.47605648359269614 to 0.48138901543003626
# Epoch 173/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1231 - val_loss: 3.1945
#
# Epoch 00173: val_loss did not improve from 3.18730
# Number of images: 45
# Presicion: 0.5751
# Recall: 0.383
# F1 score: 0.4598
# Epoch 174/1000
# 400/400 [==============================] - 334s 834ms/step - loss: 3.1321 - val_loss: 3.1844
#
# Epoch 00174: val_loss improved from 3.18730 to 3.18439, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.587
# Recall: 0.376
# F1 score: 0.4584
# Epoch 175/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1242 - val_loss: 3.2029
#
# Epoch 00175: val_loss did not improve from 3.18439
# Number of images: 45
# Presicion: 0.5808
# Recall: 0.3686
# F1 score: 0.451
# Epoch 176/1000
# 400/400 [==============================] - 328s 819ms/step - loss: 3.1272 - val_loss: 3.1915
#
# Epoch 00176: val_loss did not improve from 3.18439
# Number of images: 45
# Presicion: 0.5799
# Recall: 0.3744
# F1 score: 0.455
# Epoch 177/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1292 - val_loss: 3.1903
#
# Epoch 00177: val_loss did not improve from 3.18439
# Number of images: 45
# Presicion: 0.5954
# Recall: 0.3943
# F1 score: 0.4744
# Epoch 178/1000
# 400/400 [==============================] - 330s 824ms/step - loss: 3.1097 - val_loss: 3.1980
#
# Epoch 00178: val_loss did not improve from 3.18439
# Number of images: 45
# Presicion: 0.5685
# Recall: 0.3751
# F1 score: 0.452
# Epoch 179/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.1260 - val_loss: 3.1819
#
# Epoch 00179: val_loss improved from 3.18439 to 3.18195, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal.h5
# Number of images: 45
# Presicion: 0.5828
# Recall: 0.3801
# F1 score: 0.4601
# Epoch 180/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1336 - val_loss: 3.1920
#
# Epoch 00180: val_loss did not improve from 3.18195
# Number of images: 45
# Presicion: 0.5925
# Recall: 0.3776
# F1 score: 0.4612
# Epoch 181/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1061 - val_loss: 3.1882
#
# Epoch 00181: val_loss did not improve from 3.18195
# Number of images: 45
# Presicion: 0.5836
# Recall: 0.3804
# F1 score: 0.4606
# Epoch 182/1000
# 400/400 [==============================] - 332s 829ms/step - loss: 3.1255 - val_loss: 3.1960
#
# Epoch 00182: val_loss did not improve from 3.18195
# Number of images: 45
# Presicion: 0.5744
# Recall: 0.3738
# F1 score: 0.4529
# Epoch 183/1000
# 400/400 [==============================] - 333s 833ms/step - loss: 3.1154 - val_loss: 3.1878
#
# Epoch 00183: val_loss did not improve from 3.18195
# Number of images: 45
# Presicion: 0.5856
# Recall: 0.3895
# F1 score: 0.4678
# Epoch 184/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1182 - val_loss: 3.1878
#
# Epoch 00184: val_loss did not improve from 3.18195
# Number of images: 45
# Presicion: 0.5841
# Recall: 0.3888
# F1 score: 0.4669
# Epoch 185/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1291 - val_loss: 3.1940
#
# Epoch 00185: val_loss did not improve from 3.18195
# Number of images: 45
# Presicion: 0.5551
# Recall: 0.3973
# F1 score: 0.4631
# Epoch 186/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1250 - val_loss: 3.1838
#
# Epoch 00186: val_loss did not improve from 3.18195
# Number of images: 45
# Presicion: 0.5844
# Recall: 0.3896
# F1 score: 0.4675
# Epoch 187/1000
# 400/400 [==============================] - 329s 824ms/step - loss: 3.1235 - val_loss: 3.1847
#
# Epoch 00187: val_loss did not improve from 3.18195
# Number of images: 45
# Presicion: 0.5835
# Recall: 0.3845
# F1 score: 0.4635
# Epoch 188/1000
# 400/400 [==============================] - 334s 835ms/step - loss: 3.1222 - val_loss: 3.1858
#
# Epoch 00188: val_loss did not improve from 3.18195
# Number of images: 45
# Presicion: 0.5698
# Recall: 0.3875
# F1 score: 0.4613
# Epoch 189/1000
# 400/400 [==============================] - 332s 830ms/step - loss: 3.1193 - val_loss: 3.2075
#
# Epoch 00189: val_loss did not improve from 3.18195
# Number of images: 45
# Presicion: 0.5831
# Recall: 0.3806
# F1 score: 0.4606
# Epoch 00189: early stopping

# %%
adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss(neg_pos_ratio=3, alpha=1.0)
model.compile(optimizer=adam, loss=ssd_loss.compute_loss)

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)
val_dataset = DataGenerator(load_images_into_memory=True, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets.

# TODO: Set the paths to your dataset here.

# Images
# images_dir = data_path + 'udacity_driving_datasets'
# images_dir = data_path + 'pascal_dataset'
images_dir = data_path + 'images'

# Ground truth
# train_labels_filename = preprocess_path + '/udc.csv'
# train_labels_filename = preprocess_path + '/cic_pascal_train.csv'
# val_labels_filename   = preprocess_path + '/cic_pascal_val.csv'
# train_labels_filename = preprocess_path + '/pascal_train.csv'
# val_labels_filename   = preprocess_path + '/pascal_val.csv'
train_labels_filename = preprocess_path + '/cic_train.csv'
val_labels_filename   = preprocess_path + '/cic_val.csv'

train_dataset.parse_csv(images_dir=images_dir,
                        labels_filename=train_labels_filename,
                        input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'], # This is the order of the first six columns in the CSV file that contains the labels for your dataset. If your labels are in XML format, maybe the XML parser will be helpful, check the documentation.
                        include_classes='all')

val_dataset.parse_csv(images_dir=images_dir,
                      labels_filename=val_labels_filename,
                      input_format=['image_name', 'xmin', 'xmax', 'ymin', 'ymax', 'class_id'],
                      include_classes='all')

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

# train_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_train.h5',
#                                   resize=False,
#                                   variable_image_size=True,
#                                   verbose=True)

# val_dataset.create_hdf5_dataset(file_path='dataset_udacity_traffic_val.h5',
#                                 resize=False,
#                                 variable_image_size=True,
#                                 verbose=True)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Loading images into memory: 100%|██████████| 210/210 [00:07<00:00, 27.80it/s]
# Loading images into memory: 100%|██████████| 45/45 [00:01<00:00, 27.73it/s]
# Number of images in the training dataset:	   210
# Number of images in the validation dataset:	    45

# %%
# 3: Set the batch size.
batch_size = 32 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the image transformations for pre-processing and data augmentation options.
# For the training generator:
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.get_layer('conv4_3_norm_mbox_conf').output_shape[1:3],
                   model.get_layer('fc7_mbox_conf').output_shape[1:3],
                   model.get_layer('conv6_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv7_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv8_2_mbox_conf').output_shape[1:3],
                   model.get_layer('conv9_2_mbox_conf').output_shape[1:3]]

ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.
train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()

print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of images in the training dataset:	   210
# Number of images in the validation dataset:	    45

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='/home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5',
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)
# model_checkpoint.best = 3.1903697716717954

csv_logger = CSVLogger(filename=data_path + 'history/ssd300_adam_vgg_16/ssd300_vgg_pascal_cic.csv',
                       separator=',',
                       append=True)

early_stopping = EarlyStopping(monitor='val_loss',
                               min_delta=0.0,
                               patience=10,
                               verbose=1)

reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.2,
                                         patience=8,
                                         verbose=1,
                                         min_delta=0.001,
                                         cooldown=0,
                                         min_lr=0.00001)

f1_callback = f1_call(0.20, 
                      0.45, 
                      200, 
                      normalize_coords, 
                      img_height, 
                      img_width, 
                      val_images_300,
                      label_val, 
                      (1, 8732, 14),
                      data_path + 'history/ssd300_adam_vgg_16/ssd300_vgg_pascal_cic_f1.csv')

# learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
#                                                 verbose=1)

# terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             early_stopping,
             reduce_learning_rate,
             f1_callback]

# %%
# If you're resuming a previous training, set `initial_epoch` and `final_epoch` accordingly.
initial_epoch   = 0
final_epoch     = 100
steps_per_epoch = 15

history = model.fit_generator(generator=train_generator,
                              steps_per_epoch=steps_per_epoch,
                              epochs=final_epoch,
                              callbacks=callbacks,
                              validation_data=val_generator,
                              validation_steps=ceil(val_dataset_size/batch_size),
                              initial_epoch=initial_epoch)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 66s 4s/step - loss: 4.0972 - val_loss: 3.8712
#
# Epoch 00001: val_loss improved from inf to 3.87123, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.0725
# Recall: 0.5923
# F1 score: 0.1292
# Improve F1 score from -inf to 0.12918932246943535
# Epoch 2/100
# 15/15 [==============================] - 63s 4s/step - loss: 3.6772 - val_loss: 3.2774
#
# Epoch 00002: val_loss improved from 3.87123 to 3.27738, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.412
# Recall: 0.5078
# F1 score: 0.4549
# Improve F1 score from 0.12918932246943535 to 0.45488977423022786
# Epoch 3/100
# 15/15 [==============================] - 68s 5s/step - loss: 3.4129 - val_loss: 3.2328
#
# Epoch 00003: val_loss improved from 3.27738 to 3.23277, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.5802
# Recall: 0.4329
# F1 score: 0.4959
# Improve F1 score from 0.45488977423022786 to 0.4958767520273487
# Epoch 4/100
# 15/15 [==============================] - 63s 4s/step - loss: 3.2244 - val_loss: 2.9994
#
# Epoch 00004: val_loss improved from 3.23277 to 2.99945, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.5457
# Recall: 0.5481
# F1 score: 0.5469
# Improve F1 score from 0.4958767520273487 to 0.5469170195899132
# Epoch 5/100
# 15/15 [==============================] - 64s 4s/step - loss: 3.1920 - val_loss: 3.1258
#
# Epoch 00005: val_loss did not improve from 2.99945
# Number of images: 45
# Presicion: 0.5237
# Recall: 0.5393
# F1 score: 0.5314
# Epoch 6/100
# 15/15 [==============================] - 69s 5s/step - loss: 3.2178 - val_loss: 3.1641
#
# Epoch 00006: val_loss did not improve from 2.99945
# Number of images: 45
# Presicion: 0.4956
# Recall: 0.5881
# F1 score: 0.5379
# Epoch 7/100
# 15/15 [==============================] - 62s 4s/step - loss: 3.0925 - val_loss: 2.8484
#
# Epoch 00007: val_loss improved from 2.99945 to 2.84838, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.6293
# Recall: 0.5453
# F1 score: 0.5843
# Improve F1 score from 0.5469170195899132 to 0.5842799860445321
# Epoch 8/100
# 15/15 [==============================] - 63s 4s/step - loss: 3.1352 - val_loss: 2.8806
#
# Epoch 00008: val_loss did not improve from 2.84838
# Number of images: 45
# Presicion: 0.6231
# Recall: 0.5395
# F1 score: 0.5783
# Epoch 9/100
# 15/15 [==============================] - 66s 4s/step - loss: 3.0164 - val_loss: 2.9358
#
# Epoch 00009: val_loss did not improve from 2.84838
# Number of images: 45
# Presicion: 0.6315
# Recall: 0.5193
# F1 score: 0.5699
# Epoch 10/100
# 15/15 [==============================] - 66s 4s/step - loss: 3.0001 - val_loss: 2.9861
#
# Epoch 00010: val_loss did not improve from 2.84838
# Number of images: 45
# Presicion: 0.5839
# Recall: 0.546
# F1 score: 0.5643
# Epoch 11/100
# 15/15 [==============================] - 64s 4s/step - loss: 3.0423 - val_loss: 2.8710
#
# Epoch 00011: val_loss did not improve from 2.84838
# Number of images: 45
# Presicion: 0.6043
# Recall: 0.5576
# F1 score: 0.58
# Epoch 12/100
# 15/15 [==============================] - 64s 4s/step - loss: 3.1025 - val_loss: 2.8987
#
# Epoch 00012: val_loss did not improve from 2.84838
# Number of images: 45
# Presicion: 0.5106
# Recall: 0.5946
# F1 score: 0.5494
# Epoch 13/100
# 15/15 [==============================] - 66s 4s/step - loss: 3.1051 - val_loss: 2.9156
#
# Epoch 00013: val_loss did not improve from 2.84838
# Number of images: 45
# Presicion: 0.5575
# Recall: 0.5745
# F1 score: 0.5659
# Epoch 14/100
# 15/15 [==============================] - 63s 4s/step - loss: 3.0021 - val_loss: 2.9638
#
# Epoch 00014: val_loss did not improve from 2.84838
# Number of images: 45
# Presicion: 0.5964
# Recall: 0.5632
# F1 score: 0.5793
# Epoch 15/100
# 15/15 [==============================] - 67s 4s/step - loss: 2.9861 - val_loss: 2.9202
#
# Epoch 00015: val_loss did not improve from 2.84838
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Number of images: 45
# Presicion: 0.5167
# Recall: 0.6132
# F1 score: 0.5608
# Epoch 16/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.8192 - val_loss: 2.7188
#
# Epoch 00016: val_loss improved from 2.84838 to 2.71879, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.632
# Recall: 0.5958
# F1 score: 0.6134
# Improve F1 score from 0.5842799860445321 to 0.6133999992090715
# Epoch 17/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.6872 - val_loss: 2.7567
#
# Epoch 00017: val_loss did not improve from 2.71879
# Number of images: 45
# Presicion: 0.6277
# Recall: 0.6055
# F1 score: 0.6164
# Improve F1 score from 0.6133999992090715 to 0.6164215687621617
# Epoch 18/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.6651 - val_loss: 2.7428
#
# Epoch 00018: val_loss did not improve from 2.71879
# Number of images: 45
# Presicion: 0.6723
# Recall: 0.552
# F1 score: 0.6062
# Epoch 19/100
# 15/15 [==============================] - 67s 4s/step - loss: 2.7118 - val_loss: 2.7269
#
# Epoch 00019: val_loss did not improve from 2.71879
# Number of images: 45
# Presicion: 0.6436
# Recall: 0.6071
# F1 score: 0.6248
# Improve F1 score from 0.6164215687621617 to 0.6248244737609839
# Epoch 20/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.6338 - val_loss: 2.6319
#
# Epoch 00020: val_loss improved from 2.71879 to 2.63187, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.6793
# Recall: 0.6039
# F1 score: 0.6394
# Improve F1 score from 0.6248244737609839 to 0.6394100298346892
# Epoch 21/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.6227 - val_loss: 2.6456
#
# Epoch 00021: val_loss did not improve from 2.63187
# Number of images: 45
# Presicion: 0.6189
# Recall: 0.6063
# F1 score: 0.6125
# Epoch 22/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.6107 - val_loss: 2.5878
#
# Epoch 00022: val_loss improved from 2.63187 to 2.58776, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.672
# Recall: 0.6075
# F1 score: 0.6381
# Epoch 23/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.5551 - val_loss: 2.6350
#
# Epoch 00023: val_loss did not improve from 2.58776
# Number of images: 45
# Presicion: 0.6947
# Recall: 0.6164
# F1 score: 0.6532
# Improve F1 score from 0.6394100298346892 to 0.6532307307653868
# Epoch 24/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.5792 - val_loss: 2.6219
#
# Epoch 00024: val_loss did not improve from 2.58776
# Number of images: 45
# Presicion: 0.6823
# Recall: 0.5897
# F1 score: 0.6327
# Epoch 25/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.5959 - val_loss: 2.5901
#
# Epoch 00025: val_loss did not improve from 2.58776
# Number of images: 45
# Presicion: 0.6322
# Recall: 0.622
# F1 score: 0.6271
# Epoch 26/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.5961 - val_loss: 2.6403
#
# Epoch 00026: val_loss did not improve from 2.58776
# Number of images: 45
# Presicion: 0.6421
# Recall: 0.6168
# F1 score: 0.6292
# Epoch 27/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.6126 - val_loss: 2.6106
#
# Epoch 00027: val_loss did not improve from 2.58776
# Number of images: 45
# Presicion: 0.6577
# Recall: 0.6443
# F1 score: 0.6509
# Epoch 28/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.6379 - val_loss: 2.6154
#
# Epoch 00028: val_loss did not improve from 2.58776
# Number of images: 45
# Presicion: 0.6534
# Recall: 0.6235
# F1 score: 0.6381
# Epoch 29/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.4679 - val_loss: 2.6511
#
# Epoch 00029: val_loss did not improve from 2.58776
# Number of images: 45
# Presicion: 0.6689
# Recall: 0.6382
# F1 score: 0.6532
# Improve F1 score from 0.6532307307653868 to 0.6532333500683964
# Epoch 30/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.4529 - val_loss: 2.6270
#
# Epoch 00030: val_loss did not improve from 2.58776
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Number of images: 45
# Presicion: 0.6597
# Recall: 0.6315
# F1 score: 0.6453
# Epoch 31/100
# 15/15 [==============================] - 61s 4s/step - loss: 2.4355 - val_loss: 2.5988
#
# Epoch 00031: val_loss did not improve from 2.58776
# Number of images: 45
# Presicion: 0.6853
# Recall: 0.615
# F1 score: 0.6482
# Epoch 32/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.4422 - val_loss: 2.5501
#
# Epoch 00032: val_loss improved from 2.58776 to 2.55013, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.682
# Recall: 0.6103
# F1 score: 0.6441
# Epoch 33/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.3944 - val_loss: 2.5727
#
# Epoch 00033: val_loss did not improve from 2.55013
# Number of images: 45
# Presicion: 0.6792
# Recall: 0.6089
# F1 score: 0.6421
# Epoch 34/100
# 15/15 [==============================] - 68s 5s/step - loss: 2.4686 - val_loss: 2.5700
#
# Epoch 00034: val_loss did not improve from 2.55013
# Number of images: 45
# Presicion: 0.6745
# Recall: 0.6246
# F1 score: 0.6486
# Epoch 35/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.5137 - val_loss: 2.5693
#
# Epoch 00035: val_loss did not improve from 2.55013
# Number of images: 45
# Presicion: 0.6638
# Recall: 0.6362
# F1 score: 0.6497
# Epoch 36/100
# 15/15 [==============================] - 68s 5s/step - loss: 2.5319 - val_loss: 2.5515
#
# Epoch 00036: val_loss did not improve from 2.55013
# Number of images: 45
# Presicion: 0.679
# Recall: 0.629
# F1 score: 0.653
# Epoch 37/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.4597 - val_loss: 2.5749
#
# Epoch 00037: val_loss did not improve from 2.55013
# Number of images: 45
# Presicion: 0.6723
# Recall: 0.6347
# F1 score: 0.653
# Epoch 38/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.4204 - val_loss: 2.5384
#
# Epoch 00038: val_loss improved from 2.55013 to 2.53844, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.6797
# Recall: 0.6296
# F1 score: 0.6537
# Improve F1 score from 0.6532333500683964 to 0.6536820113270521
# Epoch 39/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.5396 - val_loss: 2.5641
#
# Epoch 00039: val_loss did not improve from 2.53844
# Number of images: 45
# Presicion: 0.6668
# Recall: 0.6198
# F1 score: 0.6425
# Epoch 40/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.4258 - val_loss: 2.5427
#
# Epoch 00040: val_loss did not improve from 2.53844
# Number of images: 45
# Presicion: 0.6757
# Recall: 0.615
# F1 score: 0.6439
# Epoch 41/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.5599 - val_loss: 2.5581
#
# Epoch 00041: val_loss did not improve from 2.53844
# Number of images: 45
# Presicion: 0.6798
# Recall: 0.6367
# F1 score: 0.6576
# Improve F1 score from 0.6536820113270521 to 0.6575559030366717
# Epoch 42/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.3749 - val_loss: 2.5882
#
# Epoch 00042: val_loss did not improve from 2.53844
# Number of images: 45
# Presicion: 0.6666
# Recall: 0.6246
# F1 score: 0.6449
# Epoch 43/100
# 15/15 [==============================] - 68s 5s/step - loss: 2.4297 - val_loss: 2.5534
#
# Epoch 00043: val_loss did not improve from 2.53844
# Number of images: 45
# Presicion: 0.6763
# Recall: 0.6369
# F1 score: 0.656
# Epoch 44/100
# 15/15 [==============================] - 69s 5s/step - loss: 2.4401 - val_loss: 2.5522
#
# Epoch 00044: val_loss did not improve from 2.53844
# Number of images: 45
# Presicion: 0.671
# Recall: 0.6361
# F1 score: 0.6531
# Epoch 45/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.3913 - val_loss: 2.5310
#
# Epoch 00045: val_loss improved from 2.53844 to 2.53098, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.679
# Recall: 0.6269
# F1 score: 0.6519
# Epoch 46/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.4191 - val_loss: 2.5388
#
# Epoch 00046: val_loss did not improve from 2.53098
# Number of images: 45
# Presicion: 0.664
# Recall: 0.6263
# F1 score: 0.6446
# Epoch 47/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.4185 - val_loss: 2.5319
#
# Epoch 00047: val_loss did not improve from 2.53098
# Number of images: 45
# Presicion: 0.6807
# Recall: 0.6295
# F1 score: 0.6541
# Epoch 48/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.4350 - val_loss: 2.5293
#
# Epoch 00048: val_loss improved from 2.53098 to 2.52926, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.6843
# Recall: 0.6371
# F1 score: 0.6599
# Improve F1 score from 0.6575559030366717 to 0.6598547081049146
# Epoch 49/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.4481 - val_loss: 2.5381
#
# Epoch 00049: val_loss did not improve from 2.52926
# Number of images: 45
# Presicion: 0.6687
# Recall: 0.637
# F1 score: 0.6525
# Epoch 50/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.4549 - val_loss: 2.5093
#
# Epoch 00050: val_loss improved from 2.52926 to 2.50928, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.6784
# Recall: 0.6467
# F1 score: 0.6622
# Improve F1 score from 0.6598547081049146 to 0.6621931371388046
# Epoch 51/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.4166 - val_loss: 2.5165
#
# Epoch 00051: val_loss did not improve from 2.50928
# Number of images: 45
# Presicion: 0.6747
# Recall: 0.6276
# F1 score: 0.6503
# Epoch 52/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.2789 - val_loss: 2.5258
#
# Epoch 00052: val_loss did not improve from 2.50928
# Number of images: 45
# Presicion: 0.6714
# Recall: 0.6243
# F1 score: 0.647
# Epoch 53/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.3811 - val_loss: 2.5386
#
# Epoch 00053: val_loss did not improve from 2.50928
# Number of images: 45
# Presicion: 0.669
# Recall: 0.6357
# F1 score: 0.6519
# Epoch 54/100
# 15/15 [==============================] - 62s 4s/step - loss: 2.4789 - val_loss: 2.5128
#
# Epoch 00054: val_loss did not improve from 2.50928
# Number of images: 45
# Presicion: 0.6831
# Recall: 0.6244
# F1 score: 0.6524
# Epoch 55/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.4300 - val_loss: 2.5055
#
# Epoch 00055: val_loss improved from 2.50928 to 2.50551, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.6918
# Recall: 0.6102
# F1 score: 0.6485
# Epoch 56/100
# 15/15 [==============================] - 63s 4s/step - loss: 2.4329 - val_loss: 2.4959
#
# Epoch 00056: val_loss improved from 2.50551 to 2.49586, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.6699
# Recall: 0.6268
# F1 score: 0.6477
# Epoch 57/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.3322 - val_loss: 2.5195
#
# Epoch 00057: val_loss did not improve from 2.49586
# Number of images: 45
# Presicion: 0.6821
# Recall: 0.6306
# F1 score: 0.6554
# Epoch 58/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.4508 - val_loss: 2.4981
#
# Epoch 00058: val_loss did not improve from 2.49586
# Number of images: 45
# Presicion: 0.6858
# Recall: 0.62
# F1 score: 0.6512
# Epoch 59/100
# 15/15 [==============================] - 60s 4s/step - loss: 2.3339 - val_loss: 2.5087
#
# Epoch 00059: val_loss did not improve from 2.49586
# Number of images: 45
# Presicion: 0.6605
# Recall: 0.6563
# F1 score: 0.6584
# Epoch 60/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.3166 - val_loss: 2.4967
#
# Epoch 00060: val_loss did not improve from 2.49586
# Number of images: 45
# Presicion: 0.6799
# Recall: 0.6207
# F1 score: 0.6489
# Epoch 61/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.4240 - val_loss: 2.4844
#
# Epoch 00061: val_loss improved from 2.49586 to 2.48439, saving model to /home/aldo/Documents/weights/models/ssd300_adam_vgg16/ssd300_pascal_cic.h5
# Number of images: 45
# Presicion: 0.6876
# Recall: 0.627
# F1 score: 0.6559
# Epoch 62/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.3436 - val_loss: 2.5129
#
# Epoch 00062: val_loss did not improve from 2.48439
# Number of images: 45
# Presicion: 0.6676
# Recall: 0.6344
# F1 score: 0.6506
# Epoch 63/100
# 15/15 [==============================] - 61s 4s/step - loss: 2.3598 - val_loss: 2.4883
#
# Epoch 00063: val_loss did not improve from 2.48439
# Number of images: 45
# Presicion: 0.6788
# Recall: 0.6461
# F1 score: 0.6621
# Epoch 64/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.4036 - val_loss: 2.5055
#
# Epoch 00064: val_loss did not improve from 2.48439
# Number of images: 45
# Presicion: 0.6785
# Recall: 0.6388
# F1 score: 0.6581
# Epoch 65/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.3756 - val_loss: 2.5064
#
# Epoch 00065: val_loss did not improve from 2.48439
# Number of images: 45
# Presicion: 0.685
# Recall: 0.6535
# F1 score: 0.6689
# Improve F1 score from 0.6621931371388046 to 0.6688882241512658
# Epoch 66/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.2709 - val_loss: 2.5342
#
# Epoch 00066: val_loss did not improve from 2.48439
# Number of images: 45
# Presicion: 0.6835
# Recall: 0.6239
# F1 score: 0.6524
# Epoch 67/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.3632 - val_loss: 2.4985
#
# Epoch 00067: val_loss did not improve from 2.48439
# Number of images: 45
# Presicion: 0.6876
# Recall: 0.6293
# F1 score: 0.6572
# Epoch 68/100
# 15/15 [==============================] - 65s 4s/step - loss: 2.2865 - val_loss: 2.5056
#
# Epoch 00068: val_loss did not improve from 2.48439
# Number of images: 45
# Presicion: 0.6859
# Recall: 0.6351
# F1 score: 0.6595
# Epoch 69/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.3143 - val_loss: 2.5054
#
# Epoch 00069: val_loss did not improve from 2.48439
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1e-05.
# Number of images: 45
# Presicion: 0.6773
# Recall: 0.6397
# F1 score: 0.658
# Epoch 70/100
# 15/15 [==============================] - 64s 4s/step - loss: 2.3782 - val_loss: 2.5091
#
# Epoch 00070: val_loss did not improve from 2.48439
# Number of images: 45
# Presicion: 0.6784
# Recall: 0.6327
# F1 score: 0.6547
# Epoch 71/100
# 15/15 [==============================] - 66s 4s/step - loss: 2.3643 - val_loss: 2.5061
#
# Epoch 00071: val_loss did not improve from 2.48439
# Number of images: 45
# Presicion: 0.6755
# Recall: 0.6385
# F1 score: 0.6564
# Epoch 00071: early stopping
