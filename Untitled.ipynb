# %%
data = [['VGG16 (20)', 26285486, 4.4508],
        ['VGG16', 23745908, 3.699],
        ['VGG1613', 18442100, 2.5732]]
frame= pd.DataFrame(data, columns=['Arquitectura base', 'No. parámetros', 'Tiempo de inferencia (sec)'])

# %%
g = sns.barplot(x='Arquitectura base', y='No. parámetros', data=frame, palette='coolwarm')
plt.ylim(0, 30000000)
for index, row in frame.iterrows():
    menusX = -0.27
    plusY = 1000000
    param = '{:,}'.format(row['No. parámetros'])
    g.text(index + menusX, row['No. parámetros'] + plusY, param, color='black')
plt.savefig('param_arquitectura.pdf', bbox_inches="tight")

# %%
g = sns.barplot(x='Arquitectura base', y='Tiempo de inferencia (sec)', data=frame, palette='coolwarm')
plt.ylim(0, 5)
for index, row in frame.iterrows():
    g.text(index - 0.1, row['Tiempo de inferencia (sec)'] + 0.15, row['Tiempo de inferencia (sec)'], color='black')
plt.savefig('tiempo_arquitectura.pdf', bbox_inches="tight")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def fix_outliers(data):
    new_data = []
    max_value = data[0]
    
    for index, value in enumerate(data):
        if value > max_value:
            new_value = (data[index -1] + data[index + 1]) / 2
            new_data.append(new_value)
        else:
            new_data.append(value)
    return new_data

# %%
vgg_tunning_cic = pd.read_csv('/home/aldo/Documents/data-cic/history/ssd300_sgd_pascal_20_classes_tunning/ssd300_fine_tunning.csv')

fig, ax = plt.subplots()
ax.plot(vgg_tunning_cic['epoch'], vgg_tunning_cic['loss'], label='Entrenamiento')
ax.plot(vgg_tunning_cic['epoch'], vgg_tunning_cic['val_loss'], label='Validación')


ax.set_xlabel('Época')
ax.set_ylabel('Costo')
ax.set_ylim(2, 6)
ax.grid(True)
ax.set_title('SSD/VGG16 (20) CIC')
legend = ax.legend(loc='upper right')
plt.savefig('vgg_tunning_cic.pdf', bbox_inches="tight")

# %%
mnetv1_pascal = pd.read_csv('/home/aldo/Documents/data-cic/history/ssd300_mobilenetv1/imagenet/ssd300_mobilenet_imagent2.csv')

fig, ax = plt.subplots()
ax.plot(mnetv1_pascal['epoch'], mnetv1_pascal['loss'], label='Entrenamiento')
ax.plot(mnetv1_pascal['epoch'], mnetv1_pascal['val_loss'], label='Validación')


ax.set_xlabel('Época')
ax.set_ylabel('Costo')
ax.set_ylim(2, 5.5)
ax.grid(True)
ax.set_title('SSD/MobileNetv1 PASCAL')
legend = ax.legend(loc='upper right')
plt.savefig('mnetv1_lr_pascal.pdf', bbox_inches="tight")

mnetv1_cic = pd.read_csv('/home/aldo/Documents/data-cic/history/ssd300_mobilenetv1/imagenet/ssd300_mobilenet_imagent2_cic.csv')

fig, ax = plt.subplots()
ax.plot(mnetv1_cic['epoch'], mnetv1_cic['loss'], label='Entrenamiento')
ax.plot(mnetv1_cic['epoch'], mnetv1_cic['val_loss'], label='Validación')

ax.set_xlabel('Época')
ax.set_ylabel('Costo')
ax.grid(True)
ax.set_title('SSD/MobileNetv1 CIC')
legend = ax.legend(loc='upper right')
plt.savefig('mnetv1_lr_cic.pdf', bbox_inches="tight")

# %%
ssdlitemnetv1_pascal = pd.read_csv('/home/aldo/Documents/data-cic/history/ssdlite320_mobilenetv1/ssdlite320_mobilenetv1_pascal.csv')

fig, ax = plt.subplots()
ax.plot(ssdlitemnetv1_pascal['epoch'], ssdlitemnetv1_pascal['loss'], label='Entrenamiento')
ax.plot(ssdlitemnetv1_pascal['epoch'], ssdlitemnetv1_pascal['val_loss'], label='Validación')


ax.set_xlabel('Época')
ax.set_ylabel('Costo')
ax.set_ylim(2, 5)
ax.grid(True)
ax.set_title('SSDLite/Mobilenetv1 PASCAL')
legend = ax.legend(loc='upper right')
plt.savefig('ssdlitemnetv1_lr_pascal.pdf', bbox_inches="tight")

ssdlitemnetv1_cic = pd.read_csv('/home/aldo/Documents/data-cic/history/ssdlite320_mobilenetv1/ssdlite320_mobilenetv1_pascal_cic.csv')

fig, ax = plt.subplots()
ax.plot(ssdlitemnetv1_cic['epoch'], ssdlitemnetv1_cic['loss'], label='Entrenamiento')
ax.plot(ssdlitemnetv1_cic['epoch'], ssdlitemnetv1_cic['val_loss'], label='Validación')


ax.set_xlabel('Época')
ax.set_ylabel('Costo')
ax.grid(True)
ax.set_title('SSDLite/Mobilenetv1 CIC')
legend = ax.legend(loc='upper right')
plt.savefig('ssdlitemnetv1_lr_cic.pdf', bbox_inches="tight")

# %%
ssdlitemnetv2_pascal = pd.read_csv('/home/aldo/Documents/data-cic/history/ssdlite320_mobilenetv2/ssdlite320_mobilenetv2_pascal.csv')

fig, ax = plt.subplots()
ax.plot(ssdlitemnetv2_pascal['epoch'], ssdlitemnetv2_pascal['loss'], label='Entrenamiento')
ax.plot(ssdlitemnetv2_pascal['epoch'], ssdlitemnetv2_pascal['val_loss'], label='Validación')


ax.set_xlabel('Época')
ax.set_ylabel('Costo')
ax.set_ylim(2, 5)
ax.grid(True)
ax.set_title('SSDLite/Mobilenetv2 PASCAL')
legend = ax.legend(loc='upper right')
plt.savefig('ssdlitemnetv2_lr_pascal.pdf', bbox_inches="tight")

ssdlitemnetv2_cic = pd.read_csv('/home/aldo/Documents/data-cic/history/ssdlite320_mobilenetv2/ssdlite320_mobilenetv2_pascal_cic.csv')

fig, ax = plt.subplots()
ax.plot(ssdlitemnetv2_cic['epoch'], ssdlitemnetv2_cic['loss'], label='Entrenamiento')
ax.plot(ssdlitemnetv2_cic['epoch'], ssdlitemnetv2_cic['val_loss'], label='Validación')


ax.set_xlabel('Época')
ax.set_ylabel('Costo')
ax.grid(True)
ax.set_title('SSDLite/Mobilenetv2 CIC')
legend = ax.legend(loc='upper right')
plt.savefig('ssdlitemnetv2_lr_cic.pdf', bbox_inches="tight")

# %%
models = [['VGG16(20)', 0.6533, 0.6412, 26285, 3.17],
          ['VGG16(20) CIC', 0.7623, 0.7502, 26285, 3.17],
          ['VGG16(2)', 0.6683, 0.63, 23745, 2.97],
          ['VGG13', 0.7275, 0.6831, 18442, 2.207],
          ['Mnetv1', 0.6855, 0.6759, 6204, 0.5448],
          ['SSDLite_Mnetv1', 0.6995, 0.7133, 4572, 0.456],
          ['SSDLite_Mnetv2', 0.6896, 0.7, 3751, 0.5]]

columns = ['name', 'f1 cpu', 'f1 lite', 'parametros', 'tiempo']

trad_off = pd.DataFrame(models, columns = columns)

# %%
g = sns.scatterplot(x='parametros', y='f1 cpu', data= trad_off)
# g.set_ylim(0.60)
axes = g.axes

for index, row in trad_off.iterrows():
    g.text(row['parametros'], row['f1 cpu'], row['name'], color='black')

# %%
g = sns.scatterplot(x='parametros', y='f1 lite', data= trad_off)
# g.set_ylim(0.60)
axes = g.axes

for index, row in trad_off.iterrows():
    g.text(row['parametros'], row['f1 lite'], row['name'], color='black')

# %%
g = sns.scatterplot(x='tiempo', y='f1 lite', data= trad_off)

for index, row in trad_off.iterrows():
    g.text(row['tiempo'], row['f1 lite'], row['name'], color='black')

# %%
f_1_6 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_1.0_exp_6.csv')
f_1_4 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_1.0_exp_4.csv')
f_1_2 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_1.0_exp_2.csv')
f_1_1 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_1.0_exp_1.csv')
f_75_6 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.75_exp_6.csv')
f_75_4 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.75_exp_4.csv')
f_75_2 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.75_exp_2.csv')
f_75_1 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.75_exp_1.csv')
f_5_6 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.5_exp_6.csv')
f_5_4 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.5_exp_4.csv')
f_5_2 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.5_exp_2.csv')
f_5_1 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.5_exp_1.csv')
f_35_6 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.35_exp_6.csv')
f_35_4 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.35_exp_4.csv')
f_35_2 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.35_exp_2.csv')
f_35_1 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.35_exp_1.csv')

# %%
fig, ax = plt.subplots()
ax.plot(f_1_6['epoch'], f_1_6['presicion'], label='6')
ax.plot(f_1_4['epoch'], f_1_4['presicion'], label='4')
ax.plot(f_1_2['epoch'], f_1_2['presicion'], label='2')
ax.plot(f_1_1['epoch'], f_1_1['presicion'], label='1')
ax.set_xlabel('Época')
ax.set_ylabel('Presicion')
ax.legend(title='Expansión')
ax.set_title('Alpha 1.0')
ax.grid(True)

fig, ax = plt.subplots()
ax.plot(f_1_6['epoch'], f_1_6['recall'], label='6')
ax.plot(f_1_4['epoch'], f_1_4['recall'], label='4')
ax.plot(f_1_2['epoch'], f_1_2['recall'], label='2')
ax.plot(f_1_1['epoch'], f_1_1['recall'], label='1')
ax.set_xlabel('Época')
ax.set_ylabel('Recall')
ax.set_title('Alpha 1.0')
ax.legend(title='Expansión')
ax.grid(True)

fig, ax = plt.subplots()
ax.plot(f_1_6['epoch'], f_1_6['f1 score'], label='6')
ax.plot(f_1_4['epoch'], f_1_4['f1 score'], label='4')
ax.plot(f_1_2['epoch'], f_1_2['f1 score'], label='2')
ax.plot(f_1_1['epoch'], f_1_1['f1 score'], label='1')
ax.set_xlabel('Época')
ax.set_ylabel('F1 score')
ax.set_title('Alpha 1.0')
ax.legend(title='Expansión')
ax.grid(True)

# %%
fig, ax = plt.subplots()
ax.plot(f_75_6['epoch'], f_75_6['presicion'], label='6')
ax.plot(f_75_4['epoch'], f_75_4['presicion'], label='4')
ax.plot(f_75_2['epoch'], f_75_2['presicion'], label='2')
ax.plot(f_75_1['epoch'], f_75_1['presicion'], label='1')
ax.set_xlabel('Época')
ax.legend(title='Expansión')
ax.set_ylabel('Presicion')
ax.set_title('Alpha 0.75')
ax.grid(True)

fig, ax = plt.subplots()
ax.plot(f_75_6['epoch'], f_75_6['recall'], label='6')
ax.plot(f_75_4['epoch'], f_75_4['recall'], label='4')
ax.plot(f_75_2['epoch'], f_75_2['recall'], label='2')
ax.plot(f_75_1['epoch'], f_75_1['recall'], label='1')
ax.set_xlabel('Época')
ax.set_ylabel('Recall')
ax.legend(title='Expansión')
ax.set_title('Alpha 0.75')
ax.grid(True)

fig, ax = plt.subplots()
ax.plot(f_75_6['epoch'], f_75_6['f1 score'], label='6')
ax.plot(f_75_4['epoch'], f_75_4['f1 score'], label='4')
ax.plot(f_75_2['epoch'], f_75_2['f1 score'], label='2')
ax.plot(f_75_1['epoch'], f_75_1['f1 score'], label='1')
ax.set_xlabel('Época')
ax.legend(title='Expansión', loc='lower right')
ax.set_ylabel('f1 score')
ax.set_title('Alpha 0.75')
ax.grid(True)

# %%
fig, ax = plt.subplots()
ax.plot(f_5_6['epoch'], f_5_6['presicion'], label='6')
ax.plot(f_5_4['epoch'], f_5_4['presicion'], label='4')
ax.plot(f_5_2['epoch'], f_5_2['presicion'], label='2')
ax.plot(f_5_1['epoch'], f_5_1['presicion'], label='1')
ax.set_xlabel('Época')
ax.set_ylabel('Presicion')
ax.set_title('Alpha 0.5')
ax.legend(title='Expansión')
ax.grid(True)

fig, ax = plt.subplots()
ax.plot(f_5_6['epoch'], f_5_6['recall'], label='6')
ax.plot(f_5_4['epoch'], f_5_4['recall'], label='4')
ax.plot(f_5_2['epoch'], f_5_2['recall'], label='2')
ax.plot(f_5_1['epoch'], f_5_1['recall'], label='1')
ax.set_xlabel('Época')
ax.set_ylabel('Recall')
ax.set_title('Alpha 0.5')
ax.legend(title='Expansión', loc='lower right')
ax.grid(True)

fig, ax = plt.subplots()
ax.plot(f_5_6['epoch'], f_5_6['f1 score'], label='6')
ax.plot(f_5_4['epoch'], f_5_4['f1 score'], label='4')
ax.plot(f_5_2['epoch'], f_5_2['f1 score'], label='2')
ax.plot(f_5_1['epoch'], f_5_1['f1 score'], label='1')
ax.set_xlabel('Época')
ax.set_ylabel('F1 score')
ax.legend(title='Expansión')
ax.set_title('Alpha 0.5')
ax.grid(True)

# %%
fig, ax = plt.subplots()
ax.plot(f_35_6['epoch'], f_35_6['presicion'], label='6')
ax.plot(f_35_4['epoch'], f_35_4['presicion'], label='4')
ax.plot(f_35_2['epoch'], f_35_2['presicion'], label='2')
ax.plot(f_35_1['epoch'], f_35_1['presicion'], label='1')
ax.set_xlabel('Época')
ax.set_ylabel('Presicion')
ax.set_title('Alpha 0.35')
ax.legend(title='Expansión')
ax.grid(True)

fig, ax = plt.subplots()
ax.plot(f_35_6['epoch'], f_35_6['recall'], label='6')
ax.plot(f_35_4['epoch'], f_35_4['recall'], label='4')
ax.plot(f_35_2['epoch'], f_35_2['recall'], label='2')
ax.plot(f_35_1['epoch'], f_35_1['recall'], label='1')
ax.set_xlabel('Época')
ax.set_ylabel('Recall')
ax.set_title('Alpha 0.35')
ax.legend(title='Expansión')
ax.grid(True)

fig, ax = plt.subplots()
ax.plot(f_35_6['epoch'], f_35_6['f1 score'], label='6')
ax.plot(f_35_4['epoch'], f_35_4['f1 score'], label='4')
ax.plot(f_35_2['epoch'], f_35_2['f1 score'], label='2')
ax.plot(f_35_1['epoch'], f_35_1['f1 score'], label='1')
ax.set_xlabel('Época')
ax.set_ylabel('F1 score')
ax.set_title('Alpha 0.35')
ax.legend(title='Expansión', loc='lower right')

ax.grid(True)

# %%
f_1_6 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_1.0_exp_6.csv')
f_1_4 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_1.0_exp_4.csv')
f_1_2 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_1.0_exp_2.csv')
f_1_1 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_1.0_exp_1.csv')
f_75_6 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.75_exp_6.csv')
f_75_4 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.75_exp_4.csv')
f_75_2 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.75_exp_2.csv')
f_75_1 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.75_exp_1.csv')
f_5_6 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.5_exp_6.csv')
f_5_4 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.5_exp_4.csv')
f_5_2 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.5_exp_2.csv')
f_5_1 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.5_exp_1.csv')
f_35_6 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.35_exp_6.csv')
f_35_4 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.35_exp_4.csv')
f_35_2 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.35_exp_2.csv')
f_35_1 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_f1_0.35_exp_1.csv')

# %%
fig, ax = plt.subplots()
ax.plot(f_1_6['epoch'], f_1_6['f1 score'], label='Entrenamiento')
ax.plot(f_1_4['epoch'], f_1_4['f1 score'], label='Entrenamiento')
ax.plot(f_1_2['epoch'], f_1_2['f1 score'], label='Entrenamiento')
ax.plot(f_1_1['epoch'], f_1_1['f1 score'], label='Entrenamiento')
ax.plot(f_75_6['epoch'], f_75_6['f1 score'], label='Entrenamiento')
ax.plot(f_75_4['epoch'], f_75_4['f1 score'], label='Entrenamiento')
ax.plot(f_75_2['epoch'], f_75_2['f1 score'], label='Entrenamiento')
ax.plot(f_75_1['epoch'], f_75_1['f1 score'], label='Entrenamiento')
ax.plot(f_5_6['epoch'], f_5_6['f1 score'], label='Entrenamiento')
ax.plot(f_5_4['epoch'], f_5_4['f1 score'], label='Entrenamiento')
ax.plot(f_5_2['epoch'], f_5_2['f1 score'], label='Entrenamiento')
ax.plot(f_5_1['epoch'], f_5_1['f1 score'], label='Entrenamiento')
ax.plot(f_35_6['epoch'], f_35_6['f1 score'], label='Entrenamiento')
ax.plot(f_35_4['epoch'], f_35_4['f1 score'], label='Entrenamiento')
ax.plot(f_35_2['epoch'], f_35_2['f1 score'], label='Entrenamiento')
ax.plot(f_35_1['epoch'], f_35_1['f1 score'], label='Entrenamiento')


ax.set_xlabel('Época')
ax.set_ylabel('f1 score')
ax.grid(True)

fig, ax = plt.subplots()
ax.plot(f_1_6['epoch'], f_1_6['presicion'], label='Entrenamiento')
ax.plot(f_1_4['epoch'], f_1_4['presicion'], label='Entrenamiento')
ax.plot(f_1_2['epoch'], f_1_2['presicion'], label='Entrenamiento')
ax.plot(f_1_1['epoch'], f_1_1['presicion'], label='Entrenamiento')
ax.plot(f_75_6['epoch'], f_75_6['presicion'], label='Entrenamiento')
ax.plot(f_75_4['epoch'], f_75_4['presicion'], label='Entrenamiento')
ax.plot(f_75_2['epoch'], f_75_2['presicion'], label='Entrenamiento')
ax.plot(f_75_1['epoch'], f_75_1['presicion'], label='Entrenamiento')
ax.plot(f_5_6['epoch'], f_5_6['presicion'], label='Entrenamiento')
ax.plot(f_5_4['epoch'], f_5_4['presicion'], label='Entrenamiento')
ax.plot(f_5_2['epoch'], f_5_2['presicion'], label='Entrenamiento')
ax.plot(f_5_1['epoch'], f_5_1['presicion'], label='Entrenamiento')
ax.plot(f_35_6['epoch'], f_35_6['presicion'], label='Entrenamiento')
ax.plot(f_35_4['epoch'], f_35_4['presicion'], label='Entrenamiento')
ax.plot(f_35_2['epoch'], f_35_2['presicion'], label='Entrenamiento')
ax.plot(f_35_1['epoch'], f_35_1['presicion'], label='Entrenamiento')


ax.set_xlabel('Época')
ax.set_ylabel('presicion')
ax.grid(True)

fig, ax = plt.subplots()
ax.plot(f_1_6['epoch'], f_1_6['recall'], label='Entrenamiento')
ax.plot(f_1_4['epoch'], f_1_4['recall'], label='Entrenamiento')
ax.plot(f_1_2['epoch'], f_1_2['recall'], label='Entrenamiento')
ax.plot(f_1_1['epoch'], f_1_1['recall'], label='Entrenamiento')
ax.plot(f_75_6['epoch'], f_75_6['recall'], label='Entrenamiento')
ax.plot(f_75_4['epoch'], f_75_4['recall'], label='Entrenamiento')
ax.plot(f_75_2['epoch'], f_75_2['recall'], label='Entrenamiento')
ax.plot(f_75_1['epoch'], f_75_1['recall'], label='Entrenamiento')
ax.plot(f_5_6['epoch'], f_5_6['recall'], label='Entrenamiento')
ax.plot(f_5_4['epoch'], f_5_4['recall'], label='Entrenamiento')
ax.plot(f_5_2['epoch'], f_5_2['recall'], label='Entrenamiento')
ax.plot(f_5_1['epoch'], f_5_1['recall'], label='Entrenamiento')
ax.plot(f_35_6['epoch'], f_35_6['recall'], label='Entrenamiento')
ax.plot(f_35_4['epoch'], f_35_4['recall'], label='Entrenamiento')
ax.plot(f_35_2['epoch'], f_35_2['recall'], label='Entrenamiento')
ax.plot(f_35_1['epoch'], f_35_1['recall'], label='Entrenamiento')


ax.set_xlabel('Época')
ax.set_ylabel('recall')
ax.grid(True)

# %%
trade_off = [[0.35, 1, 962789,  0.6282, 0.6148, 0.6265, 0.6148, 0.256],
             [0.35, 2, 997869,  0.6062, 0.5769, 0.6053, 0.5762, 0.2672],
             [0.35, 4, 1068029, 0.6292, 0.6278, 0.6308, 0.6304, 0.2854],
             [0.35, 6, 1138189, 0.63,   0.6088, 0.6084, 0.6053, 0.304],
             [0.5,  1, 1268836, 0.6426, 0.6524, 0.5966, 0.6142, 0.3242],
             [0.5,  2, 1335044, 0.6525, 0.6541, 0.6443, 0.66,   0.3444],
             [0.5,  4, 1467460, 0.6475, 0.6451, 0.6475, 0.6451, 0.3812],
             [0.5,  6, 1599876, 0.6651, 0.6585, 0.6592, 0.6674, 0.4138],
             [0.75, 1, 1887396, 0.6892, 0.6696, 0.6892, 0.6724, 0.4336],
             [0.75, 2, 2024916, 0.6944, 0.7101, 0.7012, 0.7139, 0.4664],
             [0.75, 4, 2299956, 0.6996, 0.6936, 0.7021, 0.6906, 0.5304],
             [0.75, 6, 2574996, 0.7091, 0.7053, 0.7023, 0.7034, 0.5758],
             [1.0,    1, 2618612, 0.7104, 0.7162, 0.7007, 0.7181, 0.5022],
             [1.0,    2, 2852916, 0.6987, 0.6957, 0.6947, 0.6981, 0.5406],
             [1.0,    4, 3321524, 0.6992, 0.6947, 0.7014, 0.696,  0.6218],
             [1.0,    6, 3790132, 0.6961, 0.7133, 0.6961, 0.7133, 0.69058]]

columns = ['Alpha', 'Expansión', 'No. parámetros', 'f1 score loss', 'f1 score lite loss', 'f1 score f1', 'f1 score lite f1', 'Tiempo de inferencia']

trad_off = pd.DataFrame(trade_off, columns = columns)

# %%
s = 90

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[0:1], marker='o', color='g', s=s)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[1:2], marker='^', color='g', s=100)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[2:3], marker='s', color='g', s=82)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[3:4], marker='D', color='g', s=78)

g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[4:5], marker='o', color='r', s=s)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[5:6], marker='^', color='r', s=100)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[6:7], marker='s', color='r', s=82)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[7:8], marker='D', color='r', s=78)

g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[8:9], marker='o', color='darkorange', s=s)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[9:10], marker='^', color='darkorange', s=100)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[10:11], marker='s', color='darkorange', s=82)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[11:12], marker='D', color='darkorange', s=78)

g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[12:13], marker='o', color='dodgerblue', s=s)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[13:14], marker='^', color='dodgerblue', s=100)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[14:15], marker='s', color='dodgerblue', s=82)
g = sns.scatterplot(x='Tiempo de inferencia', y='f1 score loss', data= trad_off[15:16], marker='D', color='dodgerblue', s=78)

legend_elements_a = [Line2D([0], [0], color='dodgerblue', lw=4, label='1.0'),
                     Line2D([0], [0], color='darkorange', lw=4, label='0.75'),
                     Line2D([0], [0], color='r', lw=4, label='0.5'),
                     Line2D([0], [0], color='g', lw=4, label='0.35')]

legend_elements_e = [Line2D([0], [0], color='white', lw=0, label='6', marker='D', markeredgecolor='black'),
                     Line2D([0], [0], color='white', lw=0, label='4', marker='s', markeredgecolor='black'),
                     Line2D([0], [0], color='white', lw=0, label='2', marker='^', markeredgecolor='black'),
                     Line2D([0], [0], color='white', lw=0, label='1', marker='o', markeredgecolor='black')]

# Add the legend manually to the current Axes.
first_legend = plt.legend('Alpha', handles=legend_elements_a, loc=(0.82, 0.02), frameon=False, title='Alpha')
# g.grid(True)
ax = plt.gca().add_artist(first_legend)

plt.legend('Alpha', handles=legend_elements_e, loc=(0.62, 0.02), frameon=False, title='Expansión')
# Out:
# /home/aldo/anaconda3/envs/test2/lib/python3.6/site-packages/matplotlib/legend.py:1270: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   warnings.warn("You have mixed positional and keyword arguments, some "

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[0:1], marker='o', color='g', s=s)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[1:2], marker='^', color='g', s=100)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[2:3], marker='s', color='g', s=82)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[3:4], marker='D', color='g', s=78)

g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[4:5], marker='o', color='r', s=s)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[5:6], marker='^', color='r', s=100)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[6:7], marker='s', color='r', s=82)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[7:8], marker='D', color='r', s=78)

g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[8:9], marker='o', color='darkorange', s=s)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[9:10], marker='^', color='darkorange', s=100)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[10:11], marker='s', color='darkorange', s=82)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[11:12], marker='D', color='darkorange', s=78)

g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[12:13], marker='o', color='dodgerblue', s=s)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[13:14], marker='^', color='dodgerblue', s=100)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[14:15], marker='s', color='dodgerblue', s=82)
g = sns.scatterplot(x='No. parámetros', y='f1 score loss', data= trad_off[15:16], marker='D', color='dodgerblue', s=78)

legend_elements_a = [Line2D([0], [0], color='dodgerblue', lw=4, label='1.0'),
                     Line2D([0], [0], color='darkorange', lw=4, label='0.75'),
                     Line2D([0], [0], color='r', lw=4, label='0.5'),
                     Line2D([0], [0], color='g', lw=4, label='0.35')]

legend_elements_e = [Line2D([0], [0], color='white', lw=0, label='6', marker='D', markeredgecolor='black'),
                     Line2D([0], [0], color='white', lw=0, label='4', marker='s', markeredgecolor='black'),
                     Line2D([0], [0], color='white', lw=0, label='2', marker='^', markeredgecolor='black'),
                     Line2D([0], [0], color='white', lw=0, label='1', marker='o', markeredgecolor='black')]

# Add the legend manually to the current Axes.
first_legend = plt.legend('Alpha', handles=legend_elements_a, loc=(0.82, 0.02), frameon=False, title='Alpha')
ax = plt.gca().add_artist(first_legend)

plt.legend('Alpha', handles=legend_elements_e, loc=(0.62, 0.02), frameon=False, title='Expansión')

# %%
f_1_1 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_1.0_exp_1.csv')
f_35_1 = pd.read_csv('/home/aldo/Documents/data-cic/history/tradeoff/ssdlite320_mobilenetv2_pascal_cic_f1_0.35_exp_1.csv')
f_1_1_300 = pd.read_csv('/home/aldo/Documents/data-cic/history/last_models/ssdlite300_mobilenetv2_pascal_cic_f1_1.0_exp_1.csv')
f_35_1_300 = pd.read_csv('/home/aldo/Documents/data-cic/history/last_models/ssdlite300_mobilenetv2_pascal_cic_f1_0.35_exp_1.csv')
new = pd.read_csv('/home/aldo/Documents/data-cic/history/new_net/new_share_conv_conf_cic_f1.csv')
other = pd.read_csv('/home/aldo/Documents/data-cic/history/new_net/new_share_conv_conf_cic_f1_a_1.0_e_1_ps_ng_0.5.csv')

# %%
fig, ax = plt.subplots()
ax.plot(f_1_1['epoch'], f_1_1['f1 score'], label='Entrenamiento', color='r')
# ax.plot(f_35_1['epoch'], f_35_1['f1 score'], label='Entrenamiento', color='blue')
ax.plot(f_1_1_300['epoch'], f_1_1_300['f1 score'], label='Entrenamiento', color='orange')
# ax.plot(f_35_1_300['epoch'], f_35_1_300['f1 score'], label='Entrenamiento', color='lightblue')
ax.plot(new['epoch'], new['f1 score'], label='Entrenamiento', color='black')
ax.plot(other['epoch'], other['f1 score'], label='Entrenamiento')



ax.set_xlabel('Época')
ax.set_ylabel('f1 score')
ax.grid(True)

# %%
f_1_1.max()
# Out:
# epoch        99.000000
# presicion     0.730729
# recall        0.630652
# f1 score      0.672176
# dtype: float64

# %%
f_1_1_300.max()
# Out:
# epoch        99.000000
# presicion     0.712095
# recall        0.642031
# f1 score      0.665806
# dtype: float64

# %%
new.max()
# Out:
# epoch        99.000000
# presicion     0.677734
# recall        0.675843
# f1 score      0.674827
# dtype: float64
